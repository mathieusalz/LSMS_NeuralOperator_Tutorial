# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn
import torch.optim as optim
import torch.nn.utils as utils
import torch.nn.functional as F

import torch.fft
from typing import Callable, List, Union    

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # Loading Data and Preprocessing

# %%
features_path = "data/friction_data/features_converged.csv"
targets_path = "data/friction_data/targets_aging_converged.csv"
train_samples = 700

# %%
feature = torch.Tensor(np.genfromtxt(features_path, delimiter=',')[:, np.newaxis, :])
target = torch.Tensor(np.genfromtxt(targets_path, delimiter=',')[:, np.newaxis, :])

train_x = feature[:train_samples, :, :]
train_y = target[:train_samples, :, :]
test_x = feature[train_samples:, :, :]
test_y = target[train_samples:, :, :]


fig, axes = plt.subplots(1, 2, figsize=(12, 5))
bins = np.logspace(np.log10(feature.min()), np.log10(feature.max()), 100)
axes[0].hist(feature.flatten(), bins=bins, label = f"min: {feature.min():.2e}, max: {feature.max():.2e}")
axes[0].set_xscale('log')
axes[0].set_title("Feature Distribution")
axes[0].legend()
axes[1].hist(target.flatten(), bins=100, color = 'red', label = f"min: {target.min():.2f}, max: {target.max():.2f}")
axes[1].set_title("Target Distribution")
axes[1].legend()

plt.show()
# Out:
# /tmp/ipykernel_844269/163623338.py:11: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   bins = np.logspace(np.log10(feature.min()), np.log10(feature.max()), 100)

# %%
fig, axes = plt.subplots(3, 3, figsize=(12, 12))
axes = axes.flatten()

for i, ax1 in enumerate(axes):
    # Velocity axis
    line1 = ax1.plot([i/len(feature[i,0,:]) for i in range(len(feature[i,0,:]))],
        feature[i, 0, :],
        color="blue",
        label=r"$V$"
    )
    ax1.set_xlabel("Normalized Time", fontsize = 14)
    ax1.set_ylabel(r"$V$", color="blue", fontsize = 14)
    ax1.tick_params(axis="y", colors="blue")
    ax1.spines["left"].set_color("blue")

    # Friction coefficient axis
    ax2 = ax1.twinx()
    line2 = ax2.plot([i/len(feature[i,0,:]) for i in range(len(feature[i,0,:]))],
        target[i, 0, :],
        color="red",
        label=r"$\mu$",
        linestyle = '--'
    )
    ax2.set_ylabel(r"$\mu$", color="red", fontsize = 14)
    ax2.tick_params(axis="y", colors="red")
    ax2.spines["right"].set_color("red")

plt.tight_layout()
plt.show()

# %%
def transform_vel_diff(x, V_ref = 1e-5):
    return torch.log10(x[:,:,1:]/V_ref) - torch.log10(x[:,:,:-1]/V_ref)

def transform_mu_diff(x):
    return x[:,:,1:] - x[:,:,:-1]

train_x_trans = transform_vel_diff(train_x)
# train_y_trans = transform_mu_diff(train_y)
test_x_trans = transform_vel_diff(test_x)
# test_y_trans = transform_mu_diff(test_y)

fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

# ==========================
# Feature differences
# ==========================

bins = np.logspace(np.log10(1e-6), np.log10(10), 100)

train_x_pos = train_x_trans[train_x_trans >= 0]
test_x_pos  = test_x_trans[test_x_trans >= 0]

train_x_neg = -train_x_trans[train_x_trans < 0]
test_x_neg  = -test_x_trans[test_x_trans < 0]

axes[0].hist(train_x_pos.flatten()+1e-5, bins=bins,
             alpha=0.6,
             label=f"Train (min={train_x_pos.min():.2e}, max={train_x_pos.max():.2e})")
axes[0].hist(test_x_pos.flatten()+1e-5, bins=bins,
             alpha=0.6,
             label=f"Test (min={test_x_pos.min():.2e}, max={test_x_pos.max():.2e})")
axes[0].set_xscale("log")
axes[0].set_yscale("symlog")
axes[0].set_title("(+/0) Feature Differences")
axes[0].legend()

axes[1].hist(train_x_neg.flatten(), bins=bins,
             alpha=0.6,
             label=f"Train (min={train_x_neg.min():.2e}, max={train_x_neg.max():.2e})")
axes[1].hist(test_x_neg.flatten(), bins=bins,
             alpha=0.6,
             label=f"Test (min={test_x_neg.min():.2e}, max={test_x_neg.max():.2e})")
axes[1].set_xscale("log")
axes[1].set_yscale("symlog")
axes[1].set_title("(-) Feature Differences (absolute value)")
axes[1].legend()

# ==========================
# Target differences
# ==========================

# bins = np.logspace(np.log10(1e-10), np.log10(1), 100)

# train_y_pos = train_y_trans[train_y_trans >= 0]
# test_y_pos  = test_y_trans[test_y_trans >= 0]

# train_y_neg = -train_y_trans[train_y_trans < 0]
# test_y_neg  = -test_y_trans[test_y_trans < 0]

# axes[2].hist(train_y_pos.flatten()+1e-9, bins=bins,
#              alpha=0.6,
#              label=f"Train (min={train_y_pos.min():.2e}, max={train_y_pos.max():.2e})")
# axes[2].hist(test_y_pos.flatten()+1e-9, bins=bins,
#              alpha=0.6,
#              label=f"Test (min={test_y_pos.min():.2e}, max={test_y_pos.max():.2e})")
# axes[2].set_xscale("log")
# axes[2].set_yscale("log")
# axes[2].set_title("(+/0) Target Differences")
# axes[2].legend()

# axes[3].hist(train_y_neg.flatten(), bins=bins,
#              alpha=0.6,
#              label=f"Train (min={train_y_neg.min():.2e}, max={train_y_neg.max():.2e})")
# axes[3].hist(test_y_neg.flatten(), bins=bins,
#              alpha=0.6,
#              label=f"Test (min={test_y_neg.min():.2e}, max={test_y_neg.max():.2e})")
# axes[3].set_xscale("log")
# axes[3].set_yscale("log")
# axes[3].set_title("(-) Target Differences (absolute value)")
# axes[3].legend()

# plt.tight_layout()
# plt.show()

# %%
def x_state_transform(x: np.array) -> torch.Tensor:
    return torch.Tensor(np.sqrt(np.log(1e8*x)))

def log_transform(train, test, nonZero_tol = 0):
    train_idx = np.argwhere(abs(train.flatten()) > nonZero_tol)[0]
    train_norm_state = x_state_transform(torch.abs(train.flatten()[train_idx]))
    train_min, train_max = train_norm_state.min(), train_norm_state.max()
    train_norm_state = (train_norm_state - train_min) / (train_max - train_min)

    test_idx = np.argwhere(abs(test.flatten()) > nonZero_tol)[0]
    test_norm_state = x_state_transform(torch.abs(test.flatten()[test_idx]))
    test_norm_state = (test_norm_state - train_min) / (train_max - train_min)

    train_sign = torch.sign(train)
    test_sign = torch.sign(test)

    train_norm = torch.zeros_like(train.flatten())
    train_norm[train_idx] = train_norm_state

    test_norm = torch.zeros_like(test.flatten())
    test_norm[test_idx] = test_norm_state

    train_norm = train_norm.reshape(*train.shape)
    test_norm = test_norm.reshape(*test.shape)

    train_norm = train_norm * train_sign
    test_norm = test_norm * test_sign

    return train_norm, test_norm, (train_min, train_max)

train_x_norm, test_x_norm, (vel_min, vel_max) = log_transform(train_x_trans, test_x_trans)
# _, _, (mu_min, mu_max) = log_transform(train_y_trans, test_y_trans)
# Out:
# /tmp/ipykernel_844269/3796657656.py:2: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   return torch.Tensor(np.sqrt(np.log(1e8*x)))

# %%
def reverse_log_transform(x, x_min, x_max, nonZero_tol):
    x_flat = x.flatten()
    x_rev = torch.zeros_like(x_flat)

    # Only reverse entries that remained nonzero after the forward transform
    idx = torch.nonzero(x_flat, as_tuple=True)[0]

    sign = torch.sign(x_flat[idx])
    x_abs = torch.abs(x_flat[idx])

    # Reverse min-max normalization
    x_state = x_abs * (x_max - x_min) + x_min

    # Reverse sqrt(log(1e8 * |x|))
    x_original = 1e-8 * torch.exp(x_state**2)

    x_rev[idx] = sign * x_original

    return x_rev.reshape_as(x)

# %%
# train_y_norm_rev, test_y_norm_rev = reverse_log_transform(train_y_norm, mu_min, mu_max, 0), reverse_log_transform(test_y_norm, mu_min, mu_max, 0)

# fig, axes = plt.subplots(4,4, figsize = (12,12))
# axes = axes.flatten()

# for i,ax in enumerate(axes):
#     ax.plot(abs(train_y_norm_rev[i,0,:]) + 1e-8)
#     ax.plot(abs(train_y_trans[i,0,:]) + 1e-8, linestyle = '--')
#     ax.set_yscale('log')

# %%
def reverse_mu_diff(x):
    x = torch.cumsum(x, dim = -1)
    return torch.cat([torch.zeros(x.shape[0],1,1).to(x.device), x], dim = -1)

# %%
# train_y_norm_rev2, test_y_norm_rev2 = reverse_mu_diff(train_y_norm_rev), reverse_mu_diff(test_y_norm_rev)

# fig, axes = plt.subplots(4,4, figsize = (12,12))
# axes = axes.flatten()

# for i,ax in enumerate(axes):
#     ax.plot(train_y_norm_rev2[i,0,:])
#     ax.plot(train_y[i,0,:] - train_y[i,0,0], linestyle = '--')
#     # ax.set_yscale('log')

# %%
# fig, axes = plt.subplots(1, 2, figsize=(12, 5))
# axes[0].hist(train_x_norm.flatten(), bins=100)
# axes[0].hist(test_x_norm.flatten(), bins=100)
# axes[0].set_yscale('log')
# axes[0].set_title("Vel Feature Distribution")
# axes[0].legend()

# axes[1].hist(train_y_norm.flatten(), bins = 100)
# axes[1].hist(test_y_norm.flatten(), bins = 100)
# axes[1].set_yscale('log')
# axes[1].set_title("Target Distribution")
# axes[1].legend()

# plt.show()

# %%
fig, axes = plt.subplots(4,4, figsize=(20, 20))
axes = axes.flatten()
for i in range(16):
    norm_time = [i/len(train_x_norm[i, 0, :]) for i in range(len(train_x_norm[i, 0, :]))]
    # axes[i].plot(norm_time, train_y_norm[i, 0, :].numpy(), label=r'$\Delta \mu$', color = 'red')
    axes[i].plot(norm_time, train_x_norm[i, 0, :].numpy(), label=r'$\Delta V$', color = 'k', linestyle = '--', linewidth = 2)
    axes[i].set_title(f"Sample {i+1}")
    axes[i].set_xlabel('Normalized Time')
    axes[i].set_ylabel('Magnitude')
    axes[i].legend()

# %%
start_mu_max = torch.abs(train_y).max()
train_y_norm = train_y/start_mu_max
test_y_norm = test_y/start_mu_max
train_y_norm = train_y_norm - train_y_norm[:,:,0:1]
test_y_norm = test_y_norm - test_y_norm[:,:,0:1]

print(train_y_norm.shape, test_y_norm.shape)
print(train_x_norm.shape, test_x_norm.shape)
# Out:
# torch.Size([700, 1, 499]) torch.Size([400, 1, 499])
# torch.Size([700, 1, 498]) torch.Size([400, 1, 498])

# %%
# idx_to_keep = np.where(train_y_norm[:,0,-1] < 1e-8)
# train_x_norm, train_y_norm = train_x_norm[idx_to_keep], train_y_norm[idx_to_keep]

# idx_to_keep = np.where(test_y_norm[:,0,-1] < 1e-8)
# test_x_norm, test_y_norm = test_x_norm[idx_to_keep], test_y_norm[idx_to_keep]

# print(train_x_norm.shape, test_x_norm.shape)

train_dataset = TensorDataset(train_x_norm, train_y_norm)
test_dataset = TensorDataset(test_x_norm, test_y_norm)

# %% [markdown]
# # Code for Models, Training, Postprocessing

# %% [markdown]
# ## FNO and NN

# %%
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            nn.init.constant_(m.bias, 0)
    elif isinstance(m, nn.Conv1d):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            nn.init.constant_(m.bias, 0)


class SpectralConv1d(nn.Module):
    def __init__(self, 
                 in_channels : int, 
                 out_channels: int, 
                 modes: int):
        """
        Initializes a 1D spectral convolution layer using complex weights in the Fourier domain.

        Args:
            in_channels (int): Number of input channels.
            out_channels (int): Number of output channels.
            modes (int): Number of Fourier modes to retain (low-frequency modes).
        """
        super().__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.modes = modes

        scale = 1.0 / (in_channels * out_channels)
        self.real_weights = nn.Parameter(
            torch.rand(in_channels, out_channels, modes) * 2 * scale - scale
        )
        self.imag_weights = nn.Parameter(
            torch.rand(in_channels, out_channels, modes) * 2 * scale - scale
        )

    def complex_mult1d(self, x_hat, w):
        return torch.einsum("iM,ioM->oM", x_hat, w)

    def forward(self, x):
        # x: (batch, channels, spatial_points)
        batchsize, channels, spatial_points = x.shape

        x_hat = torch.fft.rfft(x, dim=-1)  # (B, C, F)
        x_hat_under_modes = x_hat[:, :, :self.modes]

        weights = torch.complex(self.real_weights, self.imag_weights)
        out_hat_under_modes = torch.einsum("bim, iom -> bom", x_hat_under_modes, weights)

        out_hat = torch.zeros(
            batchsize, self.out_channels, x_hat.shape[-1],
            dtype=torch.cfloat, device=x.device
        )
        out_hat[:, :, :self.modes] = out_hat_under_modes

        out = torch.fft.irfft(out_hat, n=spatial_points, dim=-1)
        return out


class FNOBlock1d(nn.Module):
    def __init__(self, 
                 in_channels : int, 
                 out_channels : int, 
                 modes : int, 
                 activation : nn.Module = nn.Identity()):
        """
        Initializes a single Fourier Neural Operator (FNO) block for 1D data.

        Args:
            in_channels (int): Number of input channels.
            out_channels (int): Number of output channels.
            modes (int): Number of retained Fourier modes in the spectral convolution.
            activation (nn.Module, optional): Activation function applied after the block output. Default is nn.Identity().
        """
        
        super().__init__()
        self.activation = activation
        self.spectral_conv = SpectralConv1d(in_channels, out_channels, modes)
        self.bypass_conv = nn.Conv1d(in_channels, out_channels, kernel_size=1)

    def forward(self, x):
        sc = self.spectral_conv(x)
        bc = self.bypass_conv(x)
        out = sc + bc
        out = self.activation(out)
        return out

class Projection_NN(nn.Module):
    def __init__(self, 
                 input_dim : int, 
                 output_dim : int, 
                 width : int, 
                 depth : int, 
                 activation: nn.Module = nn.Identity(),
                 dropout = 0,
                 batchNorm = False):
        
        """
        Initializes a fully-connected feedforward projection network.

        Args:
            input_dim (int): Input dimensionality.
            output_dim (int): Output dimensionality.
            width (int): Width (number of hidden units) in each hidden layer.
            depth (int): Number of layers in the network (including input/output layers).
            activation (nn.Module, optional): Activation function applied between layers. Default is nn.Identity().
        """
        
        super().__init__()

        layers = [nn.Linear(input_dim, width)]
        layers.append(activation)
        layers.append(nn.Dropout(dropout))
        layers.append(nn.BatchNorm1d(width) if batchNorm else nn.Identity())

        for _ in range(depth - 1):
            layers.append(nn.Linear(width, width))
            layers.append(activation)
            layers.append(nn.Dropout(dropout))
            layers.append(nn.BatchNorm1d(width) if batchNorm else nn.Identity())

        layers.append(nn.Linear(width, output_dim))
        self.network = nn.Sequential(*layers)

    def forward(self, x):
        bsize, _, N = x.shape
        x = x.permute(0, 2, 1).contiguous().view(-1, self.network[0].in_features)
        x = self.network(x)
        x = x.view(bsize, N, self.network[-1].out_features).permute(0, 2, 1).contiguous()
        return x

class FNO1d(nn.Module):
    def __init__(
        self,
        in_channels : int,
        out_channels : int,
        modes : int,
        width : int,
        block_activation : nn.Module = nn.Identity(),
        n_blocks : int = 4,
        padding : int = 0,
        lift_network = None,
        decode_network = None,
    ):
        """
        Initializes a 1D Fourier Neural Operator (FNO) model.

        Args:
            in_channels (int): Number of input channels.
            out_channels (int): Number of output channels.
            modes (int): Number of Fourier modes retained in spectral convolutions.
            width (int): Width of the internal FNO layers.
            block_activation (nn.Module, optional): Activation applied after each FNO block. Default is nn.Identity().
            n_blocks (int, optional): Number of stacked FNO blocks. Default is 4.
            padding (int, optional): Amount of zero-padding added to input and removed from output. Default is 0.
        """

        super().__init__()
        
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.modes = modes
        self.width = width
        self.block_activation = block_activation
        self.n_blocks = n_blocks
        self.padding = padding
        
        self.lift_network = lift_network
        self.decode_network = decode_network

        self.fno_blocks = nn.ModuleList([
            FNOBlock1d(width, width, modes, block_activation)
            for _ in range(n_blocks)
        ])

        self.apply(init_weights)

    # x: (B, C, N)
    def forward(self, x):

        x = self.lift_network(x)

        N = x.shape[-1]
        target_length = (1 << (N - 1).bit_length()) * 2

        total_pad = target_length - N
        pad_left = total_pad // 2
        pad_right = total_pad - pad_left

        if total_pad > 0:
            x = nn.functional.pad(
                x,
                (pad_left, pad_right),
                mode="constant",
                value=0,
            )

        for block in self.fno_blocks:
            x = block(x)

        x = self.decode_network(x)

        if total_pad > 0:
            x = x[..., pad_left:pad_left + N]

        return x

# %% [markdown]
# ## Train Loop

# %%
def train_loop(model,
                     train_loader,
                     test_loader,
                     epochs,
                     optimizer,
                     scheduler=None,
                     clip_grad=False,
                     mixed_training=False,
                     add_noise=False,
                     loss_func = nn.MSELoss(),
                     half_train = False):

    criterion = loss_func

    loss_history = []
    val_loss_history = []

    for epoch in range(epochs):
        model.train()
        epoch_loss = 0.0

        for batch_x, batch_y in train_loader:

            B,C,N = batch_x.shape
            batch_x = batch_x.to(device)
            batch_y = batch_y.to(device)

            if half_train is not False:
                if np.random.random() > 0.5:
                    sample_N = int(torch.rand(1)*398+100)
                    batch_x = batch_x[:, :, :sample_N]
                    batch_y = batch_y[:, :, :sample_N]
                    batch_x = torch.nn.functional.interpolate(batch_x,N)
                    batch_y = torch.nn.functional.interpolate(batch_y,N)

            if mixed_training is not False:
                sample_freq = np.random.choice(mixed_training[0], p=mixed_training[1])
                batch_x = batch_x.to(device)[:, :, ::sample_freq]
                batch_y = batch_y.to(device)[:, :, ::sample_freq]

            if add_noise is not False:
                noise = torch.randn_like(batch_x) * add_noise[0]
                batch_x = batch_x + noise

            def closure():
                optimizer.zero_grad()

                output = model(batch_x)
                output = reverse_log_transform(output, 1.0450, 3.9815,0)
                output = reverse_mu_diff(output)
                loss = criterion(output, batch_y)

                loss.backward()

                if clip_grad:
                    utils.clip_grad_norm_(model.parameters(), 0.5)

                return loss

            loss = optimizer.step(closure)

            epoch_loss += loss.item()

        if scheduler is not None:
            scheduler.step()

        loss_history.append(epoch_loss / len(train_loader))

        model.eval()
        with torch.no_grad():
            val_loss = 0.0
            for batch_x, batch_y in test_loader:
                batch_x = batch_x.to(device)
                batch_y = batch_y.to(device)

                val_output = model(batch_x)
                val_output = reverse_log_transform(val_output, 1.0450, 3.9815,0)
                val_output = reverse_mu_diff(val_output)
                val_loss += criterion(val_output, batch_y).item()

        val_loss_history.append(val_loss / len(test_loader))

        print(
            f"EPOCH {epoch}: "
            f"train_loss: {loss_history[-1]:.3e} \t "
            f"test_loss: {val_loss_history[-1]:.3e}"
        )

    return loss_history, val_loss_history

# %%
def make_decay_fn(factor: float, 
                  interval: int):
    return lambda step: factor ** (step // interval)

# %% [markdown]
# ## Postprocessing

# %%
def plot_results(model, x, y, name, reverse = False):

    fig, axes = plt.subplots(4, 4, figsize=(10, 10))
    axes = axes.flatten()
    for i in range(16):
        pred = model(x[i:i+1].to(device)).cpu().detach()
        truth = y[i:i+1, :, :].cpu().detach()

        # if reverse:
        #     pred = reverse_log_transform(pred, mu_min, mu_max, 0)
        #     pred = reverse_mu_diff(pred)
        
        #     truth = reverse_log_transform(truth, mu_min, mu_max, 0)
        #     truth = reverse_mu_diff(truth)
            
        ax1 = axes[i]

        ax1.plot(truth.numpy().flatten(), color='tab:orange', label='Ground Truth' if i == 0 else "")
        ax1.plot(pred.numpy().flatten(), color='tab:green', linestyle = '--', label='Prediction' if i == 0 else "")
        # ax1.plot(x[i,0,:], color = 'k', label = 'input' if i==0 else '', alpha = 0.5)
        ax1.set_xticks([])
        ax1.set_yticks([])

    fig.suptitle(name, fontsize=22, y=0.98)

    fig.legend(loc='upper center', bbox_to_anchor=(0.5, 0.95), ncol=3, fontsize=16)

    plt.tight_layout(rect=[0, 0, 1, 0.95])  
    plt.show()

def plot_loss(loss, val, barometer = None):

    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(loss, label="train loss")
    ax.plot(val, label="val loss")
    if barometer is not None:
        ax.hlines(barometer, xmin = 0, xmax = len(loss), color = 'red', linestyle = '--')
    ax.legend(fontsize=14)
    ax.set_yscale("log")
    ax.grid(True)
    ax.tick_params(axis='both', which='major', labelsize=14)
    fig.suptitle("Loss History", fontsize=18)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Training

# %%
in_channels = train_x_norm.shape[1]
width = 32
out_channels = 1

lift_network = Projection_NN(
                input_dim = in_channels,
                output_dim = width,
                width = 64,
                depth = 2,
                activation = torch.nn.GELU(),
                dropout = 0.05
            )

decode_network = Projection_NN(
                input_dim = width,
                output_dim = out_channels,
                width = 64,
                depth = 2,
                activation = torch.nn.GELU(),
                dropout = 0.05
            )

model = FNO1d(
        in_channels=in_channels,
        out_channels=out_channels,
        modes = 12,
        width=width,
        block_activation=torch.nn.Mish(),
        n_blocks=4,
        padding=0,
        lift_network=lift_network,
        decode_network=decode_network,
        ).to(device)

lr = 1e-3

optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)

scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda= make_decay_fn(0.999, 100))

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

loss_history, val_loss_history = [], []

loss_history, val_loss_history = train_loop(model, train_loader, test_loader,
                                            1000, optimizer, scheduler,
                                            mixed_training=False,
                                            half_train = False,
                                            clip_grad = False)
# Out:
# EPOCH 0: train_loss: 5.200e-04 	 test_loss: 5.095e-04
# EPOCH 1: train_loss: 5.198e-04 	 test_loss: 5.095e-04
# EPOCH 2: train_loss: 5.193e-04 	 test_loss: 5.092e-04
# EPOCH 3: train_loss: 5.165e-04 	 test_loss: 5.095e-04
# EPOCH 4: train_loss: 5.169e-04 	 test_loss: 5.073e-04
# EPOCH 5: train_loss: 5.171e-04 	 test_loss: 5.081e-04
# EPOCH 6: train_loss: 5.186e-04 	 test_loss: 5.081e-04
# EPOCH 7: train_loss: 5.173e-04 	 test_loss: 5.078e-04
# EPOCH 8: train_loss: 5.165e-04 	 test_loss: 5.073e-04
# EPOCH 9: train_loss: 5.151e-04 	 test_loss: 5.058e-04
# EPOCH 10: train_loss: 5.102e-04 	 test_loss: 5.060e-04
# EPOCH 11: train_loss: 5.097e-04 	 test_loss: 5.045e-04
# EPOCH 12: train_loss: 5.107e-04 	 test_loss: 5.039e-04
# EPOCH 13: train_loss: 5.061e-04 	 test_loss: 5.075e-04
# EPOCH 14: train_loss: 5.081e-04 	 test_loss: 5.049e-04
# EPOCH 15: train_loss: 5.077e-04 	 test_loss: 5.051e-04
# EPOCH 16: train_loss: 5.093e-04 	 test_loss: 5.037e-04
# EPOCH 17: train_loss: 5.069e-04 	 test_loss: 5.057e-04
# EPOCH 18: train_loss: 5.065e-04 	 test_loss: 5.037e-04
# EPOCH 19: train_loss: 5.063e-04 	 test_loss: 5.040e-04
# EPOCH 20: train_loss: 5.071e-04 	 test_loss: 5.034e-04
# EPOCH 21: train_loss: 5.092e-04 	 test_loss: 5.035e-04
# EPOCH 22: train_loss: 5.068e-04 	 test_loss: 5.058e-04
# EPOCH 23: train_loss: 5.082e-04 	 test_loss: 5.041e-04
# EPOCH 24: train_loss: 5.108e-04 	 test_loss: 5.037e-04
# EPOCH 25: train_loss: 5.090e-04 	 test_loss: 5.036e-04
# EPOCH 26: train_loss: 5.075e-04 	 test_loss: 5.043e-04
# EPOCH 27: train_loss: 5.101e-04 	 test_loss: 5.045e-04
# EPOCH 28: train_loss: 5.114e-04 	 test_loss: 5.042e-04
# EPOCH 29: train_loss: 5.067e-04 	 test_loss: 5.057e-04
# EPOCH 30: train_loss: 5.094e-04 	 test_loss: 5.041e-04
# EPOCH 31: train_loss: 5.116e-04 	 test_loss: 5.043e-04
# EPOCH 32: train_loss: 5.079e-04 	 test_loss: 5.052e-04
# EPOCH 33: train_loss: 5.045e-04 	 test_loss: 5.037e-04
# EPOCH 34: train_loss: 5.039e-04 	 test_loss: 4.969e-04
# EPOCH 35: train_loss: 5.027e-04 	 test_loss: 5.013e-04
# EPOCH 36: train_loss: 5.016e-04 	 test_loss: 4.825e-04
# EPOCH 37: train_loss: 5.039e-04 	 test_loss: 4.754e-04
# EPOCH 38: train_loss: 4.801e-04 	 test_loss: 4.858e-04
# EPOCH 39: train_loss: 4.791e-04 	 test_loss: 4.867e-04
# EPOCH 40: train_loss: 4.850e-04 	 test_loss: 4.852e-04
# EPOCH 41: train_loss: 4.765e-04 	 test_loss: 4.744e-04
# EPOCH 42: train_loss: 4.652e-04 	 test_loss: 4.686e-04
# EPOCH 43: train_loss: 4.651e-04 	 test_loss: 4.667e-04
# EPOCH 44: train_loss: 4.637e-04 	 test_loss: 4.651e-04
# EPOCH 45: train_loss: 4.630e-04 	 test_loss: 4.666e-04
# EPOCH 46: train_loss: 4.604e-04 	 test_loss: 4.647e-04
# EPOCH 47: train_loss: 4.607e-04 	 test_loss: 4.637e-04
# EPOCH 48: train_loss: 4.756e-04 	 test_loss: 4.699e-04
# EPOCH 49: train_loss: 4.604e-04 	 test_loss: 4.627e-04
# EPOCH 50: train_loss: 4.587e-04 	 test_loss: 4.609e-04
# EPOCH 51: train_loss: 4.558e-04 	 test_loss: 4.599e-04
# EPOCH 52: train_loss: 4.565e-04 	 test_loss: 4.590e-04
# EPOCH 53: train_loss: 4.545e-04 	 test_loss: 4.590e-04
# EPOCH 54: train_loss: 4.583e-04 	 test_loss: 4.607e-04
# EPOCH 55: train_loss: 4.585e-04 	 test_loss: 4.703e-04
# EPOCH 56: train_loss: 4.623e-04 	 test_loss: 4.654e-04
# EPOCH 57: train_loss: 4.569e-04 	 test_loss: 4.610e-04
# EPOCH 58: train_loss: 4.553e-04 	 test_loss: 4.573e-04
# EPOCH 59: train_loss: 4.543e-04 	 test_loss: 4.563e-04
# EPOCH 60: train_loss: 4.527e-04 	 test_loss: 4.556e-04
# EPOCH 61: train_loss: 4.502e-04 	 test_loss: 4.547e-04
# EPOCH 62: train_loss: 4.520e-04 	 test_loss: 4.641e-04
# EPOCH 63: train_loss: 4.556e-04 	 test_loss: 4.559e-04
# EPOCH 64: train_loss: 4.497e-04 	 test_loss: 4.547e-04
# EPOCH 65: train_loss: 4.473e-04 	 test_loss: 4.495e-04
# EPOCH 66: train_loss: 4.502e-04 	 test_loss: 4.551e-04
# EPOCH 67: train_loss: 4.482e-04 	 test_loss: 4.490e-04
# EPOCH 68: train_loss: 4.456e-04 	 test_loss: 4.498e-04
# EPOCH 69: train_loss: 4.450e-04 	 test_loss: 4.441e-04
# EPOCH 70: train_loss: 4.405e-04 	 test_loss: 4.490e-04
# EPOCH 71: train_loss: 4.443e-04 	 test_loss: 4.606e-04
# EPOCH 72: train_loss: 4.533e-04 	 test_loss: 4.576e-04
# EPOCH 73: train_loss: 4.545e-04 	 test_loss: 4.578e-04
# EPOCH 74: train_loss: 4.527e-04 	 test_loss: 4.554e-04
# EPOCH 75: train_loss: 4.424e-04 	 test_loss: 4.430e-04
# EPOCH 76: train_loss: 4.444e-04 	 test_loss: 4.681e-04
# EPOCH 77: train_loss: 4.632e-04 	 test_loss: 4.601e-04
# EPOCH 78: train_loss: 4.543e-04 	 test_loss: 4.536e-04
# EPOCH 79: train_loss: 4.516e-04 	 test_loss: 4.485e-04
# EPOCH 80: train_loss: 4.483e-04 	 test_loss: 4.464e-04
# EPOCH 81: train_loss: 4.453e-04 	 test_loss: 4.456e-04
# EPOCH 82: train_loss: 4.403e-04 	 test_loss: 4.553e-04
# EPOCH 83: train_loss: 4.447e-04 	 test_loss: 4.587e-04
# EPOCH 84: train_loss: 4.494e-04 	 test_loss: 4.554e-04
# EPOCH 85: train_loss: 4.484e-04 	 test_loss: 4.418e-04
# EPOCH 86: train_loss: 4.502e-04 	 test_loss: 4.434e-04
# EPOCH 87: train_loss: 4.414e-04 	 test_loss: 4.391e-04
# EPOCH 88: train_loss: 4.378e-04 	 test_loss: 4.388e-04
# EPOCH 89: train_loss: 4.365e-04 	 test_loss: 4.376e-04
# EPOCH 90: train_loss: 4.382e-04 	 test_loss: 4.401e-04
# EPOCH 91: train_loss: 4.346e-04 	 test_loss: 4.355e-04
# EPOCH 92: train_loss: 4.339e-04 	 test_loss: 4.402e-04
# EPOCH 93: train_loss: 4.329e-04 	 test_loss: 4.360e-04
# EPOCH 94: train_loss: 4.410e-04 	 test_loss: 4.405e-04
# EPOCH 95: train_loss: 4.448e-04 	 test_loss: 4.524e-04
# EPOCH 96: train_loss: 4.486e-04 	 test_loss: 4.609e-04
# EPOCH 97: train_loss: 4.561e-04 	 test_loss: 4.466e-04
# EPOCH 98: train_loss: 4.422e-04 	 test_loss: 4.474e-04
# EPOCH 99: train_loss: 4.423e-04 	 test_loss: 4.478e-04
# EPOCH 100: train_loss: 4.392e-04 	 test_loss: 4.424e-04
# EPOCH 101: train_loss: 4.372e-04 	 test_loss: 4.412e-04
# EPOCH 102: train_loss: 4.351e-04 	 test_loss: 4.432e-04
# EPOCH 103: train_loss: 4.358e-04 	 test_loss: 4.392e-04
# EPOCH 104: train_loss: 4.349e-04 	 test_loss: 4.372e-04
# EPOCH 105: train_loss: 4.339e-04 	 test_loss: 4.432e-04
# EPOCH 106: train_loss: 4.382e-04 	 test_loss: 4.406e-04
# EPOCH 107: train_loss: 4.345e-04 	 test_loss: 4.386e-04
# EPOCH 108: train_loss: 4.301e-04 	 test_loss: 4.378e-04
# EPOCH 109: train_loss: 4.343e-04 	 test_loss: 4.419e-04
# EPOCH 110: train_loss: 4.344e-04 	 test_loss: 4.369e-04
# EPOCH 111: train_loss: 4.287e-04 	 test_loss: 4.438e-04
# EPOCH 112: train_loss: 4.354e-04 	 test_loss: 4.354e-04
# EPOCH 113: train_loss: 4.286e-04 	 test_loss: 4.407e-04
# EPOCH 114: train_loss: 4.284e-04 	 test_loss: 4.347e-04
# EPOCH 115: train_loss: 4.337e-04 	 test_loss: 4.444e-04
# EPOCH 116: train_loss: 4.363e-04 	 test_loss: 4.496e-04
# EPOCH 117: train_loss: 4.355e-04 	 test_loss: 4.423e-04
# EPOCH 118: train_loss: 4.306e-04 	 test_loss: 4.363e-04
# EPOCH 119: train_loss: 4.310e-04 	 test_loss: 4.338e-04
# EPOCH 120: train_loss: 4.302e-04 	 test_loss: 4.339e-04
# EPOCH 121: train_loss: 4.328e-04 	 test_loss: 4.409e-04
# EPOCH 122: train_loss: 4.357e-04 	 test_loss: 4.394e-04
# EPOCH 123: train_loss: 4.289e-04 	 test_loss: 4.447e-04
# EPOCH 124: train_loss: 4.328e-04 	 test_loss: 4.419e-04
# EPOCH 125: train_loss: 4.300e-04 	 test_loss: 4.365e-04
# EPOCH 126: train_loss: 4.264e-04 	 test_loss: 4.376e-04
# EPOCH 127: train_loss: 4.449e-04 	 test_loss: 4.456e-04
# EPOCH 128: train_loss: 4.500e-04 	 test_loss: 4.424e-04
# EPOCH 129: train_loss: 4.350e-04 	 test_loss: 4.408e-04
# EPOCH 130: train_loss: 4.308e-04 	 test_loss: 4.373e-04
# EPOCH 131: train_loss: 4.287e-04 	 test_loss: 4.385e-04
# EPOCH 132: train_loss: 4.277e-04 	 test_loss: 4.335e-04
# EPOCH 133: train_loss: 4.284e-04 	 test_loss: 4.340e-04
# EPOCH 134: train_loss: 4.273e-04 	 test_loss: 4.336e-04
# EPOCH 135: train_loss: 4.287e-04 	 test_loss: 4.334e-04
# EPOCH 136: train_loss: 4.308e-04 	 test_loss: 4.328e-04
# EPOCH 137: train_loss: 4.462e-04 	 test_loss: 4.592e-04
# EPOCH 138: train_loss: 4.467e-04 	 test_loss: 4.522e-04
# EPOCH 139: train_loss: 4.484e-04 	 test_loss: 4.505e-04
# EPOCH 140: train_loss: 4.440e-04 	 test_loss: 4.458e-04
# EPOCH 141: train_loss: 4.393e-04 	 test_loss: 4.427e-04
# EPOCH 142: train_loss: 4.367e-04 	 test_loss: 4.493e-04
# EPOCH 143: train_loss: 4.357e-04 	 test_loss: 4.390e-04
# EPOCH 144: train_loss: 4.316e-04 	 test_loss: 4.386e-04
# EPOCH 145: train_loss: 4.312e-04 	 test_loss: 4.375e-04
# EPOCH 146: train_loss: 4.355e-04 	 test_loss: 4.368e-04
# EPOCH 147: train_loss: 4.301e-04 	 test_loss: 4.379e-04
# EPOCH 148: train_loss: 4.301e-04 	 test_loss: 4.388e-04
# EPOCH 149: train_loss: 4.313e-04 	 test_loss: 4.405e-04
# EPOCH 150: train_loss: 4.289e-04 	 test_loss: 4.351e-04
# EPOCH 151: train_loss: 4.319e-04 	 test_loss: 4.369e-04
# EPOCH 152: train_loss: 4.277e-04 	 test_loss: 4.374e-04
# EPOCH 153: train_loss: 4.298e-04 	 test_loss: 4.375e-04
# EPOCH 154: train_loss: 4.301e-04 	 test_loss: 4.360e-04
# EPOCH 155: train_loss: 4.260e-04 	 test_loss: 4.340e-04
# EPOCH 156: train_loss: 4.264e-04 	 test_loss: 4.378e-04
# EPOCH 157: train_loss: 4.294e-04 	 test_loss: 4.330e-04
# EPOCH 158: train_loss: 4.261e-04 	 test_loss: 4.383e-04
# EPOCH 159: train_loss: 4.613e-04 	 test_loss: 4.588e-04
# EPOCH 160: train_loss: 4.558e-04 	 test_loss: 4.645e-04
# EPOCH 161: train_loss: 4.536e-04 	 test_loss: 4.423e-04
# EPOCH 162: train_loss: 4.378e-04 	 test_loss: 4.371e-04
# EPOCH 163: train_loss: 4.316e-04 	 test_loss: 4.350e-04
# EPOCH 164: train_loss: 4.344e-04 	 test_loss: 4.328e-04
# EPOCH 165: train_loss: 4.341e-04 	 test_loss: 4.369e-04
# EPOCH 166: train_loss: 4.305e-04 	 test_loss: 4.331e-04
# EPOCH 167: train_loss: 4.282e-04 	 test_loss: 4.334e-04
# EPOCH 168: train_loss: 4.277e-04 	 test_loss: 4.355e-04
# EPOCH 169: train_loss: 4.264e-04 	 test_loss: 4.324e-04
# EPOCH 170: train_loss: 4.248e-04 	 test_loss: 4.419e-04
# EPOCH 171: train_loss: 4.339e-04 	 test_loss: 4.345e-04
# EPOCH 172: train_loss: 4.270e-04 	 test_loss: 4.324e-04
# EPOCH 173: train_loss: 4.264e-04 	 test_loss: 4.351e-04
# EPOCH 174: train_loss: 4.276e-04 	 test_loss: 4.362e-04
# EPOCH 175: train_loss: 4.271e-04 	 test_loss: 4.331e-04
# EPOCH 176: train_loss: 4.224e-04 	 test_loss: 4.370e-04
# EPOCH 177: train_loss: 4.236e-04 	 test_loss: 4.367e-04
# EPOCH 178: train_loss: 4.218e-04 	 test_loss: 4.358e-04
# EPOCH 179: train_loss: 4.258e-04 	 test_loss: 4.338e-04
# EPOCH 180: train_loss: 4.275e-04 	 test_loss: 4.335e-04
# EPOCH 181: train_loss: 4.244e-04 	 test_loss: 4.432e-04
# EPOCH 182: train_loss: 4.304e-04 	 test_loss: 4.480e-04
# EPOCH 183: train_loss: 4.307e-04 	 test_loss: 4.321e-04
# EPOCH 184: train_loss: 4.230e-04 	 test_loss: 4.387e-04
# EPOCH 185: train_loss: 4.281e-04 	 test_loss: 4.497e-04
# EPOCH 186: train_loss: 4.282e-04 	 test_loss: 4.347e-04
# EPOCH 187: train_loss: 4.212e-04 	 test_loss: 4.321e-04
# EPOCH 188: train_loss: 4.324e-04 	 test_loss: 4.644e-04
# EPOCH 189: train_loss: 4.534e-04 	 test_loss: 4.498e-04
# EPOCH 190: train_loss: 4.572e-04 	 test_loss: 4.370e-04
# EPOCH 191: train_loss: 4.470e-04 	 test_loss: 4.372e-04
# EPOCH 192: train_loss: 4.313e-04 	 test_loss: 4.348e-04
# EPOCH 193: train_loss: 4.293e-04 	 test_loss: 4.406e-04
# EPOCH 194: train_loss: 4.281e-04 	 test_loss: 4.366e-04
# EPOCH 195: train_loss: 4.330e-04 	 test_loss: 4.479e-04
# EPOCH 196: train_loss: 4.268e-04 	 test_loss: 4.381e-04
# EPOCH 197: train_loss: 4.263e-04 	 test_loss: 4.340e-04
# EPOCH 198: train_loss: 4.253e-04 	 test_loss: 4.353e-04
# EPOCH 199: train_loss: 4.356e-04 	 test_loss: 4.320e-04
# EPOCH 200: train_loss: 4.347e-04 	 test_loss: 4.338e-04
# EPOCH 201: train_loss: 4.269e-04 	 test_loss: 4.339e-04
# EPOCH 202: train_loss: 4.271e-04 	 test_loss: 4.327e-04
# EPOCH 203: train_loss: 4.310e-04 	 test_loss: 4.367e-04
# EPOCH 204: train_loss: 4.224e-04 	 test_loss: 4.323e-04
# EPOCH 205: train_loss: 4.239e-04 	 test_loss: 4.329e-04
# EPOCH 206: train_loss: 4.213e-04 	 test_loss: 4.332e-04
# EPOCH 207: train_loss: 4.218e-04 	 test_loss: 4.309e-04
# EPOCH 208: train_loss: 4.246e-04 	 test_loss: 4.367e-04
# EPOCH 209: train_loss: 4.309e-04 	 test_loss: 4.351e-04
# EPOCH 210: train_loss: 4.238e-04 	 test_loss: 4.313e-04
# EPOCH 211: train_loss: 4.235e-04 	 test_loss: 4.328e-04
# EPOCH 212: train_loss: 4.238e-04 	 test_loss: 4.334e-04
# EPOCH 213: train_loss: 4.225e-04 	 test_loss: 4.353e-04
# EPOCH 214: train_loss: 4.263e-04 	 test_loss: 4.361e-04
# EPOCH 215: train_loss: 4.192e-04 	 test_loss: 4.314e-04
# EPOCH 216: train_loss: 4.213e-04 	 test_loss: 4.305e-04
# EPOCH 217: train_loss: 4.252e-04 	 test_loss: 4.330e-04
# EPOCH 218: train_loss: 4.242e-04 	 test_loss: 4.325e-04
# EPOCH 219: train_loss: 4.212e-04 	 test_loss: 4.339e-04
# EPOCH 220: train_loss: 4.218e-04 	 test_loss: 4.375e-04
# EPOCH 221: train_loss: 4.226e-04 	 test_loss: 4.340e-04
# EPOCH 222: train_loss: 4.191e-04 	 test_loss: 4.301e-04
# EPOCH 223: train_loss: 4.194e-04 	 test_loss: 4.331e-04
# EPOCH 224: train_loss: 4.195e-04 	 test_loss: 4.302e-04
# EPOCH 225: train_loss: 4.162e-04 	 test_loss: 4.307e-04
# EPOCH 226: train_loss: 4.178e-04 	 test_loss: 4.335e-04
# EPOCH 227: train_loss: 4.179e-04 	 test_loss: 4.323e-04
# EPOCH 228: train_loss: 4.212e-04 	 test_loss: 4.298e-04
# EPOCH 229: train_loss: 4.202e-04 	 test_loss: 4.293e-04
# EPOCH 230: train_loss: 4.155e-04 	 test_loss: 4.285e-04
# EPOCH 231: train_loss: 4.147e-04 	 test_loss: 4.298e-04
# EPOCH 232: train_loss: 4.200e-04 	 test_loss: 4.286e-04
# EPOCH 233: train_loss: 4.195e-04 	 test_loss: 4.264e-04
# EPOCH 234: train_loss: 4.549e-04 	 test_loss: 4.623e-04
# EPOCH 235: train_loss: 4.579e-04 	 test_loss: 4.658e-04
# EPOCH 236: train_loss: 4.545e-04 	 test_loss: 4.592e-04
# EPOCH 237: train_loss: 4.509e-04 	 test_loss: 4.579e-04
# EPOCH 238: train_loss: 4.460e-04 	 test_loss: 4.541e-04
# EPOCH 239: train_loss: 4.438e-04 	 test_loss: 4.495e-04
# EPOCH 240: train_loss: 4.399e-04 	 test_loss: 4.474e-04
# EPOCH 241: train_loss: 4.364e-04 	 test_loss: 4.462e-04
# EPOCH 242: train_loss: 4.319e-04 	 test_loss: 4.404e-04
# EPOCH 243: train_loss: 4.346e-04 	 test_loss: 4.382e-04
# EPOCH 244: train_loss: 4.337e-04 	 test_loss: 4.383e-04
# EPOCH 245: train_loss: 4.274e-04 	 test_loss: 4.369e-04
# EPOCH 246: train_loss: 4.237e-04 	 test_loss: 4.355e-04
# EPOCH 247: train_loss: 4.249e-04 	 test_loss: 4.389e-04
# EPOCH 248: train_loss: 4.267e-04 	 test_loss: 4.372e-04
# EPOCH 249: train_loss: 4.238e-04 	 test_loss: 4.338e-04
# EPOCH 250: train_loss: 4.221e-04 	 test_loss: 4.318e-04
# EPOCH 251: train_loss: 4.236e-04 	 test_loss: 4.312e-04
# EPOCH 252: train_loss: 4.274e-04 	 test_loss: 4.316e-04
# EPOCH 253: train_loss: 4.232e-04 	 test_loss: 4.320e-04
# EPOCH 254: train_loss: 4.195e-04 	 test_loss: 4.361e-04
# EPOCH 255: train_loss: 4.214e-04 	 test_loss: 4.398e-04
# EPOCH 256: train_loss: 4.227e-04 	 test_loss: 4.440e-04
# EPOCH 257: train_loss: 4.261e-04 	 test_loss: 4.438e-04
# EPOCH 258: train_loss: 4.252e-04 	 test_loss: 4.313e-04
# EPOCH 259: train_loss: 4.180e-04 	 test_loss: 4.315e-04
# EPOCH 260: train_loss: 4.192e-04 	 test_loss: 4.460e-04
# EPOCH 261: train_loss: 4.240e-04 	 test_loss: 4.418e-04
# EPOCH 262: train_loss: 4.214e-04 	 test_loss: 4.352e-04
# EPOCH 263: train_loss: 4.206e-04 	 test_loss: 4.366e-04
# EPOCH 264: train_loss: 4.202e-04 	 test_loss: 4.377e-04
# EPOCH 265: train_loss: 4.201e-04 	 test_loss: 4.366e-04
# EPOCH 266: train_loss: 4.170e-04 	 test_loss: 4.409e-04
# EPOCH 267: train_loss: 4.179e-04 	 test_loss: 4.320e-04
# EPOCH 268: train_loss: 4.164e-04 	 test_loss: 4.339e-04
# EPOCH 269: train_loss: 4.170e-04 	 test_loss: 4.359e-04
# EPOCH 270: train_loss: 4.220e-04 	 test_loss: 4.385e-04
# EPOCH 271: train_loss: 4.265e-04 	 test_loss: 4.341e-04
# EPOCH 272: train_loss: 4.252e-04 	 test_loss: 4.329e-04
# EPOCH 273: train_loss: 4.223e-04 	 test_loss: 4.339e-04
# EPOCH 274: train_loss: 4.187e-04 	 test_loss: 4.389e-04
# EPOCH 275: train_loss: 4.224e-04 	 test_loss: 4.441e-04
# EPOCH 276: train_loss: 4.260e-04 	 test_loss: 4.418e-04
# EPOCH 277: train_loss: 4.198e-04 	 test_loss: 4.305e-04
# EPOCH 278: train_loss: 4.167e-04 	 test_loss: 4.302e-04
# EPOCH 279: train_loss: 4.116e-04 	 test_loss: 4.298e-04
# EPOCH 280: train_loss: 4.134e-04 	 test_loss: 4.314e-04
# EPOCH 281: train_loss: 1.725e-03 	 test_loss: 4.827e-04
# EPOCH 282: train_loss: 5.105e-04 	 test_loss: 5.193e-04
# EPOCH 283: train_loss: 5.222e-04 	 test_loss: 5.171e-04
# EPOCH 284: train_loss: 5.191e-04 	 test_loss: 5.143e-04
# EPOCH 285: train_loss: 5.179e-04 	 test_loss: 5.126e-04
# EPOCH 286: train_loss: 5.166e-04 	 test_loss: 5.118e-04
# EPOCH 287: train_loss: 5.165e-04 	 test_loss: 5.111e-04
# EPOCH 288: train_loss: 5.168e-04 	 test_loss: 5.107e-04
# EPOCH 289: train_loss: 5.155e-04 	 test_loss: 5.103e-04
# EPOCH 290: train_loss: 5.147e-04 	 test_loss: 5.102e-04
# EPOCH 291: train_loss: 5.158e-04 	 test_loss: 5.100e-04
# EPOCH 292: train_loss: 5.159e-04 	 test_loss: 5.099e-04
# EPOCH 293: train_loss: 5.150e-04 	 test_loss: 5.097e-04
# EPOCH 294: train_loss: 5.146e-04 	 test_loss: 5.095e-04
# EPOCH 295: train_loss: 5.152e-04 	 test_loss: 5.094e-04
# EPOCH 296: train_loss: 5.140e-04 	 test_loss: 5.092e-04
# EPOCH 297: train_loss: 5.140e-04 	 test_loss: 5.091e-04
# EPOCH 298: train_loss: 5.147e-04 	 test_loss: 5.090e-04
# EPOCH 299: train_loss: 5.132e-04 	 test_loss: 5.088e-04
# EPOCH 300: train_loss: 5.126e-04 	 test_loss: 5.086e-04
# EPOCH 301: train_loss: 5.127e-04 	 test_loss: 5.085e-04
# EPOCH 302: train_loss: 5.123e-04 	 test_loss: 5.083e-04
# EPOCH 303: train_loss: 5.114e-04 	 test_loss: 5.081e-04
# EPOCH 304: train_loss: 5.123e-04 	 test_loss: 5.079e-04
# EPOCH 305: train_loss: 5.104e-04 	 test_loss: 5.077e-04
# EPOCH 306: train_loss: 5.109e-04 	 test_loss: 5.077e-04
# EPOCH 307: train_loss: 5.109e-04 	 test_loss: 5.071e-04
# EPOCH 308: train_loss: 5.104e-04 	 test_loss: 5.067e-04
# EPOCH 309: train_loss: 5.113e-04 	 test_loss: 5.063e-04
# EPOCH 310: train_loss: 5.080e-04 	 test_loss: 5.058e-04
# EPOCH 311: train_loss: 5.078e-04 	 test_loss: 5.054e-04
# EPOCH 312: train_loss: 5.074e-04 	 test_loss: 5.045e-04
# EPOCH 313: train_loss: 5.086e-04 	 test_loss: 5.038e-04
# EPOCH 314: train_loss: 5.049e-04 	 test_loss: 5.029e-04
# EPOCH 315: train_loss: 5.042e-04 	 test_loss: 5.020e-04
# EPOCH 316: train_loss: 5.055e-04 	 test_loss: 5.013e-04
# EPOCH 317: train_loss: 5.040e-04 	 test_loss: 5.005e-04
# EPOCH 318: train_loss: 5.038e-04 	 test_loss: 4.995e-04
# EPOCH 319: train_loss: 5.026e-04 	 test_loss: 4.987e-04
# EPOCH 320: train_loss: 5.024e-04 	 test_loss: 4.980e-04
# EPOCH 321: train_loss: 4.999e-04 	 test_loss: 4.972e-04
# EPOCH 322: train_loss: 5.005e-04 	 test_loss: 4.961e-04
# EPOCH 323: train_loss: 4.987e-04 	 test_loss: 4.957e-04
# EPOCH 324: train_loss: 5.013e-04 	 test_loss: 4.958e-04
# EPOCH 325: train_loss: 4.995e-04 	 test_loss: 4.947e-04
# EPOCH 326: train_loss: 4.974e-04 	 test_loss: 4.941e-04
# EPOCH 327: train_loss: 4.971e-04 	 test_loss: 4.932e-04
# EPOCH 328: train_loss: 4.966e-04 	 test_loss: 4.933e-04
# EPOCH 329: train_loss: 4.985e-04 	 test_loss: 4.930e-04
# EPOCH 330: train_loss: 4.966e-04 	 test_loss: 4.931e-04
# EPOCH 331: train_loss: 4.938e-04 	 test_loss: 4.911e-04
# EPOCH 332: train_loss: 4.915e-04 	 test_loss: 4.902e-04
# EPOCH 333: train_loss: 4.937e-04 	 test_loss: 4.897e-04
# EPOCH 334: train_loss: 4.902e-04 	 test_loss: 4.893e-04
# EPOCH 335: train_loss: 4.895e-04 	 test_loss: 4.880e-04
# EPOCH 336: train_loss: 4.910e-04 	 test_loss: 4.873e-04
# EPOCH 337: train_loss: 4.884e-04 	 test_loss: 4.870e-04
# EPOCH 338: train_loss: 4.873e-04 	 test_loss: 4.860e-04
# EPOCH 339: train_loss: 4.882e-04 	 test_loss: 4.856e-04
# EPOCH 340: train_loss: 4.877e-04 	 test_loss: 4.850e-04
# EPOCH 341: train_loss: 4.879e-04 	 test_loss: 4.849e-04
# EPOCH 342: train_loss: 4.896e-04 	 test_loss: 4.844e-04
# EPOCH 343: train_loss: 4.888e-04 	 test_loss: 4.836e-04
# EPOCH 344: train_loss: 4.860e-04 	 test_loss: 4.841e-04
# EPOCH 345: train_loss: 4.866e-04 	 test_loss: 4.823e-04
# EPOCH 346: train_loss: 4.845e-04 	 test_loss: 4.825e-04
# EPOCH 347: train_loss: 4.846e-04 	 test_loss: 4.815e-04
# EPOCH 348: train_loss: 4.843e-04 	 test_loss: 4.816e-04
# EPOCH 349: train_loss: 4.813e-04 	 test_loss: 4.810e-04
# EPOCH 350: train_loss: 4.840e-04 	 test_loss: 4.816e-04
# EPOCH 351: train_loss: 4.827e-04 	 test_loss: 4.808e-04
# EPOCH 352: train_loss: 4.835e-04 	 test_loss: 4.799e-04
# EPOCH 353: train_loss: 4.814e-04 	 test_loss: 4.795e-04
# EPOCH 354: train_loss: 4.804e-04 	 test_loss: 4.789e-04
# EPOCH 355: train_loss: 4.820e-04 	 test_loss: 4.798e-04
# EPOCH 356: train_loss: 4.813e-04 	 test_loss: 4.786e-04
# EPOCH 357: train_loss: 4.777e-04 	 test_loss: 4.781e-04
# EPOCH 358: train_loss: 4.787e-04 	 test_loss: 4.781e-04
# EPOCH 359: train_loss: 4.817e-04 	 test_loss: 4.783e-04
# EPOCH 360: train_loss: 4.826e-04 	 test_loss: 4.777e-04
# EPOCH 361: train_loss: 4.790e-04 	 test_loss: 4.768e-04
# EPOCH 362: train_loss: 4.825e-04 	 test_loss: 4.772e-04
# EPOCH 363: train_loss: 4.785e-04 	 test_loss: 4.774e-04
# EPOCH 364: train_loss: 4.797e-04 	 test_loss: 4.763e-04
# EPOCH 365: train_loss: 4.778e-04 	 test_loss: 4.772e-04
# EPOCH 366: train_loss: 4.767e-04 	 test_loss: 4.760e-04
# EPOCH 367: train_loss: 4.766e-04 	 test_loss: 4.753e-04
# EPOCH 368: train_loss: 4.781e-04 	 test_loss: 4.750e-04
# EPOCH 369: train_loss: 4.789e-04 	 test_loss: 4.761e-04
# EPOCH 370: train_loss: 4.787e-04 	 test_loss: 4.762e-04
# EPOCH 371: train_loss: 4.772e-04 	 test_loss: 4.747e-04
# EPOCH 372: train_loss: 4.750e-04 	 test_loss: 4.744e-04
# EPOCH 373: train_loss: 4.760e-04 	 test_loss: 4.742e-04
# EPOCH 374: train_loss: 4.743e-04 	 test_loss: 4.754e-04
# EPOCH 375: train_loss: 4.748e-04 	 test_loss: 4.735e-04
# EPOCH 376: train_loss: 4.766e-04 	 test_loss: 4.740e-04
# EPOCH 377: train_loss: 4.761e-04 	 test_loss: 4.742e-04
# EPOCH 378: train_loss: 4.732e-04 	 test_loss: 4.730e-04
# EPOCH 379: train_loss: 4.754e-04 	 test_loss: 4.733e-04
# EPOCH 380: train_loss: 4.740e-04 	 test_loss: 4.729e-04
# EPOCH 381: train_loss: 4.738e-04 	 test_loss: 4.721e-04
# EPOCH 382: train_loss: 4.737e-04 	 test_loss: 4.715e-04
# EPOCH 383: train_loss: 4.724e-04 	 test_loss: 4.736e-04
# EPOCH 384: train_loss: 4.731e-04 	 test_loss: 4.715e-04
# EPOCH 385: train_loss: 4.725e-04 	 test_loss: 4.744e-04
# EPOCH 386: train_loss: 4.714e-04 	 test_loss: 4.703e-04
# EPOCH 387: train_loss: 4.724e-04 	 test_loss: 4.703e-04
# EPOCH 388: train_loss: 4.724e-04 	 test_loss: 4.721e-04
# EPOCH 389: train_loss: 4.731e-04 	 test_loss: 4.724e-04
# EPOCH 390: train_loss: 4.727e-04 	 test_loss: 4.694e-04
# EPOCH 391: train_loss: 4.691e-04 	 test_loss: 4.708e-04
# EPOCH 392: train_loss: 4.697e-04 	 test_loss: 4.698e-04
# EPOCH 393: train_loss: 4.684e-04 	 test_loss: 4.711e-04
# EPOCH 394: train_loss: 4.737e-04 	 test_loss: 4.683e-04
# EPOCH 395: train_loss: 4.701e-04 	 test_loss: 4.712e-04
# EPOCH 396: train_loss: 4.690e-04 	 test_loss: 4.681e-04
# EPOCH 397: train_loss: 4.711e-04 	 test_loss: 4.676e-04
# EPOCH 398: train_loss: 4.680e-04 	 test_loss: 4.672e-04
# EPOCH 399: train_loss: 4.710e-04 	 test_loss: 4.721e-04
# EPOCH 400: train_loss: 4.686e-04 	 test_loss: 4.695e-04
# EPOCH 401: train_loss: 4.688e-04 	 test_loss: 4.678e-04
# EPOCH 402: train_loss: 4.734e-04 	 test_loss: 4.700e-04
# EPOCH 403: train_loss: 4.663e-04 	 test_loss: 4.676e-04
# EPOCH 404: train_loss: 4.673e-04 	 test_loss: 4.667e-04
# EPOCH 405: train_loss: 4.683e-04 	 test_loss: 4.660e-04
# EPOCH 406: train_loss: 4.692e-04 	 test_loss: 4.667e-04
# EPOCH 407: train_loss: 4.657e-04 	 test_loss: 4.657e-04
# EPOCH 408: train_loss: 4.640e-04 	 test_loss: 4.663e-04
# EPOCH 409: train_loss: 4.657e-04 	 test_loss: 4.651e-04
# EPOCH 410: train_loss: 4.659e-04 	 test_loss: 4.656e-04
# EPOCH 411: train_loss: 4.658e-04 	 test_loss: 4.650e-04
# EPOCH 412: train_loss: 4.672e-04 	 test_loss: 4.643e-04
# EPOCH 413: train_loss: 4.672e-04 	 test_loss: 4.698e-04
# EPOCH 414: train_loss: 4.687e-04 	 test_loss: 4.646e-04
# EPOCH 415: train_loss: 4.662e-04 	 test_loss: 4.646e-04
# EPOCH 416: train_loss: 4.681e-04 	 test_loss: 4.653e-04
# EPOCH 417: train_loss: 4.684e-04 	 test_loss: 4.638e-04
# EPOCH 418: train_loss: 4.652e-04 	 test_loss: 4.641e-04
# EPOCH 419: train_loss: 4.653e-04 	 test_loss: 4.646e-04
# EPOCH 420: train_loss: 4.630e-04 	 test_loss: 4.636e-04
# EPOCH 421: train_loss: 4.665e-04 	 test_loss: 4.649e-04
# EPOCH 422: train_loss: 4.671e-04 	 test_loss: 4.634e-04
# EPOCH 423: train_loss: 4.636e-04 	 test_loss: 4.711e-04
# EPOCH 424: train_loss: 4.703e-04 	 test_loss: 4.640e-04
# EPOCH 425: train_loss: 4.674e-04 	 test_loss: 4.635e-04
# EPOCH 426: train_loss: 4.635e-04 	 test_loss: 4.646e-04
# EPOCH 427: train_loss: 4.623e-04 	 test_loss: 4.638e-04
# EPOCH 428: train_loss: 4.652e-04 	 test_loss: 4.655e-04
# EPOCH 429: train_loss: 4.654e-04 	 test_loss: 4.655e-04
# EPOCH 430: train_loss: 4.679e-04 	 test_loss: 4.624e-04
# EPOCH 431: train_loss: 4.650e-04 	 test_loss: 4.624e-04
# EPOCH 432: train_loss: 4.627e-04 	 test_loss: 4.632e-04
# EPOCH 433: train_loss: 4.621e-04 	 test_loss: 4.626e-04
# EPOCH 434: train_loss: 4.635e-04 	 test_loss: 4.625e-04
# EPOCH 435: train_loss: 4.644e-04 	 test_loss: 4.626e-04
# EPOCH 436: train_loss: 4.669e-04 	 test_loss: 4.616e-04
# EPOCH 437: train_loss: 4.651e-04 	 test_loss: 4.624e-04
# EPOCH 438: train_loss: 4.613e-04 	 test_loss: 4.616e-04
# EPOCH 439: train_loss: 4.632e-04 	 test_loss: 4.613e-04
# EPOCH 440: train_loss: 4.646e-04 	 test_loss: 4.617e-04
# EPOCH 441: train_loss: 4.628e-04 	 test_loss: 4.632e-04
# EPOCH 442: train_loss: 4.609e-04 	 test_loss: 4.632e-04
# EPOCH 443: train_loss: 4.622e-04 	 test_loss: 4.611e-04
# EPOCH 444: train_loss: 4.617e-04 	 test_loss: 4.618e-04
# EPOCH 445: train_loss: 4.626e-04 	 test_loss: 4.620e-04
# EPOCH 446: train_loss: 4.618e-04 	 test_loss: 4.624e-04
# EPOCH 447: train_loss: 4.641e-04 	 test_loss: 4.607e-04
# EPOCH 448: train_loss: 4.642e-04 	 test_loss: 4.636e-04
# EPOCH 449: train_loss: 4.613e-04 	 test_loss: 4.637e-04
# EPOCH 450: train_loss: 4.610e-04 	 test_loss: 4.625e-04
# EPOCH 451: train_loss: 4.622e-04 	 test_loss: 4.621e-04
# EPOCH 452: train_loss: 4.602e-04 	 test_loss: 4.613e-04
# EPOCH 453: train_loss: 4.613e-04 	 test_loss: 4.603e-04
# EPOCH 454: train_loss: 4.626e-04 	 test_loss: 4.619e-04
# EPOCH 455: train_loss: 4.602e-04 	 test_loss: 4.602e-04
# EPOCH 456: train_loss: 4.625e-04 	 test_loss: 4.643e-04
# EPOCH 457: train_loss: 4.643e-04 	 test_loss: 4.603e-04
# EPOCH 458: train_loss: 4.622e-04 	 test_loss: 4.646e-04
# EPOCH 459: train_loss: 4.644e-04 	 test_loss: 4.709e-04
# EPOCH 460: train_loss: 4.697e-04 	 test_loss: 4.599e-04
# EPOCH 461: train_loss: 4.611e-04 	 test_loss: 4.606e-04
# EPOCH 462: train_loss: 4.648e-04 	 test_loss: 4.632e-04
# EPOCH 463: train_loss: 4.599e-04 	 test_loss: 4.605e-04
# EPOCH 464: train_loss: 4.600e-04 	 test_loss: 4.625e-04
# EPOCH 465: train_loss: 4.628e-04 	 test_loss: 4.622e-04
# EPOCH 466: train_loss: 4.628e-04 	 test_loss: 4.594e-04
# EPOCH 467: train_loss: 4.619e-04 	 test_loss: 4.609e-04
# EPOCH 468: train_loss: 4.605e-04 	 test_loss: 4.602e-04
# EPOCH 469: train_loss: 4.590e-04 	 test_loss: 4.638e-04
# EPOCH 470: train_loss: 4.625e-04 	 test_loss: 4.596e-04
# EPOCH 471: train_loss: 4.586e-04 	 test_loss: 4.593e-04
# EPOCH 472: train_loss: 4.593e-04 	 test_loss: 4.623e-04
# EPOCH 473: train_loss: 4.595e-04 	 test_loss: 4.591e-04
# EPOCH 474: train_loss: 4.614e-04 	 test_loss: 4.600e-04
# EPOCH 475: train_loss: 4.586e-04 	 test_loss: 4.588e-04
# EPOCH 476: train_loss: 4.626e-04 	 test_loss: 4.630e-04
# EPOCH 477: train_loss: 4.646e-04 	 test_loss: 4.633e-04
# EPOCH 478: train_loss: 4.590e-04 	 test_loss: 4.603e-04
# EPOCH 479: train_loss: 4.589e-04 	 test_loss: 4.645e-04
# EPOCH 480: train_loss: 4.600e-04 	 test_loss: 4.610e-04
# EPOCH 481: train_loss: 4.588e-04 	 test_loss: 4.583e-04
# EPOCH 482: train_loss: 4.581e-04 	 test_loss: 4.582e-04
# EPOCH 483: train_loss: 4.635e-04 	 test_loss: 4.608e-04
# EPOCH 484: train_loss: 4.598e-04 	 test_loss: 4.587e-04
# EPOCH 485: train_loss: 4.578e-04 	 test_loss: 4.584e-04
# EPOCH 486: train_loss: 4.591e-04 	 test_loss: 4.601e-04
# EPOCH 487: train_loss: 4.573e-04 	 test_loss: 4.602e-04
# EPOCH 488: train_loss: 4.583e-04 	 test_loss: 4.584e-04
# EPOCH 489: train_loss: 4.569e-04 	 test_loss: 4.594e-04
# EPOCH 490: train_loss: 4.583e-04 	 test_loss: 4.594e-04
# EPOCH 491: train_loss: 4.579e-04 	 test_loss: 4.610e-04
# EPOCH 492: train_loss: 4.576e-04 	 test_loss: 4.612e-04
# EPOCH 493: train_loss: 4.581e-04 	 test_loss: 4.576e-04
# EPOCH 494: train_loss: 4.590e-04 	 test_loss: 4.586e-04
# EPOCH 495: train_loss: 4.576e-04 	 test_loss: 4.631e-04
# EPOCH 496: train_loss: 4.582e-04 	 test_loss: 4.602e-04
# EPOCH 497: train_loss: 4.571e-04 	 test_loss: 4.580e-04
# EPOCH 498: train_loss: 4.596e-04 	 test_loss: 4.579e-04
# EPOCH 499: train_loss: 4.569e-04 	 test_loss: 4.582e-04
# EPOCH 500: train_loss: 4.563e-04 	 test_loss: 4.581e-04
# EPOCH 501: train_loss: 4.576e-04 	 test_loss: 4.580e-04
# EPOCH 502: train_loss: 4.566e-04 	 test_loss: 4.588e-04
# EPOCH 503: train_loss: 4.587e-04 	 test_loss: 4.605e-04
# EPOCH 504: train_loss: 4.577e-04 	 test_loss: 4.582e-04
# EPOCH 505: train_loss: 4.582e-04 	 test_loss: 4.641e-04
# EPOCH 506: train_loss: 4.578e-04 	 test_loss: 4.576e-04
# EPOCH 507: train_loss: 4.568e-04 	 test_loss: 4.587e-04
# EPOCH 508: train_loss: 4.548e-04 	 test_loss: 4.608e-04
# EPOCH 509: train_loss: 4.613e-04 	 test_loss: 4.633e-04
# EPOCH 510: train_loss: 4.585e-04 	 test_loss: 4.569e-04
# EPOCH 511: train_loss: 4.565e-04 	 test_loss: 4.579e-04
# EPOCH 512: train_loss: 4.562e-04 	 test_loss: 4.571e-04
# EPOCH 513: train_loss: 4.582e-04 	 test_loss: 4.569e-04
# EPOCH 514: train_loss: 4.564e-04 	 test_loss: 4.570e-04
# EPOCH 515: train_loss: 4.603e-04 	 test_loss: 4.578e-04
# EPOCH 516: train_loss: 4.567e-04 	 test_loss: 4.564e-04
# EPOCH 517: train_loss: 4.579e-04 	 test_loss: 4.564e-04
# EPOCH 518: train_loss: 4.552e-04 	 test_loss: 4.630e-04
# EPOCH 519: train_loss: 4.580e-04 	 test_loss: 4.592e-04
# EPOCH 520: train_loss: 4.570e-04 	 test_loss: 4.617e-04
# EPOCH 521: train_loss: 4.555e-04 	 test_loss: 4.628e-04
# EPOCH 522: train_loss: 4.589e-04 	 test_loss: 4.563e-04
# EPOCH 523: train_loss: 4.605e-04 	 test_loss: 4.603e-04
# EPOCH 524: train_loss: 4.595e-04 	 test_loss: 4.685e-04
# EPOCH 525: train_loss: 4.587e-04 	 test_loss: 4.583e-04
# EPOCH 526: train_loss: 4.561e-04 	 test_loss: 4.586e-04
# EPOCH 527: train_loss: 4.577e-04 	 test_loss: 4.579e-04
# EPOCH 528: train_loss: 4.586e-04 	 test_loss: 4.567e-04
# EPOCH 529: train_loss: 4.537e-04 	 test_loss: 4.584e-04
# EPOCH 530: train_loss: 4.539e-04 	 test_loss: 4.562e-04
# EPOCH 531: train_loss: 4.538e-04 	 test_loss: 4.555e-04
# EPOCH 532: train_loss: 4.530e-04 	 test_loss: 4.560e-04
# EPOCH 533: train_loss: 4.540e-04 	 test_loss: 4.558e-04
# EPOCH 534: train_loss: 4.543e-04 	 test_loss: 4.633e-04
# EPOCH 535: train_loss: 4.750e-04 	 test_loss: 4.738e-04
# EPOCH 536: train_loss: 4.613e-04 	 test_loss: 4.610e-04
# EPOCH 537: train_loss: 4.574e-04 	 test_loss: 4.571e-04
# EPOCH 538: train_loss: 4.578e-04 	 test_loss: 4.605e-04
# EPOCH 539: train_loss: 4.549e-04 	 test_loss: 4.563e-04
# EPOCH 540: train_loss: 4.528e-04 	 test_loss: 4.569e-04
# EPOCH 541: train_loss: 4.548e-04 	 test_loss: 4.553e-04
# EPOCH 542: train_loss: 4.515e-04 	 test_loss: 4.588e-04
# EPOCH 543: train_loss: 4.538e-04 	 test_loss: 4.546e-04
# EPOCH 544: train_loss: 4.531e-04 	 test_loss: 4.559e-04
# EPOCH 545: train_loss: 4.538e-04 	 test_loss: 4.563e-04
# EPOCH 546: train_loss: 4.555e-04 	 test_loss: 4.578e-04
# EPOCH 547: train_loss: 4.550e-04 	 test_loss: 4.560e-04
# EPOCH 548: train_loss: 4.539e-04 	 test_loss: 4.544e-04
# EPOCH 549: train_loss: 4.534e-04 	 test_loss: 4.542e-04
# EPOCH 550: train_loss: 4.532e-04 	 test_loss: 4.548e-04
# EPOCH 551: train_loss: 4.506e-04 	 test_loss: 4.549e-04
# EPOCH 552: train_loss: 4.535e-04 	 test_loss: 4.599e-04
# EPOCH 553: train_loss: 4.580e-04 	 test_loss: 4.601e-04
# EPOCH 554: train_loss: 4.536e-04 	 test_loss: 4.547e-04
# EPOCH 555: train_loss: 4.523e-04 	 test_loss: 4.567e-04
# EPOCH 556: train_loss: 4.561e-04 	 test_loss: 4.546e-04
# EPOCH 557: train_loss: 4.522e-04 	 test_loss: 4.548e-04
# EPOCH 558: train_loss: 4.528e-04 	 test_loss: 4.555e-04
# EPOCH 559: train_loss: 4.539e-04 	 test_loss: 4.548e-04
# EPOCH 560: train_loss: 4.499e-04 	 test_loss: 4.547e-04
# EPOCH 561: train_loss: 4.524e-04 	 test_loss: 4.545e-04
# EPOCH 562: train_loss: 4.512e-04 	 test_loss: 4.574e-04
# EPOCH 563: train_loss: 4.516e-04 	 test_loss: 4.541e-04
# EPOCH 564: train_loss: 4.540e-04 	 test_loss: 4.546e-04
# EPOCH 565: train_loss: 4.510e-04 	 test_loss: 4.553e-04
# EPOCH 566: train_loss: 4.532e-04 	 test_loss: 4.552e-04
# EPOCH 567: train_loss: 4.523e-04 	 test_loss: 4.548e-04
# EPOCH 568: train_loss: 4.523e-04 	 test_loss: 4.552e-04
# EPOCH 569: train_loss: 4.530e-04 	 test_loss: 4.540e-04
# EPOCH 570: train_loss: 4.520e-04 	 test_loss: 4.535e-04
# EPOCH 571: train_loss: 4.490e-04 	 test_loss: 4.538e-04
# EPOCH 572: train_loss: 4.503e-04 	 test_loss: 4.538e-04
# EPOCH 573: train_loss: 4.527e-04 	 test_loss: 4.561e-04
# EPOCH 574: train_loss: 4.519e-04 	 test_loss: 4.589e-04
# EPOCH 575: train_loss: 4.653e-04 	 test_loss: 4.566e-04
# EPOCH 576: train_loss: 4.527e-04 	 test_loss: 4.553e-04
# EPOCH 577: train_loss: 4.507e-04 	 test_loss: 4.663e-04
# EPOCH 578: train_loss: 4.561e-04 	 test_loss: 4.558e-04
# EPOCH 579: train_loss: 4.580e-04 	 test_loss: 4.737e-04
# EPOCH 580: train_loss: 4.615e-04 	 test_loss: 4.544e-04
# EPOCH 581: train_loss: 4.537e-04 	 test_loss: 4.632e-04
# EPOCH 582: train_loss: 4.539e-04 	 test_loss: 4.578e-04
# EPOCH 583: train_loss: 4.517e-04 	 test_loss: 4.632e-04
# EPOCH 584: train_loss: 4.539e-04 	 test_loss: 4.546e-04
# EPOCH 585: train_loss: 4.513e-04 	 test_loss: 4.539e-04
# EPOCH 586: train_loss: 4.510e-04 	 test_loss: 4.544e-04
# EPOCH 587: train_loss: 4.490e-04 	 test_loss: 4.594e-04
# EPOCH 588: train_loss: 4.532e-04 	 test_loss: 4.545e-04
# EPOCH 589: train_loss: 4.547e-04 	 test_loss: 4.545e-04
# EPOCH 590: train_loss: 4.498e-04 	 test_loss: 4.579e-04
# EPOCH 591: train_loss: 4.525e-04 	 test_loss: 4.587e-04
# EPOCH 592: train_loss: 4.523e-04 	 test_loss: 4.573e-04
# EPOCH 593: train_loss: 4.510e-04 	 test_loss: 4.583e-04
# EPOCH 594: train_loss: 4.505e-04 	 test_loss: 4.541e-04
# EPOCH 595: train_loss: 4.519e-04 	 test_loss: 4.564e-04
# EPOCH 596: train_loss: 4.508e-04 	 test_loss: 4.541e-04
# EPOCH 597: train_loss: 4.479e-04 	 test_loss: 4.575e-04
# EPOCH 598: train_loss: 4.545e-04 	 test_loss: 4.565e-04
# EPOCH 599: train_loss: 4.510e-04 	 test_loss: 4.529e-04
# EPOCH 600: train_loss: 4.511e-04 	 test_loss: 4.542e-04
# EPOCH 601: train_loss: 4.484e-04 	 test_loss: 4.586e-04
# EPOCH 602: train_loss: 4.487e-04 	 test_loss: 4.542e-04
# EPOCH 603: train_loss: 4.495e-04 	 test_loss: 4.543e-04
# EPOCH 604: train_loss: 4.471e-04 	 test_loss: 4.556e-04
# EPOCH 605: train_loss: 4.534e-04 	 test_loss: 4.533e-04
# EPOCH 606: train_loss: 4.491e-04 	 test_loss: 4.539e-04
# EPOCH 607: train_loss: 4.499e-04 	 test_loss: 4.590e-04
# EPOCH 608: train_loss: 4.489e-04 	 test_loss: 4.589e-04
# EPOCH 609: train_loss: 4.494e-04 	 test_loss: 4.529e-04
# EPOCH 610: train_loss: 4.487e-04 	 test_loss: 4.549e-04
# EPOCH 611: train_loss: 4.516e-04 	 test_loss: 4.545e-04
# EPOCH 612: train_loss: 4.555e-04 	 test_loss: 4.551e-04
# EPOCH 613: train_loss: 4.482e-04 	 test_loss: 4.542e-04
# EPOCH 614: train_loss: 4.523e-04 	 test_loss: 4.609e-04
# EPOCH 615: train_loss: 4.508e-04 	 test_loss: 4.651e-04
# EPOCH 616: train_loss: 4.555e-04 	 test_loss: 4.549e-04
# EPOCH 617: train_loss: 4.477e-04 	 test_loss: 4.545e-04
# EPOCH 618: train_loss: 4.487e-04 	 test_loss: 4.534e-04
# EPOCH 619: train_loss: 4.474e-04 	 test_loss: 4.530e-04
# EPOCH 620: train_loss: 4.454e-04 	 test_loss: 4.522e-04
# EPOCH 621: train_loss: 4.480e-04 	 test_loss: 4.552e-04
# EPOCH 622: train_loss: 4.520e-04 	 test_loss: 4.547e-04
# EPOCH 623: train_loss: 4.483e-04 	 test_loss: 4.535e-04
# EPOCH 624: train_loss: 4.471e-04 	 test_loss: 4.553e-04
# EPOCH 625: train_loss: 4.444e-04 	 test_loss: 4.546e-04
# EPOCH 626: train_loss: 4.460e-04 	 test_loss: 4.535e-04
# EPOCH 627: train_loss: 4.459e-04 	 test_loss: 4.541e-04
# EPOCH 628: train_loss: 4.483e-04 	 test_loss: 4.582e-04
# EPOCH 629: train_loss: 4.487e-04 	 test_loss: 4.534e-04
# EPOCH 630: train_loss: 4.490e-04 	 test_loss: 4.523e-04
# EPOCH 631: train_loss: 4.477e-04 	 test_loss: 4.543e-04
# EPOCH 632: train_loss: 4.481e-04 	 test_loss: 4.606e-04
# EPOCH 633: train_loss: 4.503e-04 	 test_loss: 4.551e-04
# EPOCH 634: train_loss: 4.499e-04 	 test_loss: 4.572e-04
# EPOCH 635: train_loss: 4.493e-04 	 test_loss: 4.627e-04
# EPOCH 636: train_loss: 4.540e-04 	 test_loss: 4.680e-04
# EPOCH 637: train_loss: 4.572e-04 	 test_loss: 4.547e-04
# EPOCH 638: train_loss: 4.490e-04 	 test_loss: 4.557e-04
# EPOCH 639: train_loss: 4.475e-04 	 test_loss: 4.541e-04
# EPOCH 640: train_loss: 4.468e-04 	 test_loss: 4.598e-04
# EPOCH 641: train_loss: 4.504e-04 	 test_loss: 4.525e-04
# EPOCH 642: train_loss: 4.468e-04 	 test_loss: 4.538e-04
# EPOCH 643: train_loss: 4.458e-04 	 test_loss: 4.551e-04
# EPOCH 644: train_loss: 4.469e-04 	 test_loss: 4.534e-04
# EPOCH 645: train_loss: 4.512e-04 	 test_loss: 4.670e-04
# EPOCH 646: train_loss: 4.528e-04 	 test_loss: 4.555e-04
# EPOCH 647: train_loss: 4.479e-04 	 test_loss: 4.527e-04
# EPOCH 648: train_loss: 4.452e-04 	 test_loss: 4.540e-04
# EPOCH 649: train_loss: 4.460e-04 	 test_loss: 4.524e-04
# EPOCH 650: train_loss: 4.427e-04 	 test_loss: 4.529e-04
# EPOCH 651: train_loss: 4.470e-04 	 test_loss: 4.716e-04
# EPOCH 652: train_loss: 4.640e-04 	 test_loss: 4.677e-04
# EPOCH 653: train_loss: 4.522e-04 	 test_loss: 4.527e-04
# EPOCH 654: train_loss: 4.475e-04 	 test_loss: 4.525e-04
# EPOCH 655: train_loss: 4.451e-04 	 test_loss: 4.519e-04
# EPOCH 656: train_loss: 4.434e-04 	 test_loss: 4.559e-04
# EPOCH 657: train_loss: 4.445e-04 	 test_loss: 4.517e-04
# EPOCH 658: train_loss: 4.438e-04 	 test_loss: 4.549e-04
# EPOCH 659: train_loss: 4.473e-04 	 test_loss: 4.546e-04
# EPOCH 660: train_loss: 4.464e-04 	 test_loss: 4.523e-04
# EPOCH 661: train_loss: 4.462e-04 	 test_loss: 4.562e-04
# EPOCH 662: train_loss: 4.435e-04 	 test_loss: 4.534e-04
# EPOCH 663: train_loss: 4.436e-04 	 test_loss: 4.526e-04
# EPOCH 664: train_loss: 4.430e-04 	 test_loss: 4.520e-04
# EPOCH 665: train_loss: 4.425e-04 	 test_loss: 4.543e-04
# EPOCH 666: train_loss: 4.446e-04 	 test_loss: 4.525e-04
# EPOCH 667: train_loss: 4.418e-04 	 test_loss: 4.516e-04
# EPOCH 668: train_loss: 4.416e-04 	 test_loss: 4.512e-04
# EPOCH 669: train_loss: 4.431e-04 	 test_loss: 4.505e-04
# EPOCH 670: train_loss: 4.443e-04 	 test_loss: 4.511e-04
# EPOCH 671: train_loss: 4.446e-04 	 test_loss: 4.522e-04
# EPOCH 672: train_loss: 4.448e-04 	 test_loss: 4.532e-04
# EPOCH 673: train_loss: 4.419e-04 	 test_loss: 4.516e-04
# EPOCH 674: train_loss: 4.431e-04 	 test_loss: 4.535e-04
# EPOCH 675: train_loss: 4.429e-04 	 test_loss: 4.530e-04
# EPOCH 676: train_loss: 4.429e-04 	 test_loss: 4.516e-04
# EPOCH 677: train_loss: 4.417e-04 	 test_loss: 4.562e-04
# EPOCH 678: train_loss: 4.431e-04 	 test_loss: 4.504e-04
# EPOCH 679: train_loss: 4.447e-04 	 test_loss: 4.514e-04
# EPOCH 680: train_loss: 4.409e-04 	 test_loss: 4.519e-04
# EPOCH 681: train_loss: 4.458e-04 	 test_loss: 4.544e-04
# EPOCH 682: train_loss: 4.414e-04 	 test_loss: 4.512e-04
# EPOCH 683: train_loss: 4.428e-04 	 test_loss: 4.526e-04
# EPOCH 684: train_loss: 4.455e-04 	 test_loss: 4.575e-04
# EPOCH 685: train_loss: 4.490e-04 	 test_loss: 4.532e-04
# EPOCH 686: train_loss: 4.414e-04 	 test_loss: 4.496e-04
# EPOCH 687: train_loss: 4.406e-04 	 test_loss: 4.503e-04
# EPOCH 688: train_loss: 4.411e-04 	 test_loss: 4.516e-04
# EPOCH 689: train_loss: 4.422e-04 	 test_loss: 4.503e-04
# EPOCH 690: train_loss: 4.410e-04 	 test_loss: 4.529e-04
# EPOCH 691: train_loss: 4.407e-04 	 test_loss: 4.534e-04
# EPOCH 692: train_loss: 4.454e-04 	 test_loss: 4.500e-04
# EPOCH 693: train_loss: 4.414e-04 	 test_loss: 4.490e-04
# EPOCH 694: train_loss: 4.439e-04 	 test_loss: 4.515e-04
# EPOCH 695: train_loss: 4.418e-04 	 test_loss: 4.475e-04
# EPOCH 696: train_loss: 4.424e-04 	 test_loss: 4.501e-04
# EPOCH 697: train_loss: 4.386e-04 	 test_loss: 4.500e-04
# EPOCH 698: train_loss: 4.382e-04 	 test_loss: 4.493e-04
# EPOCH 699: train_loss: 4.429e-04 	 test_loss: 4.481e-04
# EPOCH 700: train_loss: 4.480e-04 	 test_loss: 4.592e-04
# EPOCH 701: train_loss: 4.505e-04 	 test_loss: 4.648e-04
# EPOCH 702: train_loss: 4.484e-04 	 test_loss: 4.534e-04
# EPOCH 703: train_loss: 4.434e-04 	 test_loss: 4.501e-04
# EPOCH 704: train_loss: 4.414e-04 	 test_loss: 4.499e-04
# EPOCH 705: train_loss: 4.406e-04 	 test_loss: 4.481e-04
# EPOCH 706: train_loss: 4.468e-04 	 test_loss: 4.540e-04
# EPOCH 707: train_loss: 4.419e-04 	 test_loss: 4.518e-04
# EPOCH 708: train_loss: 4.400e-04 	 test_loss: 4.471e-04
# EPOCH 709: train_loss: 4.384e-04 	 test_loss: 4.470e-04
# EPOCH 710: train_loss: 4.376e-04 	 test_loss: 4.471e-04
# EPOCH 711: train_loss: 4.361e-04 	 test_loss: 4.489e-04
# EPOCH 712: train_loss: 4.354e-04 	 test_loss: 4.495e-04
# EPOCH 713: train_loss: 4.376e-04 	 test_loss: 4.524e-04
# EPOCH 714: train_loss: 4.409e-04 	 test_loss: 4.493e-04
# EPOCH 715: train_loss: 4.457e-04 	 test_loss: 4.512e-04
# EPOCH 716: train_loss: 4.424e-04 	 test_loss: 4.506e-04
# EPOCH 717: train_loss: 4.394e-04 	 test_loss: 4.502e-04
# EPOCH 718: train_loss: 4.368e-04 	 test_loss: 4.479e-04
# EPOCH 719: train_loss: 4.365e-04 	 test_loss: 4.498e-04
# EPOCH 720: train_loss: 4.391e-04 	 test_loss: 4.477e-04
# EPOCH 721: train_loss: 4.372e-04 	 test_loss: 4.478e-04
# EPOCH 722: train_loss: 4.403e-04 	 test_loss: 4.470e-04
# EPOCH 723: train_loss: 4.393e-04 	 test_loss: 4.525e-04
# EPOCH 724: train_loss: 4.379e-04 	 test_loss: 4.493e-04
# EPOCH 725: train_loss: 4.438e-04 	 test_loss: 4.540e-04
# EPOCH 726: train_loss: 4.391e-04 	 test_loss: 4.484e-04
# EPOCH 727: train_loss: 4.363e-04 	 test_loss: 4.471e-04
# EPOCH 728: train_loss: 4.356e-04 	 test_loss: 4.472e-04
# EPOCH 729: train_loss: 4.341e-04 	 test_loss: 4.518e-04
# EPOCH 730: train_loss: 4.372e-04 	 test_loss: 4.514e-04
# EPOCH 731: train_loss: 4.355e-04 	 test_loss: 4.518e-04
# EPOCH 732: train_loss: 4.354e-04 	 test_loss: 4.527e-04
# EPOCH 733: train_loss: 4.365e-04 	 test_loss: 4.563e-04
# EPOCH 734: train_loss: 4.414e-04 	 test_loss: 4.628e-04
# EPOCH 735: train_loss: 4.481e-04 	 test_loss: 4.520e-04
# EPOCH 736: train_loss: 4.441e-04 	 test_loss: 4.531e-04
# EPOCH 737: train_loss: 4.399e-04 	 test_loss: 4.544e-04
# EPOCH 738: train_loss: 4.426e-04 	 test_loss: 4.535e-04
# EPOCH 739: train_loss: 4.384e-04 	 test_loss: 4.523e-04
# EPOCH 740: train_loss: 4.364e-04 	 test_loss: 4.509e-04
# EPOCH 741: train_loss: 4.372e-04 	 test_loss: 4.514e-04
# EPOCH 742: train_loss: 4.355e-04 	 test_loss: 4.490e-04
# EPOCH 743: train_loss: 4.345e-04 	 test_loss: 4.493e-04
# EPOCH 744: train_loss: 4.394e-04 	 test_loss: 4.494e-04
# EPOCH 745: train_loss: 4.337e-04 	 test_loss: 4.514e-04
# EPOCH 746: train_loss: 4.432e-04 	 test_loss: 4.839e-04
# EPOCH 747: train_loss: 4.819e-04 	 test_loss: 4.851e-04
# EPOCH 748: train_loss: 4.806e-04 	 test_loss: 4.768e-04
# EPOCH 749: train_loss: 4.604e-04 	 test_loss: 4.621e-04
# EPOCH 750: train_loss: 4.465e-04 	 test_loss: 4.491e-04
# EPOCH 751: train_loss: 4.398e-04 	 test_loss: 4.520e-04
# EPOCH 752: train_loss: 4.402e-04 	 test_loss: 4.503e-04
# EPOCH 753: train_loss: 4.396e-04 	 test_loss: 4.511e-04
# EPOCH 754: train_loss: 4.411e-04 	 test_loss: 4.484e-04
# EPOCH 755: train_loss: 4.399e-04 	 test_loss: 4.514e-04
# EPOCH 756: train_loss: 4.354e-04 	 test_loss: 4.495e-04
# EPOCH 757: train_loss: 4.398e-04 	 test_loss: 4.522e-04
# EPOCH 758: train_loss: 4.394e-04 	 test_loss: 4.542e-04
# EPOCH 759: train_loss: 4.374e-04 	 test_loss: 4.502e-04
# EPOCH 760: train_loss: 4.338e-04 	 test_loss: 4.478e-04
# EPOCH 761: train_loss: 4.343e-04 	 test_loss: 4.476e-04
# EPOCH 762: train_loss: 4.339e-04 	 test_loss: 4.473e-04
# EPOCH 763: train_loss: 4.341e-04 	 test_loss: 4.496e-04
# EPOCH 764: train_loss: 4.358e-04 	 test_loss: 4.512e-04
# EPOCH 765: train_loss: 4.367e-04 	 test_loss: 4.497e-04
# EPOCH 766: train_loss: 4.308e-04 	 test_loss: 4.527e-04
# EPOCH 767: train_loss: 4.303e-04 	 test_loss: 4.477e-04
# EPOCH 768: train_loss: 4.316e-04 	 test_loss: 4.464e-04
# EPOCH 769: train_loss: 4.313e-04 	 test_loss: 4.477e-04
# EPOCH 770: train_loss: 4.332e-04 	 test_loss: 4.459e-04
# EPOCH 771: train_loss: 4.329e-04 	 test_loss: 4.499e-04
# EPOCH 772: train_loss: 4.323e-04 	 test_loss: 4.486e-04
# EPOCH 773: train_loss: 4.341e-04 	 test_loss: 4.461e-04
# EPOCH 774: train_loss: 4.334e-04 	 test_loss: 4.486e-04
# EPOCH 775: train_loss: 4.349e-04 	 test_loss: 4.479e-04
# EPOCH 776: train_loss: 4.350e-04 	 test_loss: 4.499e-04
# EPOCH 777: train_loss: 4.341e-04 	 test_loss: 4.587e-04
# EPOCH 778: train_loss: 4.384e-04 	 test_loss: 4.487e-04
# EPOCH 779: train_loss: 4.291e-04 	 test_loss: 4.497e-04
# EPOCH 780: train_loss: 4.259e-04 	 test_loss: 4.470e-04
# EPOCH 781: train_loss: 4.285e-04 	 test_loss: 4.463e-04
# EPOCH 782: train_loss: 4.279e-04 	 test_loss: 4.508e-04
# EPOCH 783: train_loss: 4.300e-04 	 test_loss: 4.549e-04
# EPOCH 784: train_loss: 4.291e-04 	 test_loss: 4.497e-04
# EPOCH 785: train_loss: 4.279e-04 	 test_loss: 4.513e-04
# EPOCH 786: train_loss: 4.291e-04 	 test_loss: 4.489e-04
# EPOCH 787: train_loss: 4.385e-04 	 test_loss: 4.562e-04
# EPOCH 788: train_loss: 4.501e-04 	 test_loss: 4.622e-04
# EPOCH 789: train_loss: 4.420e-04 	 test_loss: 4.580e-04
# EPOCH 790: train_loss: 4.403e-04 	 test_loss: 4.469e-04
# EPOCH 791: train_loss: 4.342e-04 	 test_loss: 4.457e-04
# EPOCH 792: train_loss: 4.331e-04 	 test_loss: 4.461e-04
# EPOCH 793: train_loss: 4.307e-04 	 test_loss: 4.488e-04
# EPOCH 794: train_loss: 4.299e-04 	 test_loss: 4.489e-04
# EPOCH 795: train_loss: 4.304e-04 	 test_loss: 4.490e-04
# EPOCH 796: train_loss: 4.313e-04 	 test_loss: 4.493e-04
# EPOCH 797: train_loss: 4.266e-04 	 test_loss: 4.509e-04
# EPOCH 798: train_loss: 4.259e-04 	 test_loss: 4.552e-04
# EPOCH 799: train_loss: 4.264e-04 	 test_loss: 4.480e-04
# EPOCH 800: train_loss: 4.272e-04 	 test_loss: 4.566e-04
# EPOCH 801: train_loss: 4.342e-04 	 test_loss: 4.635e-04
# EPOCH 802: train_loss: 4.397e-04 	 test_loss: 4.607e-04
# EPOCH 803: train_loss: 4.344e-04 	 test_loss: 4.470e-04
# EPOCH 804: train_loss: 4.305e-04 	 test_loss: 4.529e-04
# EPOCH 805: train_loss: 4.293e-04 	 test_loss: 4.517e-04
# EPOCH 806: train_loss: 4.316e-04 	 test_loss: 4.540e-04
# EPOCH 807: train_loss: 4.293e-04 	 test_loss: 4.575e-04
# EPOCH 808: train_loss: 4.267e-04 	 test_loss: 4.535e-04
# EPOCH 809: train_loss: 4.322e-04 	 test_loss: 4.527e-04
# EPOCH 810: train_loss: 4.372e-04 	 test_loss: 4.465e-04
# EPOCH 811: train_loss: 4.333e-04 	 test_loss: 4.492e-04
# EPOCH 812: train_loss: 4.396e-04 	 test_loss: 4.490e-04
# EPOCH 813: train_loss: 4.324e-04 	 test_loss: 4.498e-04
# EPOCH 814: train_loss: 4.257e-04 	 test_loss: 4.519e-04
# EPOCH 815: train_loss: 4.272e-04 	 test_loss: 4.530e-04
# EPOCH 816: train_loss: 4.262e-04 	 test_loss: 4.507e-04
# EPOCH 817: train_loss: 4.289e-04 	 test_loss: 4.477e-04
# EPOCH 818: train_loss: 4.257e-04 	 test_loss: 4.531e-04
# EPOCH 819: train_loss: 4.244e-04 	 test_loss: 4.515e-04
# EPOCH 820: train_loss: 4.263e-04 	 test_loss: 4.486e-04
# EPOCH 821: train_loss: 4.263e-04 	 test_loss: 4.561e-04
# EPOCH 822: train_loss: 4.274e-04 	 test_loss: 4.465e-04
# EPOCH 823: train_loss: 4.241e-04 	 test_loss: 4.500e-04
# EPOCH 824: train_loss: 4.298e-04 	 test_loss: 4.627e-04
# EPOCH 825: train_loss: 4.376e-04 	 test_loss: 4.599e-04
# EPOCH 826: train_loss: 4.388e-04 	 test_loss: 4.496e-04
# EPOCH 827: train_loss: 4.344e-04 	 test_loss: 4.462e-04
# EPOCH 828: train_loss: 4.299e-04 	 test_loss: 4.485e-04
# EPOCH 829: train_loss: 4.256e-04 	 test_loss: 4.457e-04
# EPOCH 830: train_loss: 4.271e-04 	 test_loss: 4.567e-04
# EPOCH 831: train_loss: 4.258e-04 	 test_loss: 4.720e-04
# EPOCH 832: train_loss: 4.276e-04 	 test_loss: 4.571e-04
# EPOCH 833: train_loss: 4.241e-04 	 test_loss: 4.482e-04
# EPOCH 834: train_loss: 4.245e-04 	 test_loss: 4.521e-04
# EPOCH 835: train_loss: 4.207e-04 	 test_loss: 4.522e-04
# EPOCH 836: train_loss: 4.211e-04 	 test_loss: 4.499e-04
# EPOCH 837: train_loss: 4.206e-04 	 test_loss: 4.632e-04
# EPOCH 838: train_loss: 4.261e-04 	 test_loss: 4.732e-04
# EPOCH 839: train_loss: 4.217e-04 	 test_loss: 4.498e-04
# EPOCH 840: train_loss: 4.209e-04 	 test_loss: 4.529e-04
# EPOCH 841: train_loss: 4.264e-04 	 test_loss: 4.756e-04
# EPOCH 842: train_loss: 4.273e-04 	 test_loss: 4.496e-04
# EPOCH 843: train_loss: 4.310e-04 	 test_loss: 4.467e-04
# EPOCH 844: train_loss: 4.284e-04 	 test_loss: 4.689e-04
# EPOCH 845: train_loss: 4.337e-04 	 test_loss: 4.463e-04
# EPOCH 846: train_loss: 4.275e-04 	 test_loss: 4.514e-04
# EPOCH 847: train_loss: 4.244e-04 	 test_loss: 4.479e-04
# EPOCH 848: train_loss: 4.230e-04 	 test_loss: 4.539e-04
# EPOCH 849: train_loss: 4.216e-04 	 test_loss: 4.550e-04
# EPOCH 850: train_loss: 4.251e-04 	 test_loss: 4.515e-04
# EPOCH 851: train_loss: 4.257e-04 	 test_loss: 4.579e-04
# EPOCH 852: train_loss: 4.354e-04 	 test_loss: 4.522e-04
# EPOCH 853: train_loss: 4.281e-04 	 test_loss: 4.537e-04
# EPOCH 854: train_loss: 4.307e-04 	 test_loss: 4.617e-04
# EPOCH 855: train_loss: 4.242e-04 	 test_loss: 4.442e-04
# EPOCH 856: train_loss: 4.223e-04 	 test_loss: 4.454e-04
# EPOCH 857: train_loss: 4.224e-04 	 test_loss: 4.475e-04
# EPOCH 858: train_loss: 4.194e-04 	 test_loss: 4.543e-04
# EPOCH 859: train_loss: 4.184e-04 	 test_loss: 4.553e-04
# EPOCH 860: train_loss: 4.188e-04 	 test_loss: 4.572e-04
# EPOCH 861: train_loss: 4.205e-04 	 test_loss: 4.488e-04
# EPOCH 862: train_loss: 4.206e-04 	 test_loss: 4.536e-04
# EPOCH 863: train_loss: 4.184e-04 	 test_loss: 4.511e-04
# EPOCH 864: train_loss: 4.191e-04 	 test_loss: 4.619e-04
# EPOCH 865: train_loss: 4.176e-04 	 test_loss: 4.517e-04
# EPOCH 866: train_loss: 4.176e-04 	 test_loss: 4.490e-04
# EPOCH 867: train_loss: 4.207e-04 	 test_loss: 4.590e-04
# EPOCH 868: train_loss: 4.188e-04 	 test_loss: 4.528e-04
# EPOCH 869: train_loss: 4.202e-04 	 test_loss: 4.615e-04
# EPOCH 870: train_loss: 4.185e-04 	 test_loss: 4.516e-04
# EPOCH 871: train_loss: 4.170e-04 	 test_loss: 4.522e-04
# EPOCH 872: train_loss: 4.192e-04 	 test_loss: 4.631e-04
# EPOCH 873: train_loss: 4.190e-04 	 test_loss: 4.487e-04
# EPOCH 874: train_loss: 4.164e-04 	 test_loss: 4.499e-04
# EPOCH 875: train_loss: 3.304e+01 	 test_loss: 2.842e-02
# EPOCH 876: train_loss: 5.078e-02 	 test_loss: 1.487e-02
# EPOCH 877: train_loss: 8.745e-02 	 test_loss: 4.460e-03
# EPOCH 878: train_loss: 1.910e-02 	 test_loss: 1.891e-03
# EPOCH 879: train_loss: 4.830e-03 	 test_loss: 1.290e-03
# EPOCH 880: train_loss: 3.194e-03 	 test_loss: 1.110e-03
# EPOCH 881: train_loss: 2.935e-03 	 test_loss: 1.030e-03
# EPOCH 882: train_loss: 2.364e-03 	 test_loss: 9.857e-04
# EPOCH 883: train_loss: 2.313e-03 	 test_loss: 9.528e-04
# EPOCH 884: train_loss: 2.191e-03 	 test_loss: 9.263e-04
# EPOCH 885: train_loss: 2.186e-03 	 test_loss: 9.019e-04
# EPOCH 886: train_loss: 2.151e-03 	 test_loss: 8.793e-04
# EPOCH 887: train_loss: 1.869e-03 	 test_loss: 8.596e-04
# EPOCH 888: train_loss: 1.917e-03 	 test_loss: 8.423e-04
# EPOCH 889: train_loss: 1.862e-03 	 test_loss: 8.256e-04
# EPOCH 890: train_loss: 1.680e-03 	 test_loss: 8.113e-04
# EPOCH 891: train_loss: 1.825e-03 	 test_loss: 7.982e-04
# EPOCH 892: train_loss: 1.698e-03 	 test_loss: 7.853e-04
# EPOCH 893: train_loss: 1.799e-03 	 test_loss: 7.731e-04
# EPOCH 894: train_loss: 1.582e-03 	 test_loss: 7.613e-04
# EPOCH 895: train_loss: 1.647e-03 	 test_loss: 7.510e-04
# EPOCH 896: train_loss: 1.594e-03 	 test_loss: 7.415e-04
# EPOCH 897: train_loss: 1.426e-03 	 test_loss: 7.329e-04
# EPOCH 898: train_loss: 1.466e-03 	 test_loss: 7.244e-04
# EPOCH 899: train_loss: 1.349e-03 	 test_loss: 7.169e-04
# EPOCH 900: train_loss: 1.368e-03 	 test_loss: 7.096e-04
# EPOCH 901: train_loss: 1.423e-03 	 test_loss: 7.029e-04
# EPOCH 902: train_loss: 1.413e-03 	 test_loss: 6.964e-04
# EPOCH 903: train_loss: 1.411e-03 	 test_loss: 6.902e-04
# EPOCH 904: train_loss: 1.182e-03 	 test_loss: 6.846e-04
# EPOCH 905: train_loss: 1.292e-03 	 test_loss: 6.790e-04
# EPOCH 906: train_loss: 1.224e-03 	 test_loss: 6.738e-04
# EPOCH 907: train_loss: 1.317e-03 	 test_loss: 6.685e-04
# EPOCH 908: train_loss: 1.240e-03 	 test_loss: 6.635e-04
# EPOCH 909: train_loss: 1.165e-03 	 test_loss: 6.589e-04
# EPOCH 910: train_loss: 1.153e-03 	 test_loss: 6.543e-04
# EPOCH 911: train_loss: 1.111e-03 	 test_loss: 6.502e-04
# EPOCH 912: train_loss: 1.144e-03 	 test_loss: 6.460e-04
# EPOCH 913: train_loss: 1.176e-03 	 test_loss: 6.423e-04
# EPOCH 914: train_loss: 1.101e-03 	 test_loss: 6.384e-04
# EPOCH 915: train_loss: 1.089e-03 	 test_loss: 6.348e-04
# EPOCH 916: train_loss: 1.055e-03 	 test_loss: 6.314e-04
# EPOCH 917: train_loss: 1.005e-03 	 test_loss: 6.281e-04
# EPOCH 918: train_loss: 1.054e-03 	 test_loss: 6.250e-04
# EPOCH 919: train_loss: 1.048e-03 	 test_loss: 6.218e-04
# EPOCH 920: train_loss: 1.023e-03 	 test_loss: 6.190e-04
# EPOCH 921: train_loss: 1.216e-03 	 test_loss: 6.162e-04
# EPOCH 922: train_loss: 9.681e-04 	 test_loss: 6.135e-04
# EPOCH 923: train_loss: 1.027e-03 	 test_loss: 6.108e-04
# EPOCH 924: train_loss: 9.282e-04 	 test_loss: 6.083e-04
# EPOCH 925: train_loss: 9.709e-04 	 test_loss: 6.059e-04
# EPOCH 926: train_loss: 9.841e-04 	 test_loss: 6.035e-04
# EPOCH 927: train_loss: 1.015e-03 	 test_loss: 6.012e-04
# EPOCH 928: train_loss: 9.435e-04 	 test_loss: 5.990e-04
# EPOCH 929: train_loss: 9.884e-04 	 test_loss: 5.970e-04
# EPOCH 930: train_loss: 9.384e-04 	 test_loss: 5.950e-04
# EPOCH 931: train_loss: 9.146e-04 	 test_loss: 5.931e-04
# EPOCH 932: train_loss: 9.220e-04 	 test_loss: 5.911e-04
# EPOCH 933: train_loss: 9.601e-04 	 test_loss: 5.891e-04
# EPOCH 934: train_loss: 9.269e-04 	 test_loss: 5.872e-04
# EPOCH 935: train_loss: 8.884e-04 	 test_loss: 5.854e-04
# EPOCH 936: train_loss: 8.695e-04 	 test_loss: 5.837e-04
# EPOCH 937: train_loss: 8.444e-04 	 test_loss: 5.821e-04
# EPOCH 938: train_loss: 8.352e-04 	 test_loss: 5.806e-04
# EPOCH 939: train_loss: 8.595e-04 	 test_loss: 5.791e-04
# EPOCH 940: train_loss: 9.770e-04 	 test_loss: 5.776e-04
# EPOCH 941: train_loss: 8.530e-04 	 test_loss: 5.761e-04
# EPOCH 942: train_loss: 8.287e-04 	 test_loss: 5.747e-04
# EPOCH 943: train_loss: 8.248e-04 	 test_loss: 5.733e-04
# EPOCH 944: train_loss: 8.259e-04 	 test_loss: 5.720e-04
# EPOCH 945: train_loss: 8.703e-04 	 test_loss: 5.707e-04
# EPOCH 946: train_loss: 8.459e-04 	 test_loss: 5.694e-04
# EPOCH 947: train_loss: 8.008e-04 	 test_loss: 5.682e-04
# EPOCH 948: train_loss: 8.679e-04 	 test_loss: 5.670e-04
# EPOCH 949: train_loss: 8.141e-04 	 test_loss: 5.657e-04
# EPOCH 950: train_loss: 8.232e-04 	 test_loss: 5.646e-04
# EPOCH 951: train_loss: 1.248e-03 	 test_loss: 5.633e-04
# EPOCH 952: train_loss: 7.690e-04 	 test_loss: 5.622e-04
# EPOCH 953: train_loss: 7.735e-04 	 test_loss: 5.611e-04
# EPOCH 954: train_loss: 7.519e-04 	 test_loss: 5.601e-04
# EPOCH 955: train_loss: 7.918e-04 	 test_loss: 5.591e-04
# EPOCH 956: train_loss: 8.363e-04 	 test_loss: 5.581e-04
# EPOCH 957: train_loss: 7.638e-04 	 test_loss: 5.572e-04
# EPOCH 958: train_loss: 7.269e-04 	 test_loss: 5.563e-04
# EPOCH 959: train_loss: 7.630e-04 	 test_loss: 5.554e-04
# EPOCH 960: train_loss: 7.624e-04 	 test_loss: 5.545e-04
# EPOCH 961: train_loss: 7.792e-04 	 test_loss: 5.536e-04
# EPOCH 962: train_loss: 7.308e-04 	 test_loss: 5.528e-04
# EPOCH 963: train_loss: 7.457e-04 	 test_loss: 5.520e-04
# EPOCH 964: train_loss: 7.055e-04 	 test_loss: 5.512e-04
# EPOCH 965: train_loss: 7.510e-04 	 test_loss: 5.504e-04
# EPOCH 966: train_loss: 7.510e-04 	 test_loss: 5.497e-04
# EPOCH 967: train_loss: 7.640e-04 	 test_loss: 5.489e-04
# EPOCH 968: train_loss: 7.361e-04 	 test_loss: 5.482e-04
# EPOCH 969: train_loss: 7.086e-04 	 test_loss: 5.475e-04
# EPOCH 970: train_loss: 7.329e-04 	 test_loss: 5.468e-04
# EPOCH 971: train_loss: 8.043e-04 	 test_loss: 5.461e-04
# EPOCH 972: train_loss: 7.517e-04 	 test_loss: 5.453e-04
# EPOCH 973: train_loss: 7.139e-04 	 test_loss: 5.447e-04
# EPOCH 974: train_loss: 6.923e-04 	 test_loss: 5.440e-04
# EPOCH 975: train_loss: 7.118e-04 	 test_loss: 5.434e-04
# EPOCH 976: train_loss: 6.949e-04 	 test_loss: 5.428e-04
# EPOCH 977: train_loss: 7.585e-04 	 test_loss: 5.421e-04
# EPOCH 978: train_loss: 6.890e-04 	 test_loss: 5.415e-04
# EPOCH 979: train_loss: 7.135e-04 	 test_loss: 5.409e-04
# EPOCH 980: train_loss: 6.969e-04 	 test_loss: 5.404e-04
# EPOCH 981: train_loss: 6.854e-04 	 test_loss: 5.398e-04
# EPOCH 982: train_loss: 6.715e-04 	 test_loss: 5.393e-04
# EPOCH 983: train_loss: 8.864e-04 	 test_loss: 5.387e-04
# EPOCH 984: train_loss: 6.935e-04 	 test_loss: 5.382e-04
# EPOCH 985: train_loss: 7.045e-04 	 test_loss: 5.377e-04
# EPOCH 986: train_loss: 6.724e-04 	 test_loss: 5.372e-04
# EPOCH 987: train_loss: 6.756e-04 	 test_loss: 5.367e-04
# EPOCH 988: train_loss: 6.955e-04 	 test_loss: 5.362e-04
# EPOCH 989: train_loss: 6.799e-04 	 test_loss: 5.357e-04
# EPOCH 990: train_loss: 6.645e-04 	 test_loss: 5.352e-04
# EPOCH 991: train_loss: 6.763e-04 	 test_loss: 5.348e-04
# EPOCH 992: train_loss: 6.610e-04 	 test_loss: 5.343e-04
# EPOCH 993: train_loss: 6.673e-04 	 test_loss: 5.339e-04
# EPOCH 994: train_loss: 6.763e-04 	 test_loss: 5.335e-04
# EPOCH 995: train_loss: 6.629e-04 	 test_loss: 5.330e-04
# EPOCH 996: train_loss: 6.788e-04 	 test_loss: 5.326e-04
# EPOCH 997: train_loss: 6.523e-04 	 test_loss: 5.322e-04
# EPOCH 998: train_loss: 6.753e-04 	 test_loss: 5.317e-04
# EPOCH 999: train_loss: 6.528e-04 	 test_loss: 5.313e-04

# %%
# plot_loss(loss_history, val_loss_history)
plot_results(model, train_x_norm, train_y_norm, "Training Set Results (Normalized)")
plot_results(model, test_x_norm, test_y_norm, "Testing Set Results (Normalized)")
# plot_results(model, train_x_norm, train_y_norm, "Training Set Results (True Scale)", True)
# plot_results(model, test_x_norm, test_y_norm, "Testing Set Results (True Scale)", True)
