# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn
import torch.optim as optim
import torch.nn.utils as utils

import torch.fft
from typing import Callable, List, Union    

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # Loading Data and Preprocessing

# %%
features_path = "data/friction_data/features_AgingLaw_v2.csv"
targets_path = "data/friction_data/targets_AgingLaw_v2.csv"
train_samples = 700

# %%
def x_state_transform(x: np.array) -> torch.Tensor:
    return torch.Tensor(np.sqrt(np.log(1e8*x)))

def x_heal_transform(x: np.array) -> torch.Tensor:
    return (torch.abs(torch.Tensor(x) - 1e-8) < 1e-12).float()

# %%
feature = torch.Tensor(np.genfromtxt(features_path, delimiter=',')[:, np.newaxis, :])
target = torch.Tensor(np.genfromtxt(targets_path, delimiter=',')[:, np.newaxis, :])

train_x = feature[:train_samples, :, :]
train_y = target[:train_samples, :, :]
test_x = feature[train_samples:, :, :]
test_y = target[train_samples:, :, :]

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

for i, ax1 in enumerate(axes):
    # Velocity axis
    line1 = ax1.plot([i/len(train_x[i,0,:]) for i in range(len(train_x[i,0,:]))],
        train_x[i, 0, :],
        color="blue",
        label="Velocity"
    )
    ax1.set_xlabel("Normalized Time", fontsize = 14)
    ax1.set_ylabel("Velocity", color="blue", fontsize = 14)
    ax1.tick_params(axis="y", colors="blue")
    ax1.spines["left"].set_color("blue")
    ax1.set_yscale('log')

    # Friction coefficient axis
    ax2 = ax1.twinx()
    line2 = ax2.plot([i/len(train_x[i,0,:]) for i in range(len(train_x[i,0,:]))],
        train_y[i, 0, :],
        color="red",
        label=r"$\mu$"
    )
    ax2.set_ylabel(r"$\mu$", color="red", fontsize = 14)
    ax2.tick_params(axis="y", colors="red")
    ax2.spines["right"].set_color("red")

    # Combined legend
    lines = line1 + line2
    labels = [l.get_label() for l in lines]
    ax1.legend(lines, labels, loc="lower right")

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
bins = np.logspace(np.log10(feature.min()), np.log10(feature.max()), 100)
axes[0].hist(feature.flatten(), bins=bins, label = f"min: {feature.min():.2e}, max: {feature.max():.2e}")
axes[0].set_xscale('log')
axes[0].set_title("Feature Distribution")
axes[0].legend()
axes[1].hist(target.flatten(), bins=100, color = 'red', label = f"min: {target.min():.2f}, max: {target.max():.2f}")
axes[1].set_title("Target Distribution")
axes[1].legend()

plt.show()
# Out:
# /tmp/ipykernel_2246101/2857547353.py:2: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   bins = np.logspace(np.log10(feature.min()), np.log10(feature.max()), 100)

# %%
train_x_norm_state = x_state_transform(train_x)
state_min, state_max = train_x_norm_state.min(), train_x_norm_state.max()
train_x_norm_state = (train_x_norm_state - state_min) / (state_max - state_min)
test_x_norm_state = x_state_transform(test_x)
test_x_norm_state = (test_x_norm_state - state_min) / (state_max - state_min)

train_x_norm_heal = x_heal_transform(train_x)
test_x_norm_heal = x_heal_transform(test_x)

train_x_norm = torch.cat([train_x_norm_state, train_x_norm_heal], dim=1)
test_x_norm = torch.cat([test_x_norm_state, test_x_norm_heal], dim=1)

y_min, y_max = train_y.min(), train_y.max()
# train_y_norm = (train_y - y_min)/ (y_max - y_min)
# test_y_norm = (test_y - y_min) / (y_max - y_min)
train_y_norm = train_y  / torch.abs(y_min) 
test_y_norm = test_y  / torch.abs(y_min)


train_dataset = TensorDataset(train_x_norm, train_y_norm)
test_dataset = TensorDataset(test_x_norm, test_y_norm)
# Out:
# /tmp/ipykernel_2246101/1439729241.py:2: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   return torch.Tensor(np.sqrt(np.log(1e8*x)))

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

axes = axes.flatten()
axes[0].hist(train_x_norm_state.flatten(), bins=100, color = 'blue', 
             label = f'Train: [{train_x_norm_state.min():.2f},{train_x_norm_state.max():.2f}]')
axes[0].hist(test_x_norm_state.flatten(), bins = 100, color = 'grey', 
             label = f'Test: [{test_x_norm_state.min():.2f},{test_x_norm_state.max():.2f}]')
axes[0].set_title("State Feature Distribution")
axes[0].legend()

axes[1].hist(train_x_norm_heal.flatten(), bins=100, color = 'green', 
             label = f'Train: [{train_x_norm_heal.min():.2f},{train_x_norm_heal.max():.2f}]')
axes[1].hist(test_x_norm_heal.flatten(), bins=100, color = 'grey', 
             label = f'Test: [{test_x_norm_heal.min():.2f},{test_x_norm_heal.max():.2f}]')
axes[1].set_title("Heal Feature Distribution")
axes[1].legend()

axes[2].hist(train_y_norm.flatten(), bins=100, color ='red', 
             label = f'Train: [{train_y_norm.min():.2f},{train_y_norm.max():.2f}]')
axes[2].hist(test_y_norm.flatten(), bins=100, color ='grey',
             label = f'Test: [{test_y_norm.min():.2f},{test_y_norm.max():.2f}]')
axes[2].set_title("Norm. Target Distribution")
axes[2].legend()

plt.show()

# %%
fig, axes = plt.subplots(4,4, figsize=(20, 20))
axes = axes.flatten()
for i in range(16):
    norm_time = [i/len(train_x_norm_state[i, 0, :]) for i in range(len(train_x_norm_state[i, 0, :]))]
    axes[i].plot(norm_time, train_x_norm_state[i, 0, :].numpy(), label='State')
    axes[i].plot(norm_time, train_x_norm_heal[i, 0, :].numpy(), label='Heal', color = 'green')
    axes[i].plot(norm_time, train_y_norm[i, 0, :].numpy(), label='Target', color = 'red')
    axes[i].set_title(f"Sample {i+1}")
    axes[i].set_xlabel('Normalized Time')
    axes[i].set_ylabel('Magnitude')
    axes[i].legend()

# %% [markdown]
# # Code for Models, Training, Postprocessing

# %% [markdown]
# ## FNO and NN

# %%
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            nn.init.constant_(m.bias, 0)
    elif isinstance(m, nn.Conv1d):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            nn.init.constant_(m.bias, 0)


class SpectralConv1d(nn.Module):
    def __init__(self, 
                 in_channels : int, 
                 out_channels: int, 
                 modes: int):
        """
        Initializes a 1D spectral convolution layer using complex weights in the Fourier domain.

        Args:
            in_channels (int): Number of input channels.
            out_channels (int): Number of output channels.
            modes (int): Number of Fourier modes to retain (low-frequency modes).
        """
        super().__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.modes = modes

        scale = 1.0 / (in_channels * out_channels)
        self.real_weights = nn.Parameter(
            torch.rand(in_channels, out_channels, modes) * 2 * scale - scale
        )
        self.imag_weights = nn.Parameter(
            torch.rand(in_channels, out_channels, modes) * 2 * scale - scale
        )

    def complex_mult1d(self, x_hat, w):
        return torch.einsum("iM,ioM->oM", x_hat, w)

    def forward(self, x):
        # x: (batch, channels, spatial_points)
        batchsize, channels, spatial_points = x.shape

        x_hat = torch.fft.rfft(x, dim=-1)  # (B, C, F)
        x_hat_under_modes = x_hat[:, :, :self.modes]

        weights = torch.complex(self.real_weights, self.imag_weights)
        out_hat_under_modes = torch.einsum("bim, iom -> bom", x_hat_under_modes, weights)

        out_hat = torch.zeros(
            batchsize, self.out_channels, x_hat.shape[-1],
            dtype=torch.cfloat, device=x.device
        )
        out_hat[:, :, :self.modes] = out_hat_under_modes

        out = torch.fft.irfft(out_hat, n=spatial_points, dim=-1)
        return out


class FNOBlock1d(nn.Module):
    def __init__(self, 
                 in_channels : int, 
                 out_channels : int, 
                 modes : int, 
                 activation : nn.Module = nn.Identity()):
        """
        Initializes a single Fourier Neural Operator (FNO) block for 1D data.

        Args:
            in_channels (int): Number of input channels.
            out_channels (int): Number of output channels.
            modes (int): Number of retained Fourier modes in the spectral convolution.
            activation (nn.Module, optional): Activation function applied after the block output. Default is nn.Identity().
        """
        
        super().__init__()
        self.activation = activation
        self.spectral_conv = SpectralConv1d(in_channels, out_channels, modes)
        self.bypass_conv = nn.Conv1d(in_channels, out_channels, kernel_size=1)

    def forward(self, x):
        sc = self.spectral_conv(x)
        bc = self.bypass_conv(x)
        out = sc + bc
        out = self.activation(out)
        return out

class Projection_NN(nn.Module):
    def __init__(self, 
                 input_dim : int, 
                 output_dim : int, 
                 width : int, 
                 depth : int, 
                 activation: nn.Module = nn.Identity(),
                 dropout = 0,
                 batchNorm = False):
        
        """
        Initializes a fully-connected feedforward projection network.

        Args:
            input_dim (int): Input dimensionality.
            output_dim (int): Output dimensionality.
            width (int): Width (number of hidden units) in each hidden layer.
            depth (int): Number of layers in the network (including input/output layers).
            activation (nn.Module, optional): Activation function applied between layers. Default is nn.Identity().
        """
        
        super().__init__()

        layers = [nn.Linear(input_dim, width)]
        layers.append(activation)
        layers.append(nn.Dropout(dropout))
        layers.append(nn.BatchNorm1d(width) if batchNorm else nn.Identity())

        for _ in range(depth - 1):
            layers.append(nn.Linear(width, width))
            layers.append(activation)
            layers.append(nn.Dropout(dropout))
            layers.append(nn.BatchNorm1d(width) if batchNorm else nn.Identity())

        layers.append(nn.Linear(width, output_dim))
        self.network = nn.Sequential(*layers)

    def forward(self, x):
        bsize, _, N = x.shape
        x = x.permute(0, 2, 1).contiguous().view(-1, self.network[0].in_features)
        x = self.network(x)
        x = x.view(bsize, N, self.network[-1].out_features).permute(0, 2, 1).contiguous()
        return x

class FNO1d(nn.Module):
    def __init__(
        self,
        in_channels : int,
        out_channels : int,
        modes : int,
        width : int,
        block_activation : nn.Module = nn.Identity(),
        n_blocks : int = 4,
        padding : int = 0,
        lift_network = None,
        decode_network = None,
    ):
        """
        Initializes a 1D Fourier Neural Operator (FNO) model.

        Args:
            in_channels (int): Number of input channels.
            out_channels (int): Number of output channels.
            modes (int): Number of Fourier modes retained in spectral convolutions.
            width (int): Width of the internal FNO layers.
            block_activation (nn.Module, optional): Activation applied after each FNO block. Default is nn.Identity().
            n_blocks (int, optional): Number of stacked FNO blocks. Default is 4.
            padding (int, optional): Amount of zero-padding added to input and removed from output. Default is 0.
        """

        super().__init__()
        
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.modes = modes
        self.width = width
        self.block_activation = block_activation
        self.n_blocks = n_blocks
        self.padding = padding
        
        self.lift_network = lift_network
        self.decode_network = decode_network

        self.fno_blocks = nn.ModuleList([
            FNOBlock1d(width, width, modes, block_activation)
            for _ in range(n_blocks)
        ])

        self.apply(init_weights)

    # x: (B, C, N)
    def forward(self, x):

        x = self.lift_network(x)

        if self.padding != 0:
            x = nn.functional.pad(x, (self.padding, self.padding), mode='constant', value=0)

        for block in self.fno_blocks:
            x = block(x)

        x = self.decode_network(x)

        if self.padding != 0:
            x = x[:, :, self.padding:-self.padding]

        return x

# %% [markdown]
# ## Train Loop

# %%
def train_loop(model,
                     train_loader,
                     test_loader,
                     epochs,
                     optimizer,
                     scheduler=None,
                     clip_grad=False,
                     mixed_training=False,
                     add_noise=False,
                     loss_func = nn.MSELoss()):

    criterion = loss_func

    loss_history = []
    val_loss_history = []

    for epoch in range(epochs):
        model.train()
        epoch_loss = 0.0

        for batch_x, batch_y in train_loader:

            if mixed_training is not False:
                sample_freq = np.random.choice(mixed_training[0], p=mixed_training[1])
                batch_x = batch_x.to(device)[:, :, ::sample_freq]
                batch_y = batch_y.to(device)[:, :, ::sample_freq]
            else:
                batch_x = batch_x.to(device)
                batch_y = batch_y.to(device)

            if add_noise is not False:
                noise = torch.randn_like(batch_x) * add_noise[0]
                batch_x = batch_x + noise

            def closure():
                optimizer.zero_grad()

                output = model(batch_x)
                output_fft = torch.fft.rfft(output, dim=-1)
                batch_y_fft = torch.fft.rfft(batch_y, dim = -1)
                loss_direct = criterion(output, batch_y)
                loss_real = criterion(output_fft.real, batch_y_fft.real)
                loss = loss_real + 5 * loss_direct

                loss.backward()

                if clip_grad:
                    utils.clip_grad_norm_(model.parameters(), 0.5)

                return loss

            loss = optimizer.step(closure)

            epoch_loss += loss.item()

        if scheduler is not None:
            scheduler.step()

        loss_history.append(epoch_loss / len(train_loader))

        model.eval()
        with torch.no_grad():
            val_loss = 0.0
            for batch_x, batch_y in test_loader:
                batch_x = batch_x.to(device)
                batch_y = batch_y.to(device)

                val_output = model(batch_x)
                output_fft = torch.fft.rfft(val_output, dim=-1)
                batch_y_fft = torch.fft.rfft(batch_y, dim = -1)
                loss_direct = criterion(val_output, batch_y)
                loss_real = criterion(output_fft.real, batch_y_fft.real)
                val_loss += (loss_real + 5*loss_direct).item()

        val_loss_history.append(val_loss / len(test_loader))

        print(
            f"EPOCH {epoch}: "
            f"train_loss: {loss_history[-1]:.3e} \t "
            f"test_loss: {val_loss_history[-1]:.3e}"
        )

    return loss_history, val_loss_history

# %%
def make_decay_fn(factor: float, 
                  interval: int):
    return lambda step: factor ** (step // interval)

# %% [markdown]
# ## Postprocessing

# %%
def plot_results(model, x, y, name):

    fig, axes = plt.subplots(4, 4, figsize=(10, 10))
    axes = axes.flatten()
    for i in range(16):
        pred = model(x[i:i+1].to(device))[0].cpu().detach().numpy()
        ax1 = axes[i]

        ax1.plot(y[i, 0, :].cpu().detach().numpy(), color='tab:orange', label='Ground Truth' if i == 0 else "")
        ax1.plot(pred[0], color='tab:green', label='Prediction' if i == 0 else "")
        ax1.set_xticks([])
        ax1.set_yticks([])

    fig.suptitle(name, fontsize=22, y=0.98)

    fig.legend(loc='upper center', bbox_to_anchor=(0.5, 0.95), ncol=2, fontsize=16)

    plt.tight_layout(rect=[0, 0, 1, 0.95])  
    plt.show()

def plot_loss(loss, val, barometer = None):

    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(loss, label="train loss")
    ax.plot(val, label="val loss")
    if barometer is not None:
        ax.hlines(barometer, xmin = 0, xmax = len(loss), color = 'red', linestyle = '--')
    ax.legend(fontsize=14)
    ax.set_yscale("log")
    ax.grid(True)
    ax.tick_params(axis='both', which='major', labelsize=14)
    fig.suptitle("Loss History", fontsize=18)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Training

# %%
in_channels = train_x_norm.shape[1]
width = 64
out_channels = 1

lift_network = Projection_NN(
                input_dim = in_channels,
                output_dim = width,
                width = 64,
                depth = 2,
                activation = torch.nn.GELU(),
            )

decode_network = Projection_NN(
                input_dim = width,
                output_dim = out_channels,
                width = 64,
                depth = 2,
                activation = torch.nn.GELU(),
            )

model = FNO1d(
        in_channels=in_channels,
        out_channels=out_channels,
        modes = 12,
        width=width,
        block_activation=torch.nn.Mish(),
        n_blocks=8,
        padding=53,
        lift_network=lift_network,
        decode_network=decode_network,
        ).to(device)


lr = 1e-3

optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)

scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda= make_decay_fn(0.999, 100))

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

loss_history, val_loss_history = [], []

loss_history, val_loss_history = train_loop(model, train_loader, test_loader,
                                            500, optimizer, scheduler,
                                            mixed_training=([1,2,3],[0.6,0.3,0.1]),
                                            add_noise = (0.025,),
                                            clip_grad = True)

torch.save(model, 'best_model_full_data.pt')
# Out:
# EPOCH 0: train_loss: 6.067e-01 	 test_loss: 6.021e-01
# EPOCH 1: train_loss: 4.695e-01 	 test_loss: 5.676e-01
# EPOCH 2: train_loss: 5.116e-01 	 test_loss: 5.218e-01
# EPOCH 3: train_loss: 4.888e-01 	 test_loss: 5.351e-01
# EPOCH 4: train_loss: 4.734e-01 	 test_loss: 5.093e-01
# EPOCH 5: train_loss: 5.553e-01 	 test_loss: 4.597e-01
# EPOCH 6: train_loss: 4.350e-01 	 test_loss: 4.329e-01
# EPOCH 7: train_loss: 4.197e-01 	 test_loss: 3.548e-01
# EPOCH 8: train_loss: 7.174e-01 	 test_loss: 5.756e-01
# EPOCH 9: train_loss: 3.810e-01 	 test_loss: 2.801e-01
# EPOCH 10: train_loss: 2.625e-01 	 test_loss: 3.047e-01
# EPOCH 11: train_loss: 2.726e-01 	 test_loss: 3.744e-01
# EPOCH 12: train_loss: 3.236e-01 	 test_loss: 3.421e-01
# EPOCH 13: train_loss: 2.893e-01 	 test_loss: 2.451e-01
# EPOCH 14: train_loss: 3.485e-01 	 test_loss: 2.774e-01
# EPOCH 15: train_loss: 2.697e-01 	 test_loss: 2.354e-01
# EPOCH 16: train_loss: 2.716e-01 	 test_loss: 2.158e-01
# EPOCH 17: train_loss: 2.566e-01 	 test_loss: 2.604e-01
# EPOCH 18: train_loss: 2.782e-01 	 test_loss: 2.697e-01
# EPOCH 19: train_loss: 2.660e-01 	 test_loss: 3.315e-01
# EPOCH 20: train_loss: 2.643e-01 	 test_loss: 2.272e-01
# EPOCH 21: train_loss: 2.615e-01 	 test_loss: 2.492e-01
# EPOCH 22: train_loss: 2.681e-01 	 test_loss: 2.030e-01
# EPOCH 23: train_loss: 2.730e-01 	 test_loss: 2.282e-01
# EPOCH 24: train_loss: 4.402e-01 	 test_loss: 4.809e-01
# EPOCH 25: train_loss: 2.429e-01 	 test_loss: 1.941e-01
# EPOCH 26: train_loss: 2.422e-01 	 test_loss: 4.414e-01
# EPOCH 27: train_loss: 2.401e-01 	 test_loss: 1.818e-01
# EPOCH 28: train_loss: 1.858e-01 	 test_loss: 1.587e-01
# EPOCH 29: train_loss: 1.699e-01 	 test_loss: 2.235e-01
# EPOCH 30: train_loss: 1.858e-01 	 test_loss: 2.088e-01
# EPOCH 31: train_loss: 3.067e-01 	 test_loss: 2.016e-01
# EPOCH 32: train_loss: 1.985e-01 	 test_loss: 1.900e-01
# EPOCH 33: train_loss: 1.405e-01 	 test_loss: 1.620e-01
# EPOCH 34: train_loss: 1.654e-01 	 test_loss: 1.592e-01
# EPOCH 35: train_loss: 1.362e-01 	 test_loss: 2.420e-01
# EPOCH 36: train_loss: 1.472e-01 	 test_loss: 1.301e-01
# EPOCH 37: train_loss: 1.998e-01 	 test_loss: 5.793e-01
# EPOCH 38: train_loss: 2.623e-01 	 test_loss: 3.575e-01
# EPOCH 39: train_loss: 2.051e-01 	 test_loss: 4.922e-01
# EPOCH 40: train_loss: 1.974e-01 	 test_loss: 2.183e-01
# EPOCH 41: train_loss: 1.929e-01 	 test_loss: 1.225e-01
# EPOCH 42: train_loss: 1.553e-01 	 test_loss: 1.263e-01
# EPOCH 43: train_loss: 2.028e-01 	 test_loss: 1.903e-01
# EPOCH 44: train_loss: 1.764e-01 	 test_loss: 1.628e-01
# EPOCH 45: train_loss: 1.270e-01 	 test_loss: 1.346e-01
# EPOCH 46: train_loss: 1.475e-01 	 test_loss: 1.303e-01
# EPOCH 47: train_loss: 1.358e-01 	 test_loss: 1.747e-01
# EPOCH 48: train_loss: 1.342e-01 	 test_loss: 1.191e-01
# EPOCH 49: train_loss: 1.167e-01 	 test_loss: 1.341e-01
# EPOCH 50: train_loss: 1.689e-01 	 test_loss: 1.991e-01
# EPOCH 51: train_loss: 1.651e-01 	 test_loss: 1.744e-01
# EPOCH 52: train_loss: 1.289e-01 	 test_loss: 1.526e-01
# EPOCH 53: train_loss: 1.227e-01 	 test_loss: 2.583e-01
# EPOCH 54: train_loss: 1.350e-01 	 test_loss: 1.833e-01
# EPOCH 55: train_loss: 1.510e-01 	 test_loss: 1.628e-01
# EPOCH 56: train_loss: 1.128e-01 	 test_loss: 2.338e-01
# EPOCH 57: train_loss: 1.069e-01 	 test_loss: 1.249e-01
# EPOCH 58: train_loss: 1.722e-01 	 test_loss: 1.471e-01
# EPOCH 59: train_loss: 1.748e-01 	 test_loss: 1.275e-01
# EPOCH 60: train_loss: 1.114e-01 	 test_loss: 1.100e-01
# EPOCH 61: train_loss: 1.064e-01 	 test_loss: 8.986e-02
# EPOCH 62: train_loss: 8.105e-02 	 test_loss: 8.794e-02
# EPOCH 63: train_loss: 6.983e-02 	 test_loss: 8.349e-02
# EPOCH 64: train_loss: 9.357e-02 	 test_loss: 9.445e-02
# EPOCH 65: train_loss: 1.611e-01 	 test_loss: 3.034e-01
# EPOCH 66: train_loss: 1.854e-01 	 test_loss: 1.260e-01
# EPOCH 67: train_loss: 1.042e-01 	 test_loss: 1.065e-01
# EPOCH 68: train_loss: 9.125e-02 	 test_loss: 9.592e-02
# EPOCH 69: train_loss: 8.048e-02 	 test_loss: 7.430e-02
# EPOCH 70: train_loss: 8.455e-02 	 test_loss: 6.310e-02
# EPOCH 71: train_loss: 8.174e-02 	 test_loss: 8.236e-02
# EPOCH 72: train_loss: 7.038e-02 	 test_loss: 6.008e-02
# EPOCH 73: train_loss: 1.210e-01 	 test_loss: 1.612e-01
# EPOCH 74: train_loss: 9.781e-02 	 test_loss: 6.262e-02
# EPOCH 75: train_loss: 7.588e-02 	 test_loss: 9.717e-02
# EPOCH 76: train_loss: 9.093e-02 	 test_loss: 1.096e-01
# EPOCH 77: train_loss: 1.080e-01 	 test_loss: 2.329e-01
# EPOCH 78: train_loss: 1.606e-01 	 test_loss: 1.522e-01
# EPOCH 79: train_loss: 1.195e-01 	 test_loss: 1.054e-01
# EPOCH 80: train_loss: 1.165e-01 	 test_loss: 1.248e-01
# EPOCH 81: train_loss: 1.016e-01 	 test_loss: 6.698e-02
# EPOCH 82: train_loss: 6.927e-02 	 test_loss: 7.737e-02
# EPOCH 83: train_loss: 6.571e-02 	 test_loss: 7.731e-02
# EPOCH 84: train_loss: 7.081e-02 	 test_loss: 6.762e-02
# EPOCH 85: train_loss: 9.273e-02 	 test_loss: 1.640e-01
# EPOCH 86: train_loss: 9.754e-02 	 test_loss: 9.467e-02
# EPOCH 87: train_loss: 9.326e-02 	 test_loss: 9.657e-02
# EPOCH 88: train_loss: 6.435e-02 	 test_loss: 9.950e-02
# EPOCH 89: train_loss: 7.631e-02 	 test_loss: 8.288e-02
# EPOCH 90: train_loss: 8.297e-02 	 test_loss: 7.559e-02
# EPOCH 91: train_loss: 7.041e-02 	 test_loss: 1.938e-01
# EPOCH 92: train_loss: 1.187e-01 	 test_loss: 1.487e-01
# EPOCH 93: train_loss: 1.377e-01 	 test_loss: 1.693e-01
# EPOCH 94: train_loss: 1.047e-01 	 test_loss: 8.028e-02
# EPOCH 95: train_loss: 6.577e-02 	 test_loss: 8.224e-02
# EPOCH 96: train_loss: 6.953e-02 	 test_loss: 6.108e-02
# EPOCH 97: train_loss: 6.954e-02 	 test_loss: 6.224e-02
# EPOCH 98: train_loss: 5.578e-02 	 test_loss: 6.609e-02
# EPOCH 99: train_loss: 5.433e-02 	 test_loss: 5.856e-02
# EPOCH 100: train_loss: 7.046e-02 	 test_loss: 7.998e-02
# EPOCH 101: train_loss: 7.155e-02 	 test_loss: 6.770e-02
# EPOCH 102: train_loss: 5.909e-02 	 test_loss: 5.381e-02
# EPOCH 103: train_loss: 5.499e-02 	 test_loss: 7.183e-02
# EPOCH 104: train_loss: 6.326e-02 	 test_loss: 9.010e-02
# EPOCH 105: train_loss: 6.923e-02 	 test_loss: 9.804e-02
# EPOCH 106: train_loss: 8.440e-02 	 test_loss: 6.523e-02
# EPOCH 107: train_loss: 5.867e-02 	 test_loss: 5.289e-02
# EPOCH 108: train_loss: 5.589e-02 	 test_loss: 4.725e-02
# EPOCH 109: train_loss: 6.539e-02 	 test_loss: 8.875e-02
# EPOCH 110: train_loss: 8.085e-02 	 test_loss: 8.209e-02
# EPOCH 111: train_loss: 5.290e-02 	 test_loss: 5.889e-02
# EPOCH 112: train_loss: 4.409e-02 	 test_loss: 4.540e-02
# EPOCH 113: train_loss: 4.480e-02 	 test_loss: 4.234e-02
# EPOCH 114: train_loss: 3.975e-02 	 test_loss: 5.172e-02
# EPOCH 115: train_loss: 4.672e-02 	 test_loss: 4.503e-02
# EPOCH 116: train_loss: 4.131e-02 	 test_loss: 4.464e-02
# EPOCH 117: train_loss: 6.120e-02 	 test_loss: 8.530e-02
# EPOCH 118: train_loss: 8.155e-02 	 test_loss: 4.917e-02
# EPOCH 119: train_loss: 4.997e-02 	 test_loss: 7.276e-02
# EPOCH 120: train_loss: 5.473e-02 	 test_loss: 4.623e-02
# EPOCH 121: train_loss: 5.509e-02 	 test_loss: 5.531e-02
# EPOCH 122: train_loss: 4.480e-02 	 test_loss: 4.595e-02
# EPOCH 123: train_loss: 5.843e-02 	 test_loss: 8.347e-02
# EPOCH 124: train_loss: 5.879e-02 	 test_loss: 5.251e-02
# EPOCH 125: train_loss: 5.155e-02 	 test_loss: 5.367e-02
# EPOCH 126: train_loss: 6.083e-02 	 test_loss: 5.625e-02
# EPOCH 127: train_loss: 6.383e-02 	 test_loss: 6.153e-02
# EPOCH 128: train_loss: 6.264e-02 	 test_loss: 1.217e-01
# EPOCH 129: train_loss: 7.660e-02 	 test_loss: 5.114e-02
# EPOCH 130: train_loss: 6.685e-02 	 test_loss: 9.306e-02
# EPOCH 131: train_loss: 4.323e-02 	 test_loss: 5.226e-02
# EPOCH 132: train_loss: 5.308e-02 	 test_loss: 5.172e-02
# EPOCH 133: train_loss: 4.257e-02 	 test_loss: 4.645e-02
# EPOCH 134: train_loss: 4.092e-02 	 test_loss: 4.468e-02
# EPOCH 135: train_loss: 3.525e-02 	 test_loss: 3.836e-02
# EPOCH 136: train_loss: 4.927e-02 	 test_loss: 5.971e-02
# EPOCH 137: train_loss: 4.926e-02 	 test_loss: 5.318e-02
# EPOCH 138: train_loss: 4.053e-02 	 test_loss: 4.314e-02
# EPOCH 139: train_loss: 3.921e-02 	 test_loss: 5.765e-02
# EPOCH 140: train_loss: 4.142e-02 	 test_loss: 4.803e-02
# EPOCH 141: train_loss: 5.032e-02 	 test_loss: 7.240e-02
# EPOCH 142: train_loss: 5.110e-02 	 test_loss: 5.752e-02
# EPOCH 143: train_loss: 5.367e-02 	 test_loss: 6.681e-02
# EPOCH 144: train_loss: 6.328e-02 	 test_loss: 5.678e-02
# EPOCH 145: train_loss: 4.345e-02 	 test_loss: 5.377e-02
# EPOCH 146: train_loss: 3.893e-02 	 test_loss: 6.556e-02
# EPOCH 147: train_loss: 4.168e-02 	 test_loss: 6.925e-02
# EPOCH 148: train_loss: 5.502e-02 	 test_loss: 5.449e-02
# EPOCH 149: train_loss: 5.317e-02 	 test_loss: 3.872e-02
# EPOCH 150: train_loss: 4.978e-02 	 test_loss: 4.569e-02
# EPOCH 151: train_loss: 4.743e-02 	 test_loss: 5.460e-02
# EPOCH 152: train_loss: 4.161e-02 	 test_loss: 6.101e-02
# EPOCH 153: train_loss: 5.696e-02 	 test_loss: 5.893e-02
# EPOCH 154: train_loss: 3.829e-02 	 test_loss: 4.564e-02
# EPOCH 155: train_loss: 4.073e-02 	 test_loss: 4.210e-02
# EPOCH 156: train_loss: 3.641e-02 	 test_loss: 4.262e-02
# EPOCH 157: train_loss: 3.086e-02 	 test_loss: 5.120e-02
# EPOCH 158: train_loss: 4.025e-02 	 test_loss: 5.640e-02
# EPOCH 159: train_loss: 3.628e-02 	 test_loss: 4.445e-02
# EPOCH 160: train_loss: 3.804e-02 	 test_loss: 6.335e-02
# EPOCH 161: train_loss: 3.595e-02 	 test_loss: 4.935e-02
# EPOCH 162: train_loss: 3.581e-02 	 test_loss: 4.103e-02
# EPOCH 163: train_loss: 5.011e-02 	 test_loss: 7.471e-02
# EPOCH 164: train_loss: 6.874e-02 	 test_loss: 1.306e-01
# EPOCH 165: train_loss: 5.058e-02 	 test_loss: 5.452e-02
# EPOCH 166: train_loss: 3.594e-02 	 test_loss: 4.446e-02
# EPOCH 167: train_loss: 3.281e-02 	 test_loss: 4.804e-02
# EPOCH 168: train_loss: 3.296e-02 	 test_loss: 3.853e-02
# EPOCH 169: train_loss: 3.040e-02 	 test_loss: 4.654e-02
# EPOCH 170: train_loss: 3.915e-02 	 test_loss: 5.094e-02
# EPOCH 171: train_loss: 3.062e-02 	 test_loss: 4.064e-02
# EPOCH 172: train_loss: 3.324e-02 	 test_loss: 4.633e-02
# EPOCH 173: train_loss: 4.977e-02 	 test_loss: 8.142e-02
# EPOCH 174: train_loss: 4.768e-02 	 test_loss: 1.053e-01
# EPOCH 175: train_loss: 4.960e-02 	 test_loss: 6.228e-02
# EPOCH 176: train_loss: 3.618e-02 	 test_loss: 4.569e-02
# EPOCH 177: train_loss: 3.866e-02 	 test_loss: 5.121e-02
# EPOCH 178: train_loss: 4.804e-02 	 test_loss: 1.007e-01
# EPOCH 179: train_loss: 4.768e-02 	 test_loss: 7.327e-02
# EPOCH 180: train_loss: 3.479e-02 	 test_loss: 6.192e-02
# EPOCH 181: train_loss: 4.140e-02 	 test_loss: 5.750e-02
# EPOCH 182: train_loss: 3.912e-02 	 test_loss: 6.116e-02
# EPOCH 183: train_loss: 4.134e-02 	 test_loss: 7.620e-02
# EPOCH 184: train_loss: 5.689e-02 	 test_loss: 9.486e-02
# EPOCH 185: train_loss: 4.651e-02 	 test_loss: 4.960e-02
# EPOCH 186: train_loss: 3.443e-02 	 test_loss: 4.208e-02
# EPOCH 187: train_loss: 3.445e-02 	 test_loss: 4.642e-02
# EPOCH 188: train_loss: 2.882e-02 	 test_loss: 4.003e-02
# EPOCH 189: train_loss: 2.636e-02 	 test_loss: 3.513e-02
# EPOCH 190: train_loss: 2.854e-02 	 test_loss: 4.216e-02
# EPOCH 191: train_loss: 3.165e-02 	 test_loss: 4.627e-02
# EPOCH 192: train_loss: 3.526e-02 	 test_loss: 4.588e-02
# EPOCH 193: train_loss: 3.156e-02 	 test_loss: 5.455e-02
# EPOCH 194: train_loss: 3.438e-02 	 test_loss: 5.241e-02
# EPOCH 195: train_loss: 3.506e-02 	 test_loss: 4.595e-02
# EPOCH 196: train_loss: 3.016e-02 	 test_loss: 3.798e-02
# EPOCH 197: train_loss: 2.776e-02 	 test_loss: 3.850e-02
# EPOCH 198: train_loss: 2.592e-02 	 test_loss: 7.954e-02
# EPOCH 199: train_loss: 4.935e-02 	 test_loss: 5.320e-02
# EPOCH 200: train_loss: 3.684e-02 	 test_loss: 3.590e-02
# EPOCH 201: train_loss: 3.647e-02 	 test_loss: 6.308e-02
# EPOCH 202: train_loss: 4.827e-02 	 test_loss: 6.070e-02
# EPOCH 203: train_loss: 5.999e-02 	 test_loss: 6.247e-02
# EPOCH 204: train_loss: 5.642e-02 	 test_loss: 5.434e-02
# EPOCH 205: train_loss: 3.376e-02 	 test_loss: 4.152e-02
# EPOCH 206: train_loss: 3.353e-02 	 test_loss: 4.519e-02
# EPOCH 207: train_loss: 2.713e-02 	 test_loss: 4.237e-02
# EPOCH 208: train_loss: 2.863e-02 	 test_loss: 4.137e-02
# EPOCH 209: train_loss: 2.645e-02 	 test_loss: 3.898e-02
# EPOCH 210: train_loss: 2.841e-02 	 test_loss: 4.702e-02
# EPOCH 211: train_loss: 2.525e-02 	 test_loss: 3.726e-02
# EPOCH 212: train_loss: 3.134e-02 	 test_loss: 4.492e-02
# EPOCH 213: train_loss: 2.954e-02 	 test_loss: 6.424e-02
# EPOCH 214: train_loss: 4.016e-02 	 test_loss: 9.414e-02
# EPOCH 215: train_loss: 5.875e-02 	 test_loss: 4.917e-02
# EPOCH 216: train_loss: 3.364e-02 	 test_loss: 4.977e-02
# EPOCH 217: train_loss: 3.140e-02 	 test_loss: 3.836e-02
# EPOCH 218: train_loss: 3.105e-02 	 test_loss: 6.222e-02
# EPOCH 219: train_loss: 2.824e-02 	 test_loss: 4.727e-02
# EPOCH 220: train_loss: 3.075e-02 	 test_loss: 4.841e-02
# EPOCH 221: train_loss: 3.725e-02 	 test_loss: 5.226e-02
# EPOCH 222: train_loss: 4.878e-02 	 test_loss: 7.395e-02
# EPOCH 223: train_loss: 4.969e-02 	 test_loss: 6.022e-02
# EPOCH 224: train_loss: 3.389e-02 	 test_loss: 4.600e-02
# EPOCH 225: train_loss: 2.538e-02 	 test_loss: 4.198e-02
# EPOCH 226: train_loss: 2.748e-02 	 test_loss: 4.839e-02
# EPOCH 227: train_loss: 2.767e-02 	 test_loss: 3.803e-02
# EPOCH 228: train_loss: 2.487e-02 	 test_loss: 3.599e-02
# EPOCH 229: train_loss: 2.334e-02 	 test_loss: 3.949e-02
# EPOCH 230: train_loss: 2.919e-02 	 test_loss: 4.867e-02
# EPOCH 231: train_loss: 3.152e-02 	 test_loss: 4.829e-02
# EPOCH 232: train_loss: 3.073e-02 	 test_loss: 4.015e-02
# EPOCH 233: train_loss: 3.027e-02 	 test_loss: 4.201e-02
# EPOCH 234: train_loss: 2.517e-02 	 test_loss: 4.179e-02
# EPOCH 235: train_loss: 3.566e-02 	 test_loss: 5.077e-02
# EPOCH 236: train_loss: 3.940e-02 	 test_loss: 5.090e-02
# EPOCH 237: train_loss: 3.970e-02 	 test_loss: 5.405e-02
# EPOCH 238: train_loss: 2.988e-02 	 test_loss: 4.329e-02
# EPOCH 239: train_loss: 2.509e-02 	 test_loss: 4.622e-02
# EPOCH 240: train_loss: 2.713e-02 	 test_loss: 3.675e-02
# EPOCH 241: train_loss: 2.819e-02 	 test_loss: 5.482e-02
# EPOCH 242: train_loss: 3.418e-02 	 test_loss: 4.849e-02
# EPOCH 243: train_loss: 3.317e-02 	 test_loss: 4.319e-02
# EPOCH 244: train_loss: 2.601e-02 	 test_loss: 5.020e-02
# EPOCH 245: train_loss: 2.563e-02 	 test_loss: 4.468e-02
# EPOCH 246: train_loss: 2.457e-02 	 test_loss: 4.632e-02
# EPOCH 247: train_loss: 3.050e-02 	 test_loss: 5.149e-02
# EPOCH 248: train_loss: 3.396e-02 	 test_loss: 4.718e-02
# EPOCH 249: train_loss: 2.936e-02 	 test_loss: 4.256e-02
# EPOCH 250: train_loss: 3.023e-02 	 test_loss: 4.228e-02
# EPOCH 251: train_loss: 2.244e-02 	 test_loss: 5.104e-02
# EPOCH 252: train_loss: 2.387e-02 	 test_loss: 4.575e-02
# EPOCH 253: train_loss: 2.698e-02 	 test_loss: 4.018e-02
# EPOCH 254: train_loss: 2.874e-02 	 test_loss: 6.133e-02
# EPOCH 255: train_loss: 3.699e-02 	 test_loss: 4.233e-02
# EPOCH 256: train_loss: 3.471e-02 	 test_loss: 3.955e-02
# EPOCH 257: train_loss: 2.764e-02 	 test_loss: 4.026e-02
# EPOCH 258: train_loss: 3.096e-02 	 test_loss: 5.478e-02
# EPOCH 259: train_loss: 2.430e-02 	 test_loss: 3.781e-02
# EPOCH 260: train_loss: 1.973e-02 	 test_loss: 3.765e-02
# EPOCH 261: train_loss: 3.353e-02 	 test_loss: 6.266e-02
# EPOCH 262: train_loss: 3.093e-02 	 test_loss: 4.957e-02
# EPOCH 263: train_loss: 3.487e-02 	 test_loss: 5.644e-02
# EPOCH 264: train_loss: 3.646e-02 	 test_loss: 5.064e-02
# EPOCH 265: train_loss: 4.116e-02 	 test_loss: 4.952e-02
# EPOCH 266: train_loss: 3.371e-02 	 test_loss: 5.514e-02
# EPOCH 267: train_loss: 2.629e-02 	 test_loss: 4.157e-02
# EPOCH 268: train_loss: 2.267e-02 	 test_loss: 4.516e-02
# EPOCH 269: train_loss: 2.445e-02 	 test_loss: 4.030e-02
# EPOCH 270: train_loss: 2.073e-02 	 test_loss: 3.720e-02
# EPOCH 271: train_loss: 2.268e-02 	 test_loss: 3.636e-02
# EPOCH 272: train_loss: 2.298e-02 	 test_loss: 4.053e-02
# EPOCH 273: train_loss: 2.715e-02 	 test_loss: 4.896e-02
# EPOCH 274: train_loss: 2.337e-02 	 test_loss: 4.193e-02
# EPOCH 275: train_loss: 2.067e-02 	 test_loss: 4.412e-02
# EPOCH 276: train_loss: 2.139e-02 	 test_loss: 4.010e-02
# EPOCH 277: train_loss: 2.824e-02 	 test_loss: 4.462e-02
# EPOCH 278: train_loss: 2.444e-02 	 test_loss: 3.887e-02
# EPOCH 279: train_loss: 3.306e-02 	 test_loss: 4.840e-02
# EPOCH 280: train_loss: 2.994e-02 	 test_loss: 3.842e-02
# EPOCH 281: train_loss: 2.697e-02 	 test_loss: 3.994e-02
# EPOCH 282: train_loss: 2.675e-02 	 test_loss: 4.564e-02
# EPOCH 283: train_loss: 3.106e-02 	 test_loss: 7.005e-02
# EPOCH 284: train_loss: 2.757e-02 	 test_loss: 4.670e-02
# EPOCH 285: train_loss: 2.187e-02 	 test_loss: 4.467e-02
# EPOCH 286: train_loss: 2.228e-02 	 test_loss: 4.515e-02
# EPOCH 287: train_loss: 2.242e-02 	 test_loss: 3.910e-02
# EPOCH 288: train_loss: 1.981e-02 	 test_loss: 3.967e-02
# EPOCH 289: train_loss: 2.454e-02 	 test_loss: 4.021e-02
# EPOCH 290: train_loss: 1.999e-02 	 test_loss: 3.859e-02
# EPOCH 291: train_loss: 2.372e-02 	 test_loss: 4.201e-02
# EPOCH 292: train_loss: 2.908e-02 	 test_loss: 4.955e-02
# EPOCH 293: train_loss: 2.237e-02 	 test_loss: 3.660e-02
# EPOCH 294: train_loss: 2.164e-02 	 test_loss: 3.847e-02
# EPOCH 295: train_loss: 2.094e-02 	 test_loss: 4.230e-02
# EPOCH 296: train_loss: 2.467e-02 	 test_loss: 4.153e-02
# EPOCH 297: train_loss: 3.096e-02 	 test_loss: 4.172e-02
# EPOCH 298: train_loss: 2.082e-02 	 test_loss: 3.992e-02
# EPOCH 299: train_loss: 2.093e-02 	 test_loss: 3.897e-02
# EPOCH 300: train_loss: 1.792e-02 	 test_loss: 3.558e-02
# EPOCH 301: train_loss: 1.812e-02 	 test_loss: 3.744e-02
# EPOCH 302: train_loss: 1.916e-02 	 test_loss: 3.733e-02
# EPOCH 303: train_loss: 2.324e-02 	 test_loss: 4.599e-02
# EPOCH 304: train_loss: 1.929e-02 	 test_loss: 3.715e-02
# EPOCH 305: train_loss: 2.220e-02 	 test_loss: 3.887e-02
# EPOCH 306: train_loss: 5.450e-02 	 test_loss: 5.700e-02
# EPOCH 307: train_loss: 2.604e-02 	 test_loss: 4.211e-02
# EPOCH 308: train_loss: 2.057e-02 	 test_loss: 4.241e-02
# EPOCH 309: train_loss: 2.337e-02 	 test_loss: 5.028e-02
# EPOCH 310: train_loss: 2.829e-02 	 test_loss: 4.367e-02
# EPOCH 311: train_loss: 2.705e-02 	 test_loss: 4.025e-02
# EPOCH 312: train_loss: 2.015e-02 	 test_loss: 5.273e-02
# EPOCH 313: train_loss: 1.810e-02 	 test_loss: 4.200e-02
# EPOCH 314: train_loss: 2.264e-02 	 test_loss: 5.137e-02
# EPOCH 315: train_loss: 2.023e-02 	 test_loss: 3.720e-02
# EPOCH 316: train_loss: 2.060e-02 	 test_loss: 4.849e-02
# EPOCH 317: train_loss: 2.395e-02 	 test_loss: 5.301e-02
# EPOCH 318: train_loss: 2.130e-02 	 test_loss: 3.763e-02
# EPOCH 319: train_loss: 2.295e-02 	 test_loss: 4.173e-02
# EPOCH 320: train_loss: 1.906e-02 	 test_loss: 3.916e-02
# EPOCH 321: train_loss: 1.729e-02 	 test_loss: 3.714e-02
# EPOCH 322: train_loss: 1.641e-02 	 test_loss: 4.170e-02
# EPOCH 323: train_loss: 1.817e-02 	 test_loss: 4.166e-02
# EPOCH 324: train_loss: 2.026e-02 	 test_loss: 4.419e-02
# EPOCH 325: train_loss: 2.295e-02 	 test_loss: 4.237e-02
# EPOCH 326: train_loss: 1.972e-02 	 test_loss: 4.017e-02
# EPOCH 327: train_loss: 1.865e-02 	 test_loss: 4.072e-02
# EPOCH 328: train_loss: 2.235e-02 	 test_loss: 3.640e-02
# EPOCH 329: train_loss: 2.701e-02 	 test_loss: 4.455e-02
# EPOCH 330: train_loss: 2.319e-02 	 test_loss: 8.689e-02
# EPOCH 331: train_loss: 2.766e-02 	 test_loss: 4.848e-02
# EPOCH 332: train_loss: 2.548e-02 	 test_loss: 4.303e-02
# EPOCH 333: train_loss: 2.157e-02 	 test_loss: 4.241e-02
# EPOCH 334: train_loss: 2.273e-02 	 test_loss: 3.801e-02
# EPOCH 335: train_loss: 2.158e-02 	 test_loss: 5.332e-02
# EPOCH 336: train_loss: 2.000e-02 	 test_loss: 3.796e-02
# EPOCH 337: train_loss: 1.731e-02 	 test_loss: 5.376e-02
# EPOCH 338: train_loss: 1.911e-02 	 test_loss: 3.632e-02
# EPOCH 339: train_loss: 1.695e-02 	 test_loss: 4.287e-02
# EPOCH 340: train_loss: 2.041e-02 	 test_loss: 4.720e-02
# EPOCH 341: train_loss: 2.057e-02 	 test_loss: 3.734e-02
# EPOCH 342: train_loss: 1.969e-02 	 test_loss: 4.208e-02
# EPOCH 343: train_loss: 2.074e-02 	 test_loss: 4.064e-02
# EPOCH 344: train_loss: 1.548e-02 	 test_loss: 3.608e-02
# EPOCH 345: train_loss: 2.239e-02 	 test_loss: 4.155e-02
# EPOCH 346: train_loss: 2.200e-02 	 test_loss: 5.821e-02
# EPOCH 347: train_loss: 2.915e-02 	 test_loss: 4.301e-02
# EPOCH 348: train_loss: 2.675e-02 	 test_loss: 5.971e-02
# EPOCH 349: train_loss: 2.472e-02 	 test_loss: 4.276e-02
# EPOCH 350: train_loss: 1.758e-02 	 test_loss: 3.921e-02
# EPOCH 351: train_loss: 2.110e-02 	 test_loss: 4.977e-02
# EPOCH 352: train_loss: 2.488e-02 	 test_loss: 5.266e-02
# EPOCH 353: train_loss: 1.971e-02 	 test_loss: 4.425e-02
# EPOCH 354: train_loss: 1.536e-02 	 test_loss: 4.215e-02
# EPOCH 355: train_loss: 1.608e-02 	 test_loss: 4.592e-02
# EPOCH 356: train_loss: 1.884e-02 	 test_loss: 4.287e-02
# EPOCH 357: train_loss: 1.859e-02 	 test_loss: 4.298e-02
# EPOCH 358: train_loss: 2.189e-02 	 test_loss: 4.618e-02
# EPOCH 359: train_loss: 2.787e-02 	 test_loss: 4.384e-02
# EPOCH 360: train_loss: 2.837e-02 	 test_loss: 5.793e-02
# EPOCH 361: train_loss: 3.262e-02 	 test_loss: 4.591e-02
# EPOCH 362: train_loss: 2.288e-02 	 test_loss: 4.172e-02
# EPOCH 363: train_loss: 2.013e-02 	 test_loss: 5.604e-02
# EPOCH 364: train_loss: 2.825e-02 	 test_loss: 5.541e-02
# EPOCH 365: train_loss: 3.592e-02 	 test_loss: 7.825e-02
# EPOCH 366: train_loss: 3.198e-02 	 test_loss: 5.065e-02
# EPOCH 367: train_loss: 2.091e-02 	 test_loss: 5.296e-02
# EPOCH 368: train_loss: 1.984e-02 	 test_loss: 4.575e-02
# EPOCH 369: train_loss: 1.930e-02 	 test_loss: 5.135e-02
# EPOCH 370: train_loss: 2.294e-02 	 test_loss: 4.629e-02
# EPOCH 371: train_loss: 2.342e-02 	 test_loss: 4.978e-02
# EPOCH 372: train_loss: 1.968e-02 	 test_loss: 3.998e-02
# EPOCH 373: train_loss: 2.441e-02 	 test_loss: 4.956e-02
# EPOCH 374: train_loss: 2.405e-02 	 test_loss: 3.946e-02
# EPOCH 375: train_loss: 1.783e-02 	 test_loss: 4.994e-02
# EPOCH 376: train_loss: 2.057e-02 	 test_loss: 3.993e-02
# EPOCH 377: train_loss: 1.735e-02 	 test_loss: 3.693e-02
# EPOCH 378: train_loss: 2.218e-02 	 test_loss: 3.989e-02
# EPOCH 379: train_loss: 1.786e-02 	 test_loss: 3.535e-02
# EPOCH 380: train_loss: 2.083e-02 	 test_loss: 3.734e-02
# EPOCH 381: train_loss: 2.520e-02 	 test_loss: 4.803e-02
# EPOCH 382: train_loss: 2.610e-02 	 test_loss: 3.782e-02
# EPOCH 383: train_loss: 1.429e-02 	 test_loss: 3.947e-02
# EPOCH 384: train_loss: 1.410e-02 	 test_loss: 3.790e-02
# EPOCH 385: train_loss: 1.404e-02 	 test_loss: 3.839e-02
# EPOCH 386: train_loss: 1.568e-02 	 test_loss: 3.686e-02
# EPOCH 387: train_loss: 1.664e-02 	 test_loss: 3.814e-02
# EPOCH 388: train_loss: 1.538e-02 	 test_loss: 3.599e-02
# EPOCH 389: train_loss: 1.360e-02 	 test_loss: 3.836e-02
# EPOCH 390: train_loss: 1.634e-02 	 test_loss: 4.020e-02
# EPOCH 391: train_loss: 1.680e-02 	 test_loss: 4.825e-02
# EPOCH 392: train_loss: 2.064e-02 	 test_loss: 4.177e-02
# EPOCH 393: train_loss: 1.740e-02 	 test_loss: 4.989e-02
# EPOCH 394: train_loss: 1.477e-02 	 test_loss: 4.347e-02
# EPOCH 395: train_loss: 1.550e-02 	 test_loss: 3.986e-02
# EPOCH 396: train_loss: 2.129e-02 	 test_loss: 4.432e-02
# EPOCH 397: train_loss: 1.624e-02 	 test_loss: 5.399e-02
# EPOCH 398: train_loss: 2.269e-02 	 test_loss: 4.829e-02
# EPOCH 399: train_loss: 1.747e-02 	 test_loss: 4.895e-02
# EPOCH 400: train_loss: 1.835e-02 	 test_loss: 5.931e-02
# EPOCH 401: train_loss: 1.664e-02 	 test_loss: 4.273e-02
# EPOCH 402: train_loss: 1.537e-02 	 test_loss: 5.109e-02
# EPOCH 403: train_loss: 1.747e-02 	 test_loss: 5.166e-02
# EPOCH 404: train_loss: 2.234e-02 	 test_loss: 4.838e-02
# EPOCH 405: train_loss: 1.653e-02 	 test_loss: 4.462e-02
# EPOCH 406: train_loss: 2.257e-02 	 test_loss: 4.845e-02
# EPOCH 407: train_loss: 1.650e-02 	 test_loss: 4.096e-02
# EPOCH 408: train_loss: 1.874e-02 	 test_loss: 4.616e-02
# EPOCH 409: train_loss: 1.559e-02 	 test_loss: 4.042e-02
# EPOCH 410: train_loss: 1.614e-02 	 test_loss: 4.185e-02
# EPOCH 411: train_loss: 1.762e-02 	 test_loss: 3.949e-02
# EPOCH 412: train_loss: 1.783e-02 	 test_loss: 3.974e-02
# EPOCH 413: train_loss: 1.722e-02 	 test_loss: 4.055e-02
# EPOCH 414: train_loss: 1.498e-02 	 test_loss: 4.078e-02
# EPOCH 415: train_loss: 1.465e-02 	 test_loss: 3.878e-02
# EPOCH 416: train_loss: 1.718e-02 	 test_loss: 4.385e-02
# EPOCH 417: train_loss: 1.610e-02 	 test_loss: 4.216e-02
# EPOCH 418: train_loss: 1.826e-02 	 test_loss: 4.266e-02
# EPOCH 419: train_loss: 1.384e-02 	 test_loss: 3.949e-02
# EPOCH 420: train_loss: 1.475e-02 	 test_loss: 5.469e-02
# EPOCH 421: train_loss: 1.532e-02 	 test_loss: 4.796e-02
# EPOCH 422: train_loss: 1.362e-02 	 test_loss: 4.178e-02
# EPOCH 423: train_loss: 1.260e-02 	 test_loss: 4.638e-02
# EPOCH 424: train_loss: 1.633e-02 	 test_loss: 4.201e-02
# EPOCH 425: train_loss: 1.267e-02 	 test_loss: 3.981e-02
# EPOCH 426: train_loss: 1.479e-02 	 test_loss: 4.187e-02
# EPOCH 427: train_loss: 1.398e-02 	 test_loss: 4.537e-02
# EPOCH 428: train_loss: 1.446e-02 	 test_loss: 4.359e-02
# EPOCH 429: train_loss: 1.414e-02 	 test_loss: 3.877e-02
# EPOCH 430: train_loss: 1.235e-02 	 test_loss: 4.320e-02
# EPOCH 431: train_loss: 2.015e-02 	 test_loss: 4.535e-02
# EPOCH 432: train_loss: 1.599e-02 	 test_loss: 4.515e-02
# EPOCH 433: train_loss: 1.477e-02 	 test_loss: 4.058e-02
# EPOCH 434: train_loss: 1.681e-02 	 test_loss: 4.540e-02
# EPOCH 435: train_loss: 1.615e-02 	 test_loss: 4.305e-02
# EPOCH 436: train_loss: 1.454e-02 	 test_loss: 4.652e-02
# EPOCH 437: train_loss: 1.937e-02 	 test_loss: 4.952e-02
# EPOCH 438: train_loss: 1.313e-02 	 test_loss: 4.113e-02
# EPOCH 439: train_loss: 1.392e-02 	 test_loss: 4.082e-02
# EPOCH 440: train_loss: 1.433e-02 	 test_loss: 4.901e-02
# EPOCH 441: train_loss: 2.127e-02 	 test_loss: 4.555e-02
# EPOCH 442: train_loss: 1.432e-02 	 test_loss: 4.351e-02
# EPOCH 443: train_loss: 1.307e-02 	 test_loss: 4.396e-02
# EPOCH 444: train_loss: 1.289e-02 	 test_loss: 3.920e-02
# EPOCH 445: train_loss: 1.215e-02 	 test_loss: 4.171e-02
# EPOCH 446: train_loss: 1.480e-02 	 test_loss: 4.460e-02
# EPOCH 447: train_loss: 1.537e-02 	 test_loss: 5.410e-02
# EPOCH 448: train_loss: 1.711e-02 	 test_loss: 4.209e-02
# EPOCH 449: train_loss: 1.334e-02 	 test_loss: 4.527e-02
# EPOCH 450: train_loss: 1.275e-02 	 test_loss: 4.489e-02
# EPOCH 451: train_loss: 1.329e-02 	 test_loss: 4.293e-02
# EPOCH 452: train_loss: 1.114e-02 	 test_loss: 4.795e-02
# EPOCH 453: train_loss: 1.486e-02 	 test_loss: 4.357e-02
# EPOCH 454: train_loss: 1.690e-02 	 test_loss: 4.483e-02
# EPOCH 455: train_loss: 1.345e-02 	 test_loss: 4.256e-02
# EPOCH 456: train_loss: 1.477e-02 	 test_loss: 3.960e-02
# EPOCH 457: train_loss: 1.307e-02 	 test_loss: 4.754e-02
# EPOCH 458: train_loss: 1.776e-02 	 test_loss: 4.666e-02
# EPOCH 459: train_loss: 1.333e-02 	 test_loss: 4.257e-02
# EPOCH 460: train_loss: 1.187e-02 	 test_loss: 5.097e-02
# EPOCH 461: train_loss: 1.432e-02 	 test_loss: 4.224e-02
# EPOCH 462: train_loss: 1.173e-02 	 test_loss: 4.250e-02
# EPOCH 463: train_loss: 1.205e-02 	 test_loss: 4.237e-02
# EPOCH 464: train_loss: 1.268e-02 	 test_loss: 4.240e-02
# EPOCH 465: train_loss: 1.267e-02 	 test_loss: 4.272e-02
# EPOCH 466: train_loss: 1.516e-02 	 test_loss: 4.612e-02
# EPOCH 467: train_loss: 1.370e-02 	 test_loss: 4.763e-02
# EPOCH 468: train_loss: 1.556e-02 	 test_loss: 4.370e-02
# EPOCH 469: train_loss: 1.343e-02 	 test_loss: 4.647e-02
# EPOCH 470: train_loss: 1.389e-02 	 test_loss: 5.119e-02
# EPOCH 471: train_loss: 2.098e-02 	 test_loss: 4.144e-02
# EPOCH 472: train_loss: 1.339e-02 	 test_loss: 4.528e-02
# EPOCH 473: train_loss: 1.934e-02 	 test_loss: 4.766e-02
# EPOCH 474: train_loss: 1.461e-02 	 test_loss: 4.231e-02
# EPOCH 475: train_loss: 1.245e-02 	 test_loss: 4.759e-02
# EPOCH 476: train_loss: 1.332e-02 	 test_loss: 4.146e-02
# EPOCH 477: train_loss: 1.195e-02 	 test_loss: 4.462e-02
# EPOCH 478: train_loss: 1.236e-02 	 test_loss: 5.688e-02
# EPOCH 479: train_loss: 1.854e-02 	 test_loss: 4.239e-02
# EPOCH 480: train_loss: 1.682e-02 	 test_loss: 4.133e-02
# EPOCH 481: train_loss: 1.551e-02 	 test_loss: 5.786e-02
# EPOCH 482: train_loss: 1.590e-02 	 test_loss: 4.584e-02
# EPOCH 483: train_loss: 1.476e-02 	 test_loss: 4.750e-02
# EPOCH 484: train_loss: 1.426e-02 	 test_loss: 4.820e-02
# EPOCH 485: train_loss: 1.602e-02 	 test_loss: 4.626e-02
# EPOCH 486: train_loss: 1.222e-02 	 test_loss: 4.543e-02
# EPOCH 487: train_loss: 1.243e-02 	 test_loss: 4.174e-02
# EPOCH 488: train_loss: 1.441e-02 	 test_loss: 4.268e-02
# EPOCH 489: train_loss: 1.315e-02 	 test_loss: 4.598e-02
# EPOCH 490: train_loss: 1.242e-02 	 test_loss: 4.156e-02
# EPOCH 491: train_loss: 1.234e-02 	 test_loss: 5.907e-02
# EPOCH 492: train_loss: 1.484e-02 	 test_loss: 4.708e-02
# EPOCH 493: train_loss: 2.015e-02 	 test_loss: 6.054e-02
# EPOCH 494: train_loss: 2.161e-02 	 test_loss: 5.842e-02
# EPOCH 495: train_loss: 1.911e-02 	 test_loss: 4.825e-02
# EPOCH 496: train_loss: 1.398e-02 	 test_loss: 4.251e-02
# EPOCH 497: train_loss: 1.480e-02 	 test_loss: 4.352e-02
# EPOCH 498: train_loss: 1.852e-02 	 test_loss: 5.627e-02
# EPOCH 499: train_loss: 1.475e-02 	 test_loss: 3.978e-02

# %%
plot_loss(loss_history, val_loss_history)
plot_results(model, train_x_norm, train_y_norm, "Training Set Results")
plot_results(model, test_x_norm, test_y_norm, "Testing Set Results")
