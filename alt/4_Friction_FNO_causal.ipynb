# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn
import torch.optim as optim
import torch.nn.utils as utils
import torch.nn.functional as F

import torch.fft
from typing import Callable, List, Union    

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # Loading Data and Preprocessing

# %%
features_path = "data/friction_data/features_AgingLaw_v2.csv"
targets_path = "data/friction_data/targets_AgingLaw_v2.csv"
train_samples = 700

# %%
def x_state_transform(x: np.array) -> torch.Tensor:
    return torch.Tensor(np.sqrt(np.log(1e8*x)))

def x_heal_transform(x: np.array) -> torch.Tensor:
    return (torch.abs(torch.Tensor(x) - 1e-8) < 1e-12).float()

# %%
feature = torch.Tensor(np.genfromtxt(features_path, delimiter=',')[:, np.newaxis, :])
target = torch.Tensor(np.genfromtxt(targets_path, delimiter=',')[:, np.newaxis, :])

train_x = feature[:train_samples, :, :]
train_y = target[:train_samples, :, :]
test_x = feature[train_samples:, :, :]
test_y = target[train_samples:, :, :]

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

for i, ax1 in enumerate(axes):
    # Velocity axis
    line1 = ax1.plot([i/len(train_x[i,0,:]) for i in range(len(train_x[i,0,:]))],
        train_x[i, 0, :],
        color="blue",
        label="Velocity"
    )
    ax1.set_xlabel("Normalized Time", fontsize = 14)
    ax1.set_ylabel("Velocity", color="blue", fontsize = 14)
    ax1.tick_params(axis="y", colors="blue")
    ax1.spines["left"].set_color("blue")
    ax1.set_yscale('log')

    # Friction coefficient axis
    ax2 = ax1.twinx()
    line2 = ax2.plot([i/len(train_x[i,0,:]) for i in range(len(train_x[i,0,:]))],
        train_y[i, 0, :],
        color="red",
        label=r"$\mu$"
    )
    ax2.set_ylabel(r"$\mu$", color="red", fontsize = 14)
    ax2.tick_params(axis="y", colors="red")
    ax2.spines["right"].set_color("red")

    # Combined legend
    lines = line1 + line2
    labels = [l.get_label() for l in lines]
    ax1.legend(lines, labels, loc="lower right")

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
bins = np.logspace(np.log10(feature.min()), np.log10(feature.max()), 100)
axes[0].hist(feature.flatten(), bins=bins, label = f"min: {feature.min():.2e}, max: {feature.max():.2e}")
axes[0].set_xscale('log')
axes[0].set_title("Feature Distribution")
axes[0].legend()
axes[1].hist(target.flatten(), bins=100, color = 'red', label = f"min: {target.min():.2f}, max: {target.max():.2f}")
axes[1].set_title("Target Distribution")
axes[1].legend()

plt.show()
# Out:
# /tmp/ipykernel_331135/2857547353.py:2: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   bins = np.logspace(np.log10(feature.min()), np.log10(feature.max()), 100)

# %%
train_x_norm_state = x_state_transform(train_x)
state_min, state_max = train_x_norm_state.min(), train_x_norm_state.max()
train_x_norm_state = (train_x_norm_state - state_min) / (state_max - state_min)
test_x_norm_state = x_state_transform(test_x)
test_x_norm_state = (test_x_norm_state - state_min) / (state_max - state_min)

train_x_norm_heal = x_heal_transform(train_x)
test_x_norm_heal = x_heal_transform(test_x)

# train_x_norm = torch.cat([train_x_norm_state, train_x_norm_heal], dim=1)
# test_x_norm = torch.cat([test_x_norm_state, test_x_norm_heal], dim=1)

train_x_norm = train_x_norm_state
test_x_norm = test_x_norm_state

y_min, y_max = train_y.min(), train_y.max()
# train_y_norm = (train_y - y_min)/ (y_max - y_min)
# test_y_norm = (test_y - y_min) / (y_max - y_min)
train_y_norm = train_y  / torch.abs(y_min) 
test_y_norm = test_y  / torch.abs(y_min)

train_dataset = TensorDataset(train_x_norm, train_y_norm)
test_dataset = TensorDataset(test_x_norm, test_y_norm)

print(state_min, state_max)
print(y_min, y_max)
# Out:
# tensor(0.) tensor(3.5983)
# tensor(-0.1439) tensor(0.0689)
# /tmp/ipykernel_331135/1439729241.py:2: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   return torch.Tensor(np.sqrt(np.log(1e8*x)))

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

axes = axes.flatten()
axes[0].hist(train_x_norm_state.flatten(), bins=100, color = 'blue', 
             label = f'Train: [{train_x_norm_state.min():.2f},{train_x_norm_state.max():.2f}]')
axes[0].hist(test_x_norm_state.flatten(), bins = 100, color = 'grey', 
             label = f'Test: [{test_x_norm_state.min():.2f},{test_x_norm_state.max():.2f}]')
axes[0].set_title("State Feature Distribution")
axes[0].legend()

axes[1].hist(train_x_norm_heal.flatten(), bins=100, color = 'green', 
             label = f'Train: [{train_x_norm_heal.min():.2f},{train_x_norm_heal.max():.2f}]')
axes[1].hist(test_x_norm_heal.flatten(), bins=100, color = 'grey', 
             label = f'Test: [{test_x_norm_heal.min():.2f},{test_x_norm_heal.max():.2f}]')
axes[1].set_title("Heal Feature Distribution")
axes[1].legend()

axes[2].hist(train_y_norm.flatten(), bins=100, color ='red', 
             label = f'Train: [{train_y_norm.min():.2f},{train_y_norm.max():.2f}]')
axes[2].hist(test_y_norm.flatten(), bins=100, color ='grey',
             label = f'Test: [{test_y_norm.min():.2f},{test_y_norm.max():.2f}]')
axes[2].set_title("Norm. Target Distribution")
axes[2].legend()

plt.show()

# %%
fig, axes = plt.subplots(4,4, figsize=(20, 20))
axes = axes.flatten()
for i in range(16):
    norm_time = [i/len(train_x_norm_state[i, 0, :]) for i in range(len(train_x_norm_state[i, 0, :]))]
    axes[i].plot(norm_time, train_x_norm_state[i, 0, :].numpy(), label='State')
    axes[i].plot(norm_time, train_x_norm_heal[i, 0, :].numpy(), label='Heal', color = 'green')
    axes[i].plot(norm_time, train_y_norm[i, 0, :].numpy(), label='Target', color = 'red')
    axes[i].set_title(f"Sample {i+1}")
    axes[i].set_xlabel('Normalized Time')
    axes[i].set_ylabel('Magnitude')
    axes[i].legend()

# %% [markdown]
# # Code for Models, Training, Postprocessing

# %% [markdown]
# ## FNO and NN

# %%
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            nn.init.constant_(m.bias, 0)
    elif isinstance(m, nn.Conv1d):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            nn.init.constant_(m.bias, 0)


class SpectralConv1d(nn.Module):
    def __init__(self, 
                 in_channels : int, 
                 out_channels: int, 
                 modes: int):
        """
        Initializes a 1D spectral convolution layer using complex weights in the Fourier domain.

        Args:
            in_channels (int): Number of input channels.
            out_channels (int): Number of output channels.
            modes (int): Number of Fourier modes to retain (low-frequency modes).
        """
        super().__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.modes = modes

        scale = 1.0 / (in_channels * out_channels)
        self.real_weights = nn.Parameter(
            torch.rand(in_channels, out_channels, modes) * 2 * scale - scale
        )
        self.imag_weights = nn.Parameter(
            torch.rand(in_channels, out_channels, modes) * 2 * scale - scale
        )

    def complex_mult1d(self, x_hat, w):
        return torch.einsum("iM,ioM->oM", x_hat, w)

    def forward(self, x):
        # x: (batch, channels, spatial_points)
        batchsize, channels, spatial_points = x.shape

        x_hat = torch.fft.rfft(x, dim=-1)  # (B, C, F)
        x_hat_under_modes = x_hat[:, :, :self.modes]

        weights = torch.complex(self.real_weights, self.imag_weights)
        out_hat_under_modes = torch.einsum("bim, iom -> bom", x_hat_under_modes, weights)

        out_hat = torch.zeros(
            batchsize, self.out_channels, x_hat.shape[-1],
            dtype=torch.cfloat, device=x.device
        )
        out_hat[:, :, :self.modes] = out_hat_under_modes

        out = torch.fft.irfft(out_hat, n=spatial_points, dim=-1)
        return out


class FNOBlock1d(nn.Module):
    def __init__(self, 
                 in_channels : int, 
                 out_channels : int, 
                 modes : int, 
                 activation : nn.Module = nn.Identity()):
        """
        Initializes a single Fourier Neural Operator (FNO) block for 1D data.

        Args:
            in_channels (int): Number of input channels.
            out_channels (int): Number of output channels.
            modes (int): Number of retained Fourier modes in the spectral convolution.
            activation (nn.Module, optional): Activation function applied after the block output. Default is nn.Identity().
        """
        
        super().__init__()
        self.activation = activation
        self.spectral_conv = SpectralConv1d(in_channels, out_channels, modes)
        self.bypass_conv = nn.Conv1d(in_channels, out_channels, kernel_size=1)

    def forward(self, x):
        sc = self.spectral_conv(x)
        bc = self.bypass_conv(x)
        out = sc + bc
        out = self.activation(out)
        return out

class Projection_NN(nn.Module):
    def __init__(self, 
                 input_dim : int, 
                 output_dim : int, 
                 width : int, 
                 depth : int, 
                 activation: nn.Module = nn.Identity(),
                 dropout = 0,
                 batchNorm = False):
        
        """
        Initializes a fully-connected feedforward projection network.

        Args:
            input_dim (int): Input dimensionality.
            output_dim (int): Output dimensionality.
            width (int): Width (number of hidden units) in each hidden layer.
            depth (int): Number of layers in the network (including input/output layers).
            activation (nn.Module, optional): Activation function applied between layers. Default is nn.Identity().
        """
        
        super().__init__()

        layers = [nn.Linear(input_dim, width)]
        layers.append(activation)
        layers.append(nn.Dropout(dropout))
        layers.append(nn.BatchNorm1d(width) if batchNorm else nn.Identity())

        for _ in range(depth - 1):
            layers.append(nn.Linear(width, width))
            layers.append(activation)
            layers.append(nn.Dropout(dropout))
            layers.append(nn.BatchNorm1d(width) if batchNorm else nn.Identity())

        layers.append(nn.Linear(width, output_dim))
        self.network = nn.Sequential(*layers)

    def forward(self, x):
        bsize, _, N = x.shape
        x = x.permute(0, 2, 1).contiguous().view(-1, self.network[0].in_features)
        x = self.network(x)
        x = x.view(bsize, N, self.network[-1].out_features).permute(0, 2, 1).contiguous()
        return x

class FNO1d(nn.Module):
    def __init__(
        self,
        in_channels : int,
        out_channels : int,
        modes : int,
        width : int,
        block_activation : nn.Module = nn.Identity(),
        n_blocks : int = 4,
        padding : int = 0,
        lift_network = None,
        decode_network = None,
    ):
        """
        Initializes a 1D Fourier Neural Operator (FNO) model.

        Args:
            in_channels (int): Number of input channels.
            out_channels (int): Number of output channels.
            modes (int): Number of Fourier modes retained in spectral convolutions.
            width (int): Width of the internal FNO layers.
            block_activation (nn.Module, optional): Activation applied after each FNO block. Default is nn.Identity().
            n_blocks (int, optional): Number of stacked FNO blocks. Default is 4.
            padding (int, optional): Amount of zero-padding added to input and removed from output. Default is 0.
        """

        super().__init__()
        
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.modes = modes
        self.width = width
        self.block_activation = block_activation
        self.n_blocks = n_blocks
        self.padding = padding
        
        self.lift_network = lift_network
        self.decode_network = decode_network

        self.fno_blocks = nn.ModuleList([
            FNOBlock1d(width, width, modes, block_activation)
            for _ in range(n_blocks)
        ])

        self.apply(init_weights)

    # x: (B, C, N)
    def forward(self, x):

        x = self.lift_network(x)

        N = x.shape[-1]
        target_length = (1 << (N - 1).bit_length())*2

        total_pad = target_length - N
        pad_left = total_pad // 2
        pad_right = total_pad - pad_left

        if total_pad > 0:
            x = nn.functional.pad(
                x,
                (pad_left, pad_right),
                mode="constant",
                value=0,
            )

        for block in self.fno_blocks:
            x = block(x)

        x = self.decode_network(x)

        if total_pad > 0:
            x = x[..., pad_left:pad_left + N]

        return x

# %% [markdown]
# ## Train Loop

# %%
def train_loop(model,
                     train_loader,
                     test_loader,
                     epochs,
                     optimizer,
                     scheduler=None,
                     clip_grad=False,
                     mixed_training=False,
                     add_noise=False,
                     loss_func = nn.MSELoss(),
                     half_train = False):

    criterion = loss_func

    loss_history = []
    val_loss_history = []

    for epoch in range(epochs):
        model.train()
        epoch_loss = 0.0

        for batch_x, batch_y in train_loader:

            B,C,N = batch_x.shape

            if half_train is not False:
                sample_N = int(torch.rand(1)*120+30)
                batch_x = batch_x.to(device)[:, :, :sample_N]
                batch_y = batch_y.to(device)[:, :, :sample_N]
                batch_x = torch.nn.functional.interpolate(batch_x,N)
                batch_y = torch.nn.functional.interpolate(batch_y,N)

            if mixed_training is not False:
                sample_freq = np.random.choice(mixed_training[0], p=mixed_training[1])
                batch_x = batch_x.to(device)[:, :, ::sample_freq]
                batch_y = batch_y.to(device)[:, :, ::sample_freq]

            if add_noise is not False:
                noise = torch.randn_like(batch_x) * add_noise[0]
                batch_x = batch_x + noise

            def closure():
                optimizer.zero_grad()

                output = model(batch_x)
                loss = criterion(output, batch_y)

                loss.backward()

                if clip_grad:
                    utils.clip_grad_norm_(model.parameters(), 0.5)

                return loss

            loss = optimizer.step(closure)

            epoch_loss += loss.item()

        if scheduler is not None:
            scheduler.step()

        loss_history.append(epoch_loss / len(train_loader))

        model.eval()
        with torch.no_grad():
            val_loss = 0.0
            for batch_x, batch_y in test_loader:
                batch_x = batch_x.to(device)
                batch_y = batch_y.to(device)

                val_output = model(batch_x)
                val_loss += criterion(val_output, batch_y).item()

        val_loss_history.append(val_loss / len(test_loader))

        print(
            f"EPOCH {epoch}: "
            f"train_loss: {loss_history[-1]:.3e} \t "
            f"test_loss: {val_loss_history[-1]:.3e}"
        )

    return loss_history, val_loss_history

# %%
def make_decay_fn(factor: float, 
                  interval: int):
    return lambda step: factor ** (step // interval)

# %% [markdown]
# ## Postprocessing

# %%
def plot_results(model, x, y, name):

    fig, axes = plt.subplots(4, 4, figsize=(10, 10))
    axes = axes.flatten()
    for i in range(16):
        pred = model(x[i:i+1].to(device))[0].cpu().detach().numpy()
        ax1 = axes[i]

        ax1.plot(y[i, 0, :].cpu().detach().numpy(), color='tab:orange', label='Ground Truth' if i == 0 else "")
        ax1.plot(pred[0], color='tab:green', label='Prediction' if i == 0 else "")
        ax1.set_xticks([])
        ax1.set_yticks([])

    fig.suptitle(name, fontsize=22, y=0.98)

    fig.legend(loc='upper center', bbox_to_anchor=(0.5, 0.95), ncol=2, fontsize=16)

    plt.tight_layout(rect=[0, 0, 1, 0.95])  
    plt.show()

def plot_loss(loss, val, barometer = None):

    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(loss, label="train loss")
    ax.plot(val, label="val loss")
    if barometer is not None:
        ax.hlines(barometer, xmin = 0, xmax = len(loss), color = 'red', linestyle = '--')
    ax.legend(fontsize=14)
    ax.set_yscale("log")
    ax.grid(True)
    ax.tick_params(axis='both', which='major', labelsize=14)
    fig.suptitle("Loss History", fontsize=18)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Training

# %%
in_channels = train_x_norm.shape[1]
width = 64
out_channels = 1

lift_network = Projection_NN(
                input_dim = in_channels,
                output_dim = width,
                width = 64,
                depth = 2,
                activation = torch.nn.GELU(),
                dropout = 0.025
            )

decode_network = Projection_NN(
                input_dim = width,
                output_dim = out_channels,
                width = 64,
                depth = 2,
                activation = torch.nn.GELU(),
            )

model = FNO1d(
        in_channels=in_channels,
        out_channels=out_channels,
        modes = 12,
        width=width,
        block_activation=torch.nn.Mish(),
        n_blocks=8,
        padding=0,
        lift_network=lift_network,
        decode_network=decode_network,
        ).to(device)


lr = 1e-3

optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)

scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda= make_decay_fn(0.999, 100))

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

loss_history, val_loss_history = [], []

loss_history, val_loss_history = train_loop(model, train_loader, test_loader,
                                            1500, optimizer, scheduler,
                                            mixed_training=([1,2,4], [0.5,0.3,0.2]),
                                            half_train = True)

checkpoint = {
    "state_dict": model.state_dict(),
    "config": {
        "in_channels": model.in_channels,
        "out_channels": model.out_channels,
        "modes": model.modes,
        "width": model.width,
        "n_blocks": model.n_blocks,
        "padding": model.padding,

        "lift_width": 64,
        "lift_depth": 2,
        "decode_width": 64,
        "decode_depth": 2,

        "block_activation": "mish",
        "projection_activation": "gelu",
    }
}

torch.save(checkpoint, "best_model_halfData_extreme.pt")
# Out:
# EPOCH 0: train_loss: 9.779e-03 	 test_loss: 7.101e-03
# EPOCH 1: train_loss: 8.540e-03 	 test_loss: 6.396e-03
# EPOCH 2: train_loss: 9.012e-03 	 test_loss: 6.069e-03
# EPOCH 3: train_loss: 8.184e-03 	 test_loss: 6.510e-03
# EPOCH 4: train_loss: 7.413e-03 	 test_loss: 5.298e-03
# EPOCH 5: train_loss: 7.714e-03 	 test_loss: 5.031e-03
# EPOCH 6: train_loss: 7.168e-03 	 test_loss: 5.056e-03
# EPOCH 7: train_loss: 7.047e-03 	 test_loss: 5.113e-03
# EPOCH 8: train_loss: 7.712e-03 	 test_loss: 5.300e-03
# EPOCH 9: train_loss: 6.443e-03 	 test_loss: 4.358e-03
# EPOCH 10: train_loss: 6.641e-03 	 test_loss: 4.634e-03
# EPOCH 11: train_loss: 6.090e-03 	 test_loss: 4.623e-03
# EPOCH 12: train_loss: 4.912e-03 	 test_loss: 3.945e-03
# EPOCH 13: train_loss: 4.642e-03 	 test_loss: 6.033e-03
# EPOCH 14: train_loss: 5.975e-03 	 test_loss: 5.526e-03
# EPOCH 15: train_loss: 5.071e-03 	 test_loss: 3.493e-03
# EPOCH 16: train_loss: 4.943e-03 	 test_loss: 4.045e-03
# EPOCH 17: train_loss: 4.202e-03 	 test_loss: 3.643e-03
# EPOCH 18: train_loss: 3.176e-03 	 test_loss: 2.496e-03
# EPOCH 19: train_loss: 2.843e-03 	 test_loss: 2.412e-03
# EPOCH 20: train_loss: 2.412e-03 	 test_loss: 2.486e-03
# EPOCH 21: train_loss: 2.190e-03 	 test_loss: 2.118e-03
# EPOCH 22: train_loss: 2.287e-03 	 test_loss: 2.804e-03
# EPOCH 23: train_loss: 2.534e-03 	 test_loss: 1.885e-03
# EPOCH 24: train_loss: 2.250e-03 	 test_loss: 3.995e-03
# EPOCH 25: train_loss: 2.527e-03 	 test_loss: 2.422e-03
# EPOCH 26: train_loss: 2.307e-03 	 test_loss: 2.037e-03
# EPOCH 27: train_loss: 1.881e-03 	 test_loss: 1.794e-03
# EPOCH 28: train_loss: 1.653e-03 	 test_loss: 1.991e-03
# EPOCH 29: train_loss: 1.907e-03 	 test_loss: 1.939e-03
# EPOCH 30: train_loss: 1.508e-03 	 test_loss: 1.987e-03
# EPOCH 31: train_loss: 1.834e-03 	 test_loss: 1.800e-03
# EPOCH 32: train_loss: 1.671e-03 	 test_loss: 1.714e-03
# EPOCH 33: train_loss: 1.621e-03 	 test_loss: 1.572e-03
# EPOCH 34: train_loss: 1.712e-03 	 test_loss: 1.915e-03
# EPOCH 35: train_loss: 1.783e-03 	 test_loss: 1.811e-03
# EPOCH 36: train_loss: 1.953e-03 	 test_loss: 1.799e-03
# EPOCH 37: train_loss: 1.632e-03 	 test_loss: 1.643e-03
# EPOCH 38: train_loss: 1.416e-03 	 test_loss: 2.928e-03
# EPOCH 39: train_loss: 1.715e-03 	 test_loss: 1.569e-03
# EPOCH 40: train_loss: 1.530e-03 	 test_loss: 1.679e-03
# EPOCH 41: train_loss: 1.514e-03 	 test_loss: 1.906e-03
# EPOCH 42: train_loss: 1.398e-03 	 test_loss: 1.789e-03
# EPOCH 43: train_loss: 1.798e-03 	 test_loss: 2.035e-03
# EPOCH 44: train_loss: 1.279e-03 	 test_loss: 2.444e-03
# EPOCH 45: train_loss: 1.523e-03 	 test_loss: 1.665e-03
# EPOCH 46: train_loss: 1.391e-03 	 test_loss: 1.857e-03
# EPOCH 47: train_loss: 1.317e-03 	 test_loss: 1.936e-03
# EPOCH 48: train_loss: 1.236e-03 	 test_loss: 1.811e-03
# EPOCH 49: train_loss: 1.388e-03 	 test_loss: 1.595e-03
# EPOCH 50: train_loss: 1.122e-03 	 test_loss: 2.184e-03
# EPOCH 51: train_loss: 1.386e-03 	 test_loss: 1.566e-03
# EPOCH 52: train_loss: 1.281e-03 	 test_loss: 1.722e-03
# EPOCH 53: train_loss: 1.194e-03 	 test_loss: 1.719e-03
# EPOCH 54: train_loss: 1.051e-03 	 test_loss: 2.335e-03
# EPOCH 55: train_loss: 1.116e-03 	 test_loss: 1.465e-03
# EPOCH 56: train_loss: 1.161e-03 	 test_loss: 2.147e-03
# EPOCH 57: train_loss: 1.183e-03 	 test_loss: 1.368e-03
# EPOCH 58: train_loss: 1.092e-03 	 test_loss: 1.679e-03
# EPOCH 59: train_loss: 1.331e-03 	 test_loss: 1.583e-03
# EPOCH 60: train_loss: 1.079e-03 	 test_loss: 2.026e-03
# EPOCH 61: train_loss: 1.014e-03 	 test_loss: 1.277e-03
# EPOCH 62: train_loss: 9.705e-04 	 test_loss: 1.181e-03
# EPOCH 63: train_loss: 9.004e-04 	 test_loss: 1.831e-03
# EPOCH 64: train_loss: 1.074e-03 	 test_loss: 1.396e-03
# EPOCH 65: train_loss: 1.052e-03 	 test_loss: 1.107e-03
# EPOCH 66: train_loss: 1.263e-03 	 test_loss: 1.433e-03
# EPOCH 67: train_loss: 1.226e-03 	 test_loss: 1.618e-03
# EPOCH 68: train_loss: 1.072e-03 	 test_loss: 1.356e-03
# EPOCH 69: train_loss: 9.656e-04 	 test_loss: 1.583e-03
# EPOCH 70: train_loss: 1.127e-03 	 test_loss: 1.254e-03
# EPOCH 71: train_loss: 1.144e-03 	 test_loss: 1.183e-03
# EPOCH 72: train_loss: 1.174e-03 	 test_loss: 1.031e-03
# EPOCH 73: train_loss: 1.131e-03 	 test_loss: 1.334e-03
# EPOCH 74: train_loss: 9.697e-04 	 test_loss: 1.050e-03
# EPOCH 75: train_loss: 1.081e-03 	 test_loss: 1.021e-03
# EPOCH 76: train_loss: 9.320e-04 	 test_loss: 1.197e-03
# EPOCH 77: train_loss: 1.096e-03 	 test_loss: 1.042e-03
# EPOCH 78: train_loss: 1.042e-03 	 test_loss: 1.171e-03
# EPOCH 79: train_loss: 9.071e-04 	 test_loss: 1.074e-03
# EPOCH 80: train_loss: 9.299e-04 	 test_loss: 8.510e-04
# EPOCH 81: train_loss: 8.892e-04 	 test_loss: 1.324e-03
# EPOCH 82: train_loss: 9.988e-04 	 test_loss: 1.232e-03
# EPOCH 83: train_loss: 8.819e-04 	 test_loss: 7.500e-04
# EPOCH 84: train_loss: 1.044e-03 	 test_loss: 1.284e-03
# EPOCH 85: train_loss: 9.998e-04 	 test_loss: 1.488e-03
# EPOCH 86: train_loss: 9.893e-04 	 test_loss: 1.303e-03
# EPOCH 87: train_loss: 9.495e-04 	 test_loss: 1.374e-03
# EPOCH 88: train_loss: 8.874e-04 	 test_loss: 1.061e-03
# EPOCH 89: train_loss: 9.702e-04 	 test_loss: 7.909e-04
# EPOCH 90: train_loss: 9.273e-04 	 test_loss: 9.174e-04
# EPOCH 91: train_loss: 1.002e-03 	 test_loss: 1.132e-03
# EPOCH 92: train_loss: 8.626e-04 	 test_loss: 1.302e-03
# EPOCH 93: train_loss: 1.035e-03 	 test_loss: 1.019e-03
# EPOCH 94: train_loss: 9.652e-04 	 test_loss: 1.015e-03
# EPOCH 95: train_loss: 1.080e-03 	 test_loss: 1.208e-03
# EPOCH 96: train_loss: 8.807e-04 	 test_loss: 1.415e-03
# EPOCH 97: train_loss: 1.080e-03 	 test_loss: 1.108e-03
# EPOCH 98: train_loss: 1.276e-03 	 test_loss: 9.778e-04
# EPOCH 99: train_loss: 1.853e-03 	 test_loss: 2.862e-03
# EPOCH 100: train_loss: 1.467e-03 	 test_loss: 1.461e-03
# EPOCH 101: train_loss: 1.126e-03 	 test_loss: 1.376e-03
# EPOCH 102: train_loss: 8.616e-04 	 test_loss: 9.965e-04
# EPOCH 103: train_loss: 8.142e-04 	 test_loss: 1.419e-03
# EPOCH 104: train_loss: 9.267e-04 	 test_loss: 1.148e-03
# EPOCH 105: train_loss: 7.342e-04 	 test_loss: 1.360e-03
# EPOCH 106: train_loss: 7.638e-04 	 test_loss: 1.132e-03
# EPOCH 107: train_loss: 8.086e-04 	 test_loss: 1.176e-03
# EPOCH 108: train_loss: 8.517e-04 	 test_loss: 8.894e-04
# EPOCH 109: train_loss: 9.012e-04 	 test_loss: 1.460e-03
# EPOCH 110: train_loss: 9.332e-04 	 test_loss: 1.780e-03
# EPOCH 111: train_loss: 1.128e-03 	 test_loss: 9.362e-04
# EPOCH 112: train_loss: 1.020e-03 	 test_loss: 1.099e-03
# EPOCH 113: train_loss: 9.906e-04 	 test_loss: 9.122e-04
# EPOCH 114: train_loss: 1.062e-03 	 test_loss: 9.717e-04
# EPOCH 115: train_loss: 8.987e-04 	 test_loss: 1.109e-03
# EPOCH 116: train_loss: 9.038e-04 	 test_loss: 9.231e-04
# EPOCH 117: train_loss: 8.910e-04 	 test_loss: 8.318e-04
# EPOCH 118: train_loss: 7.859e-04 	 test_loss: 9.540e-04
# EPOCH 119: train_loss: 6.320e-04 	 test_loss: 9.772e-04
# EPOCH 120: train_loss: 6.911e-04 	 test_loss: 1.252e-03
# EPOCH 121: train_loss: 9.198e-04 	 test_loss: 8.449e-04
# EPOCH 122: train_loss: 8.427e-04 	 test_loss: 1.464e-03
# EPOCH 123: train_loss: 1.038e-03 	 test_loss: 6.979e-04
# EPOCH 124: train_loss: 1.053e-03 	 test_loss: 1.177e-03
# EPOCH 125: train_loss: 1.053e-03 	 test_loss: 1.598e-03
# EPOCH 126: train_loss: 1.009e-03 	 test_loss: 1.566e-03
# EPOCH 127: train_loss: 9.123e-04 	 test_loss: 7.800e-04
# EPOCH 128: train_loss: 9.519e-04 	 test_loss: 9.082e-04
# EPOCH 129: train_loss: 8.975e-04 	 test_loss: 1.050e-03
# EPOCH 130: train_loss: 7.114e-04 	 test_loss: 1.013e-03
# EPOCH 131: train_loss: 8.031e-04 	 test_loss: 9.351e-04
# EPOCH 132: train_loss: 8.985e-04 	 test_loss: 8.580e-04
# EPOCH 133: train_loss: 7.546e-04 	 test_loss: 7.759e-04
# EPOCH 134: train_loss: 8.163e-04 	 test_loss: 9.110e-04
# EPOCH 135: train_loss: 8.619e-04 	 test_loss: 1.402e-03
# EPOCH 136: train_loss: 1.011e-03 	 test_loss: 1.157e-03
# EPOCH 137: train_loss: 8.160e-04 	 test_loss: 8.121e-04
# EPOCH 138: train_loss: 8.058e-04 	 test_loss: 1.465e-03
# EPOCH 139: train_loss: 7.112e-04 	 test_loss: 1.259e-03
# EPOCH 140: train_loss: 7.751e-04 	 test_loss: 6.620e-04
# EPOCH 141: train_loss: 8.546e-04 	 test_loss: 9.848e-04
# EPOCH 142: train_loss: 6.863e-04 	 test_loss: 6.873e-04
# EPOCH 143: train_loss: 7.298e-04 	 test_loss: 7.584e-04
# EPOCH 144: train_loss: 6.349e-04 	 test_loss: 1.514e-03
# EPOCH 145: train_loss: 8.993e-04 	 test_loss: 7.545e-04
# EPOCH 146: train_loss: 6.570e-04 	 test_loss: 1.033e-03
# EPOCH 147: train_loss: 6.844e-04 	 test_loss: 1.067e-03
# EPOCH 148: train_loss: 7.475e-04 	 test_loss: 5.436e-04
# EPOCH 149: train_loss: 6.426e-04 	 test_loss: 6.990e-04
# EPOCH 150: train_loss: 7.214e-04 	 test_loss: 1.099e-03
# EPOCH 151: train_loss: 6.902e-04 	 test_loss: 7.359e-04
# EPOCH 152: train_loss: 7.096e-04 	 test_loss: 8.695e-04
# EPOCH 153: train_loss: 8.414e-04 	 test_loss: 7.525e-04
# EPOCH 154: train_loss: 7.790e-04 	 test_loss: 7.848e-04
# EPOCH 155: train_loss: 7.939e-04 	 test_loss: 8.469e-04
# EPOCH 156: train_loss: 6.946e-04 	 test_loss: 1.011e-03
# EPOCH 157: train_loss: 8.756e-04 	 test_loss: 8.672e-04
# EPOCH 158: train_loss: 9.624e-04 	 test_loss: 9.628e-04
# EPOCH 159: train_loss: 7.344e-04 	 test_loss: 5.416e-04
# EPOCH 160: train_loss: 6.864e-04 	 test_loss: 6.829e-04
# EPOCH 161: train_loss: 7.520e-04 	 test_loss: 1.287e-03
# EPOCH 162: train_loss: 9.909e-04 	 test_loss: 1.275e-03
# EPOCH 163: train_loss: 8.330e-04 	 test_loss: 8.247e-04
# EPOCH 164: train_loss: 8.711e-04 	 test_loss: 8.384e-04
# EPOCH 165: train_loss: 7.938e-04 	 test_loss: 1.114e-03
# EPOCH 166: train_loss: 6.791e-04 	 test_loss: 9.594e-04
# EPOCH 167: train_loss: 7.441e-04 	 test_loss: 6.015e-04
# EPOCH 168: train_loss: 6.779e-04 	 test_loss: 5.623e-04
# EPOCH 169: train_loss: 6.518e-04 	 test_loss: 1.370e-03
# EPOCH 170: train_loss: 7.595e-04 	 test_loss: 1.107e-03
# EPOCH 171: train_loss: 7.574e-04 	 test_loss: 8.697e-04
# EPOCH 172: train_loss: 6.809e-04 	 test_loss: 5.632e-04
# EPOCH 173: train_loss: 8.026e-04 	 test_loss: 9.249e-04
# EPOCH 174: train_loss: 6.991e-04 	 test_loss: 9.472e-04
# EPOCH 175: train_loss: 6.707e-04 	 test_loss: 6.551e-04
# EPOCH 176: train_loss: 8.323e-04 	 test_loss: 1.030e-03
# EPOCH 177: train_loss: 7.799e-04 	 test_loss: 7.090e-04
# EPOCH 178: train_loss: 6.621e-04 	 test_loss: 8.081e-04
# EPOCH 179: train_loss: 6.861e-04 	 test_loss: 1.045e-03
# EPOCH 180: train_loss: 6.971e-04 	 test_loss: 9.203e-04
# EPOCH 181: train_loss: 7.035e-04 	 test_loss: 8.504e-04
# EPOCH 182: train_loss: 6.713e-04 	 test_loss: 7.854e-04
# EPOCH 183: train_loss: 6.819e-04 	 test_loss: 1.027e-03
# EPOCH 184: train_loss: 6.848e-04 	 test_loss: 9.105e-04
# EPOCH 185: train_loss: 6.165e-04 	 test_loss: 8.892e-04
# EPOCH 186: train_loss: 9.063e-04 	 test_loss: 8.949e-04
# EPOCH 187: train_loss: 9.433e-04 	 test_loss: 6.130e-04
# EPOCH 188: train_loss: 8.260e-04 	 test_loss: 5.909e-04
# EPOCH 189: train_loss: 7.243e-04 	 test_loss: 8.607e-04
# EPOCH 190: train_loss: 6.865e-04 	 test_loss: 7.029e-04
# EPOCH 191: train_loss: 7.657e-04 	 test_loss: 7.815e-04
# EPOCH 192: train_loss: 6.260e-04 	 test_loss: 1.363e-03
# EPOCH 193: train_loss: 6.933e-04 	 test_loss: 6.586e-04
# EPOCH 194: train_loss: 7.478e-04 	 test_loss: 1.109e-03
# EPOCH 195: train_loss: 6.643e-04 	 test_loss: 1.061e-03
# EPOCH 196: train_loss: 6.619e-04 	 test_loss: 8.388e-04
# EPOCH 197: train_loss: 7.296e-04 	 test_loss: 8.460e-04
# EPOCH 198: train_loss: 6.243e-04 	 test_loss: 9.547e-04
# EPOCH 199: train_loss: 6.763e-04 	 test_loss: 7.205e-04
# EPOCH 200: train_loss: 5.827e-04 	 test_loss: 6.928e-04
# EPOCH 201: train_loss: 7.142e-04 	 test_loss: 7.091e-04
# EPOCH 202: train_loss: 5.858e-04 	 test_loss: 4.826e-04
# EPOCH 203: train_loss: 5.703e-04 	 test_loss: 7.672e-04
# EPOCH 204: train_loss: 5.716e-04 	 test_loss: 9.258e-04
# EPOCH 205: train_loss: 6.000e-04 	 test_loss: 5.552e-04
# EPOCH 206: train_loss: 7.723e-04 	 test_loss: 6.450e-04
# EPOCH 207: train_loss: 6.227e-04 	 test_loss: 5.480e-04
# EPOCH 208: train_loss: 8.135e-04 	 test_loss: 8.840e-04
# EPOCH 209: train_loss: 8.308e-04 	 test_loss: 8.665e-04
# EPOCH 210: train_loss: 6.281e-04 	 test_loss: 6.330e-04
# EPOCH 211: train_loss: 5.834e-04 	 test_loss: 7.425e-04
# EPOCH 212: train_loss: 5.812e-04 	 test_loss: 7.039e-04
# EPOCH 213: train_loss: 6.901e-04 	 test_loss: 5.229e-04
# EPOCH 214: train_loss: 6.514e-04 	 test_loss: 7.646e-04
# EPOCH 215: train_loss: 6.464e-04 	 test_loss: 8.478e-04
# EPOCH 216: train_loss: 6.059e-04 	 test_loss: 7.573e-04
# EPOCH 217: train_loss: 6.446e-04 	 test_loss: 9.351e-04
# EPOCH 218: train_loss: 6.869e-04 	 test_loss: 7.385e-04
# EPOCH 219: train_loss: 7.000e-04 	 test_loss: 6.110e-04
# EPOCH 220: train_loss: 6.087e-04 	 test_loss: 9.663e-04
# EPOCH 221: train_loss: 6.675e-04 	 test_loss: 7.206e-04
# EPOCH 222: train_loss: 6.887e-04 	 test_loss: 5.836e-04
# EPOCH 223: train_loss: 6.451e-04 	 test_loss: 8.333e-04
# EPOCH 224: train_loss: 7.243e-04 	 test_loss: 7.014e-04
# EPOCH 225: train_loss: 5.423e-04 	 test_loss: 1.317e-03
# EPOCH 226: train_loss: 6.465e-04 	 test_loss: 6.631e-04
# EPOCH 227: train_loss: 6.849e-04 	 test_loss: 5.810e-04
# EPOCH 228: train_loss: 6.701e-04 	 test_loss: 7.270e-04
# EPOCH 229: train_loss: 5.340e-04 	 test_loss: 7.035e-04
# EPOCH 230: train_loss: 5.462e-04 	 test_loss: 8.657e-04
# EPOCH 231: train_loss: 6.190e-04 	 test_loss: 6.508e-04
# EPOCH 232: train_loss: 5.736e-04 	 test_loss: 8.754e-04
# EPOCH 233: train_loss: 5.736e-04 	 test_loss: 9.583e-04
# EPOCH 234: train_loss: 7.018e-04 	 test_loss: 1.004e-03
# EPOCH 235: train_loss: 1.046e-03 	 test_loss: 8.057e-04
# EPOCH 236: train_loss: 8.651e-04 	 test_loss: 2.045e-03
# EPOCH 237: train_loss: 9.567e-04 	 test_loss: 8.511e-04
# EPOCH 238: train_loss: 7.314e-04 	 test_loss: 8.112e-04
# EPOCH 239: train_loss: 6.680e-04 	 test_loss: 5.880e-04
# EPOCH 240: train_loss: 7.402e-04 	 test_loss: 8.634e-04
# EPOCH 241: train_loss: 6.360e-04 	 test_loss: 7.436e-04
# EPOCH 242: train_loss: 7.109e-04 	 test_loss: 7.334e-04
# EPOCH 243: train_loss: 5.867e-04 	 test_loss: 6.793e-04
# EPOCH 244: train_loss: 6.664e-04 	 test_loss: 1.394e-03
# EPOCH 245: train_loss: 6.697e-04 	 test_loss: 6.235e-04
# EPOCH 246: train_loss: 6.471e-04 	 test_loss: 6.444e-04
# EPOCH 247: train_loss: 6.118e-04 	 test_loss: 7.804e-04
# EPOCH 248: train_loss: 7.096e-04 	 test_loss: 7.786e-04
# EPOCH 249: train_loss: 5.755e-04 	 test_loss: 6.658e-04
# EPOCH 250: train_loss: 6.208e-04 	 test_loss: 7.264e-04
# EPOCH 251: train_loss: 5.388e-04 	 test_loss: 6.181e-04
# EPOCH 252: train_loss: 5.493e-04 	 test_loss: 9.194e-04
# EPOCH 253: train_loss: 6.465e-04 	 test_loss: 7.319e-04
# EPOCH 254: train_loss: 5.618e-04 	 test_loss: 7.528e-04
# EPOCH 255: train_loss: 6.058e-04 	 test_loss: 8.192e-04
# EPOCH 256: train_loss: 5.897e-04 	 test_loss: 5.685e-04
# EPOCH 257: train_loss: 6.123e-04 	 test_loss: 6.307e-04
# EPOCH 258: train_loss: 7.016e-04 	 test_loss: 6.371e-04
# EPOCH 259: train_loss: 6.309e-04 	 test_loss: 8.282e-04
# EPOCH 260: train_loss: 6.827e-04 	 test_loss: 8.422e-04
# EPOCH 261: train_loss: 6.170e-04 	 test_loss: 5.505e-04
# EPOCH 262: train_loss: 6.101e-04 	 test_loss: 8.037e-04
# EPOCH 263: train_loss: 5.350e-04 	 test_loss: 7.640e-04
# EPOCH 264: train_loss: 5.985e-04 	 test_loss: 7.756e-04
# EPOCH 265: train_loss: 6.499e-04 	 test_loss: 1.099e-03
# EPOCH 266: train_loss: 8.628e-04 	 test_loss: 6.418e-04
# EPOCH 267: train_loss: 6.908e-04 	 test_loss: 8.522e-04
# EPOCH 268: train_loss: 6.559e-04 	 test_loss: 7.025e-04
# EPOCH 269: train_loss: 7.002e-04 	 test_loss: 7.045e-04
# EPOCH 270: train_loss: 5.616e-04 	 test_loss: 1.029e-03
# EPOCH 271: train_loss: 6.639e-04 	 test_loss: 7.819e-04
# EPOCH 272: train_loss: 5.015e-04 	 test_loss: 5.601e-04
# EPOCH 273: train_loss: 6.497e-04 	 test_loss: 7.617e-04
# EPOCH 274: train_loss: 6.085e-04 	 test_loss: 8.164e-04
# EPOCH 275: train_loss: 5.849e-04 	 test_loss: 7.389e-04
# EPOCH 276: train_loss: 5.078e-04 	 test_loss: 6.309e-04
# EPOCH 277: train_loss: 5.679e-04 	 test_loss: 7.299e-04
# EPOCH 278: train_loss: 7.453e-04 	 test_loss: 5.934e-04
# EPOCH 279: train_loss: 8.051e-04 	 test_loss: 6.851e-04
# EPOCH 280: train_loss: 7.452e-04 	 test_loss: 7.251e-04
# EPOCH 281: train_loss: 5.444e-04 	 test_loss: 1.163e-03
# EPOCH 282: train_loss: 6.436e-04 	 test_loss: 5.841e-04
# EPOCH 283: train_loss: 6.027e-04 	 test_loss: 5.811e-04
# EPOCH 284: train_loss: 6.487e-04 	 test_loss: 1.191e-03
# EPOCH 285: train_loss: 7.117e-04 	 test_loss: 9.604e-04
# EPOCH 286: train_loss: 7.814e-04 	 test_loss: 8.123e-04
# EPOCH 287: train_loss: 6.700e-04 	 test_loss: 7.406e-04
# EPOCH 288: train_loss: 6.318e-04 	 test_loss: 6.533e-04
# EPOCH 289: train_loss: 6.819e-04 	 test_loss: 5.897e-04
# EPOCH 290: train_loss: 7.075e-04 	 test_loss: 1.079e-03
# EPOCH 291: train_loss: 6.865e-04 	 test_loss: 6.281e-04
# EPOCH 292: train_loss: 7.498e-04 	 test_loss: 9.626e-04
# EPOCH 293: train_loss: 9.331e-04 	 test_loss: 9.719e-04
# EPOCH 294: train_loss: 7.229e-04 	 test_loss: 8.905e-04
# EPOCH 295: train_loss: 6.023e-04 	 test_loss: 9.155e-04
# EPOCH 296: train_loss: 6.571e-04 	 test_loss: 4.797e-04
# EPOCH 297: train_loss: 7.443e-04 	 test_loss: 1.175e-03
# EPOCH 298: train_loss: 6.814e-04 	 test_loss: 7.025e-04
# EPOCH 299: train_loss: 6.981e-04 	 test_loss: 6.889e-04
# EPOCH 300: train_loss: 6.908e-04 	 test_loss: 8.368e-04
# EPOCH 301: train_loss: 5.831e-04 	 test_loss: 7.213e-04
# EPOCH 302: train_loss: 5.464e-04 	 test_loss: 5.153e-04
# EPOCH 303: train_loss: 5.379e-04 	 test_loss: 4.705e-04
# EPOCH 304: train_loss: 5.922e-04 	 test_loss: 9.144e-04
# EPOCH 305: train_loss: 5.417e-04 	 test_loss: 6.595e-04
# EPOCH 306: train_loss: 5.428e-04 	 test_loss: 6.147e-04
# EPOCH 307: train_loss: 6.286e-04 	 test_loss: 4.837e-04
# EPOCH 308: train_loss: 5.711e-04 	 test_loss: 4.707e-04
# EPOCH 309: train_loss: 5.512e-04 	 test_loss: 8.084e-04
# EPOCH 310: train_loss: 5.863e-04 	 test_loss: 1.017e-03
# EPOCH 311: train_loss: 7.074e-04 	 test_loss: 5.345e-04
# EPOCH 312: train_loss: 7.018e-04 	 test_loss: 5.217e-04
# EPOCH 313: train_loss: 5.595e-04 	 test_loss: 8.051e-04
# EPOCH 314: train_loss: 6.093e-04 	 test_loss: 5.642e-04
# EPOCH 315: train_loss: 6.648e-04 	 test_loss: 9.571e-04
# EPOCH 316: train_loss: 8.147e-04 	 test_loss: 8.840e-04
# EPOCH 317: train_loss: 7.108e-04 	 test_loss: 1.171e-03
# EPOCH 318: train_loss: 7.596e-04 	 test_loss: 5.184e-04
# EPOCH 319: train_loss: 6.768e-04 	 test_loss: 7.159e-04
# EPOCH 320: train_loss: 5.776e-04 	 test_loss: 6.830e-04
# EPOCH 321: train_loss: 6.669e-04 	 test_loss: 8.460e-04
# EPOCH 322: train_loss: 6.286e-04 	 test_loss: 6.853e-04
# EPOCH 323: train_loss: 6.676e-04 	 test_loss: 6.595e-04
# EPOCH 324: train_loss: 5.939e-04 	 test_loss: 1.005e-03
# EPOCH 325: train_loss: 6.063e-04 	 test_loss: 6.432e-04
# EPOCH 326: train_loss: 5.579e-04 	 test_loss: 9.724e-04
# EPOCH 327: train_loss: 5.427e-04 	 test_loss: 5.990e-04
# EPOCH 328: train_loss: 5.407e-04 	 test_loss: 5.824e-04
# EPOCH 329: train_loss: 5.518e-04 	 test_loss: 6.354e-04
# EPOCH 330: train_loss: 4.860e-04 	 test_loss: 6.637e-04
# EPOCH 331: train_loss: 6.070e-04 	 test_loss: 8.344e-04
# EPOCH 332: train_loss: 6.403e-04 	 test_loss: 7.766e-04
# EPOCH 333: train_loss: 5.540e-04 	 test_loss: 5.806e-04
# EPOCH 334: train_loss: 5.146e-04 	 test_loss: 8.476e-04
# EPOCH 335: train_loss: 6.851e-04 	 test_loss: 7.038e-04
# EPOCH 336: train_loss: 6.308e-04 	 test_loss: 5.868e-04
# EPOCH 337: train_loss: 4.786e-04 	 test_loss: 7.196e-04
# EPOCH 338: train_loss: 5.295e-04 	 test_loss: 7.319e-04
# EPOCH 339: train_loss: 5.047e-04 	 test_loss: 6.606e-04
# EPOCH 340: train_loss: 4.899e-04 	 test_loss: 4.318e-04
# EPOCH 341: train_loss: 6.093e-04 	 test_loss: 6.693e-04
# EPOCH 342: train_loss: 5.255e-04 	 test_loss: 4.910e-04
# EPOCH 343: train_loss: 5.669e-04 	 test_loss: 5.575e-04
# EPOCH 344: train_loss: 5.684e-04 	 test_loss: 7.914e-04
# EPOCH 345: train_loss: 6.073e-04 	 test_loss: 6.744e-04
# EPOCH 346: train_loss: 7.129e-04 	 test_loss: 7.448e-04
# EPOCH 347: train_loss: 5.493e-04 	 test_loss: 6.773e-04
# EPOCH 348: train_loss: 5.451e-04 	 test_loss: 5.879e-04
# EPOCH 349: train_loss: 5.436e-04 	 test_loss: 7.798e-04
# EPOCH 350: train_loss: 6.089e-04 	 test_loss: 7.118e-04
# EPOCH 351: train_loss: 5.335e-04 	 test_loss: 6.340e-04
# EPOCH 352: train_loss: 5.904e-04 	 test_loss: 6.301e-04
# EPOCH 353: train_loss: 7.022e-04 	 test_loss: 8.645e-04
# EPOCH 354: train_loss: 6.601e-04 	 test_loss: 6.152e-04
# EPOCH 355: train_loss: 6.138e-04 	 test_loss: 8.571e-04
# EPOCH 356: train_loss: 7.638e-04 	 test_loss: 7.451e-04
# EPOCH 357: train_loss: 6.451e-04 	 test_loss: 9.679e-04
# EPOCH 358: train_loss: 8.897e-04 	 test_loss: 7.937e-04
# EPOCH 359: train_loss: 7.697e-04 	 test_loss: 6.840e-04
# EPOCH 360: train_loss: 6.836e-04 	 test_loss: 5.526e-04
# EPOCH 361: train_loss: 5.263e-04 	 test_loss: 4.696e-04
# EPOCH 362: train_loss: 5.095e-04 	 test_loss: 7.337e-04
# EPOCH 363: train_loss: 4.882e-04 	 test_loss: 4.357e-04
# EPOCH 364: train_loss: 5.471e-04 	 test_loss: 5.976e-04
# EPOCH 365: train_loss: 5.138e-04 	 test_loss: 1.004e-03
# EPOCH 366: train_loss: 5.436e-04 	 test_loss: 6.314e-04
# EPOCH 367: train_loss: 5.303e-04 	 test_loss: 5.951e-04
# EPOCH 368: train_loss: 6.286e-04 	 test_loss: 5.811e-04
# EPOCH 369: train_loss: 7.007e-04 	 test_loss: 5.896e-04
# EPOCH 370: train_loss: 5.963e-04 	 test_loss: 8.434e-04
# EPOCH 371: train_loss: 6.352e-04 	 test_loss: 5.927e-04
# EPOCH 372: train_loss: 8.088e-04 	 test_loss: 9.152e-04
# EPOCH 373: train_loss: 7.195e-04 	 test_loss: 7.325e-04
# EPOCH 374: train_loss: 6.213e-04 	 test_loss: 7.541e-04
# EPOCH 375: train_loss: 6.233e-04 	 test_loss: 5.745e-04
# EPOCH 376: train_loss: 6.178e-04 	 test_loss: 6.838e-04
# EPOCH 377: train_loss: 7.214e-04 	 test_loss: 6.408e-04
# EPOCH 378: train_loss: 5.554e-04 	 test_loss: 6.685e-04
# EPOCH 379: train_loss: 5.039e-04 	 test_loss: 6.507e-04
# EPOCH 380: train_loss: 6.485e-04 	 test_loss: 5.383e-04
# EPOCH 381: train_loss: 4.702e-04 	 test_loss: 1.016e-03
# EPOCH 382: train_loss: 6.267e-04 	 test_loss: 4.880e-04
# EPOCH 383: train_loss: 5.745e-04 	 test_loss: 1.677e-03
# EPOCH 384: train_loss: 6.189e-04 	 test_loss: 8.371e-04
# EPOCH 385: train_loss: 5.589e-04 	 test_loss: 5.335e-04
# EPOCH 386: train_loss: 5.357e-04 	 test_loss: 5.614e-04
# EPOCH 387: train_loss: 5.112e-04 	 test_loss: 5.245e-04
# EPOCH 388: train_loss: 5.202e-04 	 test_loss: 6.104e-04
# EPOCH 389: train_loss: 5.549e-04 	 test_loss: 7.144e-04
# EPOCH 390: train_loss: 6.642e-04 	 test_loss: 7.277e-04
# EPOCH 391: train_loss: 5.807e-04 	 test_loss: 8.341e-04
# EPOCH 392: train_loss: 6.576e-04 	 test_loss: 5.704e-04
# EPOCH 393: train_loss: 6.575e-04 	 test_loss: 8.215e-04
# EPOCH 394: train_loss: 6.380e-04 	 test_loss: 7.600e-04
# EPOCH 395: train_loss: 4.961e-04 	 test_loss: 6.212e-04
# EPOCH 396: train_loss: 5.223e-04 	 test_loss: 8.851e-04
# EPOCH 397: train_loss: 4.673e-04 	 test_loss: 6.552e-04
# EPOCH 398: train_loss: 5.816e-04 	 test_loss: 6.522e-04
# EPOCH 399: train_loss: 5.602e-04 	 test_loss: 6.365e-04
# EPOCH 400: train_loss: 6.202e-04 	 test_loss: 5.850e-04
# EPOCH 401: train_loss: 4.584e-04 	 test_loss: 5.923e-04
# EPOCH 402: train_loss: 5.292e-04 	 test_loss: 6.381e-04
# EPOCH 403: train_loss: 5.480e-04 	 test_loss: 6.143e-04
# EPOCH 404: train_loss: 5.469e-04 	 test_loss: 1.011e-03
# EPOCH 405: train_loss: 6.692e-04 	 test_loss: 5.816e-04
# EPOCH 406: train_loss: 7.571e-04 	 test_loss: 7.666e-04
# EPOCH 407: train_loss: 8.342e-04 	 test_loss: 8.666e-04
# EPOCH 408: train_loss: 7.108e-04 	 test_loss: 7.570e-04
# EPOCH 409: train_loss: 5.750e-04 	 test_loss: 5.802e-04
# EPOCH 410: train_loss: 6.578e-04 	 test_loss: 7.642e-04
# EPOCH 411: train_loss: 5.739e-04 	 test_loss: 4.632e-04
# EPOCH 412: train_loss: 5.543e-04 	 test_loss: 6.411e-04
# EPOCH 413: train_loss: 4.988e-04 	 test_loss: 7.588e-04
# EPOCH 414: train_loss: 5.591e-04 	 test_loss: 5.484e-04
# EPOCH 415: train_loss: 6.454e-04 	 test_loss: 7.013e-04
# EPOCH 416: train_loss: 4.753e-04 	 test_loss: 8.815e-04
# EPOCH 417: train_loss: 5.514e-04 	 test_loss: 4.176e-04
# EPOCH 418: train_loss: 5.543e-04 	 test_loss: 5.410e-04
# EPOCH 419: train_loss: 4.229e-04 	 test_loss: 7.489e-04
# EPOCH 420: train_loss: 4.888e-04 	 test_loss: 6.110e-04
# EPOCH 421: train_loss: 5.399e-04 	 test_loss: 4.876e-04
# EPOCH 422: train_loss: 5.147e-04 	 test_loss: 5.264e-04
# EPOCH 423: train_loss: 5.408e-04 	 test_loss: 6.621e-04
# EPOCH 424: train_loss: 5.498e-04 	 test_loss: 6.962e-04
# EPOCH 425: train_loss: 5.408e-04 	 test_loss: 5.649e-04
# EPOCH 426: train_loss: 6.599e-04 	 test_loss: 7.583e-04
# EPOCH 427: train_loss: 6.655e-04 	 test_loss: 6.278e-04
# EPOCH 428: train_loss: 5.607e-04 	 test_loss: 6.232e-04
# EPOCH 429: train_loss: 5.792e-04 	 test_loss: 5.873e-04
# EPOCH 430: train_loss: 5.312e-04 	 test_loss: 5.936e-04
# EPOCH 431: train_loss: 5.197e-04 	 test_loss: 5.810e-04
# EPOCH 432: train_loss: 4.858e-04 	 test_loss: 7.777e-04
# EPOCH 433: train_loss: 4.790e-04 	 test_loss: 5.974e-04
# EPOCH 434: train_loss: 4.732e-04 	 test_loss: 5.923e-04
# EPOCH 435: train_loss: 5.701e-04 	 test_loss: 5.636e-04
# EPOCH 436: train_loss: 4.809e-04 	 test_loss: 6.012e-04
# EPOCH 437: train_loss: 5.768e-04 	 test_loss: 4.488e-04
# EPOCH 438: train_loss: 5.733e-04 	 test_loss: 9.190e-04
# EPOCH 439: train_loss: 5.488e-04 	 test_loss: 4.109e-04
# EPOCH 440: train_loss: 5.928e-04 	 test_loss: 5.928e-04
# EPOCH 441: train_loss: 5.329e-04 	 test_loss: 6.453e-04
# EPOCH 442: train_loss: 5.290e-04 	 test_loss: 7.432e-04
# EPOCH 443: train_loss: 5.079e-04 	 test_loss: 6.649e-04
# EPOCH 444: train_loss: 5.811e-04 	 test_loss: 4.918e-04
# EPOCH 445: train_loss: 4.485e-04 	 test_loss: 7.232e-04
# EPOCH 446: train_loss: 5.124e-04 	 test_loss: 4.430e-04
# EPOCH 447: train_loss: 5.783e-04 	 test_loss: 6.593e-04
# EPOCH 448: train_loss: 4.941e-04 	 test_loss: 4.214e-04
# EPOCH 449: train_loss: 5.440e-04 	 test_loss: 4.811e-04
# EPOCH 450: train_loss: 4.659e-04 	 test_loss: 8.512e-04
# EPOCH 451: train_loss: 4.804e-04 	 test_loss: 4.120e-04
# EPOCH 452: train_loss: 6.480e-04 	 test_loss: 8.748e-04
# EPOCH 453: train_loss: 4.933e-04 	 test_loss: 6.315e-04
# EPOCH 454: train_loss: 5.542e-04 	 test_loss: 4.283e-04
# EPOCH 455: train_loss: 5.870e-04 	 test_loss: 5.860e-04
# EPOCH 456: train_loss: 5.864e-04 	 test_loss: 7.019e-04
# EPOCH 457: train_loss: 5.358e-04 	 test_loss: 6.291e-04
# EPOCH 458: train_loss: 5.057e-04 	 test_loss: 6.209e-04
# EPOCH 459: train_loss: 5.295e-04 	 test_loss: 7.385e-04
# EPOCH 460: train_loss: 5.081e-04 	 test_loss: 4.452e-04
# EPOCH 461: train_loss: 5.090e-04 	 test_loss: 5.925e-04
# EPOCH 462: train_loss: 5.044e-04 	 test_loss: 6.060e-04
# EPOCH 463: train_loss: 5.613e-04 	 test_loss: 5.843e-04
# EPOCH 464: train_loss: 5.267e-04 	 test_loss: 5.753e-04
# EPOCH 465: train_loss: 5.816e-04 	 test_loss: 5.069e-04
# EPOCH 466: train_loss: 4.924e-04 	 test_loss: 7.949e-04
# EPOCH 467: train_loss: 5.994e-04 	 test_loss: 6.830e-04
# EPOCH 468: train_loss: 6.619e-04 	 test_loss: 5.541e-04
# EPOCH 469: train_loss: 6.679e-04 	 test_loss: 5.815e-04
# EPOCH 470: train_loss: 6.509e-04 	 test_loss: 5.876e-04
# EPOCH 471: train_loss: 6.527e-04 	 test_loss: 7.076e-04
# EPOCH 472: train_loss: 5.849e-04 	 test_loss: 6.424e-04
# EPOCH 473: train_loss: 5.513e-04 	 test_loss: 4.555e-04
# EPOCH 474: train_loss: 4.672e-04 	 test_loss: 5.263e-04
# EPOCH 475: train_loss: 4.894e-04 	 test_loss: 6.951e-04
# EPOCH 476: train_loss: 5.875e-04 	 test_loss: 6.457e-04
# EPOCH 477: train_loss: 4.981e-04 	 test_loss: 5.749e-04
# EPOCH 478: train_loss: 5.395e-04 	 test_loss: 5.957e-04
# EPOCH 479: train_loss: 4.609e-04 	 test_loss: 4.036e-04
# EPOCH 480: train_loss: 5.126e-04 	 test_loss: 4.760e-04
# EPOCH 481: train_loss: 4.004e-04 	 test_loss: 7.366e-04
# EPOCH 482: train_loss: 4.732e-04 	 test_loss: 6.280e-04
# EPOCH 483: train_loss: 5.280e-04 	 test_loss: 5.470e-04
# EPOCH 484: train_loss: 4.576e-04 	 test_loss: 5.175e-04
# EPOCH 485: train_loss: 4.066e-04 	 test_loss: 4.947e-04
# EPOCH 486: train_loss: 4.433e-04 	 test_loss: 4.960e-04
# EPOCH 487: train_loss: 3.955e-04 	 test_loss: 4.688e-04
# EPOCH 488: train_loss: 4.255e-04 	 test_loss: 5.158e-04
# EPOCH 489: train_loss: 5.274e-04 	 test_loss: 5.084e-04
# EPOCH 490: train_loss: 4.912e-04 	 test_loss: 5.052e-04
# EPOCH 491: train_loss: 5.399e-04 	 test_loss: 5.156e-04
# EPOCH 492: train_loss: 4.335e-04 	 test_loss: 5.499e-04
# EPOCH 493: train_loss: 4.550e-04 	 test_loss: 7.690e-04
# EPOCH 494: train_loss: 4.508e-04 	 test_loss: 6.066e-04
# EPOCH 495: train_loss: 4.893e-04 	 test_loss: 5.438e-04
# EPOCH 496: train_loss: 5.088e-04 	 test_loss: 5.184e-04
# EPOCH 497: train_loss: 5.585e-04 	 test_loss: 5.326e-04
# EPOCH 498: train_loss: 5.564e-04 	 test_loss: 4.551e-04
# EPOCH 499: train_loss: 4.718e-04 	 test_loss: 7.142e-04
# EPOCH 500: train_loss: 5.276e-04 	 test_loss: 5.168e-04
# EPOCH 501: train_loss: 5.553e-04 	 test_loss: 6.042e-04
# EPOCH 502: train_loss: 5.966e-04 	 test_loss: 4.794e-04
# EPOCH 503: train_loss: 4.996e-04 	 test_loss: 4.394e-04
# EPOCH 504: train_loss: 4.793e-04 	 test_loss: 7.041e-04
# EPOCH 505: train_loss: 6.037e-04 	 test_loss: 5.520e-04
# EPOCH 506: train_loss: 5.913e-04 	 test_loss: 5.462e-04
# EPOCH 507: train_loss: 5.225e-04 	 test_loss: 5.354e-04
# EPOCH 508: train_loss: 4.728e-04 	 test_loss: 7.439e-04
# EPOCH 509: train_loss: 5.239e-04 	 test_loss: 5.011e-04
# EPOCH 510: train_loss: 4.898e-04 	 test_loss: 8.260e-04
# EPOCH 511: train_loss: 4.929e-04 	 test_loss: 6.531e-04
# EPOCH 512: train_loss: 4.865e-04 	 test_loss: 5.796e-04
# EPOCH 513: train_loss: 5.126e-04 	 test_loss: 5.756e-04
# EPOCH 514: train_loss: 4.977e-04 	 test_loss: 5.364e-04
# EPOCH 515: train_loss: 4.389e-04 	 test_loss: 7.321e-04
# EPOCH 516: train_loss: 5.122e-04 	 test_loss: 6.686e-04
# EPOCH 517: train_loss: 5.179e-04 	 test_loss: 7.165e-04
# EPOCH 518: train_loss: 7.110e-04 	 test_loss: 8.739e-04
# EPOCH 519: train_loss: 6.350e-04 	 test_loss: 7.837e-04
# EPOCH 520: train_loss: 5.479e-04 	 test_loss: 5.788e-04
# EPOCH 521: train_loss: 4.808e-04 	 test_loss: 9.122e-04
# EPOCH 522: train_loss: 5.971e-04 	 test_loss: 6.849e-04
# EPOCH 523: train_loss: 5.941e-04 	 test_loss: 6.314e-04
# EPOCH 524: train_loss: 5.831e-04 	 test_loss: 7.288e-04
# EPOCH 525: train_loss: 4.813e-04 	 test_loss: 5.642e-04
# EPOCH 526: train_loss: 4.595e-04 	 test_loss: 3.985e-04
# EPOCH 527: train_loss: 5.301e-04 	 test_loss: 7.891e-04
# EPOCH 528: train_loss: 4.735e-04 	 test_loss: 4.896e-04
# EPOCH 529: train_loss: 4.240e-04 	 test_loss: 4.419e-04
# EPOCH 530: train_loss: 4.611e-04 	 test_loss: 4.227e-04
# EPOCH 531: train_loss: 4.519e-04 	 test_loss: 6.609e-04
# EPOCH 532: train_loss: 4.382e-04 	 test_loss: 7.040e-04
# EPOCH 533: train_loss: 4.464e-04 	 test_loss: 4.453e-04
# EPOCH 534: train_loss: 5.452e-04 	 test_loss: 8.171e-04
# EPOCH 535: train_loss: 5.887e-04 	 test_loss: 1.000e-03
# EPOCH 536: train_loss: 1.002e-03 	 test_loss: 5.382e-04
# EPOCH 537: train_loss: 6.570e-04 	 test_loss: 5.456e-04
# EPOCH 538: train_loss: 6.048e-04 	 test_loss: 9.399e-04
# EPOCH 539: train_loss: 5.479e-04 	 test_loss: 6.504e-04
# EPOCH 540: train_loss: 5.440e-04 	 test_loss: 4.968e-04
# EPOCH 541: train_loss: 6.541e-04 	 test_loss: 6.661e-04
# EPOCH 542: train_loss: 5.276e-04 	 test_loss: 5.457e-04
# EPOCH 543: train_loss: 5.596e-04 	 test_loss: 6.360e-04
# EPOCH 544: train_loss: 5.339e-04 	 test_loss: 5.347e-04
# EPOCH 545: train_loss: 4.769e-04 	 test_loss: 6.124e-04
# EPOCH 546: train_loss: 4.464e-04 	 test_loss: 5.429e-04
# EPOCH 547: train_loss: 5.095e-04 	 test_loss: 4.916e-04
# EPOCH 548: train_loss: 4.092e-04 	 test_loss: 5.801e-04
# EPOCH 549: train_loss: 4.329e-04 	 test_loss: 7.454e-04
# EPOCH 550: train_loss: 5.595e-04 	 test_loss: 5.426e-04
# EPOCH 551: train_loss: 4.757e-04 	 test_loss: 6.030e-04
# EPOCH 552: train_loss: 4.422e-04 	 test_loss: 8.156e-04
# EPOCH 553: train_loss: 5.533e-04 	 test_loss: 7.907e-04
# EPOCH 554: train_loss: 5.831e-04 	 test_loss: 4.266e-04
# EPOCH 555: train_loss: 4.862e-04 	 test_loss: 8.936e-04
# EPOCH 556: train_loss: 4.142e-04 	 test_loss: 7.029e-04
# EPOCH 557: train_loss: 5.387e-04 	 test_loss: 5.142e-04
# EPOCH 558: train_loss: 5.135e-04 	 test_loss: 9.210e-04
# EPOCH 559: train_loss: 6.336e-04 	 test_loss: 7.668e-04
# EPOCH 560: train_loss: 5.726e-04 	 test_loss: 4.298e-04
# EPOCH 561: train_loss: 5.986e-04 	 test_loss: 1.087e-03
# EPOCH 562: train_loss: 6.515e-04 	 test_loss: 5.609e-04
# EPOCH 563: train_loss: 6.111e-04 	 test_loss: 6.046e-04
# EPOCH 564: train_loss: 5.795e-04 	 test_loss: 6.787e-04
# EPOCH 565: train_loss: 4.586e-04 	 test_loss: 6.460e-04
# EPOCH 566: train_loss: 5.064e-04 	 test_loss: 7.551e-04
# EPOCH 567: train_loss: 4.949e-04 	 test_loss: 5.905e-04
# EPOCH 568: train_loss: 4.586e-04 	 test_loss: 6.671e-04
# EPOCH 569: train_loss: 5.029e-04 	 test_loss: 5.600e-04
# EPOCH 570: train_loss: 4.916e-04 	 test_loss: 7.023e-04
# EPOCH 571: train_loss: 4.272e-04 	 test_loss: 5.143e-04
# EPOCH 572: train_loss: 5.091e-04 	 test_loss: 6.013e-04
# EPOCH 573: train_loss: 5.074e-04 	 test_loss: 6.293e-04
# EPOCH 574: train_loss: 6.200e-04 	 test_loss: 6.487e-04
# EPOCH 575: train_loss: 4.604e-04 	 test_loss: 4.668e-04
# EPOCH 576: train_loss: 5.115e-04 	 test_loss: 4.877e-04
# EPOCH 577: train_loss: 5.142e-04 	 test_loss: 4.846e-04
# EPOCH 578: train_loss: 5.274e-04 	 test_loss: 7.776e-04
# EPOCH 579: train_loss: 4.511e-04 	 test_loss: 6.205e-04
# EPOCH 580: train_loss: 4.760e-04 	 test_loss: 5.551e-04
# EPOCH 581: train_loss: 4.662e-04 	 test_loss: 5.155e-04
# EPOCH 582: train_loss: 3.861e-04 	 test_loss: 4.027e-04
# EPOCH 583: train_loss: 3.904e-04 	 test_loss: 7.603e-04
# EPOCH 584: train_loss: 5.715e-04 	 test_loss: 5.753e-04
# EPOCH 585: train_loss: 4.388e-04 	 test_loss: 5.117e-04
# EPOCH 586: train_loss: 4.953e-04 	 test_loss: 8.099e-04
# EPOCH 587: train_loss: 6.365e-04 	 test_loss: 5.766e-04
# EPOCH 588: train_loss: 5.569e-04 	 test_loss: 5.449e-04
# EPOCH 589: train_loss: 5.088e-04 	 test_loss: 5.773e-04
# EPOCH 590: train_loss: 5.209e-04 	 test_loss: 4.804e-04
# EPOCH 591: train_loss: 4.115e-04 	 test_loss: 4.916e-04
# EPOCH 592: train_loss: 4.777e-04 	 test_loss: 6.748e-04
# EPOCH 593: train_loss: 4.654e-04 	 test_loss: 5.448e-04
# EPOCH 594: train_loss: 4.435e-04 	 test_loss: 5.112e-04
# EPOCH 595: train_loss: 4.365e-04 	 test_loss: 4.897e-04
# EPOCH 596: train_loss: 5.125e-04 	 test_loss: 4.920e-04
# EPOCH 597: train_loss: 5.388e-04 	 test_loss: 6.932e-04
# EPOCH 598: train_loss: 4.249e-04 	 test_loss: 4.796e-04
# EPOCH 599: train_loss: 4.218e-04 	 test_loss: 5.180e-04
# EPOCH 600: train_loss: 4.932e-04 	 test_loss: 5.847e-04
# EPOCH 601: train_loss: 4.342e-04 	 test_loss: 4.817e-04
# EPOCH 602: train_loss: 5.447e-04 	 test_loss: 5.235e-04
# EPOCH 603: train_loss: 4.788e-04 	 test_loss: 6.335e-04
# EPOCH 604: train_loss: 4.319e-04 	 test_loss: 4.826e-04
# EPOCH 605: train_loss: 4.143e-04 	 test_loss: 5.522e-04
# EPOCH 606: train_loss: 4.418e-04 	 test_loss: 6.218e-04
# EPOCH 607: train_loss: 3.971e-04 	 test_loss: 5.117e-04
# EPOCH 608: train_loss: 4.377e-04 	 test_loss: 5.566e-04
# EPOCH 609: train_loss: 3.943e-04 	 test_loss: 5.708e-04
# EPOCH 610: train_loss: 4.706e-04 	 test_loss: 8.297e-04
# EPOCH 611: train_loss: 4.243e-04 	 test_loss: 5.509e-04
# EPOCH 612: train_loss: 4.344e-04 	 test_loss: 5.798e-04
# EPOCH 613: train_loss: 4.791e-04 	 test_loss: 6.513e-04
# EPOCH 614: train_loss: 4.926e-04 	 test_loss: 5.579e-04
# EPOCH 615: train_loss: 4.693e-04 	 test_loss: 6.121e-04
# EPOCH 616: train_loss: 4.480e-04 	 test_loss: 4.806e-04
# EPOCH 617: train_loss: 4.966e-04 	 test_loss: 6.378e-04
# EPOCH 618: train_loss: 5.150e-04 	 test_loss: 5.803e-04
# EPOCH 619: train_loss: 4.983e-04 	 test_loss: 5.373e-04
# EPOCH 620: train_loss: 5.395e-04 	 test_loss: 5.943e-04
# EPOCH 621: train_loss: 4.466e-04 	 test_loss: 6.772e-04
# EPOCH 622: train_loss: 4.117e-04 	 test_loss: 7.216e-04
# EPOCH 623: train_loss: 4.537e-04 	 test_loss: 5.217e-04
# EPOCH 624: train_loss: 4.238e-04 	 test_loss: 4.907e-04
# EPOCH 625: train_loss: 4.182e-04 	 test_loss: 4.392e-04
# EPOCH 626: train_loss: 4.241e-04 	 test_loss: 5.513e-04
# EPOCH 627: train_loss: 4.264e-04 	 test_loss: 4.780e-04
# EPOCH 628: train_loss: 4.048e-04 	 test_loss: 5.706e-04
# EPOCH 629: train_loss: 3.904e-04 	 test_loss: 4.908e-04
# EPOCH 630: train_loss: 4.123e-04 	 test_loss: 4.594e-04
# EPOCH 631: train_loss: 4.024e-04 	 test_loss: 4.902e-04
# EPOCH 632: train_loss: 3.899e-04 	 test_loss: 7.027e-04
# EPOCH 633: train_loss: 3.900e-04 	 test_loss: 7.132e-04
# EPOCH 634: train_loss: 4.396e-04 	 test_loss: 7.681e-04
# EPOCH 635: train_loss: 5.010e-04 	 test_loss: 6.239e-04
# EPOCH 636: train_loss: 4.775e-04 	 test_loss: 6.006e-04
# EPOCH 637: train_loss: 4.926e-04 	 test_loss: 6.192e-04
# EPOCH 638: train_loss: 6.073e-04 	 test_loss: 5.708e-04
# EPOCH 639: train_loss: 6.253e-04 	 test_loss: 6.780e-04
# EPOCH 640: train_loss: 5.094e-04 	 test_loss: 9.184e-04
# EPOCH 641: train_loss: 5.979e-04 	 test_loss: 5.114e-04
# EPOCH 642: train_loss: 5.314e-04 	 test_loss: 5.610e-04
# EPOCH 643: train_loss: 4.311e-04 	 test_loss: 6.037e-04
# EPOCH 644: train_loss: 4.388e-04 	 test_loss: 5.654e-04
# EPOCH 645: train_loss: 5.484e-04 	 test_loss: 5.699e-04
# EPOCH 646: train_loss: 7.443e-04 	 test_loss: 7.383e-04
# EPOCH 647: train_loss: 6.129e-04 	 test_loss: 5.617e-04
# EPOCH 648: train_loss: 6.476e-04 	 test_loss: 7.426e-04
# EPOCH 649: train_loss: 6.551e-04 	 test_loss: 7.578e-04
# EPOCH 650: train_loss: 5.751e-04 	 test_loss: 6.259e-04
# EPOCH 651: train_loss: 4.967e-04 	 test_loss: 6.117e-04
# EPOCH 652: train_loss: 4.589e-04 	 test_loss: 7.773e-04
# EPOCH 653: train_loss: 5.647e-04 	 test_loss: 5.310e-04
# EPOCH 654: train_loss: 4.413e-04 	 test_loss: 5.299e-04
# EPOCH 655: train_loss: 4.244e-04 	 test_loss: 7.087e-04
# EPOCH 656: train_loss: 4.288e-04 	 test_loss: 5.796e-04
# EPOCH 657: train_loss: 4.143e-04 	 test_loss: 4.692e-04
# EPOCH 658: train_loss: 4.354e-04 	 test_loss: 6.822e-04
# EPOCH 659: train_loss: 4.161e-04 	 test_loss: 5.933e-04
# EPOCH 660: train_loss: 4.233e-04 	 test_loss: 5.351e-04
# EPOCH 661: train_loss: 4.212e-04 	 test_loss: 6.537e-04
# EPOCH 662: train_loss: 4.820e-04 	 test_loss: 4.865e-04
# EPOCH 663: train_loss: 5.106e-04 	 test_loss: 4.599e-04
# EPOCH 664: train_loss: 4.540e-04 	 test_loss: 6.314e-04
# EPOCH 665: train_loss: 3.952e-04 	 test_loss: 5.666e-04
# EPOCH 666: train_loss: 4.802e-04 	 test_loss: 4.948e-04
# EPOCH 667: train_loss: 4.273e-04 	 test_loss: 6.191e-04
# EPOCH 668: train_loss: 3.828e-04 	 test_loss: 6.551e-04
# EPOCH 669: train_loss: 4.684e-04 	 test_loss: 5.278e-04
# EPOCH 670: train_loss: 4.415e-04 	 test_loss: 6.101e-04
# EPOCH 671: train_loss: 3.658e-04 	 test_loss: 5.897e-04
# EPOCH 672: train_loss: 4.016e-04 	 test_loss: 5.311e-04
# EPOCH 673: train_loss: 4.511e-04 	 test_loss: 4.742e-04
# EPOCH 674: train_loss: 4.084e-04 	 test_loss: 5.992e-04
# EPOCH 675: train_loss: 3.670e-04 	 test_loss: 5.289e-04
# EPOCH 676: train_loss: 4.263e-04 	 test_loss: 6.725e-04
# EPOCH 677: train_loss: 3.950e-04 	 test_loss: 5.789e-04
# EPOCH 678: train_loss: 4.137e-04 	 test_loss: 6.293e-04
# EPOCH 679: train_loss: 4.791e-04 	 test_loss: 5.863e-04
# EPOCH 680: train_loss: 4.035e-04 	 test_loss: 4.208e-04
# EPOCH 681: train_loss: 4.034e-04 	 test_loss: 5.743e-04
# EPOCH 682: train_loss: 3.937e-04 	 test_loss: 6.686e-04
# EPOCH 683: train_loss: 4.314e-04 	 test_loss: 7.014e-04
# EPOCH 684: train_loss: 6.741e-04 	 test_loss: 6.592e-04
# EPOCH 685: train_loss: 4.767e-04 	 test_loss: 7.035e-04
# EPOCH 686: train_loss: 4.093e-04 	 test_loss: 6.799e-04
# EPOCH 687: train_loss: 4.378e-04 	 test_loss: 6.871e-04
# EPOCH 688: train_loss: 5.054e-04 	 test_loss: 8.396e-04
# EPOCH 689: train_loss: 5.984e-04 	 test_loss: 9.808e-04
# EPOCH 690: train_loss: 6.118e-04 	 test_loss: 6.892e-04
# EPOCH 691: train_loss: 5.477e-04 	 test_loss: 4.450e-04
# EPOCH 692: train_loss: 4.745e-04 	 test_loss: 8.499e-04
# EPOCH 693: train_loss: 4.644e-04 	 test_loss: 7.776e-04
# EPOCH 694: train_loss: 4.063e-04 	 test_loss: 4.317e-04
# EPOCH 695: train_loss: 4.016e-04 	 test_loss: 1.027e-03
# EPOCH 696: train_loss: 5.617e-04 	 test_loss: 4.323e-04
# EPOCH 697: train_loss: 4.524e-04 	 test_loss: 6.663e-04
# EPOCH 698: train_loss: 4.659e-04 	 test_loss: 4.878e-04
# EPOCH 699: train_loss: 4.601e-04 	 test_loss: 4.746e-04
# EPOCH 700: train_loss: 4.334e-04 	 test_loss: 1.078e-03
# EPOCH 701: train_loss: 6.419e-04 	 test_loss: 4.899e-04
# EPOCH 702: train_loss: 6.078e-04 	 test_loss: 5.235e-04
# EPOCH 703: train_loss: 5.031e-04 	 test_loss: 7.636e-04
# EPOCH 704: train_loss: 4.837e-04 	 test_loss: 5.467e-04
# EPOCH 705: train_loss: 4.327e-04 	 test_loss: 5.261e-04
# EPOCH 706: train_loss: 4.210e-04 	 test_loss: 5.649e-04
# EPOCH 707: train_loss: 4.204e-04 	 test_loss: 5.758e-04
# EPOCH 708: train_loss: 4.188e-04 	 test_loss: 5.052e-04
# EPOCH 709: train_loss: 3.684e-04 	 test_loss: 6.593e-04
# EPOCH 710: train_loss: 4.152e-04 	 test_loss: 6.310e-04
# EPOCH 711: train_loss: 3.865e-04 	 test_loss: 5.515e-04
# EPOCH 712: train_loss: 3.608e-04 	 test_loss: 5.427e-04
# EPOCH 713: train_loss: 3.550e-04 	 test_loss: 6.959e-04
# EPOCH 714: train_loss: 4.455e-04 	 test_loss: 3.956e-04
# EPOCH 715: train_loss: 3.850e-04 	 test_loss: 6.926e-04
# EPOCH 716: train_loss: 3.883e-04 	 test_loss: 5.066e-04
# EPOCH 717: train_loss: 4.320e-04 	 test_loss: 5.915e-04
# EPOCH 718: train_loss: 3.827e-04 	 test_loss: 6.014e-04
# EPOCH 719: train_loss: 3.784e-04 	 test_loss: 5.241e-04
# EPOCH 720: train_loss: 4.111e-04 	 test_loss: 7.960e-04
# EPOCH 721: train_loss: 4.071e-04 	 test_loss: 4.118e-04
# EPOCH 722: train_loss: 4.273e-04 	 test_loss: 7.488e-04
# EPOCH 723: train_loss: 4.826e-04 	 test_loss: 4.065e-04
# EPOCH 724: train_loss: 4.034e-04 	 test_loss: 6.928e-04
# EPOCH 725: train_loss: 4.157e-04 	 test_loss: 5.603e-04
# EPOCH 726: train_loss: 4.174e-04 	 test_loss: 5.320e-04
# EPOCH 727: train_loss: 3.753e-04 	 test_loss: 4.303e-04
# EPOCH 728: train_loss: 5.611e-04 	 test_loss: 5.804e-04
# EPOCH 729: train_loss: 4.349e-04 	 test_loss: 5.618e-04
# EPOCH 730: train_loss: 5.116e-04 	 test_loss: 9.421e-04
# EPOCH 731: train_loss: 5.949e-04 	 test_loss: 9.933e-04
# EPOCH 732: train_loss: 5.000e-04 	 test_loss: 5.854e-04
# EPOCH 733: train_loss: 4.361e-04 	 test_loss: 5.099e-04
# EPOCH 734: train_loss: 4.214e-04 	 test_loss: 5.055e-04
# EPOCH 735: train_loss: 4.555e-04 	 test_loss: 4.533e-04
# EPOCH 736: train_loss: 3.530e-04 	 test_loss: 5.647e-04
# EPOCH 737: train_loss: 4.528e-04 	 test_loss: 5.284e-04
# EPOCH 738: train_loss: 4.146e-04 	 test_loss: 5.778e-04
# EPOCH 739: train_loss: 5.920e-04 	 test_loss: 6.298e-04
# EPOCH 740: train_loss: 4.629e-04 	 test_loss: 5.101e-04
# EPOCH 741: train_loss: 4.593e-04 	 test_loss: 5.474e-04
# EPOCH 742: train_loss: 4.020e-04 	 test_loss: 5.595e-04
# EPOCH 743: train_loss: 4.128e-04 	 test_loss: 6.842e-04
# EPOCH 744: train_loss: 4.466e-04 	 test_loss: 5.760e-04
# EPOCH 745: train_loss: 5.340e-04 	 test_loss: 6.117e-04
# EPOCH 746: train_loss: 4.174e-04 	 test_loss: 6.367e-04
# EPOCH 747: train_loss: 5.361e-04 	 test_loss: 6.173e-04
# EPOCH 748: train_loss: 4.511e-04 	 test_loss: 5.649e-04
# EPOCH 749: train_loss: 5.539e-04 	 test_loss: 6.188e-04
# EPOCH 750: train_loss: 5.464e-04 	 test_loss: 6.317e-04
# EPOCH 751: train_loss: 5.557e-04 	 test_loss: 5.312e-04
# EPOCH 752: train_loss: 5.608e-04 	 test_loss: 7.114e-04
# EPOCH 753: train_loss: 5.112e-04 	 test_loss: 5.323e-04
# EPOCH 754: train_loss: 4.236e-04 	 test_loss: 6.750e-04
# EPOCH 755: train_loss: 4.980e-04 	 test_loss: 5.790e-04
# EPOCH 756: train_loss: 4.566e-04 	 test_loss: 5.289e-04
# EPOCH 757: train_loss: 4.574e-04 	 test_loss: 6.562e-04
# EPOCH 758: train_loss: 3.438e-04 	 test_loss: 5.609e-04
# EPOCH 759: train_loss: 4.819e-04 	 test_loss: 5.744e-04
# EPOCH 760: train_loss: 5.272e-04 	 test_loss: 7.955e-04
# EPOCH 761: train_loss: 7.274e-04 	 test_loss: 6.898e-04
# EPOCH 762: train_loss: 5.698e-04 	 test_loss: 6.150e-04
# EPOCH 763: train_loss: 4.744e-04 	 test_loss: 5.406e-04
# EPOCH 764: train_loss: 4.436e-04 	 test_loss: 5.986e-04
# EPOCH 765: train_loss: 4.038e-04 	 test_loss: 5.063e-04
# EPOCH 766: train_loss: 4.647e-04 	 test_loss: 6.496e-04
# EPOCH 767: train_loss: 5.053e-04 	 test_loss: 6.935e-04
# EPOCH 768: train_loss: 4.130e-04 	 test_loss: 4.837e-04
# EPOCH 769: train_loss: 4.563e-04 	 test_loss: 5.513e-04
# EPOCH 770: train_loss: 4.662e-04 	 test_loss: 6.586e-04
# EPOCH 771: train_loss: 5.096e-04 	 test_loss: 6.913e-04
# EPOCH 772: train_loss: 4.689e-04 	 test_loss: 5.972e-04
# EPOCH 773: train_loss: 4.434e-04 	 test_loss: 7.408e-04
# EPOCH 774: train_loss: 5.386e-04 	 test_loss: 4.812e-04
# EPOCH 775: train_loss: 4.042e-04 	 test_loss: 5.432e-04
# EPOCH 776: train_loss: 4.270e-04 	 test_loss: 5.637e-04
# EPOCH 777: train_loss: 4.296e-04 	 test_loss: 4.951e-04
# EPOCH 778: train_loss: 4.114e-04 	 test_loss: 5.293e-04
# EPOCH 779: train_loss: 4.028e-04 	 test_loss: 5.713e-04
# EPOCH 780: train_loss: 5.048e-04 	 test_loss: 5.606e-04
# EPOCH 781: train_loss: 5.179e-04 	 test_loss: 5.421e-04
# EPOCH 782: train_loss: 4.233e-04 	 test_loss: 6.096e-04
# EPOCH 783: train_loss: 3.529e-04 	 test_loss: 4.540e-04
# EPOCH 784: train_loss: 3.782e-04 	 test_loss: 5.333e-04
# EPOCH 785: train_loss: 3.869e-04 	 test_loss: 5.230e-04
# EPOCH 786: train_loss: 4.022e-04 	 test_loss: 5.642e-04
# EPOCH 787: train_loss: 3.505e-04 	 test_loss: 7.565e-04
# EPOCH 788: train_loss: 4.516e-04 	 test_loss: 4.890e-04
# EPOCH 789: train_loss: 3.959e-04 	 test_loss: 4.996e-04
# EPOCH 790: train_loss: 4.050e-04 	 test_loss: 5.621e-04
# EPOCH 791: train_loss: 3.967e-04 	 test_loss: 5.842e-04
# EPOCH 792: train_loss: 3.995e-04 	 test_loss: 5.165e-04
# EPOCH 793: train_loss: 4.932e-04 	 test_loss: 5.528e-04
# EPOCH 794: train_loss: 4.826e-04 	 test_loss: 6.186e-04
# EPOCH 795: train_loss: 4.954e-04 	 test_loss: 6.183e-04
# EPOCH 796: train_loss: 3.497e-04 	 test_loss: 4.695e-04
# EPOCH 797: train_loss: 3.905e-04 	 test_loss: 6.889e-04
# EPOCH 798: train_loss: 4.472e-04 	 test_loss: 6.120e-04
# EPOCH 799: train_loss: 3.417e-04 	 test_loss: 5.998e-04
# EPOCH 800: train_loss: 3.955e-04 	 test_loss: 5.624e-04
# EPOCH 801: train_loss: 3.648e-04 	 test_loss: 5.389e-04
# EPOCH 802: train_loss: 3.308e-04 	 test_loss: 4.520e-04
# EPOCH 803: train_loss: 4.351e-04 	 test_loss: 6.206e-04
# EPOCH 804: train_loss: 3.977e-04 	 test_loss: 5.833e-04
# EPOCH 805: train_loss: 4.421e-04 	 test_loss: 5.675e-04
# EPOCH 806: train_loss: 3.707e-04 	 test_loss: 5.954e-04
# EPOCH 807: train_loss: 4.188e-04 	 test_loss: 4.512e-04
# EPOCH 808: train_loss: 4.176e-04 	 test_loss: 6.375e-04
# EPOCH 809: train_loss: 3.861e-04 	 test_loss: 5.532e-04
# EPOCH 810: train_loss: 5.116e-04 	 test_loss: 6.485e-04
# EPOCH 811: train_loss: 4.134e-04 	 test_loss: 6.806e-04
# EPOCH 812: train_loss: 3.970e-04 	 test_loss: 5.307e-04
# EPOCH 813: train_loss: 4.747e-04 	 test_loss: 4.694e-04
# EPOCH 814: train_loss: 4.398e-04 	 test_loss: 4.759e-04
# EPOCH 815: train_loss: 3.981e-04 	 test_loss: 7.011e-04
# EPOCH 816: train_loss: 4.182e-04 	 test_loss: 5.948e-04
# EPOCH 817: train_loss: 4.292e-04 	 test_loss: 5.011e-04
# EPOCH 818: train_loss: 4.397e-04 	 test_loss: 5.817e-04
# EPOCH 819: train_loss: 4.610e-04 	 test_loss: 4.152e-04
# EPOCH 820: train_loss: 4.658e-04 	 test_loss: 6.213e-04
# EPOCH 821: train_loss: 4.130e-04 	 test_loss: 5.150e-04
# EPOCH 822: train_loss: 4.532e-04 	 test_loss: 6.027e-04
# EPOCH 823: train_loss: 4.104e-04 	 test_loss: 6.013e-04
# EPOCH 824: train_loss: 4.026e-04 	 test_loss: 7.191e-04
# EPOCH 825: train_loss: 4.752e-04 	 test_loss: 7.096e-04
# EPOCH 826: train_loss: 3.854e-04 	 test_loss: 5.176e-04
# EPOCH 827: train_loss: 4.096e-04 	 test_loss: 5.644e-04
# EPOCH 828: train_loss: 3.888e-04 	 test_loss: 5.496e-04
# EPOCH 829: train_loss: 4.674e-04 	 test_loss: 7.229e-04
# EPOCH 830: train_loss: 4.771e-04 	 test_loss: 5.274e-04
# EPOCH 831: train_loss: 3.913e-04 	 test_loss: 5.357e-04
# EPOCH 832: train_loss: 4.681e-04 	 test_loss: 7.883e-04
# EPOCH 833: train_loss: 4.675e-04 	 test_loss: 5.325e-04
# EPOCH 834: train_loss: 4.312e-04 	 test_loss: 4.735e-04
# EPOCH 835: train_loss: 4.739e-04 	 test_loss: 5.340e-04
# EPOCH 836: train_loss: 3.871e-04 	 test_loss: 5.490e-04
# EPOCH 837: train_loss: 4.577e-04 	 test_loss: 5.328e-04
# EPOCH 838: train_loss: 3.241e-04 	 test_loss: 7.541e-04
# EPOCH 839: train_loss: 3.927e-04 	 test_loss: 5.460e-04
# EPOCH 840: train_loss: 4.578e-04 	 test_loss: 5.201e-04
# EPOCH 841: train_loss: 3.879e-04 	 test_loss: 5.585e-04
# EPOCH 842: train_loss: 4.365e-04 	 test_loss: 6.059e-04
# EPOCH 843: train_loss: 4.526e-04 	 test_loss: 5.556e-04
# EPOCH 844: train_loss: 3.824e-04 	 test_loss: 4.806e-04
# EPOCH 845: train_loss: 3.352e-04 	 test_loss: 7.109e-04
# EPOCH 846: train_loss: 3.052e-04 	 test_loss: 5.573e-04
# EPOCH 847: train_loss: 4.339e-04 	 test_loss: 5.975e-04
# EPOCH 848: train_loss: 3.899e-04 	 test_loss: 5.820e-04
# EPOCH 849: train_loss: 4.311e-04 	 test_loss: 5.201e-04
# EPOCH 850: train_loss: 4.690e-04 	 test_loss: 5.349e-04
# EPOCH 851: train_loss: 4.188e-04 	 test_loss: 5.093e-04
# EPOCH 852: train_loss: 4.262e-04 	 test_loss: 4.638e-04
# EPOCH 853: train_loss: 3.722e-04 	 test_loss: 5.828e-04
# EPOCH 854: train_loss: 3.851e-04 	 test_loss: 4.808e-04
# EPOCH 855: train_loss: 4.307e-04 	 test_loss: 4.635e-04
# EPOCH 856: train_loss: 3.673e-04 	 test_loss: 4.771e-04
# EPOCH 857: train_loss: 3.968e-04 	 test_loss: 5.703e-04
# EPOCH 858: train_loss: 3.942e-04 	 test_loss: 4.678e-04
# ...
# EPOCH 1220: train_loss: 3.312e-04 	 test_loss: 4.724e-04
# EPOCH 1221: train_loss: 3.397e-04 	 test_loss: 4.535e-04
# EPOCH 1222: train_loss: 3.259e-04 	 test_loss: 5.272e-04
# EPOCH 1223: train_loss: 3.233e-04 	 test_loss: 4.740e-04
# EPOCH 1224: train_loss: 3.683e-04 	 test_loss: 4.218e-04
# EPOCH 1225: train_loss: 3.755e-04 	 test_loss: 5.170e-04
# EPOCH 1226: train_loss: 3.405e-04 	 test_loss: 6.230e-04
# EPOCH 1227: train_loss: 2.953e-04 	 test_loss: 4.565e-04
# EPOCH 1228: train_loss: 3.253e-04 	 test_loss: 5.366e-04
# EPOCH 1229: train_loss: 3.350e-04 	 test_loss: 6.412e-04
# EPOCH 1230: train_loss: 2.680e-04 	 test_loss: 3.927e-04
# EPOCH 1231: train_loss: 3.082e-04 	 test_loss: 4.856e-04
# EPOCH 1232: train_loss: 2.758e-04 	 test_loss: 4.845e-04
# EPOCH 1233: train_loss: 3.786e-04 	 test_loss: 5.110e-04
# EPOCH 1234: train_loss: 3.569e-04 	 test_loss: 4.862e-04
# EPOCH 1235: train_loss: 4.158e-04 	 test_loss: 5.487e-04
# EPOCH 1236: train_loss: 3.205e-04 	 test_loss: 4.946e-04
# EPOCH 1237: train_loss: 3.234e-04 	 test_loss: 5.201e-04
# EPOCH 1238: train_loss: 2.843e-04 	 test_loss: 4.453e-04
# EPOCH 1239: train_loss: 2.935e-04 	 test_loss: 4.973e-04
# EPOCH 1240: train_loss: 3.135e-04 	 test_loss: 5.411e-04
# EPOCH 1241: train_loss: 3.518e-04 	 test_loss: 4.522e-04
# EPOCH 1242: train_loss: 3.463e-04 	 test_loss: 5.487e-04
# EPOCH 1243: train_loss: 3.143e-04 	 test_loss: 4.675e-04
# EPOCH 1244: train_loss: 2.786e-04 	 test_loss: 5.467e-04
# EPOCH 1245: train_loss: 3.366e-04 	 test_loss: 5.817e-04
# EPOCH 1246: train_loss: 3.245e-04 	 test_loss: 4.787e-04
# EPOCH 1247: train_loss: 2.808e-04 	 test_loss: 4.851e-04
# EPOCH 1248: train_loss: 3.428e-04 	 test_loss: 5.093e-04
# EPOCH 1249: train_loss: 3.799e-04 	 test_loss: 4.752e-04
# EPOCH 1250: train_loss: 3.058e-04 	 test_loss: 4.797e-04
# EPOCH 1251: train_loss: 2.954e-04 	 test_loss: 4.340e-04
# EPOCH 1252: train_loss: 3.342e-04 	 test_loss: 5.672e-04
# EPOCH 1253: train_loss: 3.260e-04 	 test_loss: 4.870e-04
# EPOCH 1254: train_loss: 4.331e-04 	 test_loss: 6.720e-04
# EPOCH 1255: train_loss: 3.583e-04 	 test_loss: 4.991e-04
# EPOCH 1256: train_loss: 3.505e-04 	 test_loss: 5.572e-04
# EPOCH 1257: train_loss: 3.363e-04 	 test_loss: 5.200e-04
# EPOCH 1258: train_loss: 3.739e-04 	 test_loss: 4.635e-04
# EPOCH 1259: train_loss: 3.650e-04 	 test_loss: 6.128e-04
# EPOCH 1260: train_loss: 3.373e-04 	 test_loss: 4.845e-04
# EPOCH 1261: train_loss: 4.888e-04 	 test_loss: 5.467e-04
# EPOCH 1262: train_loss: 3.340e-04 	 test_loss: 5.154e-04
# EPOCH 1263: train_loss: 3.206e-04 	 test_loss: 4.967e-04
# EPOCH 1264: train_loss: 3.537e-04 	 test_loss: 4.870e-04
# EPOCH 1265: train_loss: 3.325e-04 	 test_loss: 5.037e-04
# EPOCH 1266: train_loss: 3.403e-04 	 test_loss: 5.276e-04
# EPOCH 1267: train_loss: 3.512e-04 	 test_loss: 4.995e-04
# EPOCH 1268: train_loss: 2.847e-04 	 test_loss: 5.533e-04
# EPOCH 1269: train_loss: 2.677e-04 	 test_loss: 8.456e-04
# EPOCH 1270: train_loss: 2.791e-04 	 test_loss: 6.673e-04
# EPOCH 1271: train_loss: 2.992e-04 	 test_loss: 5.751e-04
# EPOCH 1272: train_loss: 3.764e-04 	 test_loss: 5.891e-04
# EPOCH 1273: train_loss: 3.464e-04 	 test_loss: 5.370e-04
# EPOCH 1274: train_loss: 3.332e-04 	 test_loss: 5.917e-04
# EPOCH 1275: train_loss: 3.532e-04 	 test_loss: 5.497e-04
# EPOCH 1276: train_loss: 3.551e-04 	 test_loss: 5.428e-04
# EPOCH 1277: train_loss: 3.416e-04 	 test_loss: 5.075e-04
# EPOCH 1278: train_loss: 3.358e-04 	 test_loss: 5.023e-04
# EPOCH 1279: train_loss: 3.059e-04 	 test_loss: 5.289e-04
# EPOCH 1280: train_loss: 2.907e-04 	 test_loss: 5.033e-04
# EPOCH 1281: train_loss: 3.661e-04 	 test_loss: 6.567e-04
# EPOCH 1282: train_loss: 3.905e-04 	 test_loss: 4.601e-04
# EPOCH 1283: train_loss: 3.408e-04 	 test_loss: 4.685e-04
# EPOCH 1284: train_loss: 2.943e-04 	 test_loss: 6.100e-04
# EPOCH 1285: train_loss: 2.596e-04 	 test_loss: 5.604e-04
# EPOCH 1286: train_loss: 3.054e-04 	 test_loss: 4.407e-04
# EPOCH 1287: train_loss: 3.530e-04 	 test_loss: 5.959e-04
# EPOCH 1288: train_loss: 3.540e-04 	 test_loss: 5.241e-04
# EPOCH 1289: train_loss: 2.870e-04 	 test_loss: 5.309e-04
# EPOCH 1290: train_loss: 2.720e-04 	 test_loss: 5.737e-04
# EPOCH 1291: train_loss: 2.966e-04 	 test_loss: 4.356e-04
# EPOCH 1292: train_loss: 3.528e-04 	 test_loss: 4.921e-04
# EPOCH 1293: train_loss: 3.791e-04 	 test_loss: 7.024e-04
# EPOCH 1294: train_loss: 3.344e-04 	 test_loss: 5.689e-04
# EPOCH 1295: train_loss: 3.012e-04 	 test_loss: 5.008e-04
# EPOCH 1296: train_loss: 3.105e-04 	 test_loss: 6.276e-04
# EPOCH 1297: train_loss: 3.105e-04 	 test_loss: 5.796e-04
# EPOCH 1298: train_loss: 3.835e-04 	 test_loss: 5.460e-04
# EPOCH 1299: train_loss: 3.081e-04 	 test_loss: 5.010e-04
# EPOCH 1300: train_loss: 3.477e-04 	 test_loss: 5.318e-04
# EPOCH 1301: train_loss: 3.603e-04 	 test_loss: 5.220e-04
# EPOCH 1302: train_loss: 2.643e-04 	 test_loss: 6.037e-04
# EPOCH 1303: train_loss: 3.059e-04 	 test_loss: 4.623e-04
# EPOCH 1304: train_loss: 3.000e-04 	 test_loss: 5.223e-04
# EPOCH 1305: train_loss: 3.323e-04 	 test_loss: 6.103e-04
# EPOCH 1306: train_loss: 3.013e-04 	 test_loss: 5.419e-04
# EPOCH 1307: train_loss: 2.999e-04 	 test_loss: 4.505e-04
# EPOCH 1308: train_loss: 2.680e-04 	 test_loss: 4.793e-04
# EPOCH 1309: train_loss: 3.183e-04 	 test_loss: 4.149e-04
# EPOCH 1310: train_loss: 3.162e-04 	 test_loss: 4.768e-04
# EPOCH 1311: train_loss: 2.856e-04 	 test_loss: 4.876e-04
# EPOCH 1312: train_loss: 2.818e-04 	 test_loss: 4.441e-04
# EPOCH 1313: train_loss: 2.901e-04 	 test_loss: 4.763e-04
# EPOCH 1314: train_loss: 2.650e-04 	 test_loss: 4.462e-04
# EPOCH 1315: train_loss: 3.118e-04 	 test_loss: 5.503e-04
# EPOCH 1316: train_loss: 2.914e-04 	 test_loss: 4.602e-04
# EPOCH 1317: train_loss: 3.446e-04 	 test_loss: 4.931e-04
# EPOCH 1318: train_loss: 2.745e-04 	 test_loss: 5.822e-04
# EPOCH 1319: train_loss: 3.584e-04 	 test_loss: 4.774e-04
# EPOCH 1320: train_loss: 3.456e-04 	 test_loss: 4.994e-04
# EPOCH 1321: train_loss: 3.498e-04 	 test_loss: 5.144e-04
# EPOCH 1322: train_loss: 3.353e-04 	 test_loss: 4.870e-04
# EPOCH 1323: train_loss: 3.883e-04 	 test_loss: 6.117e-04
# EPOCH 1324: train_loss: 3.218e-04 	 test_loss: 4.812e-04
# EPOCH 1325: train_loss: 2.771e-04 	 test_loss: 5.145e-04
# EPOCH 1326: train_loss: 2.965e-04 	 test_loss: 5.094e-04
# EPOCH 1327: train_loss: 2.487e-04 	 test_loss: 4.754e-04
# EPOCH 1328: train_loss: 2.907e-04 	 test_loss: 5.104e-04
# EPOCH 1329: train_loss: 2.782e-04 	 test_loss: 5.522e-04
# EPOCH 1330: train_loss: 3.183e-04 	 test_loss: 5.202e-04
# EPOCH 1331: train_loss: 2.905e-04 	 test_loss: 4.469e-04
# EPOCH 1332: train_loss: 3.499e-04 	 test_loss: 5.660e-04
# EPOCH 1333: train_loss: 3.314e-04 	 test_loss: 4.905e-04
# EPOCH 1334: train_loss: 3.100e-04 	 test_loss: 4.747e-04
# EPOCH 1335: train_loss: 2.812e-04 	 test_loss: 4.708e-04
# EPOCH 1336: train_loss: 2.995e-04 	 test_loss: 4.883e-04
# EPOCH 1337: train_loss: 3.203e-04 	 test_loss: 8.681e-04
# EPOCH 1338: train_loss: 2.926e-04 	 test_loss: 4.919e-04
# EPOCH 1339: train_loss: 2.640e-04 	 test_loss: 4.549e-04
# EPOCH 1340: train_loss: 3.754e-04 	 test_loss: 4.867e-04
# EPOCH 1341: train_loss: 3.976e-04 	 test_loss: 7.842e-04
# EPOCH 1342: train_loss: 4.362e-04 	 test_loss: 5.846e-04
# EPOCH 1343: train_loss: 3.443e-04 	 test_loss: 6.584e-04
# EPOCH 1344: train_loss: 3.598e-04 	 test_loss: 6.412e-04
# EPOCH 1345: train_loss: 3.180e-04 	 test_loss: 4.919e-04
# EPOCH 1346: train_loss: 3.061e-04 	 test_loss: 4.828e-04
# EPOCH 1347: train_loss: 2.580e-04 	 test_loss: 5.404e-04
# EPOCH 1348: train_loss: 3.349e-04 	 test_loss: 6.492e-04
# EPOCH 1349: train_loss: 3.671e-04 	 test_loss: 5.549e-04
# EPOCH 1350: train_loss: 3.522e-04 	 test_loss: 5.139e-04
# EPOCH 1351: train_loss: 2.853e-04 	 test_loss: 6.043e-04
# EPOCH 1352: train_loss: 3.238e-04 	 test_loss: 4.841e-04
# EPOCH 1353: train_loss: 3.467e-04 	 test_loss: 5.611e-04
# EPOCH 1354: train_loss: 2.863e-04 	 test_loss: 4.819e-04
# EPOCH 1355: train_loss: 3.071e-04 	 test_loss: 5.238e-04
# EPOCH 1356: train_loss: 3.614e-04 	 test_loss: 6.126e-04
# EPOCH 1357: train_loss: 3.119e-04 	 test_loss: 5.213e-04
# EPOCH 1358: train_loss: 2.995e-04 	 test_loss: 4.954e-04
# EPOCH 1359: train_loss: 3.156e-04 	 test_loss: 6.573e-04
# EPOCH 1360: train_loss: 3.791e-04 	 test_loss: 5.911e-04
# EPOCH 1361: train_loss: 3.350e-04 	 test_loss: 5.348e-04
# EPOCH 1362: train_loss: 2.524e-04 	 test_loss: 5.997e-04
# EPOCH 1363: train_loss: 2.811e-04 	 test_loss: 5.043e-04
# EPOCH 1364: train_loss: 2.962e-04 	 test_loss: 5.469e-04
# EPOCH 1365: train_loss: 3.298e-04 	 test_loss: 5.550e-04
# EPOCH 1366: train_loss: 2.822e-04 	 test_loss: 4.485e-04
# EPOCH 1367: train_loss: 2.476e-04 	 test_loss: 5.625e-04
# EPOCH 1368: train_loss: 2.748e-04 	 test_loss: 4.986e-04
# EPOCH 1369: train_loss: 3.230e-04 	 test_loss: 6.443e-04
# EPOCH 1370: train_loss: 3.376e-04 	 test_loss: 5.067e-04
# EPOCH 1371: train_loss: 3.049e-04 	 test_loss: 4.887e-04
# EPOCH 1372: train_loss: 3.380e-04 	 test_loss: 5.963e-04
# EPOCH 1373: train_loss: 3.438e-04 	 test_loss: 5.642e-04
# EPOCH 1374: train_loss: 2.913e-04 	 test_loss: 4.756e-04
# EPOCH 1375: train_loss: 3.332e-04 	 test_loss: 5.272e-04
# EPOCH 1376: train_loss: 2.854e-04 	 test_loss: 4.603e-04
# EPOCH 1377: train_loss: 3.088e-04 	 test_loss: 6.014e-04
# EPOCH 1378: train_loss: 3.739e-04 	 test_loss: 5.384e-04
# EPOCH 1379: train_loss: 2.820e-04 	 test_loss: 7.826e-04
# EPOCH 1380: train_loss: 3.652e-04 	 test_loss: 4.933e-04
# EPOCH 1381: train_loss: 3.275e-04 	 test_loss: 5.850e-04
# EPOCH 1382: train_loss: 3.562e-04 	 test_loss: 5.617e-04
# EPOCH 1383: train_loss: 2.867e-04 	 test_loss: 4.693e-04
# EPOCH 1384: train_loss: 3.528e-04 	 test_loss: 5.348e-04
# EPOCH 1385: train_loss: 2.879e-04 	 test_loss: 5.107e-04
# EPOCH 1386: train_loss: 3.037e-04 	 test_loss: 4.911e-04
# EPOCH 1387: train_loss: 3.222e-04 	 test_loss: 5.351e-04
# EPOCH 1388: train_loss: 3.036e-04 	 test_loss: 5.366e-04
# EPOCH 1389: train_loss: 3.686e-04 	 test_loss: 4.970e-04
# EPOCH 1390: train_loss: 3.710e-04 	 test_loss: 5.114e-04
# EPOCH 1391: train_loss: 3.076e-04 	 test_loss: 5.053e-04
# EPOCH 1392: train_loss: 2.818e-04 	 test_loss: 4.694e-04
# EPOCH 1393: train_loss: 3.360e-04 	 test_loss: 5.575e-04
# EPOCH 1394: train_loss: 3.854e-04 	 test_loss: 5.717e-04
# EPOCH 1395: train_loss: 3.772e-04 	 test_loss: 6.025e-04
# EPOCH 1396: train_loss: 3.754e-04 	 test_loss: 5.170e-04
# EPOCH 1397: train_loss: 4.636e-04 	 test_loss: 6.794e-04
# EPOCH 1398: train_loss: 4.288e-04 	 test_loss: 7.708e-04
# EPOCH 1399: train_loss: 4.292e-04 	 test_loss: 7.689e-04
# EPOCH 1400: train_loss: 5.693e-04 	 test_loss: 7.190e-04
# EPOCH 1401: train_loss: 5.225e-04 	 test_loss: 5.648e-04
# EPOCH 1402: train_loss: 4.848e-04 	 test_loss: 7.162e-04
# EPOCH 1403: train_loss: 3.603e-04 	 test_loss: 5.570e-04
# EPOCH 1404: train_loss: 3.082e-04 	 test_loss: 4.520e-04
# EPOCH 1405: train_loss: 3.578e-04 	 test_loss: 5.663e-04
# EPOCH 1406: train_loss: 3.266e-04 	 test_loss: 5.348e-04
# EPOCH 1407: train_loss: 3.439e-04 	 test_loss: 5.884e-04
# EPOCH 1408: train_loss: 2.973e-04 	 test_loss: 5.408e-04
# EPOCH 1409: train_loss: 2.971e-04 	 test_loss: 4.866e-04
# EPOCH 1410: train_loss: 2.341e-04 	 test_loss: 5.360e-04
# EPOCH 1411: train_loss: 2.741e-04 	 test_loss: 8.254e-04
# EPOCH 1412: train_loss: 3.540e-04 	 test_loss: 5.259e-04
# EPOCH 1413: train_loss: 3.239e-04 	 test_loss: 5.126e-04
# EPOCH 1414: train_loss: 3.658e-04 	 test_loss: 5.746e-04
# EPOCH 1415: train_loss: 3.173e-04 	 test_loss: 5.673e-04
# EPOCH 1416: train_loss: 2.913e-04 	 test_loss: 5.997e-04
# EPOCH 1417: train_loss: 2.721e-04 	 test_loss: 4.523e-04
# EPOCH 1418: train_loss: 3.372e-04 	 test_loss: 4.902e-04
# EPOCH 1419: train_loss: 2.972e-04 	 test_loss: 5.258e-04
# EPOCH 1420: train_loss: 3.675e-04 	 test_loss: 6.595e-04
# EPOCH 1421: train_loss: 3.650e-04 	 test_loss: 6.886e-04
# EPOCH 1422: train_loss: 3.096e-04 	 test_loss: 4.954e-04
# EPOCH 1423: train_loss: 2.713e-04 	 test_loss: 4.736e-04
# EPOCH 1424: train_loss: 3.256e-04 	 test_loss: 5.414e-04
# EPOCH 1425: train_loss: 2.940e-04 	 test_loss: 5.374e-04
# EPOCH 1426: train_loss: 2.744e-04 	 test_loss: 6.025e-04
# EPOCH 1427: train_loss: 4.160e-04 	 test_loss: 7.240e-04
# EPOCH 1428: train_loss: 4.345e-04 	 test_loss: 5.389e-04
# EPOCH 1429: train_loss: 3.891e-04 	 test_loss: 5.594e-04
# EPOCH 1430: train_loss: 3.929e-04 	 test_loss: 6.332e-04
# EPOCH 1431: train_loss: 4.207e-04 	 test_loss: 5.982e-04
# EPOCH 1432: train_loss: 3.140e-04 	 test_loss: 6.162e-04
# EPOCH 1433: train_loss: 2.941e-04 	 test_loss: 5.297e-04
# EPOCH 1434: train_loss: 2.740e-04 	 test_loss: 4.956e-04
# EPOCH 1435: train_loss: 2.835e-04 	 test_loss: 5.191e-04
# EPOCH 1436: train_loss: 3.000e-04 	 test_loss: 4.995e-04
# EPOCH 1437: train_loss: 2.803e-04 	 test_loss: 4.657e-04
# EPOCH 1438: train_loss: 2.989e-04 	 test_loss: 5.893e-04
# EPOCH 1439: train_loss: 3.140e-04 	 test_loss: 5.315e-04
# EPOCH 1440: train_loss: 3.163e-04 	 test_loss: 5.517e-04
# EPOCH 1441: train_loss: 3.100e-04 	 test_loss: 5.471e-04
# EPOCH 1442: train_loss: 3.034e-04 	 test_loss: 5.610e-04
# EPOCH 1443: train_loss: 3.723e-04 	 test_loss: 4.730e-04
# EPOCH 1444: train_loss: 3.166e-04 	 test_loss: 6.364e-04
# EPOCH 1445: train_loss: 2.676e-04 	 test_loss: 5.455e-04
# EPOCH 1446: train_loss: 3.225e-04 	 test_loss: 7.630e-04
# EPOCH 1447: train_loss: 3.718e-04 	 test_loss: 4.553e-04
# EPOCH 1448: train_loss: 3.135e-04 	 test_loss: 6.341e-04
# EPOCH 1449: train_loss: 3.656e-04 	 test_loss: 6.257e-04
# EPOCH 1450: train_loss: 3.446e-04 	 test_loss: 5.179e-04
# EPOCH 1451: train_loss: 3.519e-04 	 test_loss: 6.488e-04
# EPOCH 1452: train_loss: 3.397e-04 	 test_loss: 4.802e-04
# EPOCH 1453: train_loss: 3.144e-04 	 test_loss: 5.359e-04
# EPOCH 1454: train_loss: 3.786e-04 	 test_loss: 5.533e-04
# EPOCH 1455: train_loss: 4.290e-04 	 test_loss: 4.778e-04
# EPOCH 1456: train_loss: 2.576e-04 	 test_loss: 5.528e-04
# EPOCH 1457: train_loss: 3.288e-04 	 test_loss: 5.261e-04
# EPOCH 1458: train_loss: 2.843e-04 	 test_loss: 4.839e-04
# EPOCH 1459: train_loss: 2.951e-04 	 test_loss: 4.853e-04
# EPOCH 1460: train_loss: 2.179e-04 	 test_loss: 5.078e-04
# EPOCH 1461: train_loss: 2.921e-04 	 test_loss: 5.172e-04
# EPOCH 1462: train_loss: 3.545e-04 	 test_loss: 5.118e-04
# EPOCH 1463: train_loss: 3.116e-04 	 test_loss: 5.877e-04
# EPOCH 1464: train_loss: 2.874e-04 	 test_loss: 6.267e-04
# EPOCH 1465: train_loss: 3.066e-04 	 test_loss: 5.029e-04
# EPOCH 1466: train_loss: 3.335e-04 	 test_loss: 5.940e-04
# EPOCH 1467: train_loss: 2.898e-04 	 test_loss: 5.658e-04
# EPOCH 1468: train_loss: 3.222e-04 	 test_loss: 5.227e-04
# EPOCH 1469: train_loss: 2.362e-04 	 test_loss: 4.590e-04
# EPOCH 1470: train_loss: 2.603e-04 	 test_loss: 5.459e-04
# EPOCH 1471: train_loss: 2.659e-04 	 test_loss: 5.375e-04
# EPOCH 1472: train_loss: 3.221e-04 	 test_loss: 4.791e-04
# EPOCH 1473: train_loss: 2.873e-04 	 test_loss: 5.351e-04
# EPOCH 1474: train_loss: 3.418e-04 	 test_loss: 5.405e-04
# EPOCH 1475: train_loss: 2.941e-04 	 test_loss: 5.480e-04
# EPOCH 1476: train_loss: 3.149e-04 	 test_loss: 5.633e-04
# EPOCH 1477: train_loss: 3.529e-04 	 test_loss: 6.154e-04
# EPOCH 1478: train_loss: 2.769e-04 	 test_loss: 5.678e-04
# EPOCH 1479: train_loss: 2.173e-04 	 test_loss: 4.948e-04
# EPOCH 1480: train_loss: 2.775e-04 	 test_loss: 5.349e-04
# EPOCH 1481: train_loss: 2.324e-04 	 test_loss: 5.261e-04
# EPOCH 1482: train_loss: 2.118e-04 	 test_loss: 5.567e-04
# EPOCH 1483: train_loss: 3.124e-04 	 test_loss: 6.048e-04
# EPOCH 1484: train_loss: 2.658e-04 	 test_loss: 5.241e-04
# EPOCH 1485: train_loss: 2.874e-04 	 test_loss: 6.342e-04
# EPOCH 1486: train_loss: 2.932e-04 	 test_loss: 5.451e-04
# EPOCH 1487: train_loss: 2.883e-04 	 test_loss: 5.085e-04
# EPOCH 1488: train_loss: 3.121e-04 	 test_loss: 5.022e-04
# EPOCH 1489: train_loss: 2.704e-04 	 test_loss: 5.910e-04
# EPOCH 1490: train_loss: 2.835e-04 	 test_loss: 5.532e-04
# EPOCH 1491: train_loss: 2.832e-04 	 test_loss: 4.880e-04
# EPOCH 1492: train_loss: 2.799e-04 	 test_loss: 5.747e-04
# EPOCH 1493: train_loss: 2.638e-04 	 test_loss: 5.269e-04
# EPOCH 1494: train_loss: 2.646e-04 	 test_loss: 5.428e-04
# EPOCH 1495: train_loss: 2.303e-04 	 test_loss: 5.781e-04
# EPOCH 1496: train_loss: 2.493e-04 	 test_loss: 5.695e-04
# EPOCH 1497: train_loss: 3.088e-04 	 test_loss: 4.802e-04
# EPOCH 1498: train_loss: 2.642e-04 	 test_loss: 6.390e-04
# EPOCH 1499: train_loss: 3.011e-04 	 test_loss: 4.718e-04

# %%
plot_loss(loss_history, val_loss_history, barometer = 2e-4)
plot_results(model, train_x_norm, train_y_norm, "Training Set Results")
plot_results(model, test_x_norm, test_y_norm, "Testing Set Results")

# %%
t = torch.linspace(0,1,150)
idx = 0
model.eval()
plt.plot(t, model(test_x_norm[idx:idx+1,:,:].to(device)).detach().cpu().flatten())
plt.plot(t[:75], model(test_x_norm[idx:idx+1,:,:75].to(device)).detach().cpu().flatten())
plt.plot(t, test_y_norm[idx:idx+1,:,:].flatten(), '--', color = 'k')
