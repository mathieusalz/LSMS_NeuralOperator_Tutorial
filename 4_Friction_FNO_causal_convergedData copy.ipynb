# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn
import torch.optim as optim
import torch.nn.utils as utils
import torch.nn.functional as F

import torch.fft
from typing import Callable, List, Union    

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # Loading Data and Preprocessing

# %%
features_path = "data/friction_data/features_converged.csv"
targets_path = "data/friction_data/targets_aging_converged.csv"
train_samples = 700

# %%
feature = torch.Tensor(np.genfromtxt(features_path, delimiter=',')[:, np.newaxis, :])
target = torch.Tensor(np.genfromtxt(targets_path, delimiter=',')[:, np.newaxis, :])

train_x = feature[:train_samples, :, :]
train_y = target[:train_samples, :, :]
test_x = feature[train_samples:, :, :]
test_y = target[train_samples:, :, :]


fig, axes = plt.subplots(1, 2, figsize=(12, 5))
bins = np.logspace(np.log10(feature.min()), np.log10(feature.max()), 100)
axes[0].hist(feature.flatten(), bins=bins, label = f"min: {feature.min():.2e}, max: {feature.max():.2e}")
axes[0].set_xscale('log')
axes[0].set_title("Feature Distribution")
axes[0].legend()
axes[1].hist(target.flatten(), bins=100, color = 'red', label = f"min: {target.min():.2f}, max: {target.max():.2f}")
axes[1].set_title("Target Distribution")
axes[1].legend()

plt.show()
# Out:
# /tmp/ipykernel_836444/163623338.py:11: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   bins = np.logspace(np.log10(feature.min()), np.log10(feature.max()), 100)

# %%
fig, axes = plt.subplots(3, 3, figsize=(12, 12))
axes = axes.flatten()

for i, ax1 in enumerate(axes):
    # Velocity axis
    line1 = ax1.plot([i/len(feature[i,0,:]) for i in range(len(feature[i,0,:]))],
        feature[i, 0, :],
        color="blue",
        label=r"$V$"
    )
    ax1.set_xlabel("Normalized Time", fontsize = 14)
    ax1.set_ylabel(r"$V$", color="blue", fontsize = 14)
    ax1.tick_params(axis="y", colors="blue")
    ax1.spines["left"].set_color("blue")

    # Friction coefficient axis
    ax2 = ax1.twinx()
    line2 = ax2.plot([i/len(feature[i,0,:]) for i in range(len(feature[i,0,:]))],
        target[i, 0, :],
        color="red",
        label=r"$\mu$",
        linestyle = '--'
    )
    ax2.set_ylabel(r"$\mu$", color="red", fontsize = 14)
    ax2.tick_params(axis="y", colors="red")
    ax2.spines["right"].set_color("red")

plt.tight_layout()
plt.show()

# %%
def transform_vel_diff(x, V_ref = 1e-5):
    return torch.log10(x[:,:,1:]/V_ref) - torch.log10(x[:,:,:-1]/V_ref)

def transform_mu_diff(x):
    return x[:,:,1:] - x[:,:,:-1]

train_x_trans = transform_vel_diff(train_x)
train_y_trans = transform_mu_diff(train_y)
test_x_trans = transform_vel_diff(test_x)
test_y_trans = transform_mu_diff(test_y)

fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

# ==========================
# Feature differences
# ==========================

bins = np.logspace(np.log10(1e-6), np.log10(10), 100)

train_x_pos = train_x_trans[train_x_trans >= 0]
test_x_pos  = test_x_trans[test_x_trans >= 0]

train_x_neg = -train_x_trans[train_x_trans < 0]
test_x_neg  = -test_x_trans[test_x_trans < 0]

axes[0].hist(train_x_pos.flatten()+1e-5, bins=bins,
             alpha=0.6,
             label=f"Train (min={train_x_pos.min():.2e}, max={train_x_pos.max():.2e})")
axes[0].hist(test_x_pos.flatten()+1e-5, bins=bins,
             alpha=0.6,
             label=f"Test (min={test_x_pos.min():.2e}, max={test_x_pos.max():.2e})")
axes[0].set_xscale("log")
axes[0].set_yscale("symlog")
axes[0].set_title("(+/0) Feature Differences")
axes[0].legend()

axes[1].hist(train_x_neg.flatten(), bins=bins,
             alpha=0.6,
             label=f"Train (min={train_x_neg.min():.2e}, max={train_x_neg.max():.2e})")
axes[1].hist(test_x_neg.flatten(), bins=bins,
             alpha=0.6,
             label=f"Test (min={test_x_neg.min():.2e}, max={test_x_neg.max():.2e})")
axes[1].set_xscale("log")
axes[1].set_yscale("symlog")
axes[1].set_title("(-) Feature Differences (absolute value)")
axes[1].legend()

# ==========================
# Target differences
# ==========================

bins = np.logspace(np.log10(1e-10), np.log10(1), 100)

train_y_pos = train_y_trans[train_y_trans >= 0]
test_y_pos  = test_y_trans[test_y_trans >= 0]

train_y_neg = -train_y_trans[train_y_trans < 0]
test_y_neg  = -test_y_trans[test_y_trans < 0]

axes[2].hist(train_y_pos.flatten()+1e-9, bins=bins,
             alpha=0.6,
             label=f"Train (min={train_y_pos.min():.2e}, max={train_y_pos.max():.2e})")
axes[2].hist(test_y_pos.flatten()+1e-9, bins=bins,
             alpha=0.6,
             label=f"Test (min={test_y_pos.min():.2e}, max={test_y_pos.max():.2e})")
axes[2].set_xscale("log")
axes[2].set_yscale("log")
axes[2].set_title("(+/0) Target Differences")
axes[2].legend()

axes[3].hist(train_y_neg.flatten(), bins=bins,
             alpha=0.6,
             label=f"Train (min={train_y_neg.min():.2e}, max={train_y_neg.max():.2e})")
axes[3].hist(test_y_neg.flatten(), bins=bins,
             alpha=0.6,
             label=f"Test (min={test_y_neg.min():.2e}, max={test_y_neg.max():.2e})")
axes[3].set_xscale("log")
axes[3].set_yscale("log")
axes[3].set_title("(-) Target Differences (absolute value)")
axes[3].legend()

plt.tight_layout()
plt.show()

# %%
def x_state_transform(x: np.array) -> torch.Tensor:
    return torch.Tensor(np.sqrt(np.log(1e8*x)))

def log_transform(train, test, nonZero_tol = 0):
    train_idx = np.argwhere(abs(train.flatten()) > nonZero_tol)[0]
    train_norm_state = x_state_transform(torch.abs(train.flatten()[train_idx]))
    train_min, train_max = train_norm_state.min(), train_norm_state.max()
    train_norm_state = (train_norm_state - train_min) / (train_max - train_min)

    test_idx = np.argwhere(abs(test.flatten()) > nonZero_tol)[0]
    test_norm_state = x_state_transform(torch.abs(test.flatten()[test_idx]))
    test_norm_state = (test_norm_state - train_min) / (train_max - train_min)

    train_sign = torch.sign(train)
    test_sign = torch.sign(test)

    train_norm = torch.zeros_like(train.flatten())
    train_norm[train_idx] = train_norm_state

    test_norm = torch.zeros_like(test.flatten())
    test_norm[test_idx] = test_norm_state

    train_norm = train_norm.reshape(*train.shape)
    test_norm = test_norm.reshape(*test.shape)

    train_norm = train_norm * train_sign
    test_norm = test_norm * test_sign

    return train_norm, test_norm, (train_min, train_max)

train_x_norm, test_x_norm, (vel_min, vel_max) = log_transform(train_x_trans, test_x_trans)
train_y_norm, test_y_norm, (mu_min, mu_max) = log_transform(train_y_trans, test_y_trans)
# Out:
# /tmp/ipykernel_836444/3914101703.py:2: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   return torch.Tensor(np.sqrt(np.log(1e8*x)))

# %%
def reverse_log_transform(x, x_min, x_max, nonZero_tol):
    x_flat = x.flatten()
    x_rev = torch.zeros_like(x_flat)

    # Only reverse entries that remained nonzero after the forward transform
    idx = torch.nonzero(x_flat, as_tuple=True)[0]

    sign = torch.sign(x_flat[idx])
    x_abs = torch.abs(x_flat[idx])

    # Reverse min-max normalization
    x_state = x_abs * (x_max - x_min) + x_min

    # Reverse sqrt(log(1e8 * |x|))
    x_original = 1e-8 * torch.exp(x_state**2)

    x_rev[idx] = sign * x_original

    return x_rev.reshape_as(x)

# %%
print(mu_min, mu_max)
# Out:
# tensor(1.0450) tensor(3.9815)

# %%
train_y_norm_rev, test_y_norm_rev = reverse_log_transform(train_y_norm, mu_min, mu_max, 0), reverse_log_transform(test_y_norm, mu_min, mu_max, 0)

fig, axes = plt.subplots(4,4, figsize = (12,12))
axes = axes.flatten()

for i,ax in enumerate(axes):
    ax.plot(abs(train_y_norm_rev[i,0,:]) + 1e-8)
    ax.plot(abs(train_y_trans[i,0,:]) + 1e-8, linestyle = '--')
    ax.set_yscale('log')

# %%
def reverse_mu_diff(x):
    x = torch.cumsum(x, dim = -1)
    return torch.cat([torch.zeros(x.shape[0],1,1), x], dim = -1)

# %%
train_y_norm_rev2, test_y_norm_rev2 = reverse_mu_diff(train_y_norm_rev), reverse_mu_diff(test_y_norm_rev)

fig, axes = plt.subplots(4,4, figsize = (12,12))
axes = axes.flatten()

for i,ax in enumerate(axes):
    ax.plot(train_y_norm_rev2[i,0,:])
    ax.plot(train_y[i,0,:] - train_y[i,0,0], linestyle = '--')
    # ax.set_yscale('log')

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
axes[0].hist(train_x_norm.flatten(), bins=100)
axes[0].hist(test_x_norm.flatten(), bins=100)
axes[0].set_yscale('log')
axes[0].set_title("Vel Feature Distribution")
axes[0].legend()

axes[1].hist(train_y_norm.flatten(), bins = 100)
axes[1].hist(test_y_norm.flatten(), bins = 100)
axes[1].set_yscale('log')
axes[1].set_title("Target Distribution")
axes[1].legend()

plt.show()
# Out:
# /tmp/ipykernel_836444/3811868631.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[0].legend()
# /tmp/ipykernel_836444/3811868631.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axes[1].legend()

# %%
fig, axes = plt.subplots(4,4, figsize=(20, 20))
axes = axes.flatten()
for i in range(16):
    norm_time = [i/len(train_x_norm[i, 0, :]) for i in range(len(train_x_norm[i, 0, :]))]
    axes[i].plot(norm_time, train_y_norm[i, 0, :].numpy(), label=r'$\Delta \mu$', color = 'red')
    axes[i].plot(norm_time, train_x_norm[i, 0, :].numpy(), label=r'$\Delta V$', color = 'k', linestyle = '--', linewidth = 2)
    axes[i].set_title(f"Sample {i+1}")
    axes[i].set_xlabel('Normalized Time')
    axes[i].set_ylabel('Magnitude')
    axes[i].legend()

# %%
idx_to_keep = np.where(train_y_norm[:,0,-1] < 1e-8)
train_x_norm, train_y_norm = train_x_norm[idx_to_keep], train_y_norm[idx_to_keep]

idx_to_keep = np.where(test_y_norm[:,0,-1] < 1e-8)
test_x_norm, test_y_norm = test_x_norm[idx_to_keep], test_y_norm[idx_to_keep]

print(train_x_norm.shape, test_x_norm.shape)

train_dataset = TensorDataset(train_x_norm, train_y_norm)
test_dataset = TensorDataset(test_x_norm, test_y_norm)
# Out:
# torch.Size([532, 1, 498]) torch.Size([304, 1, 498])

# %% [markdown]
# # Code for Models, Training, Postprocessing

# %% [markdown]
# ## FNO and NN

# %%
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            nn.init.constant_(m.bias, 0)
    elif isinstance(m, nn.Conv1d):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            nn.init.constant_(m.bias, 0)


class SpectralConv1d(nn.Module):
    def __init__(self, 
                 in_channels : int, 
                 out_channels: int, 
                 modes: int):
        """
        Initializes a 1D spectral convolution layer using complex weights in the Fourier domain.

        Args:
            in_channels (int): Number of input channels.
            out_channels (int): Number of output channels.
            modes (int): Number of Fourier modes to retain (low-frequency modes).
        """
        super().__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.modes = modes

        scale = 1.0 / (in_channels * out_channels)
        self.real_weights = nn.Parameter(
            torch.rand(in_channels, out_channels, modes) * 2 * scale - scale
        )
        self.imag_weights = nn.Parameter(
            torch.rand(in_channels, out_channels, modes) * 2 * scale - scale
        )

    def complex_mult1d(self, x_hat, w):
        return torch.einsum("iM,ioM->oM", x_hat, w)

    def forward(self, x):
        # x: (batch, channels, spatial_points)
        batchsize, channels, spatial_points = x.shape

        x_hat = torch.fft.rfft(x, dim=-1)  # (B, C, F)
        x_hat_under_modes = x_hat[:, :, :self.modes]

        weights = torch.complex(self.real_weights, self.imag_weights)
        out_hat_under_modes = torch.einsum("bim, iom -> bom", x_hat_under_modes, weights)

        out_hat = torch.zeros(
            batchsize, self.out_channels, x_hat.shape[-1],
            dtype=torch.cfloat, device=x.device
        )
        out_hat[:, :, :self.modes] = out_hat_under_modes

        out = torch.fft.irfft(out_hat, n=spatial_points, dim=-1)
        return out


class FNOBlock1d(nn.Module):
    def __init__(self, 
                 in_channels : int, 
                 out_channels : int, 
                 modes : int, 
                 activation : nn.Module = nn.Identity()):
        """
        Initializes a single Fourier Neural Operator (FNO) block for 1D data.

        Args:
            in_channels (int): Number of input channels.
            out_channels (int): Number of output channels.
            modes (int): Number of retained Fourier modes in the spectral convolution.
            activation (nn.Module, optional): Activation function applied after the block output. Default is nn.Identity().
        """
        
        super().__init__()
        self.activation = activation
        self.spectral_conv = SpectralConv1d(in_channels, out_channels, modes)
        self.bypass_conv = nn.Conv1d(in_channels, out_channels, kernel_size=1)

    def forward(self, x):
        sc = self.spectral_conv(x)
        bc = self.bypass_conv(x)
        out = sc + bc
        out = self.activation(out)
        return out

class Projection_NN(nn.Module):
    def __init__(self, 
                 input_dim : int, 
                 output_dim : int, 
                 width : int, 
                 depth : int, 
                 activation: nn.Module = nn.Identity(),
                 dropout = 0,
                 batchNorm = False):
        
        """
        Initializes a fully-connected feedforward projection network.

        Args:
            input_dim (int): Input dimensionality.
            output_dim (int): Output dimensionality.
            width (int): Width (number of hidden units) in each hidden layer.
            depth (int): Number of layers in the network (including input/output layers).
            activation (nn.Module, optional): Activation function applied between layers. Default is nn.Identity().
        """
        
        super().__init__()

        layers = [nn.Linear(input_dim, width)]
        layers.append(activation)
        layers.append(nn.Dropout(dropout))
        layers.append(nn.BatchNorm1d(width) if batchNorm else nn.Identity())

        for _ in range(depth - 1):
            layers.append(nn.Linear(width, width))
            layers.append(activation)
            layers.append(nn.Dropout(dropout))
            layers.append(nn.BatchNorm1d(width) if batchNorm else nn.Identity())

        layers.append(nn.Linear(width, output_dim))
        self.network = nn.Sequential(*layers)

    def forward(self, x):
        bsize, _, N = x.shape
        x = x.permute(0, 2, 1).contiguous().view(-1, self.network[0].in_features)
        x = self.network(x)
        x = x.view(bsize, N, self.network[-1].out_features).permute(0, 2, 1).contiguous()
        return x

class FNO1d(nn.Module):
    def __init__(
        self,
        in_channels : int,
        out_channels : int,
        modes : int,
        width : int,
        block_activation : nn.Module = nn.Identity(),
        n_blocks : int = 4,
        padding : int = 0,
        lift_network = None,
        decode_network = None,
    ):
        """
        Initializes a 1D Fourier Neural Operator (FNO) model.

        Args:
            in_channels (int): Number of input channels.
            out_channels (int): Number of output channels.
            modes (int): Number of Fourier modes retained in spectral convolutions.
            width (int): Width of the internal FNO layers.
            block_activation (nn.Module, optional): Activation applied after each FNO block. Default is nn.Identity().
            n_blocks (int, optional): Number of stacked FNO blocks. Default is 4.
            padding (int, optional): Amount of zero-padding added to input and removed from output. Default is 0.
        """

        super().__init__()
        
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.modes = modes
        self.width = width
        self.block_activation = block_activation
        self.n_blocks = n_blocks
        self.padding = padding
        
        self.lift_network = lift_network
        self.decode_network = decode_network

        self.fno_blocks = nn.ModuleList([
            FNOBlock1d(width, width, modes, block_activation)
            for _ in range(n_blocks)
        ])

        self.apply(init_weights)

    # x: (B, C, N)
    def forward(self, x):

        x = self.lift_network(x)

        N = x.shape[-1]
        target_length = (1 << (N - 1).bit_length()) * 2

        total_pad = target_length - N
        pad_left = total_pad // 2
        pad_right = total_pad - pad_left

        if total_pad > 0:
            x = nn.functional.pad(
                x,
                (pad_left, pad_right),
                mode="constant",
                value=0,
            )

        for block in self.fno_blocks:
            x = block(x)

        x = self.decode_network(x)

        if total_pad > 0:
            x = x[..., pad_left:pad_left + N]

        return x

# %% [markdown]
# ## Train Loop

# %%
def train_loop(model,
                     train_loader,
                     test_loader,
                     epochs,
                     optimizer,
                     scheduler=None,
                     clip_grad=False,
                     mixed_training=False,
                     add_noise=False,
                     loss_func = nn.MSELoss(),
                     half_train = False):

    criterion = loss_func

    loss_history = []
    val_loss_history = []

    for epoch in range(epochs):
        model.train()
        epoch_loss = 0.0

        for batch_x, batch_y in train_loader:

            B,C,N = batch_x.shape
            batch_x = batch_x.to(device)
            batch_y = batch_y.to(device)

            if half_train is not False:
                if np.random.random() > 0.5:
                    sample_N = int(torch.rand(1)*398+100)
                    batch_x = batch_x[:, :, :sample_N]
                    batch_y = batch_y[:, :, :sample_N]
                    batch_x = torch.nn.functional.interpolate(batch_x,N)
                    batch_y = torch.nn.functional.interpolate(batch_y,N)

            if mixed_training is not False:
                sample_freq = np.random.choice(mixed_training[0], p=mixed_training[1])
                batch_x = batch_x.to(device)[:, :, ::sample_freq]
                batch_y = batch_y.to(device)[:, :, ::sample_freq]

            if add_noise is not False:
                noise = torch.randn_like(batch_x) * add_noise[0]
                batch_x = batch_x + noise

            def closure():
                optimizer.zero_grad()

                output = model(batch_x)
                loss = criterion(output, batch_y)

                loss.backward()

                if clip_grad:
                    utils.clip_grad_norm_(model.parameters(), 0.5)

                return loss

            loss = optimizer.step(closure)

            epoch_loss += loss.item()

        if scheduler is not None:
            scheduler.step()

        loss_history.append(epoch_loss / len(train_loader))

        model.eval()
        with torch.no_grad():
            val_loss = 0.0
            for batch_x, batch_y in test_loader:
                batch_x = batch_x.to(device)
                batch_y = batch_y.to(device)

                val_output = model(batch_x)
                val_loss += criterion(val_output, batch_y).item()

        val_loss_history.append(val_loss / len(test_loader))

        print(
            f"EPOCH {epoch}: "
            f"train_loss: {loss_history[-1]:.3e} \t "
            f"test_loss: {val_loss_history[-1]:.3e}"
        )

    return loss_history, val_loss_history

# %%
def make_decay_fn(factor: float, 
                  interval: int):
    return lambda step: factor ** (step // interval)

# %% [markdown]
# ## Postprocessing

# %%
def plot_results(model, x, y, name, reverse = False):

    fig, axes = plt.subplots(4, 4, figsize=(10, 10))
    axes = axes.flatten()
    for i in range(16):
        pred = model(x[i:i+1].to(device)).cpu().detach()
        truth = y[i:i+1, :, :].cpu().detach()

        if reverse:
            pred = reverse_log_transform(pred, mu_min, mu_max, 0)
            pred = reverse_mu_diff(pred)
        
            truth = reverse_log_transform(truth, mu_min, mu_max, 0)
            truth = reverse_mu_diff(truth)
            
        ax1 = axes[i]

        ax1.plot(truth.numpy().flatten(), color='tab:orange', label='Ground Truth' if i == 0 else "")
        ax1.plot(pred.numpy().flatten(), color='tab:green', linestyle = '--', label='Prediction' if i == 0 else "")
        # ax1.plot(x[i,0,:], color = 'k', label = 'input' if i==0 else '', alpha = 0.5)
        ax1.set_xticks([])
        ax1.set_yticks([])

    fig.suptitle(name, fontsize=22, y=0.98)

    fig.legend(loc='upper center', bbox_to_anchor=(0.5, 0.95), ncol=3, fontsize=16)

    plt.tight_layout(rect=[0, 0, 1, 0.95])  
    plt.show()

def plot_loss(loss, val, barometer = None):

    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(loss, label="train loss")
    ax.plot(val, label="val loss")
    if barometer is not None:
        ax.hlines(barometer, xmin = 0, xmax = len(loss), color = 'red', linestyle = '--')
    ax.legend(fontsize=14)
    ax.set_yscale("log")
    ax.grid(True)
    ax.tick_params(axis='both', which='major', labelsize=14)
    fig.suptitle("Loss History", fontsize=18)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Training

# %%
in_channels = train_x_norm.shape[1]
width = 32
out_channels = 1

lift_network = Projection_NN(
                input_dim = in_channels,
                output_dim = width,
                width = 64,
                depth = 2,
                activation = torch.nn.GELU(),
                dropout = 0.05
            )

decode_network = Projection_NN(
                input_dim = width,
                output_dim = out_channels,
                width = 64,
                depth = 2,
                activation = torch.nn.GELU(),
                dropout = 0.05
            )

model = FNO1d(
        in_channels=in_channels,
        out_channels=out_channels,
        modes = 12,
        width=width,
        block_activation=torch.nn.Mish(),
        n_blocks=4,
        padding=0,
        lift_network=lift_network,
        decode_network=decode_network,
        ).to(device)

lr = 1e-3

optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)

scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda= make_decay_fn(0.999, 100))

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

loss_history, val_loss_history = [], []

loss_history, val_loss_history = train_loop(model, train_loader, test_loader,
                                            1000, optimizer, scheduler,
                                            mixed_training=False,
                                            half_train = True,
                                            clip_grad = True)
# Out:
# EPOCH 0: train_loss: 2.409e-01 	 test_loss: 2.714e-01
# EPOCH 1: train_loss: 2.447e-01 	 test_loss: 2.671e-01
# EPOCH 2: train_loss: 2.035e-01 	 test_loss: 2.432e-01
# EPOCH 3: train_loss: 2.081e-01 	 test_loss: 1.865e-01
# EPOCH 4: train_loss: 1.666e-01 	 test_loss: 1.170e-01
# EPOCH 5: train_loss: 1.332e-01 	 test_loss: 1.013e-01
# EPOCH 6: train_loss: 1.317e-01 	 test_loss: 1.275e-01
# EPOCH 7: train_loss: 1.639e-01 	 test_loss: 8.553e-02
# EPOCH 8: train_loss: 1.234e-01 	 test_loss: 1.097e-01
# EPOCH 9: train_loss: 1.146e-01 	 test_loss: 1.059e-01
# EPOCH 10: train_loss: 1.057e-01 	 test_loss: 9.025e-02
# EPOCH 11: train_loss: 1.160e-01 	 test_loss: 9.154e-02
# EPOCH 12: train_loss: 1.187e-01 	 test_loss: 1.118e-01
# EPOCH 13: train_loss: 1.093e-01 	 test_loss: 8.386e-02
# EPOCH 14: train_loss: 1.077e-01 	 test_loss: 8.170e-02
# EPOCH 15: train_loss: 9.618e-02 	 test_loss: 8.560e-02
# EPOCH 16: train_loss: 8.027e-02 	 test_loss: 7.585e-02
# EPOCH 17: train_loss: 1.142e-01 	 test_loss: 8.044e-02
# EPOCH 18: train_loss: 1.063e-01 	 test_loss: 1.410e-01
# EPOCH 19: train_loss: 1.307e-01 	 test_loss: 1.207e-01
# EPOCH 20: train_loss: 9.350e-02 	 test_loss: 8.718e-02
# EPOCH 21: train_loss: 9.657e-02 	 test_loss: 8.016e-02
# EPOCH 22: train_loss: 9.267e-02 	 test_loss: 1.144e-01
# EPOCH 23: train_loss: 1.185e-01 	 test_loss: 1.003e-01
# EPOCH 24: train_loss: 9.462e-02 	 test_loss: 9.403e-02
# EPOCH 25: train_loss: 8.927e-02 	 test_loss: 7.617e-02
# EPOCH 26: train_loss: 9.114e-02 	 test_loss: 7.064e-02
# EPOCH 27: train_loss: 7.804e-02 	 test_loss: 7.350e-02
# EPOCH 28: train_loss: 9.125e-02 	 test_loss: 7.146e-02
# EPOCH 29: train_loss: 8.385e-02 	 test_loss: 8.047e-02
# EPOCH 30: train_loss: 8.470e-02 	 test_loss: 8.903e-02
# EPOCH 31: train_loss: 9.951e-02 	 test_loss: 6.865e-02
# EPOCH 32: train_loss: 7.594e-02 	 test_loss: 6.985e-02
# EPOCH 33: train_loss: 8.131e-02 	 test_loss: 7.157e-02
# EPOCH 34: train_loss: 7.245e-02 	 test_loss: 7.191e-02
# EPOCH 35: train_loss: 7.586e-02 	 test_loss: 6.647e-02
# EPOCH 36: train_loss: 8.234e-02 	 test_loss: 7.404e-02
# EPOCH 37: train_loss: 7.771e-02 	 test_loss: 6.594e-02
# EPOCH 38: train_loss: 6.962e-02 	 test_loss: 7.190e-02
# EPOCH 39: train_loss: 7.437e-02 	 test_loss: 6.652e-02
# EPOCH 40: train_loss: 6.788e-02 	 test_loss: 7.400e-02
# EPOCH 41: train_loss: 7.668e-02 	 test_loss: 8.424e-02
# EPOCH 42: train_loss: 7.482e-02 	 test_loss: 6.311e-02
# EPOCH 43: train_loss: 7.296e-02 	 test_loss: 6.058e-02
# EPOCH 44: train_loss: 6.626e-02 	 test_loss: 6.081e-02
# EPOCH 45: train_loss: 6.660e-02 	 test_loss: 6.476e-02
# EPOCH 46: train_loss: 7.297e-02 	 test_loss: 8.081e-02
# EPOCH 47: train_loss: 7.847e-02 	 test_loss: 7.285e-02
# EPOCH 48: train_loss: 7.313e-02 	 test_loss: 8.051e-02
# EPOCH 49: train_loss: 7.573e-02 	 test_loss: 6.090e-02
# EPOCH 50: train_loss: 7.550e-02 	 test_loss: 5.981e-02
# EPOCH 51: train_loss: 6.475e-02 	 test_loss: 5.762e-02
# EPOCH 52: train_loss: 6.928e-02 	 test_loss: 1.249e-01
# EPOCH 53: train_loss: 8.684e-02 	 test_loss: 8.014e-02
# EPOCH 54: train_loss: 7.028e-02 	 test_loss: 7.229e-02
# EPOCH 55: train_loss: 6.295e-02 	 test_loss: 6.023e-02
# EPOCH 56: train_loss: 6.700e-02 	 test_loss: 6.313e-02
# EPOCH 57: train_loss: 6.398e-02 	 test_loss: 5.995e-02
# EPOCH 58: train_loss: 6.145e-02 	 test_loss: 6.230e-02
# EPOCH 59: train_loss: 5.941e-02 	 test_loss: 6.280e-02
# EPOCH 60: train_loss: 6.751e-02 	 test_loss: 5.882e-02
# EPOCH 61: train_loss: 5.502e-02 	 test_loss: 6.250e-02
# EPOCH 62: train_loss: 6.067e-02 	 test_loss: 5.702e-02
# EPOCH 63: train_loss: 4.865e-02 	 test_loss: 6.221e-02
# EPOCH 64: train_loss: 5.720e-02 	 test_loss: 5.763e-02
# EPOCH 65: train_loss: 5.634e-02 	 test_loss: 5.743e-02
# EPOCH 66: train_loss: 5.757e-02 	 test_loss: 5.330e-02
# EPOCH 67: train_loss: 7.148e-02 	 test_loss: 5.233e-02
# EPOCH 68: train_loss: 5.886e-02 	 test_loss: 5.226e-02
# EPOCH 69: train_loss: 7.157e-02 	 test_loss: 5.179e-02
# EPOCH 70: train_loss: 6.371e-02 	 test_loss: 5.228e-02
# EPOCH 71: train_loss: 6.766e-02 	 test_loss: 5.478e-02
# EPOCH 72: train_loss: 5.623e-02 	 test_loss: 6.722e-02
# EPOCH 73: train_loss: 7.989e-02 	 test_loss: 5.527e-02
# EPOCH 74: train_loss: 8.225e-02 	 test_loss: 5.912e-02
# EPOCH 75: train_loss: 5.900e-02 	 test_loss: 7.048e-02
# EPOCH 76: train_loss: 6.359e-02 	 test_loss: 5.412e-02
# EPOCH 77: train_loss: 7.346e-02 	 test_loss: 5.287e-02
# EPOCH 78: train_loss: 8.158e-02 	 test_loss: 5.654e-02
# EPOCH 79: train_loss: 5.319e-02 	 test_loss: 5.243e-02
# EPOCH 80: train_loss: 5.422e-02 	 test_loss: 6.022e-02
# EPOCH 81: train_loss: 5.394e-02 	 test_loss: 6.305e-02
# EPOCH 82: train_loss: 5.221e-02 	 test_loss: 6.508e-02
# EPOCH 83: train_loss: 5.305e-02 	 test_loss: 5.378e-02
# EPOCH 84: train_loss: 8.098e-02 	 test_loss: 5.701e-02
# EPOCH 85: train_loss: 9.663e-02 	 test_loss: 5.965e-02
# EPOCH 86: train_loss: 5.820e-02 	 test_loss: 5.783e-02
# EPOCH 87: train_loss: 5.472e-02 	 test_loss: 5.263e-02
# EPOCH 88: train_loss: 4.993e-02 	 test_loss: 7.331e-02
# EPOCH 89: train_loss: 7.094e-02 	 test_loss: 8.765e-02
# EPOCH 90: train_loss: 8.317e-02 	 test_loss: 5.782e-02
# EPOCH 91: train_loss: 5.155e-02 	 test_loss: 5.099e-02
# EPOCH 92: train_loss: 5.079e-02 	 test_loss: 5.609e-02
# EPOCH 93: train_loss: 6.218e-02 	 test_loss: 1.046e-01
# EPOCH 94: train_loss: 9.359e-02 	 test_loss: 5.733e-02
# EPOCH 95: train_loss: 6.228e-02 	 test_loss: 5.120e-02
# EPOCH 96: train_loss: 5.575e-02 	 test_loss: 7.362e-02
# EPOCH 97: train_loss: 6.945e-02 	 test_loss: 5.003e-02
# EPOCH 98: train_loss: 5.848e-02 	 test_loss: 7.695e-02
# EPOCH 99: train_loss: 9.495e-02 	 test_loss: 6.738e-02
# EPOCH 100: train_loss: 5.557e-02 	 test_loss: 5.244e-02
# EPOCH 101: train_loss: 5.137e-02 	 test_loss: 4.980e-02
# EPOCH 102: train_loss: 5.297e-02 	 test_loss: 4.912e-02
# EPOCH 103: train_loss: 6.085e-02 	 test_loss: 4.726e-02
# EPOCH 104: train_loss: 4.086e-02 	 test_loss: 5.090e-02
# EPOCH 105: train_loss: 5.372e-02 	 test_loss: 6.034e-02
# EPOCH 106: train_loss: 5.585e-02 	 test_loss: 4.707e-02
# EPOCH 107: train_loss: 4.686e-02 	 test_loss: 5.386e-02
# EPOCH 108: train_loss: 5.184e-02 	 test_loss: 8.670e-02
# EPOCH 109: train_loss: 8.851e-02 	 test_loss: 4.660e-02
# EPOCH 110: train_loss: 6.341e-02 	 test_loss: 6.095e-02
# EPOCH 111: train_loss: 5.930e-02 	 test_loss: 6.384e-02
# EPOCH 112: train_loss: 5.997e-02 	 test_loss: 5.519e-02
# EPOCH 113: train_loss: 5.386e-02 	 test_loss: 4.788e-02
# EPOCH 114: train_loss: 5.093e-02 	 test_loss: 5.807e-02
# EPOCH 115: train_loss: 5.946e-02 	 test_loss: 7.169e-02
# EPOCH 116: train_loss: 5.042e-02 	 test_loss: 6.654e-02
# EPOCH 117: train_loss: 5.928e-02 	 test_loss: 5.092e-02
# EPOCH 118: train_loss: 4.957e-02 	 test_loss: 6.179e-02
# EPOCH 119: train_loss: 5.871e-02 	 test_loss: 5.368e-02
# EPOCH 120: train_loss: 5.097e-02 	 test_loss: 5.150e-02
# EPOCH 121: train_loss: 3.811e-02 	 test_loss: 4.518e-02
# EPOCH 122: train_loss: 4.446e-02 	 test_loss: 4.797e-02
# EPOCH 123: train_loss: 4.724e-02 	 test_loss: 4.702e-02
# EPOCH 124: train_loss: 4.241e-02 	 test_loss: 4.385e-02
# EPOCH 125: train_loss: 3.200e-02 	 test_loss: 4.801e-02
# EPOCH 126: train_loss: 4.330e-02 	 test_loss: 4.327e-02
# EPOCH 127: train_loss: 4.293e-02 	 test_loss: 4.869e-02
# EPOCH 128: train_loss: 4.711e-02 	 test_loss: 4.315e-02
# EPOCH 129: train_loss: 4.676e-02 	 test_loss: 4.626e-02
# EPOCH 130: train_loss: 4.330e-02 	 test_loss: 4.337e-02
# EPOCH 131: train_loss: 3.755e-02 	 test_loss: 4.437e-02
# EPOCH 132: train_loss: 4.712e-02 	 test_loss: 4.346e-02
# EPOCH 133: train_loss: 4.209e-02 	 test_loss: 4.328e-02
# EPOCH 134: train_loss: 3.657e-02 	 test_loss: 4.358e-02
# EPOCH 135: train_loss: 4.232e-02 	 test_loss: 4.147e-02
# EPOCH 136: train_loss: 4.095e-02 	 test_loss: 4.299e-02
# EPOCH 137: train_loss: 4.337e-02 	 test_loss: 4.278e-02
# EPOCH 138: train_loss: 5.026e-02 	 test_loss: 4.434e-02
# EPOCH 139: train_loss: 4.565e-02 	 test_loss: 4.162e-02
# EPOCH 140: train_loss: 4.244e-02 	 test_loss: 4.032e-02
# EPOCH 141: train_loss: 4.475e-02 	 test_loss: 4.006e-02
# EPOCH 142: train_loss: 4.147e-02 	 test_loss: 4.401e-02
# EPOCH 143: train_loss: 5.481e-02 	 test_loss: 5.571e-02
# EPOCH 144: train_loss: 5.099e-02 	 test_loss: 4.221e-02
# EPOCH 145: train_loss: 4.284e-02 	 test_loss: 5.130e-02
# EPOCH 146: train_loss: 4.922e-02 	 test_loss: 4.739e-02
# EPOCH 147: train_loss: 4.278e-02 	 test_loss: 4.329e-02
# EPOCH 148: train_loss: 4.067e-02 	 test_loss: 3.987e-02
# EPOCH 149: train_loss: 4.393e-02 	 test_loss: 5.143e-02
# EPOCH 150: train_loss: 4.649e-02 	 test_loss: 4.817e-02
# EPOCH 151: train_loss: 4.527e-02 	 test_loss: 3.844e-02
# EPOCH 152: train_loss: 4.214e-02 	 test_loss: 3.798e-02
# EPOCH 153: train_loss: 3.602e-02 	 test_loss: 3.862e-02
# EPOCH 154: train_loss: 3.616e-02 	 test_loss: 3.563e-02
# EPOCH 155: train_loss: 4.322e-02 	 test_loss: 4.433e-02
# EPOCH 156: train_loss: 4.400e-02 	 test_loss: 4.841e-02
# EPOCH 157: train_loss: 4.195e-02 	 test_loss: 3.986e-02
# EPOCH 158: train_loss: 3.628e-02 	 test_loss: 3.544e-02
# EPOCH 159: train_loss: 3.809e-02 	 test_loss: 3.492e-02
# EPOCH 160: train_loss: 3.622e-02 	 test_loss: 3.269e-02
# EPOCH 161: train_loss: 3.383e-02 	 test_loss: 3.806e-02
# EPOCH 162: train_loss: 4.291e-02 	 test_loss: 5.004e-02
# EPOCH 163: train_loss: 2.931e-02 	 test_loss: 3.287e-02
# EPOCH 164: train_loss: 4.295e-02 	 test_loss: 3.600e-02
# EPOCH 165: train_loss: 4.085e-02 	 test_loss: 3.410e-02
# EPOCH 166: train_loss: 3.129e-02 	 test_loss: 3.006e-02
# EPOCH 167: train_loss: 3.447e-02 	 test_loss: 3.182e-02
# EPOCH 168: train_loss: 3.071e-02 	 test_loss: 2.982e-02
# EPOCH 169: train_loss: 3.980e-02 	 test_loss: 3.187e-02
# EPOCH 170: train_loss: 3.959e-02 	 test_loss: 3.181e-02
# EPOCH 171: train_loss: 3.192e-02 	 test_loss: 3.143e-02
# EPOCH 172: train_loss: 2.899e-02 	 test_loss: 2.873e-02
# EPOCH 173: train_loss: 2.962e-02 	 test_loss: 2.867e-02
# EPOCH 174: train_loss: 3.312e-02 	 test_loss: 2.781e-02
# EPOCH 175: train_loss: 3.132e-02 	 test_loss: 4.148e-02
# EPOCH 176: train_loss: 3.211e-02 	 test_loss: 2.979e-02
# EPOCH 177: train_loss: 2.510e-02 	 test_loss: 2.797e-02
# EPOCH 178: train_loss: 2.734e-02 	 test_loss: 3.534e-02
# EPOCH 179: train_loss: 2.984e-02 	 test_loss: 3.062e-02
# EPOCH 180: train_loss: 3.114e-02 	 test_loss: 2.813e-02
# EPOCH 181: train_loss: 3.359e-02 	 test_loss: 3.411e-02
# EPOCH 182: train_loss: 3.679e-02 	 test_loss: 2.615e-02
# EPOCH 183: train_loss: 2.626e-02 	 test_loss: 2.510e-02
# EPOCH 184: train_loss: 2.974e-02 	 test_loss: 2.445e-02
# EPOCH 185: train_loss: 2.563e-02 	 test_loss: 2.416e-02
# EPOCH 186: train_loss: 2.723e-02 	 test_loss: 3.215e-02
# EPOCH 187: train_loss: 2.740e-02 	 test_loss: 2.446e-02
# EPOCH 188: train_loss: 2.953e-02 	 test_loss: 2.543e-02
# EPOCH 189: train_loss: 2.631e-02 	 test_loss: 2.334e-02
# EPOCH 190: train_loss: 2.558e-02 	 test_loss: 2.382e-02
# EPOCH 191: train_loss: 2.352e-02 	 test_loss: 2.262e-02
# EPOCH 192: train_loss: 2.535e-02 	 test_loss: 2.280e-02
# EPOCH 193: train_loss: 2.615e-02 	 test_loss: 2.726e-02
# EPOCH 194: train_loss: 2.411e-02 	 test_loss: 3.499e-02
# EPOCH 195: train_loss: 2.533e-02 	 test_loss: 2.397e-02
# EPOCH 196: train_loss: 2.352e-02 	 test_loss: 2.882e-02
# EPOCH 197: train_loss: 2.710e-02 	 test_loss: 2.327e-02
# EPOCH 198: train_loss: 2.446e-02 	 test_loss: 2.430e-02
# EPOCH 199: train_loss: 2.162e-02 	 test_loss: 2.167e-02
# EPOCH 200: train_loss: 2.466e-02 	 test_loss: 3.298e-02
# EPOCH 201: train_loss: 2.482e-02 	 test_loss: 2.050e-02
# EPOCH 202: train_loss: 2.176e-02 	 test_loss: 2.027e-02
# EPOCH 203: train_loss: 2.380e-02 	 test_loss: 2.121e-02
# EPOCH 204: train_loss: 2.234e-02 	 test_loss: 2.161e-02
# EPOCH 205: train_loss: 2.141e-02 	 test_loss: 2.362e-02
# EPOCH 206: train_loss: 2.140e-02 	 test_loss: 2.618e-02
# EPOCH 207: train_loss: 2.140e-02 	 test_loss: 2.718e-02
# EPOCH 208: train_loss: 1.918e-02 	 test_loss: 2.092e-02
# EPOCH 209: train_loss: 1.869e-02 	 test_loss: 2.238e-02
# EPOCH 210: train_loss: 2.069e-02 	 test_loss: 2.024e-02
# EPOCH 211: train_loss: 1.907e-02 	 test_loss: 2.204e-02
# EPOCH 212: train_loss: 1.966e-02 	 test_loss: 2.369e-02
# EPOCH 213: train_loss: 1.899e-02 	 test_loss: 2.016e-02
# EPOCH 214: train_loss: 1.988e-02 	 test_loss: 1.950e-02
# EPOCH 215: train_loss: 1.989e-02 	 test_loss: 2.103e-02
# EPOCH 216: train_loss: 2.277e-02 	 test_loss: 2.183e-02
# EPOCH 217: train_loss: 2.566e-02 	 test_loss: 2.552e-02
# EPOCH 218: train_loss: 3.340e-02 	 test_loss: 3.846e-02
# EPOCH 219: train_loss: 3.052e-02 	 test_loss: 2.394e-02
# EPOCH 220: train_loss: 2.014e-02 	 test_loss: 1.955e-02
# EPOCH 221: train_loss: 1.637e-02 	 test_loss: 2.023e-02
# EPOCH 222: train_loss: 1.868e-02 	 test_loss: 2.092e-02
# EPOCH 223: train_loss: 1.662e-02 	 test_loss: 2.265e-02
# EPOCH 224: train_loss: 2.073e-02 	 test_loss: 1.971e-02
# EPOCH 225: train_loss: 2.058e-02 	 test_loss: 1.960e-02
# EPOCH 226: train_loss: 1.579e-02 	 test_loss: 1.960e-02
# EPOCH 227: train_loss: 1.539e-02 	 test_loss: 2.018e-02
# EPOCH 228: train_loss: 1.983e-02 	 test_loss: 1.872e-02
# EPOCH 229: train_loss: 1.585e-02 	 test_loss: 1.805e-02
# EPOCH 230: train_loss: 1.896e-02 	 test_loss: 1.913e-02
# EPOCH 231: train_loss: 1.968e-02 	 test_loss: 2.025e-02
# EPOCH 232: train_loss: 1.766e-02 	 test_loss: 1.773e-02
# EPOCH 233: train_loss: 1.831e-02 	 test_loss: 1.986e-02
# EPOCH 234: train_loss: 1.687e-02 	 test_loss: 1.878e-02
# EPOCH 235: train_loss: 1.623e-02 	 test_loss: 1.931e-02
# EPOCH 236: train_loss: 1.600e-02 	 test_loss: 1.804e-02
# EPOCH 237: train_loss: 1.649e-02 	 test_loss: 1.931e-02
# EPOCH 238: train_loss: 1.748e-02 	 test_loss: 2.029e-02
# EPOCH 239: train_loss: 1.732e-02 	 test_loss: 1.873e-02
# EPOCH 240: train_loss: 1.627e-02 	 test_loss: 1.733e-02
# EPOCH 241: train_loss: 1.514e-02 	 test_loss: 1.823e-02
# EPOCH 242: train_loss: 1.393e-02 	 test_loss: 1.789e-02
# EPOCH 243: train_loss: 1.676e-02 	 test_loss: 1.760e-02
# EPOCH 244: train_loss: 1.491e-02 	 test_loss: 1.726e-02
# EPOCH 245: train_loss: 1.654e-02 	 test_loss: 1.893e-02
# EPOCH 246: train_loss: 1.537e-02 	 test_loss: 1.811e-02
# EPOCH 247: train_loss: 1.696e-02 	 test_loss: 2.155e-02
# EPOCH 248: train_loss: 1.838e-02 	 test_loss: 1.778e-02
# EPOCH 249: train_loss: 1.660e-02 	 test_loss: 1.780e-02
# EPOCH 250: train_loss: 1.644e-02 	 test_loss: 1.880e-02
# EPOCH 251: train_loss: 1.877e-02 	 test_loss: 1.750e-02
# EPOCH 252: train_loss: 1.343e-02 	 test_loss: 1.705e-02
# EPOCH 253: train_loss: 1.321e-02 	 test_loss: 1.637e-02
# EPOCH 254: train_loss: 1.601e-02 	 test_loss: 1.926e-02
# EPOCH 255: train_loss: 1.306e-02 	 test_loss: 1.617e-02
# EPOCH 256: train_loss: 1.618e-02 	 test_loss: 1.698e-02
# EPOCH 257: train_loss: 1.610e-02 	 test_loss: 1.754e-02
# EPOCH 258: train_loss: 1.489e-02 	 test_loss: 1.594e-02
# EPOCH 259: train_loss: 1.675e-02 	 test_loss: 1.740e-02
# EPOCH 260: train_loss: 1.590e-02 	 test_loss: 1.614e-02
# EPOCH 261: train_loss: 1.204e-02 	 test_loss: 1.687e-02
# EPOCH 262: train_loss: 1.343e-02 	 test_loss: 1.619e-02
# EPOCH 263: train_loss: 1.475e-02 	 test_loss: 1.598e-02
# EPOCH 264: train_loss: 1.374e-02 	 test_loss: 1.527e-02
# EPOCH 265: train_loss: 1.145e-02 	 test_loss: 1.637e-02
# EPOCH 266: train_loss: 1.252e-02 	 test_loss: 1.722e-02
# EPOCH 267: train_loss: 1.229e-02 	 test_loss: 1.549e-02
# EPOCH 268: train_loss: 1.498e-02 	 test_loss: 1.619e-02
# EPOCH 269: train_loss: 1.485e-02 	 test_loss: 1.650e-02
# EPOCH 270: train_loss: 1.317e-02 	 test_loss: 1.605e-02
# EPOCH 271: train_loss: 1.617e-02 	 test_loss: 1.839e-02
# EPOCH 272: train_loss: 1.360e-02 	 test_loss: 1.605e-02
# EPOCH 273: train_loss: 1.331e-02 	 test_loss: 1.623e-02
# EPOCH 274: train_loss: 1.361e-02 	 test_loss: 1.634e-02
# EPOCH 275: train_loss: 1.139e-02 	 test_loss: 1.631e-02
# EPOCH 276: train_loss: 1.748e-02 	 test_loss: 1.875e-02
# EPOCH 277: train_loss: 1.373e-02 	 test_loss: 1.593e-02
# EPOCH 278: train_loss: 1.246e-02 	 test_loss: 1.530e-02
# EPOCH 279: train_loss: 1.399e-02 	 test_loss: 1.519e-02
# EPOCH 280: train_loss: 1.044e-02 	 test_loss: 1.498e-02
# EPOCH 281: train_loss: 1.564e-02 	 test_loss: 1.712e-02
# EPOCH 282: train_loss: 1.276e-02 	 test_loss: 1.542e-02
# EPOCH 283: train_loss: 1.635e-02 	 test_loss: 1.518e-02
# EPOCH 284: train_loss: 1.201e-02 	 test_loss: 1.608e-02
# EPOCH 285: train_loss: 1.379e-02 	 test_loss: 1.423e-02
# EPOCH 286: train_loss: 1.089e-02 	 test_loss: 1.463e-02
# EPOCH 287: train_loss: 1.436e-02 	 test_loss: 1.465e-02
# EPOCH 288: train_loss: 1.209e-02 	 test_loss: 1.467e-02
# EPOCH 289: train_loss: 1.152e-02 	 test_loss: 1.438e-02
# EPOCH 290: train_loss: 1.049e-02 	 test_loss: 1.394e-02
# EPOCH 291: train_loss: 1.356e-02 	 test_loss: 1.508e-02
# EPOCH 292: train_loss: 1.111e-02 	 test_loss: 1.528e-02
# EPOCH 293: train_loss: 1.116e-02 	 test_loss: 1.431e-02
# EPOCH 294: train_loss: 1.174e-02 	 test_loss: 1.538e-02
# EPOCH 295: train_loss: 1.232e-02 	 test_loss: 1.564e-02
# EPOCH 296: train_loss: 1.226e-02 	 test_loss: 1.424e-02
# EPOCH 297: train_loss: 1.008e-02 	 test_loss: 1.523e-02
# EPOCH 298: train_loss: 1.127e-02 	 test_loss: 1.460e-02
# EPOCH 299: train_loss: 1.251e-02 	 test_loss: 1.488e-02
# EPOCH 300: train_loss: 9.205e-03 	 test_loss: 1.657e-02
# EPOCH 301: train_loss: 9.788e-03 	 test_loss: 1.548e-02
# EPOCH 302: train_loss: 9.959e-03 	 test_loss: 1.533e-02
# EPOCH 303: train_loss: 1.061e-02 	 test_loss: 1.360e-02
# EPOCH 304: train_loss: 1.167e-02 	 test_loss: 1.479e-02
# EPOCH 305: train_loss: 1.128e-02 	 test_loss: 1.395e-02
# EPOCH 306: train_loss: 1.062e-02 	 test_loss: 1.417e-02
# EPOCH 307: train_loss: 1.160e-02 	 test_loss: 1.405e-02
# EPOCH 308: train_loss: 1.245e-02 	 test_loss: 1.510e-02
# EPOCH 309: train_loss: 1.196e-02 	 test_loss: 1.503e-02
# EPOCH 310: train_loss: 1.292e-02 	 test_loss: 1.661e-02
# EPOCH 311: train_loss: 1.227e-02 	 test_loss: 1.489e-02
# EPOCH 312: train_loss: 1.120e-02 	 test_loss: 1.422e-02
# EPOCH 313: train_loss: 1.382e-02 	 test_loss: 1.450e-02
# EPOCH 314: train_loss: 1.251e-02 	 test_loss: 1.380e-02
# EPOCH 315: train_loss: 1.113e-02 	 test_loss: 1.368e-02
# EPOCH 316: train_loss: 9.381e-03 	 test_loss: 1.328e-02
# EPOCH 317: train_loss: 1.208e-02 	 test_loss: 1.364e-02
# EPOCH 318: train_loss: 1.260e-02 	 test_loss: 1.310e-02
# EPOCH 319: train_loss: 9.906e-03 	 test_loss: 1.411e-02
# EPOCH 320: train_loss: 1.309e-02 	 test_loss: 1.533e-02
# EPOCH 321: train_loss: 1.225e-02 	 test_loss: 1.427e-02
# EPOCH 322: train_loss: 1.233e-02 	 test_loss: 1.477e-02
# EPOCH 323: train_loss: 1.082e-02 	 test_loss: 1.330e-02
# EPOCH 324: train_loss: 1.115e-02 	 test_loss: 1.336e-02
# EPOCH 325: train_loss: 1.109e-02 	 test_loss: 1.374e-02
# EPOCH 326: train_loss: 9.315e-03 	 test_loss: 1.444e-02
# EPOCH 327: train_loss: 1.072e-02 	 test_loss: 1.427e-02
# EPOCH 328: train_loss: 8.918e-03 	 test_loss: 1.647e-02
# EPOCH 329: train_loss: 1.035e-02 	 test_loss: 1.439e-02
# EPOCH 330: train_loss: 1.131e-02 	 test_loss: 1.343e-02
# EPOCH 331: train_loss: 1.453e-02 	 test_loss: 1.602e-02
# EPOCH 332: train_loss: 1.092e-02 	 test_loss: 1.523e-02
# EPOCH 333: train_loss: 1.143e-02 	 test_loss: 1.374e-02
# EPOCH 334: train_loss: 1.117e-02 	 test_loss: 1.453e-02
# EPOCH 335: train_loss: 1.146e-02 	 test_loss: 1.447e-02
# EPOCH 336: train_loss: 1.068e-02 	 test_loss: 1.345e-02
# EPOCH 337: train_loss: 1.129e-02 	 test_loss: 1.428e-02
# EPOCH 338: train_loss: 1.160e-02 	 test_loss: 1.402e-02
# EPOCH 339: train_loss: 8.531e-03 	 test_loss: 1.290e-02
# EPOCH 340: train_loss: 1.279e-02 	 test_loss: 1.319e-02
# EPOCH 341: train_loss: 1.363e-02 	 test_loss: 1.348e-02
# EPOCH 342: train_loss: 1.070e-02 	 test_loss: 1.349e-02
# EPOCH 343: train_loss: 1.339e-02 	 test_loss: 1.275e-02
# EPOCH 344: train_loss: 9.612e-03 	 test_loss: 1.296e-02
# EPOCH 345: train_loss: 8.983e-03 	 test_loss: 1.356e-02
# EPOCH 346: train_loss: 1.180e-02 	 test_loss: 1.368e-02
# EPOCH 347: train_loss: 1.028e-02 	 test_loss: 1.436e-02
# EPOCH 348: train_loss: 9.931e-03 	 test_loss: 1.266e-02
# EPOCH 349: train_loss: 1.000e-02 	 test_loss: 1.389e-02
# EPOCH 350: train_loss: 9.973e-03 	 test_loss: 1.369e-02
# EPOCH 351: train_loss: 8.660e-03 	 test_loss: 1.289e-02
# EPOCH 352: train_loss: 1.134e-02 	 test_loss: 1.332e-02
# EPOCH 353: train_loss: 7.807e-03 	 test_loss: 1.363e-02
# EPOCH 354: train_loss: 1.027e-02 	 test_loss: 1.284e-02
# EPOCH 355: train_loss: 1.162e-02 	 test_loss: 1.262e-02
# EPOCH 356: train_loss: 9.978e-03 	 test_loss: 1.392e-02
# EPOCH 357: train_loss: 8.482e-03 	 test_loss: 1.229e-02
# EPOCH 358: train_loss: 1.318e-02 	 test_loss: 1.703e-02
# EPOCH 359: train_loss: 1.163e-02 	 test_loss: 1.377e-02
# EPOCH 360: train_loss: 1.086e-02 	 test_loss: 1.350e-02
# EPOCH 361: train_loss: 1.141e-02 	 test_loss: 1.521e-02
# EPOCH 362: train_loss: 1.244e-02 	 test_loss: 1.404e-02
# EPOCH 363: train_loss: 8.678e-03 	 test_loss: 1.331e-02
# EPOCH 364: train_loss: 1.022e-02 	 test_loss: 1.305e-02
# EPOCH 365: train_loss: 8.825e-03 	 test_loss: 1.283e-02
# EPOCH 366: train_loss: 9.249e-03 	 test_loss: 1.366e-02
# EPOCH 367: train_loss: 8.614e-03 	 test_loss: 1.296e-02
# EPOCH 368: train_loss: 9.394e-03 	 test_loss: 1.245e-02
# EPOCH 369: train_loss: 1.177e-02 	 test_loss: 1.290e-02
# EPOCH 370: train_loss: 9.312e-03 	 test_loss: 1.298e-02
# EPOCH 371: train_loss: 7.741e-03 	 test_loss: 1.311e-02
# EPOCH 372: train_loss: 1.124e-02 	 test_loss: 1.493e-02
# EPOCH 373: train_loss: 1.066e-02 	 test_loss: 1.293e-02
# EPOCH 374: train_loss: 9.138e-03 	 test_loss: 1.270e-02
# EPOCH 375: train_loss: 9.425e-03 	 test_loss: 1.283e-02
# EPOCH 376: train_loss: 9.076e-03 	 test_loss: 1.222e-02
# EPOCH 377: train_loss: 8.663e-03 	 test_loss: 1.185e-02
# EPOCH 378: train_loss: 1.007e-02 	 test_loss: 1.216e-02
# EPOCH 379: train_loss: 9.493e-03 	 test_loss: 1.236e-02
# EPOCH 380: train_loss: 7.458e-03 	 test_loss: 1.212e-02
# EPOCH 381: train_loss: 1.044e-02 	 test_loss: 1.313e-02
# EPOCH 382: train_loss: 1.016e-02 	 test_loss: 1.281e-02
# EPOCH 383: train_loss: 7.830e-03 	 test_loss: 1.224e-02
# EPOCH 384: train_loss: 7.918e-03 	 test_loss: 1.247e-02
# EPOCH 385: train_loss: 1.128e-02 	 test_loss: 1.187e-02
# EPOCH 386: train_loss: 9.168e-03 	 test_loss: 1.259e-02
# EPOCH 387: train_loss: 9.364e-03 	 test_loss: 1.213e-02
# EPOCH 388: train_loss: 8.737e-03 	 test_loss: 1.261e-02
# EPOCH 389: train_loss: 1.216e-02 	 test_loss: 1.217e-02
# EPOCH 390: train_loss: 1.088e-02 	 test_loss: 1.350e-02
# EPOCH 391: train_loss: 1.064e-02 	 test_loss: 1.240e-02
# EPOCH 392: train_loss: 9.530e-03 	 test_loss: 1.273e-02
# EPOCH 393: train_loss: 9.145e-03 	 test_loss: 1.247e-02
# EPOCH 394: train_loss: 8.867e-03 	 test_loss: 1.190e-02
# EPOCH 395: train_loss: 1.092e-02 	 test_loss: 1.234e-02
# EPOCH 396: train_loss: 9.556e-03 	 test_loss: 1.254e-02
# EPOCH 397: train_loss: 7.898e-03 	 test_loss: 1.231e-02
# EPOCH 398: train_loss: 8.174e-03 	 test_loss: 1.283e-02
# EPOCH 399: train_loss: 8.965e-03 	 test_loss: 1.216e-02
# EPOCH 400: train_loss: 9.056e-03 	 test_loss: 1.250e-02
# EPOCH 401: train_loss: 1.175e-02 	 test_loss: 1.237e-02
# EPOCH 402: train_loss: 8.071e-03 	 test_loss: 1.113e-02
# EPOCH 403: train_loss: 8.816e-03 	 test_loss: 1.231e-02
# EPOCH 404: train_loss: 9.285e-03 	 test_loss: 1.262e-02
# EPOCH 405: train_loss: 8.545e-03 	 test_loss: 1.205e-02
# EPOCH 406: train_loss: 1.048e-02 	 test_loss: 1.269e-02
# EPOCH 407: train_loss: 8.096e-03 	 test_loss: 1.265e-02
# EPOCH 408: train_loss: 1.061e-02 	 test_loss: 1.277e-02
# EPOCH 409: train_loss: 9.370e-03 	 test_loss: 1.260e-02
# EPOCH 410: train_loss: 8.118e-03 	 test_loss: 1.158e-02
# EPOCH 411: train_loss: 9.237e-03 	 test_loss: 1.226e-02
# EPOCH 412: train_loss: 8.166e-03 	 test_loss: 1.209e-02
# EPOCH 413: train_loss: 7.699e-03 	 test_loss: 1.133e-02
# EPOCH 414: train_loss: 7.437e-03 	 test_loss: 1.182e-02
# EPOCH 415: train_loss: 8.002e-03 	 test_loss: 1.188e-02
# EPOCH 416: train_loss: 8.600e-03 	 test_loss: 1.133e-02
# EPOCH 417: train_loss: 7.871e-03 	 test_loss: 1.175e-02
# EPOCH 418: train_loss: 9.486e-03 	 test_loss: 1.240e-02
# EPOCH 419: train_loss: 9.073e-03 	 test_loss: 1.238e-02
# EPOCH 420: train_loss: 7.244e-03 	 test_loss: 1.124e-02
# EPOCH 421: train_loss: 9.200e-03 	 test_loss: 1.171e-02
# EPOCH 422: train_loss: 6.673e-03 	 test_loss: 1.198e-02
# EPOCH 423: train_loss: 1.242e-02 	 test_loss: 1.343e-02
# EPOCH 424: train_loss: 8.544e-03 	 test_loss: 1.234e-02
# EPOCH 425: train_loss: 6.491e-03 	 test_loss: 1.142e-02
# EPOCH 426: train_loss: 8.826e-03 	 test_loss: 1.169e-02
# EPOCH 427: train_loss: 9.181e-03 	 test_loss: 1.144e-02
# EPOCH 428: train_loss: 7.668e-03 	 test_loss: 1.134e-02
# EPOCH 429: train_loss: 7.417e-03 	 test_loss: 1.148e-02
# EPOCH 430: train_loss: 7.793e-03 	 test_loss: 1.110e-02
# EPOCH 431: train_loss: 1.098e-02 	 test_loss: 1.132e-02
# EPOCH 432: train_loss: 8.297e-03 	 test_loss: 1.206e-02
# EPOCH 433: train_loss: 8.672e-03 	 test_loss: 1.266e-02
# EPOCH 434: train_loss: 9.880e-03 	 test_loss: 1.118e-02
# EPOCH 435: train_loss: 8.372e-03 	 test_loss: 1.161e-02
# EPOCH 436: train_loss: 1.037e-02 	 test_loss: 1.176e-02
# EPOCH 437: train_loss: 9.045e-03 	 test_loss: 1.172e-02
# EPOCH 438: train_loss: 7.059e-03 	 test_loss: 1.106e-02
# EPOCH 439: train_loss: 6.909e-03 	 test_loss: 1.153e-02
# EPOCH 440: train_loss: 8.433e-03 	 test_loss: 1.236e-02
# EPOCH 441: train_loss: 9.276e-03 	 test_loss: 1.145e-02
# EPOCH 442: train_loss: 9.765e-03 	 test_loss: 1.122e-02
# EPOCH 443: train_loss: 7.132e-03 	 test_loss: 1.166e-02
# EPOCH 444: train_loss: 8.162e-03 	 test_loss: 1.094e-02
# EPOCH 445: train_loss: 1.001e-02 	 test_loss: 1.443e-02
# EPOCH 446: train_loss: 1.026e-02 	 test_loss: 1.252e-02
# EPOCH 447: train_loss: 8.398e-03 	 test_loss: 1.023e-02
# EPOCH 448: train_loss: 8.763e-03 	 test_loss: 1.128e-02
# EPOCH 449: train_loss: 9.484e-03 	 test_loss: 1.148e-02
# EPOCH 450: train_loss: 7.910e-03 	 test_loss: 1.155e-02
# EPOCH 451: train_loss: 8.055e-03 	 test_loss: 1.158e-02
# EPOCH 452: train_loss: 7.681e-03 	 test_loss: 1.138e-02
# EPOCH 453: train_loss: 8.947e-03 	 test_loss: 1.156e-02
# EPOCH 454: train_loss: 7.928e-03 	 test_loss: 1.208e-02
# EPOCH 455: train_loss: 7.706e-03 	 test_loss: 1.138e-02
# EPOCH 456: train_loss: 7.417e-03 	 test_loss: 1.122e-02
# EPOCH 457: train_loss: 8.359e-03 	 test_loss: 1.183e-02
# EPOCH 458: train_loss: 6.553e-03 	 test_loss: 1.073e-02
# EPOCH 459: train_loss: 8.844e-03 	 test_loss: 1.136e-02
# EPOCH 460: train_loss: 6.751e-03 	 test_loss: 1.212e-02
# EPOCH 461: train_loss: 9.941e-03 	 test_loss: 1.203e-02
# EPOCH 462: train_loss: 1.262e-02 	 test_loss: 1.297e-02
# EPOCH 463: train_loss: 9.368e-03 	 test_loss: 1.219e-02
# EPOCH 464: train_loss: 8.545e-03 	 test_loss: 1.304e-02
# EPOCH 465: train_loss: 7.791e-03 	 test_loss: 1.316e-02
# EPOCH 466: train_loss: 7.084e-03 	 test_loss: 1.212e-02
# EPOCH 467: train_loss: 8.052e-03 	 test_loss: 1.131e-02
# EPOCH 468: train_loss: 7.915e-03 	 test_loss: 1.136e-02
# EPOCH 469: train_loss: 7.508e-03 	 test_loss: 1.110e-02
# EPOCH 470: train_loss: 7.424e-03 	 test_loss: 1.168e-02
# EPOCH 471: train_loss: 1.128e-02 	 test_loss: 1.176e-02
# EPOCH 472: train_loss: 7.552e-03 	 test_loss: 1.132e-02
# EPOCH 473: train_loss: 7.666e-03 	 test_loss: 1.213e-02
# EPOCH 474: train_loss: 6.872e-03 	 test_loss: 1.141e-02
# EPOCH 475: train_loss: 7.121e-03 	 test_loss: 1.160e-02
# EPOCH 476: train_loss: 9.245e-03 	 test_loss: 1.144e-02
# EPOCH 477: train_loss: 9.202e-03 	 test_loss: 1.304e-02
# EPOCH 478: train_loss: 7.960e-03 	 test_loss: 1.228e-02
# EPOCH 479: train_loss: 7.784e-03 	 test_loss: 1.165e-02
# EPOCH 480: train_loss: 7.571e-03 	 test_loss: 1.137e-02
# EPOCH 481: train_loss: 9.637e-03 	 test_loss: 1.294e-02
# EPOCH 482: train_loss: 8.451e-03 	 test_loss: 1.258e-02
# EPOCH 483: train_loss: 7.545e-03 	 test_loss: 1.266e-02
# EPOCH 484: train_loss: 8.076e-03 	 test_loss: 1.138e-02
# EPOCH 485: train_loss: 8.791e-03 	 test_loss: 1.212e-02
# EPOCH 486: train_loss: 8.082e-03 	 test_loss: 1.158e-02
# EPOCH 487: train_loss: 7.119e-03 	 test_loss: 1.093e-02
# EPOCH 488: train_loss: 7.151e-03 	 test_loss: 1.124e-02
# EPOCH 489: train_loss: 6.468e-03 	 test_loss: 1.160e-02
# EPOCH 490: train_loss: 8.902e-03 	 test_loss: 1.177e-02
# EPOCH 491: train_loss: 7.986e-03 	 test_loss: 1.245e-02
# EPOCH 492: train_loss: 9.423e-03 	 test_loss: 1.139e-02
# EPOCH 493: train_loss: 8.211e-03 	 test_loss: 1.269e-02
# EPOCH 494: train_loss: 9.011e-03 	 test_loss: 1.294e-02
# EPOCH 495: train_loss: 9.547e-03 	 test_loss: 1.366e-02
# EPOCH 496: train_loss: 6.775e-03 	 test_loss: 1.282e-02
# EPOCH 497: train_loss: 6.521e-03 	 test_loss: 1.117e-02
# EPOCH 498: train_loss: 7.497e-03 	 test_loss: 1.138e-02
# EPOCH 499: train_loss: 7.309e-03 	 test_loss: 1.115e-02
# EPOCH 500: train_loss: 8.424e-03 	 test_loss: 1.215e-02
# EPOCH 501: train_loss: 6.689e-03 	 test_loss: 1.110e-02
# EPOCH 502: train_loss: 6.191e-03 	 test_loss: 1.133e-02
# EPOCH 503: train_loss: 5.782e-03 	 test_loss: 1.109e-02
# EPOCH 504: train_loss: 7.519e-03 	 test_loss: 1.124e-02
# EPOCH 505: train_loss: 8.064e-03 	 test_loss: 1.202e-02
# EPOCH 506: train_loss: 5.893e-03 	 test_loss: 1.101e-02
# EPOCH 507: train_loss: 7.062e-03 	 test_loss: 1.106e-02
# EPOCH 508: train_loss: 5.759e-03 	 test_loss: 1.152e-02
# EPOCH 509: train_loss: 5.657e-03 	 test_loss: 1.110e-02
# EPOCH 510: train_loss: 5.093e-03 	 test_loss: 1.128e-02
# EPOCH 511: train_loss: 5.962e-03 	 test_loss: 1.163e-02
# EPOCH 512: train_loss: 8.003e-03 	 test_loss: 1.187e-02
# EPOCH 513: train_loss: 8.314e-03 	 test_loss: 1.201e-02
# EPOCH 514: train_loss: 8.599e-03 	 test_loss: 1.200e-02
# EPOCH 515: train_loss: 6.744e-03 	 test_loss: 1.186e-02
# EPOCH 516: train_loss: 8.094e-03 	 test_loss: 1.117e-02
# EPOCH 517: train_loss: 8.341e-03 	 test_loss: 1.142e-02
# EPOCH 518: train_loss: 6.535e-03 	 test_loss: 1.174e-02
# EPOCH 519: train_loss: 7.604e-03 	 test_loss: 1.156e-02
# EPOCH 520: train_loss: 6.651e-03 	 test_loss: 1.136e-02
# EPOCH 521: train_loss: 8.396e-03 	 test_loss: 1.138e-02
# EPOCH 522: train_loss: 7.898e-03 	 test_loss: 1.210e-02
# EPOCH 523: train_loss: 7.846e-03 	 test_loss: 1.084e-02
# EPOCH 524: train_loss: 6.364e-03 	 test_loss: 1.079e-02
# EPOCH 525: train_loss: 6.334e-03 	 test_loss: 1.156e-02
# EPOCH 526: train_loss: 1.037e-02 	 test_loss: 1.245e-02
# EPOCH 527: train_loss: 9.314e-03 	 test_loss: 1.245e-02
# EPOCH 528: train_loss: 6.744e-03 	 test_loss: 1.171e-02
# EPOCH 529: train_loss: 7.575e-03 	 test_loss: 1.153e-02
# EPOCH 530: train_loss: 6.425e-03 	 test_loss: 1.102e-02
# EPOCH 531: train_loss: 8.585e-03 	 test_loss: 1.171e-02
# EPOCH 532: train_loss: 7.229e-03 	 test_loss: 1.354e-02
# EPOCH 533: train_loss: 6.638e-03 	 test_loss: 1.160e-02
# EPOCH 534: train_loss: 5.810e-03 	 test_loss: 1.304e-02
# EPOCH 535: train_loss: 8.984e-03 	 test_loss: 1.143e-02
# EPOCH 536: train_loss: 6.380e-03 	 test_loss: 1.089e-02
# EPOCH 537: train_loss: 7.188e-03 	 test_loss: 1.056e-02
# EPOCH 538: train_loss: 8.631e-03 	 test_loss: 1.085e-02
# EPOCH 539: train_loss: 7.214e-03 	 test_loss: 1.249e-02
# EPOCH 540: train_loss: 6.369e-03 	 test_loss: 1.101e-02
# EPOCH 541: train_loss: 7.538e-03 	 test_loss: 1.072e-02
# EPOCH 542: train_loss: 6.909e-03 	 test_loss: 1.184e-02
# EPOCH 543: train_loss: 6.019e-03 	 test_loss: 1.057e-02
# EPOCH 544: train_loss: 7.394e-03 	 test_loss: 1.107e-02
# EPOCH 545: train_loss: 5.559e-03 	 test_loss: 1.184e-02
# EPOCH 546: train_loss: 5.808e-03 	 test_loss: 1.219e-02
# EPOCH 547: train_loss: 6.147e-03 	 test_loss: 1.076e-02
# EPOCH 548: train_loss: 5.587e-03 	 test_loss: 1.062e-02
# EPOCH 549: train_loss: 6.939e-03 	 test_loss: 1.106e-02
# EPOCH 550: train_loss: 7.854e-03 	 test_loss: 1.079e-02
# EPOCH 551: train_loss: 5.266e-03 	 test_loss: 1.091e-02
# EPOCH 552: train_loss: 5.782e-03 	 test_loss: 1.111e-02
# EPOCH 553: train_loss: 6.808e-03 	 test_loss: 1.091e-02
# EPOCH 554: train_loss: 4.922e-03 	 test_loss: 1.103e-02
# EPOCH 555: train_loss: 7.206e-03 	 test_loss: 1.211e-02
# EPOCH 556: train_loss: 7.449e-03 	 test_loss: 1.163e-02
# EPOCH 557: train_loss: 7.006e-03 	 test_loss: 1.109e-02
# EPOCH 558: train_loss: 7.132e-03 	 test_loss: 1.141e-02
# EPOCH 559: train_loss: 6.373e-03 	 test_loss: 1.115e-02
# EPOCH 560: train_loss: 8.769e-03 	 test_loss: 1.123e-02
# EPOCH 561: train_loss: 6.855e-03 	 test_loss: 1.072e-02
# EPOCH 562: train_loss: 6.407e-03 	 test_loss: 1.112e-02
# EPOCH 563: train_loss: 6.456e-03 	 test_loss: 1.209e-02
# EPOCH 564: train_loss: 8.424e-03 	 test_loss: 1.128e-02
# EPOCH 565: train_loss: 8.659e-03 	 test_loss: 1.125e-02
# EPOCH 566: train_loss: 8.970e-03 	 test_loss: 1.158e-02
# EPOCH 567: train_loss: 6.754e-03 	 test_loss: 1.050e-02
# EPOCH 568: train_loss: 7.505e-03 	 test_loss: 1.094e-02
# EPOCH 569: train_loss: 5.448e-03 	 test_loss: 1.133e-02
# EPOCH 570: train_loss: 6.814e-03 	 test_loss: 1.033e-02
# EPOCH 571: train_loss: 5.117e-03 	 test_loss: 1.082e-02
# EPOCH 572: train_loss: 7.282e-03 	 test_loss: 1.171e-02
# EPOCH 573: train_loss: 8.562e-03 	 test_loss: 1.173e-02
# EPOCH 574: train_loss: 7.002e-03 	 test_loss: 1.045e-02
# EPOCH 575: train_loss: 6.402e-03 	 test_loss: 1.027e-02
# EPOCH 576: train_loss: 5.977e-03 	 test_loss: 1.097e-02
# EPOCH 577: train_loss: 6.139e-03 	 test_loss: 1.078e-02
# EPOCH 578: train_loss: 5.884e-03 	 test_loss: 1.256e-02
# EPOCH 579: train_loss: 8.759e-03 	 test_loss: 1.063e-02
# EPOCH 580: train_loss: 6.634e-03 	 test_loss: 1.167e-02
# EPOCH 581: train_loss: 7.570e-03 	 test_loss: 1.324e-02
# EPOCH 582: train_loss: 7.920e-03 	 test_loss: 1.014e-02
# EPOCH 583: train_loss: 6.468e-03 	 test_loss: 1.037e-02
# EPOCH 584: train_loss: 7.056e-03 	 test_loss: 1.077e-02
# EPOCH 585: train_loss: 6.199e-03 	 test_loss: 1.071e-02
# EPOCH 586: train_loss: 6.204e-03 	 test_loss: 1.083e-02
# EPOCH 587: train_loss: 6.581e-03 	 test_loss: 1.128e-02
# EPOCH 588: train_loss: 6.091e-03 	 test_loss: 9.983e-03
# EPOCH 589: train_loss: 6.561e-03 	 test_loss: 1.005e-02
# EPOCH 590: train_loss: 8.300e-03 	 test_loss: 1.128e-02
# EPOCH 591: train_loss: 7.036e-03 	 test_loss: 1.096e-02
# EPOCH 592: train_loss: 5.762e-03 	 test_loss: 1.066e-02
# EPOCH 593: train_loss: 9.066e-03 	 test_loss: 1.145e-02
# EPOCH 594: train_loss: 7.968e-03 	 test_loss: 1.382e-02
# EPOCH 595: train_loss: 7.963e-03 	 test_loss: 1.205e-02
# EPOCH 596: train_loss: 7.851e-03 	 test_loss: 1.137e-02
# EPOCH 597: train_loss: 6.798e-03 	 test_loss: 1.166e-02
# EPOCH 598: train_loss: 7.055e-03 	 test_loss: 1.133e-02
# EPOCH 599: train_loss: 6.119e-03 	 test_loss: 1.008e-02
# EPOCH 600: train_loss: 6.430e-03 	 test_loss: 1.020e-02
# EPOCH 601: train_loss: 6.045e-03 	 test_loss: 1.064e-02
# EPOCH 602: train_loss: 6.598e-03 	 test_loss: 1.074e-02
# EPOCH 603: train_loss: 8.337e-03 	 test_loss: 1.069e-02
# EPOCH 604: train_loss: 8.356e-03 	 test_loss: 1.074e-02
# EPOCH 605: train_loss: 6.682e-03 	 test_loss: 1.097e-02
# EPOCH 606: train_loss: 8.340e-03 	 test_loss: 1.015e-02
# EPOCH 607: train_loss: 7.552e-03 	 test_loss: 1.045e-02
# EPOCH 608: train_loss: 5.593e-03 	 test_loss: 1.135e-02
# EPOCH 609: train_loss: 8.003e-03 	 test_loss: 9.698e-03
# EPOCH 610: train_loss: 4.976e-03 	 test_loss: 1.013e-02
# EPOCH 611: train_loss: 6.154e-03 	 test_loss: 1.012e-02
# EPOCH 612: train_loss: 6.241e-03 	 test_loss: 1.088e-02
# EPOCH 613: train_loss: 6.656e-03 	 test_loss: 1.131e-02
# EPOCH 614: train_loss: 6.317e-03 	 test_loss: 1.177e-02
# EPOCH 615: train_loss: 6.942e-03 	 test_loss: 1.152e-02
# EPOCH 616: train_loss: 7.378e-03 	 test_loss: 1.144e-02
# EPOCH 617: train_loss: 4.391e-03 	 test_loss: 1.195e-02
# EPOCH 618: train_loss: 5.415e-03 	 test_loss: 1.105e-02
# EPOCH 619: train_loss: 6.680e-03 	 test_loss: 1.055e-02
# EPOCH 620: train_loss: 5.001e-03 	 test_loss: 1.070e-02
# EPOCH 621: train_loss: 7.098e-03 	 test_loss: 1.068e-02
# EPOCH 622: train_loss: 6.452e-03 	 test_loss: 1.059e-02
# EPOCH 623: train_loss: 5.771e-03 	 test_loss: 1.119e-02
# EPOCH 624: train_loss: 5.645e-03 	 test_loss: 1.030e-02
# EPOCH 625: train_loss: 5.695e-03 	 test_loss: 9.750e-03
# EPOCH 626: train_loss: 6.443e-03 	 test_loss: 1.016e-02
# EPOCH 627: train_loss: 5.460e-03 	 test_loss: 1.124e-02
# EPOCH 628: train_loss: 5.982e-03 	 test_loss: 1.186e-02
# EPOCH 629: train_loss: 5.635e-03 	 test_loss: 1.106e-02
# EPOCH 630: train_loss: 7.535e-03 	 test_loss: 1.221e-02
# EPOCH 631: train_loss: 8.547e-03 	 test_loss: 1.123e-02
# EPOCH 632: train_loss: 7.448e-03 	 test_loss: 1.134e-02
# EPOCH 633: train_loss: 8.968e-03 	 test_loss: 1.153e-02
# EPOCH 634: train_loss: 6.132e-03 	 test_loss: 1.289e-02
# EPOCH 635: train_loss: 6.758e-03 	 test_loss: 1.194e-02
# EPOCH 636: train_loss: 6.756e-03 	 test_loss: 1.122e-02
# EPOCH 637: train_loss: 5.361e-03 	 test_loss: 1.085e-02
# EPOCH 638: train_loss: 6.619e-03 	 test_loss: 1.066e-02
# EPOCH 639: train_loss: 5.180e-03 	 test_loss: 1.154e-02
# EPOCH 640: train_loss: 5.379e-03 	 test_loss: 1.130e-02
# EPOCH 641: train_loss: 5.455e-03 	 test_loss: 1.061e-02
# EPOCH 642: train_loss: 5.437e-03 	 test_loss: 1.027e-02
# EPOCH 643: train_loss: 9.888e-03 	 test_loss: 1.108e-02
# EPOCH 644: train_loss: 6.715e-03 	 test_loss: 1.157e-02
# EPOCH 645: train_loss: 7.486e-03 	 test_loss: 1.190e-02
# EPOCH 646: train_loss: 6.157e-03 	 test_loss: 1.141e-02
# EPOCH 647: train_loss: 7.810e-03 	 test_loss: 1.080e-02
# EPOCH 648: train_loss: 5.609e-03 	 test_loss: 1.081e-02
# EPOCH 649: train_loss: 5.733e-03 	 test_loss: 1.153e-02
# EPOCH 650: train_loss: 6.228e-03 	 test_loss: 1.179e-02
# EPOCH 651: train_loss: 7.121e-03 	 test_loss: 1.079e-02
# EPOCH 652: train_loss: 7.117e-03 	 test_loss: 1.141e-02
# EPOCH 653: train_loss: 4.546e-03 	 test_loss: 1.096e-02
# EPOCH 654: train_loss: 6.070e-03 	 test_loss: 1.069e-02
# EPOCH 655: train_loss: 5.146e-03 	 test_loss: 1.104e-02
# EPOCH 656: train_loss: 5.590e-03 	 test_loss: 1.128e-02
# EPOCH 657: train_loss: 5.280e-03 	 test_loss: 1.099e-02
# EPOCH 658: train_loss: 6.708e-03 	 test_loss: 1.046e-02
# EPOCH 659: train_loss: 5.460e-03 	 test_loss: 1.035e-02
# EPOCH 660: train_loss: 5.559e-03 	 test_loss: 1.059e-02
# EPOCH 661: train_loss: 8.894e-03 	 test_loss: 1.135e-02
# EPOCH 662: train_loss: 9.211e-03 	 test_loss: 1.161e-02
# EPOCH 663: train_loss: 6.086e-03 	 test_loss: 1.121e-02
# EPOCH 664: train_loss: 7.635e-03 	 test_loss: 1.108e-02
# EPOCH 665: train_loss: 6.096e-03 	 test_loss: 1.111e-02
# EPOCH 666: train_loss: 6.857e-03 	 test_loss: 1.068e-02
# EPOCH 667: train_loss: 6.236e-03 	 test_loss: 1.054e-02
# EPOCH 668: train_loss: 4.154e-03 	 test_loss: 1.089e-02
# EPOCH 669: train_loss: 5.154e-03 	 test_loss: 1.036e-02
# EPOCH 670: train_loss: 5.677e-03 	 test_loss: 1.042e-02
# EPOCH 671: train_loss: 4.518e-03 	 test_loss: 1.035e-02
# EPOCH 672: train_loss: 4.806e-03 	 test_loss: 1.055e-02
# EPOCH 673: train_loss: 9.290e-03 	 test_loss: 1.017e-02
# EPOCH 674: train_loss: 4.890e-03 	 test_loss: 1.030e-02
# EPOCH 675: train_loss: 5.938e-03 	 test_loss: 1.008e-02
# EPOCH 676: train_loss: 8.195e-03 	 test_loss: 9.846e-03
# EPOCH 677: train_loss: 6.976e-03 	 test_loss: 1.016e-02
# EPOCH 678: train_loss: 7.693e-03 	 test_loss: 1.023e-02
# EPOCH 679: train_loss: 4.733e-03 	 test_loss: 1.025e-02
# EPOCH 680: train_loss: 6.402e-03 	 test_loss: 1.086e-02
# EPOCH 681: train_loss: 5.286e-03 	 test_loss: 1.118e-02
# EPOCH 682: train_loss: 7.373e-03 	 test_loss: 1.061e-02
# EPOCH 683: train_loss: 5.223e-03 	 test_loss: 1.045e-02
# EPOCH 684: train_loss: 6.821e-03 	 test_loss: 1.092e-02
# EPOCH 685: train_loss: 6.195e-03 	 test_loss: 1.077e-02
# EPOCH 686: train_loss: 4.272e-03 	 test_loss: 1.056e-02
# EPOCH 687: train_loss: 9.229e-03 	 test_loss: 1.053e-02
# EPOCH 688: train_loss: 7.951e-03 	 test_loss: 1.105e-02
# EPOCH 689: train_loss: 6.531e-03 	 test_loss: 1.049e-02
# EPOCH 690: train_loss: 6.853e-03 	 test_loss: 1.010e-02
# EPOCH 691: train_loss: 7.992e-03 	 test_loss: 1.052e-02
# EPOCH 692: train_loss: 6.765e-03 	 test_loss: 1.080e-02
# EPOCH 693: train_loss: 6.729e-03 	 test_loss: 1.028e-02
# EPOCH 694: train_loss: 5.688e-03 	 test_loss: 1.058e-02
# EPOCH 695: train_loss: 6.349e-03 	 test_loss: 1.043e-02
# EPOCH 696: train_loss: 6.966e-03 	 test_loss: 1.183e-02
# EPOCH 697: train_loss: 4.752e-03 	 test_loss: 1.136e-02
# EPOCH 698: train_loss: 5.123e-03 	 test_loss: 1.110e-02
# EPOCH 699: train_loss: 6.345e-03 	 test_loss: 1.147e-02
# EPOCH 700: train_loss: 7.106e-03 	 test_loss: 1.180e-02
# EPOCH 701: train_loss: 6.616e-03 	 test_loss: 1.132e-02
# EPOCH 702: train_loss: 4.926e-03 	 test_loss: 1.093e-02
# EPOCH 703: train_loss: 9.077e-03 	 test_loss: 1.193e-02
# EPOCH 704: train_loss: 7.014e-03 	 test_loss: 1.139e-02
# EPOCH 705: train_loss: 5.493e-03 	 test_loss: 1.021e-02
# EPOCH 706: train_loss: 6.397e-03 	 test_loss: 9.986e-03
# EPOCH 707: train_loss: 6.078e-03 	 test_loss: 1.160e-02
# EPOCH 708: train_loss: 4.302e-03 	 test_loss: 1.060e-02
# EPOCH 709: train_loss: 7.533e-03 	 test_loss: 1.066e-02
# EPOCH 710: train_loss: 8.953e-03 	 test_loss: 1.142e-02
# EPOCH 711: train_loss: 6.441e-03 	 test_loss: 1.143e-02
# EPOCH 712: train_loss: 5.700e-03 	 test_loss: 1.146e-02
# EPOCH 713: train_loss: 6.631e-03 	 test_loss: 1.104e-02
# EPOCH 714: train_loss: 6.603e-03 	 test_loss: 1.043e-02
# EPOCH 715: train_loss: 6.999e-03 	 test_loss: 1.215e-02
# EPOCH 716: train_loss: 6.199e-03 	 test_loss: 1.063e-02
# EPOCH 717: train_loss: 6.657e-03 	 test_loss: 1.119e-02
# EPOCH 718: train_loss: 6.967e-03 	 test_loss: 1.184e-02
# EPOCH 719: train_loss: 8.095e-03 	 test_loss: 1.404e-02
# EPOCH 720: train_loss: 9.798e-03 	 test_loss: 1.257e-02
# EPOCH 721: train_loss: 8.171e-03 	 test_loss: 1.106e-02
# EPOCH 722: train_loss: 6.619e-03 	 test_loss: 1.023e-02
# EPOCH 723: train_loss: 7.253e-03 	 test_loss: 9.679e-03
# EPOCH 724: train_loss: 6.746e-03 	 test_loss: 9.738e-03
# EPOCH 725: train_loss: 5.570e-03 	 test_loss: 9.826e-03
# EPOCH 726: train_loss: 5.995e-03 	 test_loss: 9.764e-03
# EPOCH 727: train_loss: 4.591e-03 	 test_loss: 1.027e-02
# EPOCH 728: train_loss: 7.436e-03 	 test_loss: 1.143e-02
# EPOCH 729: train_loss: 7.740e-03 	 test_loss: 1.209e-02
# EPOCH 730: train_loss: 7.162e-03 	 test_loss: 1.053e-02
# EPOCH 731: train_loss: 6.098e-03 	 test_loss: 1.013e-02
# EPOCH 732: train_loss: 4.909e-03 	 test_loss: 1.072e-02
# EPOCH 733: train_loss: 5.023e-03 	 test_loss: 1.032e-02
# EPOCH 734: train_loss: 6.658e-03 	 test_loss: 1.110e-02
# EPOCH 735: train_loss: 6.498e-03 	 test_loss: 1.042e-02
# EPOCH 736: train_loss: 5.757e-03 	 test_loss: 1.053e-02
# EPOCH 737: train_loss: 8.479e-03 	 test_loss: 1.083e-02
# EPOCH 738: train_loss: 5.771e-03 	 test_loss: 1.030e-02
# EPOCH 739: train_loss: 4.192e-03 	 test_loss: 1.081e-02
# EPOCH 740: train_loss: 4.931e-03 	 test_loss: 1.001e-02
# EPOCH 741: train_loss: 5.672e-03 	 test_loss: 1.075e-02
# EPOCH 742: train_loss: 6.034e-03 	 test_loss: 1.169e-02
# EPOCH 743: train_loss: 5.258e-03 	 test_loss: 1.045e-02
# EPOCH 744: train_loss: 6.297e-03 	 test_loss: 1.032e-02
# EPOCH 745: train_loss: 6.777e-03 	 test_loss: 1.112e-02
# EPOCH 746: train_loss: 6.976e-03 	 test_loss: 1.446e-02
# EPOCH 747: train_loss: 6.649e-03 	 test_loss: 1.180e-02
# EPOCH 748: train_loss: 6.131e-03 	 test_loss: 1.065e-02
# EPOCH 749: train_loss: 5.541e-03 	 test_loss: 1.135e-02
# EPOCH 750: train_loss: 6.060e-03 	 test_loss: 1.177e-02
# EPOCH 751: train_loss: 4.901e-03 	 test_loss: 1.196e-02
# EPOCH 752: train_loss: 5.260e-03 	 test_loss: 1.172e-02
# EPOCH 753: train_loss: 5.940e-03 	 test_loss: 1.087e-02
# EPOCH 754: train_loss: 6.701e-03 	 test_loss: 1.187e-02
# EPOCH 755: train_loss: 5.379e-03 	 test_loss: 1.156e-02
# EPOCH 756: train_loss: 6.413e-03 	 test_loss: 1.123e-02
# EPOCH 757: train_loss: 4.445e-03 	 test_loss: 1.177e-02
# EPOCH 758: train_loss: 7.461e-03 	 test_loss: 1.209e-02
# EPOCH 759: train_loss: 8.071e-03 	 test_loss: 1.138e-02
# EPOCH 760: train_loss: 5.751e-03 	 test_loss: 1.091e-02
# EPOCH 761: train_loss: 7.912e-03 	 test_loss: 1.123e-02
# EPOCH 762: train_loss: 3.592e-03 	 test_loss: 1.359e-02
# EPOCH 763: train_loss: 5.380e-03 	 test_loss: 1.214e-02
# EPOCH 764: train_loss: 5.849e-03 	 test_loss: 1.245e-02
# EPOCH 765: train_loss: 5.390e-03 	 test_loss: 1.188e-02
# EPOCH 766: train_loss: 9.082e-03 	 test_loss: 1.247e-02
# EPOCH 767: train_loss: 7.603e-03 	 test_loss: 1.104e-02
# EPOCH 768: train_loss: 5.518e-03 	 test_loss: 1.038e-02
# EPOCH 769: train_loss: 5.102e-03 	 test_loss: 1.122e-02
# EPOCH 770: train_loss: 4.622e-03 	 test_loss: 1.102e-02
# EPOCH 771: train_loss: 6.706e-03 	 test_loss: 1.234e-02
# EPOCH 772: train_loss: 6.565e-03 	 test_loss: 1.139e-02
# EPOCH 773: train_loss: 5.208e-03 	 test_loss: 1.090e-02
# EPOCH 774: train_loss: 7.108e-03 	 test_loss: 1.143e-02
# EPOCH 775: train_loss: 5.949e-03 	 test_loss: 1.178e-02
# EPOCH 776: train_loss: 6.408e-03 	 test_loss: 1.022e-02
# EPOCH 777: train_loss: 5.390e-03 	 test_loss: 1.096e-02
# EPOCH 778: train_loss: 4.418e-03 	 test_loss: 1.205e-02
# EPOCH 779: train_loss: 8.488e-03 	 test_loss: 1.017e-02
# EPOCH 780: train_loss: 8.396e-03 	 test_loss: 1.079e-02
# EPOCH 781: train_loss: 5.565e-03 	 test_loss: 1.165e-02
# EPOCH 782: train_loss: 5.646e-03 	 test_loss: 1.297e-02
# EPOCH 783: train_loss: 4.862e-03 	 test_loss: 1.197e-02
# EPOCH 784: train_loss: 5.641e-03 	 test_loss: 1.057e-02
# EPOCH 785: train_loss: 7.318e-03 	 test_loss: 1.080e-02
# EPOCH 786: train_loss: 6.156e-03 	 test_loss: 1.087e-02
# EPOCH 787: train_loss: 7.418e-03 	 test_loss: 1.125e-02
# EPOCH 788: train_loss: 7.405e-03 	 test_loss: 1.095e-02
# EPOCH 789: train_loss: 6.737e-03 	 test_loss: 1.087e-02
# EPOCH 790: train_loss: 1.019e-02 	 test_loss: 1.389e-02
# EPOCH 791: train_loss: 6.621e-03 	 test_loss: 1.153e-02
# EPOCH 792: train_loss: 6.355e-03 	 test_loss: 9.750e-03
# EPOCH 793: train_loss: 6.482e-03 	 test_loss: 9.975e-03
# EPOCH 794: train_loss: 5.341e-03 	 test_loss: 1.126e-02
# EPOCH 795: train_loss: 5.452e-03 	 test_loss: 1.072e-02
# EPOCH 796: train_loss: 6.119e-03 	 test_loss: 1.020e-02
# EPOCH 797: train_loss: 4.270e-03 	 test_loss: 1.065e-02
# EPOCH 798: train_loss: 4.880e-03 	 test_loss: 1.083e-02
# EPOCH 799: train_loss: 5.503e-03 	 test_loss: 1.095e-02
# EPOCH 800: train_loss: 6.999e-03 	 test_loss: 1.148e-02
# EPOCH 801: train_loss: 4.718e-03 	 test_loss: 1.198e-02
# EPOCH 802: train_loss: 4.541e-03 	 test_loss: 1.135e-02
# EPOCH 803: train_loss: 6.055e-03 	 test_loss: 1.111e-02
# EPOCH 804: train_loss: 4.271e-03 	 test_loss: 1.079e-02
# EPOCH 805: train_loss: 5.178e-03 	 test_loss: 1.107e-02
# EPOCH 806: train_loss: 4.115e-03 	 test_loss: 1.119e-02
# EPOCH 807: train_loss: 4.740e-03 	 test_loss: 1.116e-02
# EPOCH 808: train_loss: 5.381e-03 	 test_loss: 1.082e-02
# EPOCH 809: train_loss: 5.159e-03 	 test_loss: 1.069e-02
# EPOCH 810: train_loss: 4.965e-03 	 test_loss: 1.114e-02
# EPOCH 811: train_loss: 5.903e-03 	 test_loss: 1.091e-02
# EPOCH 812: train_loss: 5.396e-03 	 test_loss: 1.145e-02
# EPOCH 813: train_loss: 6.129e-03 	 test_loss: 1.143e-02
# EPOCH 814: train_loss: 5.550e-03 	 test_loss: 1.093e-02
# EPOCH 815: train_loss: 5.188e-03 	 test_loss: 1.066e-02
# EPOCH 816: train_loss: 4.853e-03 	 test_loss: 1.116e-02
# EPOCH 817: train_loss: 7.710e-03 	 test_loss: 1.043e-02
# EPOCH 818: train_loss: 6.129e-03 	 test_loss: 1.059e-02
# EPOCH 819: train_loss: 4.801e-03 	 test_loss: 1.005e-02
# EPOCH 820: train_loss: 5.217e-03 	 test_loss: 9.919e-03
# EPOCH 821: train_loss: 6.903e-03 	 test_loss: 1.180e-02
# EPOCH 822: train_loss: 6.796e-03 	 test_loss: 1.085e-02
# EPOCH 823: train_loss: 4.246e-03 	 test_loss: 1.027e-02
# EPOCH 824: train_loss: 7.835e-03 	 test_loss: 1.066e-02
# EPOCH 825: train_loss: 5.591e-03 	 test_loss: 1.002e-02
# EPOCH 826: train_loss: 4.954e-03 	 test_loss: 1.011e-02
# EPOCH 827: train_loss: 5.827e-03 	 test_loss: 9.993e-03
# EPOCH 828: train_loss: 5.545e-03 	 test_loss: 1.071e-02
# EPOCH 829: train_loss: 5.876e-03 	 test_loss: 1.036e-02
# EPOCH 830: train_loss: 5.090e-03 	 test_loss: 1.027e-02
# EPOCH 831: train_loss: 4.697e-03 	 test_loss: 1.003e-02
# EPOCH 832: train_loss: 4.664e-03 	 test_loss: 1.050e-02
# EPOCH 833: train_loss: 4.974e-03 	 test_loss: 1.071e-02
# EPOCH 834: train_loss: 4.710e-03 	 test_loss: 1.019e-02
# EPOCH 835: train_loss: 5.311e-03 	 test_loss: 9.811e-03
# EPOCH 836: train_loss: 4.419e-03 	 test_loss: 1.023e-02
# EPOCH 837: train_loss: 4.893e-03 	 test_loss: 1.056e-02
# EPOCH 838: train_loss: 5.262e-03 	 test_loss: 1.026e-02
# EPOCH 839: train_loss: 4.921e-03 	 test_loss: 1.089e-02
# EPOCH 840: train_loss: 3.896e-03 	 test_loss: 1.036e-02
# EPOCH 841: train_loss: 5.157e-03 	 test_loss: 1.014e-02
# EPOCH 842: train_loss: 6.486e-03 	 test_loss: 1.017e-02
# EPOCH 843: train_loss: 6.034e-03 	 test_loss: 1.090e-02
# EPOCH 844: train_loss: 4.791e-03 	 test_loss: 1.048e-02
# EPOCH 845: train_loss: 3.825e-03 	 test_loss: 1.046e-02
# EPOCH 846: train_loss: 4.240e-03 	 test_loss: 1.083e-02
# EPOCH 847: train_loss: 5.705e-03 	 test_loss: 1.115e-02
# EPOCH 848: train_loss: 4.464e-03 	 test_loss: 1.116e-02
# EPOCH 849: train_loss: 4.622e-03 	 test_loss: 1.098e-02
# EPOCH 850: train_loss: 6.331e-03 	 test_loss: 1.220e-02
# EPOCH 851: train_loss: 6.589e-03 	 test_loss: 1.022e-02
# EPOCH 852: train_loss: 6.190e-03 	 test_loss: 1.114e-02
# EPOCH 853: train_loss: 5.365e-03 	 test_loss: 1.259e-02
# EPOCH 854: train_loss: 5.242e-03 	 test_loss: 1.111e-02
# EPOCH 855: train_loss: 5.454e-03 	 test_loss: 1.064e-02
# EPOCH 856: train_loss: 4.290e-03 	 test_loss: 1.083e-02
# EPOCH 857: train_loss: 5.146e-03 	 test_loss: 1.089e-02
# EPOCH 858: train_loss: 5.109e-03 	 test_loss: 1.121e-02
# EPOCH 859: train_loss: 5.570e-03 	 test_loss: 1.212e-02
# EPOCH 860: train_loss: 5.036e-03 	 test_loss: 1.155e-02
# EPOCH 861: train_loss: 4.627e-03 	 test_loss: 1.121e-02
# EPOCH 862: train_loss: 4.868e-03 	 test_loss: 1.077e-02
# EPOCH 863: train_loss: 6.400e-03 	 test_loss: 1.156e-02
# EPOCH 864: train_loss: 6.128e-03 	 test_loss: 1.319e-02
# EPOCH 865: train_loss: 5.920e-03 	 test_loss: 1.220e-02
# EPOCH 866: train_loss: 5.319e-03 	 test_loss: 1.112e-02
# EPOCH 867: train_loss: 6.301e-03 	 test_loss: 1.100e-02
# EPOCH 868: train_loss: 4.742e-03 	 test_loss: 1.120e-02
# EPOCH 869: train_loss: 5.780e-03 	 test_loss: 1.193e-02
# EPOCH 870: train_loss: 5.531e-03 	 test_loss: 1.136e-02
# EPOCH 871: train_loss: 5.939e-03 	 test_loss: 1.087e-02
# EPOCH 872: train_loss: 5.961e-03 	 test_loss: 1.129e-02
# EPOCH 873: train_loss: 7.123e-03 	 test_loss: 1.273e-02
# EPOCH 874: train_loss: 5.264e-03 	 test_loss: 1.387e-02
# EPOCH 875: train_loss: 4.619e-03 	 test_loss: 1.205e-02
# EPOCH 876: train_loss: 5.947e-03 	 test_loss: 1.097e-02
# EPOCH 877: train_loss: 5.291e-03 	 test_loss: 1.066e-02
# EPOCH 878: train_loss: 5.281e-03 	 test_loss: 1.064e-02
# EPOCH 879: train_loss: 7.011e-03 	 test_loss: 1.187e-02
# EPOCH 880: train_loss: 5.948e-03 	 test_loss: 1.134e-02
# EPOCH 881: train_loss: 4.610e-03 	 test_loss: 1.052e-02
# EPOCH 882: train_loss: 3.354e-03 	 test_loss: 1.054e-02
# EPOCH 883: train_loss: 5.590e-03 	 test_loss: 1.100e-02
# EPOCH 884: train_loss: 5.285e-03 	 test_loss: 1.060e-02
# EPOCH 885: train_loss: 5.701e-03 	 test_loss: 1.221e-02
# EPOCH 886: train_loss: 7.295e-03 	 test_loss: 1.179e-02
# EPOCH 887: train_loss: 4.767e-03 	 test_loss: 1.169e-02
# EPOCH 888: train_loss: 9.045e-03 	 test_loss: 1.221e-02
# EPOCH 889: train_loss: 6.398e-03 	 test_loss: 1.095e-02
# EPOCH 890: train_loss: 6.172e-03 	 test_loss: 1.173e-02
# EPOCH 891: train_loss: 5.268e-03 	 test_loss: 1.280e-02
# EPOCH 892: train_loss: 5.310e-03 	 test_loss: 1.197e-02
# EPOCH 893: train_loss: 3.518e-03 	 test_loss: 1.146e-02
# EPOCH 894: train_loss: 7.660e-03 	 test_loss: 1.152e-02
# EPOCH 895: train_loss: 5.146e-03 	 test_loss: 1.188e-02
# EPOCH 896: train_loss: 4.840e-03 	 test_loss: 1.096e-02
# EPOCH 897: train_loss: 5.735e-03 	 test_loss: 1.113e-02
# EPOCH 898: train_loss: 6.182e-03 	 test_loss: 1.093e-02
# EPOCH 899: train_loss: 5.762e-03 	 test_loss: 1.067e-02
# EPOCH 900: train_loss: 4.793e-03 	 test_loss: 1.132e-02
# EPOCH 901: train_loss: 4.891e-03 	 test_loss: 1.114e-02
# EPOCH 902: train_loss: 5.528e-03 	 test_loss: 1.059e-02
# EPOCH 903: train_loss: 5.548e-03 	 test_loss: 1.151e-02
# EPOCH 904: train_loss: 6.572e-03 	 test_loss: 1.213e-02
# EPOCH 905: train_loss: 5.333e-03 	 test_loss: 1.023e-02
# EPOCH 906: train_loss: 5.996e-03 	 test_loss: 1.048e-02
# EPOCH 907: train_loss: 5.391e-03 	 test_loss: 1.350e-02
# EPOCH 908: train_loss: 6.619e-03 	 test_loss: 1.243e-02
# EPOCH 909: train_loss: 5.699e-03 	 test_loss: 1.061e-02
# EPOCH 910: train_loss: 4.356e-03 	 test_loss: 1.129e-02
# EPOCH 911: train_loss: 5.706e-03 	 test_loss: 1.115e-02
# EPOCH 912: train_loss: 4.375e-03 	 test_loss: 1.110e-02
# EPOCH 913: train_loss: 4.444e-03 	 test_loss: 1.094e-02
# EPOCH 914: train_loss: 5.147e-03 	 test_loss: 1.102e-02
# EPOCH 915: train_loss: 3.839e-03 	 test_loss: 1.245e-02
# EPOCH 916: train_loss: 6.242e-03 	 test_loss: 1.139e-02
# EPOCH 917: train_loss: 4.841e-03 	 test_loss: 1.150e-02
# EPOCH 918: train_loss: 4.663e-03 	 test_loss: 1.110e-02
# EPOCH 919: train_loss: 4.335e-03 	 test_loss: 1.064e-02
# EPOCH 920: train_loss: 5.977e-03 	 test_loss: 1.035e-02
# EPOCH 921: train_loss: 4.818e-03 	 test_loss: 1.054e-02
# EPOCH 922: train_loss: 3.933e-03 	 test_loss: 1.104e-02
# EPOCH 923: train_loss: 5.140e-03 	 test_loss: 1.191e-02
# EPOCH 924: train_loss: 5.626e-03 	 test_loss: 1.175e-02
# EPOCH 925: train_loss: 6.829e-03 	 test_loss: 1.386e-02
# EPOCH 926: train_loss: 5.481e-03 	 test_loss: 1.076e-02
# EPOCH 927: train_loss: 5.561e-03 	 test_loss: 9.461e-03
# EPOCH 928: train_loss: 6.572e-03 	 test_loss: 1.184e-02
# EPOCH 929: train_loss: 5.725e-03 	 test_loss: 1.132e-02
# EPOCH 930: train_loss: 4.474e-03 	 test_loss: 1.191e-02
# EPOCH 931: train_loss: 7.568e-03 	 test_loss: 1.013e-02
# EPOCH 932: train_loss: 6.654e-03 	 test_loss: 9.974e-03
# EPOCH 933: train_loss: 5.235e-03 	 test_loss: 1.058e-02
# EPOCH 934: train_loss: 4.415e-03 	 test_loss: 1.017e-02
# EPOCH 935: train_loss: 6.482e-03 	 test_loss: 1.103e-02
# EPOCH 936: train_loss: 5.325e-03 	 test_loss: 1.215e-02
# EPOCH 937: train_loss: 6.642e-03 	 test_loss: 1.143e-02
# EPOCH 938: train_loss: 4.572e-03 	 test_loss: 1.081e-02
# EPOCH 939: train_loss: 4.928e-03 	 test_loss: 1.067e-02
# EPOCH 940: train_loss: 6.116e-03 	 test_loss: 1.169e-02
# EPOCH 941: train_loss: 6.974e-03 	 test_loss: 1.068e-02
# EPOCH 942: train_loss: 6.882e-03 	 test_loss: 1.086e-02
# EPOCH 943: train_loss: 5.032e-03 	 test_loss: 1.030e-02
# EPOCH 944: train_loss: 4.338e-03 	 test_loss: 1.063e-02
# EPOCH 945: train_loss: 5.582e-03 	 test_loss: 1.087e-02
# EPOCH 946: train_loss: 5.445e-03 	 test_loss: 1.075e-02
# EPOCH 947: train_loss: 5.925e-03 	 test_loss: 1.083e-02
# EPOCH 948: train_loss: 5.141e-03 	 test_loss: 1.105e-02
# EPOCH 949: train_loss: 5.054e-03 	 test_loss: 1.127e-02
# EPOCH 950: train_loss: 6.193e-03 	 test_loss: 1.083e-02
# EPOCH 951: train_loss: 4.565e-03 	 test_loss: 1.135e-02
# EPOCH 952: train_loss: 5.267e-03 	 test_loss: 1.094e-02
# EPOCH 953: train_loss: 6.562e-03 	 test_loss: 1.166e-02
# EPOCH 954: train_loss: 4.281e-03 	 test_loss: 1.090e-02
# EPOCH 955: train_loss: 6.653e-03 	 test_loss: 1.087e-02
# EPOCH 956: train_loss: 5.853e-03 	 test_loss: 1.095e-02
# EPOCH 957: train_loss: 5.770e-03 	 test_loss: 1.200e-02
# EPOCH 958: train_loss: 7.404e-03 	 test_loss: 1.083e-02
# EPOCH 959: train_loss: 5.320e-03 	 test_loss: 1.111e-02
# EPOCH 960: train_loss: 5.160e-03 	 test_loss: 1.074e-02
# EPOCH 961: train_loss: 5.465e-03 	 test_loss: 1.165e-02
# EPOCH 962: train_loss: 5.165e-03 	 test_loss: 1.115e-02
# EPOCH 963: train_loss: 4.672e-03 	 test_loss: 1.071e-02
# EPOCH 964: train_loss: 4.753e-03 	 test_loss: 1.116e-02
# EPOCH 965: train_loss: 6.768e-03 	 test_loss: 1.127e-02
# EPOCH 966: train_loss: 5.352e-03 	 test_loss: 1.119e-02
# EPOCH 967: train_loss: 4.894e-03 	 test_loss: 1.116e-02
# EPOCH 968: train_loss: 5.556e-03 	 test_loss: 1.106e-02
# EPOCH 969: train_loss: 4.057e-03 	 test_loss: 1.128e-02
# EPOCH 970: train_loss: 5.236e-03 	 test_loss: 1.119e-02
# EPOCH 971: train_loss: 4.016e-03 	 test_loss: 1.103e-02
# EPOCH 972: train_loss: 5.894e-03 	 test_loss: 1.111e-02
# EPOCH 973: train_loss: 5.962e-03 	 test_loss: 1.105e-02
# EPOCH 974: train_loss: 5.962e-03 	 test_loss: 1.085e-02
# EPOCH 975: train_loss: 3.627e-03 	 test_loss: 1.134e-02
# EPOCH 976: train_loss: 4.898e-03 	 test_loss: 1.114e-02
# EPOCH 977: train_loss: 5.913e-03 	 test_loss: 1.130e-02
# EPOCH 978: train_loss: 4.957e-03 	 test_loss: 1.092e-02
# EPOCH 979: train_loss: 3.865e-03 	 test_loss: 1.045e-02
# EPOCH 980: train_loss: 4.129e-03 	 test_loss: 1.018e-02
# EPOCH 981: train_loss: 3.809e-03 	 test_loss: 1.055e-02
# EPOCH 982: train_loss: 5.372e-03 	 test_loss: 1.091e-02
# EPOCH 983: train_loss: 3.815e-03 	 test_loss: 1.087e-02
# EPOCH 984: train_loss: 5.080e-03 	 test_loss: 1.124e-02
# EPOCH 985: train_loss: 3.983e-03 	 test_loss: 1.120e-02
# EPOCH 986: train_loss: 4.008e-03 	 test_loss: 1.139e-02
# EPOCH 987: train_loss: 5.194e-03 	 test_loss: 1.110e-02
# EPOCH 988: train_loss: 4.465e-03 	 test_loss: 1.126e-02
# EPOCH 989: train_loss: 4.437e-03 	 test_loss: 1.103e-02
# EPOCH 990: train_loss: 4.276e-03 	 test_loss: 1.205e-02
# EPOCH 991: train_loss: 5.870e-03 	 test_loss: 1.056e-02
# EPOCH 992: train_loss: 5.944e-03 	 test_loss: 1.037e-02
# EPOCH 993: train_loss: 4.699e-03 	 test_loss: 1.144e-02
# EPOCH 994: train_loss: 9.243e-03 	 test_loss: 1.171e-02
# EPOCH 995: train_loss: 6.019e-03 	 test_loss: 1.104e-02
# EPOCH 996: train_loss: 5.630e-03 	 test_loss: 1.075e-02
# EPOCH 997: train_loss: 5.539e-03 	 test_loss: 1.193e-02
# EPOCH 998: train_loss: 4.057e-03 	 test_loss: 1.155e-02
# EPOCH 999: train_loss: 5.978e-03 	 test_loss: 1.073e-02

# %%
plot_loss(loss_history, val_loss_history)
plot_results(model, train_x_norm, train_y_norm, "Training Set Results (Normalized)")
plot_results(model, test_x_norm, test_y_norm, "Testing Set Results (Normalized)")
plot_results(model, train_x_norm, train_y_norm, "Training Set Results (True Scale)", True)
plot_results(model, test_x_norm, test_y_norm, "Testing Set Results (True Scale)", True)
